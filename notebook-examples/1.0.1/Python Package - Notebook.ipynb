# %%
# %pip install beacon-api==1.0.0rc2
# Out:
# Requirement already satisfied: beacon-api==1.0.0rc2 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (1.0.0rc2)
# Requirement already satisfied: requests>=2.0.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api==1.0.0rc2) (2.32.4)
# Requirement already satisfied: pandas>=2.0.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api==1.0.0rc2) (2.3.1)
# Requirement already satisfied: pyarrow>=19.0.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api==1.0.0rc2) (20.0.0)
# Requirement already satisfied: networkx>=3.0.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api==1.0.0rc2) (3.5)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api==1.0.0rc2) (3.10.3)
# Requirement already satisfied: xarray>=2025.1.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api==1.0.0rc2) (2025.7.1)
# Requirement already satisfied: netCDF4>=1.5.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api==1.0.0rc2) (1.7.2)
# Requirement already satisfied: geopandas>=1.1.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api==1.0.0rc2) (1.1.1)
# Requirement already satisfied: typing_extensions>=4.10.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api==1.0.0rc2) (4.14.1)
# Requirement already satisfied: lonboard>=0.10.4 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api==1.0.0rc2) (0.11.1)
# Requirement already satisfied: palettable>=3.3.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api==1.0.0rc2) (3.3.3)
# Requirement already satisfied: zarr>=3.0.10 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api==1.0.0rc2) (3.1.0)
# Requirement already satisfied: numpy>=1.24 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from geopandas>=1.1.0->beacon-api==1.0.0rc2) (2.3.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from geopandas>=1.1.0->beacon-api==1.0.0rc2) (0.11.0)
# Requirement already satisfied: packaging in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from geopandas>=1.1.0->beacon-api==1.0.0rc2) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from geopandas>=1.1.0->beacon-api==1.0.0rc2) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from geopandas>=1.1.0->beacon-api==1.0.0rc2) (2.1.1)
# Requirement already satisfied: anywidget~=0.9.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from lonboard>=0.10.4->beacon-api==1.0.0rc2) (0.9.18)
# Requirement already satisfied: arro3-compute>=0.4.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from lonboard>=0.10.4->beacon-api==1.0.0rc2) (0.5.1)
# Requirement already satisfied: arro3-core>=0.4.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from lonboard>=0.10.4->beacon-api==1.0.0rc2) (0.5.1)
# Requirement already satisfied: arro3-io>=0.4.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from lonboard>=0.10.4->beacon-api==1.0.0rc2) (0.5.1)
# Requirement already satisfied: ipywidgets>=7.6.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from lonboard>=0.10.4->beacon-api==1.0.0rc2) (8.1.7)
# Requirement already satisfied: traitlets>=5.7.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from lonboard>=0.10.4->beacon-api==1.0.0rc2) (5.14.3)
# Requirement already satisfied: psygnal>=0.8.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from anywidget~=0.9.0->lonboard>=0.10.4->beacon-api==1.0.0rc2) (0.14.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from ipywidgets>=7.6.0->lonboard>=0.10.4->beacon-api==1.0.0rc2) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from ipywidgets>=7.6.0->lonboard>=0.10.4->beacon-api==1.0.0rc2) (9.4.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from ipywidgets>=7.6.0->lonboard>=0.10.4->beacon-api==1.0.0rc2) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from ipywidgets>=7.6.0->lonboard>=0.10.4->beacon-api==1.0.0rc2) (3.0.15)
# Requirement already satisfied: decorator in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon-api==1.0.0rc2) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon-api==1.0.0rc2) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon-api==1.0.0rc2) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon-api==1.0.0rc2) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon-api==1.0.0rc2) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon-api==1.0.0rc2) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon-api==1.0.0rc2) (2.19.2)
# Requirement already satisfied: stack_data in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon-api==1.0.0rc2) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon-api==1.0.0rc2) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon-api==1.0.0rc2) (0.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.0.0->beacon-api==1.0.0rc2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.0.0->beacon-api==1.0.0rc2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.0.0->beacon-api==1.0.0rc2) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.0.0->beacon-api==1.0.0rc2) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.0.0->beacon-api==1.0.0rc2) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.0.0->beacon-api==1.0.0rc2) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.0.0->beacon-api==1.0.0rc2) (2.9.0.post0)
# Requirement already satisfied: cftime in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from netCDF4>=1.5.0->beacon-api==1.0.0rc2) (1.6.4.post1)
# Requirement already satisfied: certifi in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from netCDF4>=1.5.0->beacon-api==1.0.0rc2) (2025.7.14)
# Requirement already satisfied: pytz>=2020.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from pandas>=2.0.0->beacon-api==1.0.0rc2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from pandas>=2.0.0->beacon-api==1.0.0rc2) (2025.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon-api==1.0.0rc2) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->beacon-api==1.0.0rc2) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from requests>=2.0.0->beacon-api==1.0.0rc2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from requests>=2.0.0->beacon-api==1.0.0rc2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from requests>=2.0.0->beacon-api==1.0.0rc2) (2.5.0)
# Requirement already satisfied: donfig>=0.8 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from zarr>=3.0.10->beacon-api==1.0.0rc2) (0.8.1.post1)
# Requirement already satisfied: numcodecs>=0.14 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from numcodecs[crc32c]>=0.14->zarr>=3.0.10->beacon-api==1.0.0rc2) (0.16.1)
# Requirement already satisfied: pyyaml in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from donfig>=0.8->zarr>=3.0.10->beacon-api==1.0.0rc2) (6.0.2)
# Requirement already satisfied: crc32c>=2.7 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from numcodecs[crc32c]>=0.14->zarr>=3.0.10->beacon-api==1.0.0rc2) (2.7.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon-api==1.0.0rc2) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon-api==1.0.0rc2) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon-api==1.0.0rc2) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Available Instances
# The available instances for the Blue Cloud.
# ## MARIS Server
#
# - beacon-argo.maris.nl (Euro-Argo data, retrieved from S3 bucket)
# - beacon-cora-pr.maris.nl (CORA Profile data, retrieved from CMEMS: INSITU_GLO_PHY_TS_DISCRETE_MY_013_001)
# - beacon-cora-ts.maris.nl (CORA Timeseries data, retrieved from CMEMS: INSITU_GLO_PHY_TS_DISCRETE_MY_013_001)
# - beacon-emod-chem.maris.nl (EMODnet Chemistry Collection)
# - beacon-wod.maris.nl (WOD data, retrieved from NOAA)
# - beacon-cmems.maris.nl (CMEMS BGC data, retrieved from CMEMS: INSITU_GLO_BGC_DISCRETE_MY_013_046)
# - beacon-cdi.maris.nl (SeaDataNet CDI open collection)
#
# ### Merged Instances
# - beacon-wb1-ts.maris.nl (Merged Temperature and Salinity instance of ARGO, CORA Profile, CORA Timeseries, WOD, and CDI data)
# - beacon-wb2-eutrophication.maris.nl (Merged eutrophication instance of EMODnet Chemistry Collection, CMEMS BGC data, and WOD data)
#
# ## D4Science Server
#
# - beacon-argo.d4science.org (Euro-Argo data, retrieved from S3 bucket)
# - beacon-cora-pr.d4science.org (CORA Profile data, retrieved from CMEMS: INSITU_GLO_PHY_TS_DISCRETE_MY_013_001)
# - beacon-cora-ts.d4science.org (CORA Timeseries data, retrieved from CMEMS: INSITU_GLO_PHY_TS_DISCRETE_MY_013_001)
# - beacon-emodnet-chemistry.d4science.org (EMODnet Chemistry Collection)
# - beacon-wod.d4science.org (WOD data, retrieved from NOAA)
# - beacon-cmems-bgc.d4science.org (CMEMS BGC data, retrieved from CMEMS: INSITU_GLO_BGC_DISCRETE_MY_013_046)
# - beacon-seadatanet.d4science.org (SeaDataNet CDI open collection)
#
# ### Merged Instances
# - beacon-wb1-ts.d4science.org (Merged Temperature and Salinity instance of ARGO, CORA Profile, CORA Timeseries, WOD, and CDI data)
# - beacon-wb2-eutrophication.d4science.org (Merged eutrophication instance of EMODnet Chemistry Collection, CMEMS BGC data, and WOD data)

# %%
# Import the beacon_api package to connect to a Beacon node
from beacon_api import *

# %%
# If running against a D4Science Beacon Node in the Blue Cloud VRE, use the following code to set the token:
#import os
#TOKEN =os.getenv('D4SCIENCE_TOKEN')

# If running against a MARIS Beacon Node, use the following code to set the token:
TOKEN = "MARIS_BLUE_CLOUD_TOKEN"


# Connect to the Beacon node
client = Client("https://beacon-argo.maris.nl", jwt_token=TOKEN)
# Out:
# Connected to: https://beacon-argo.maris.nl/ server successfully

# %%
client.available_columns()
# Out:
# ['DATA_TYPE',
#  'DATA_TYPE.long_name',
#  'DATA_TYPE.conventions',
#  'DATA_TYPE._FillValue',
#  'FORMAT_VERSION',
#  'FORMAT_VERSION.long_name',
#  'FORMAT_VERSION._FillValue',
#  'HANDBOOK_VERSION',
#  'HANDBOOK_VERSION.long_name',
#  'HANDBOOK_VERSION._FillValue',
#  'REFERENCE_DATE_TIME',
#  'REFERENCE_DATE_TIME.long_name',
#  'REFERENCE_DATE_TIME.conventions',
#  'REFERENCE_DATE_TIME._FillValue',
#  'DATE_CREATION',
#  'DATE_CREATION.long_name',
#  'DATE_CREATION.conventions',
#  'DATE_CREATION._FillValue',
#  'DATE_UPDATE',
#  'DATE_UPDATE.long_name',
#  'DATE_UPDATE.conventions',
#  'DATE_UPDATE._FillValue',
#  'PLATFORM_NUMBER',
#  'PLATFORM_NUMBER.long_name',
#  'PLATFORM_NUMBER.conventions',
#  'PLATFORM_NUMBER._FillValue',
#  'PROJECT_NAME',
#  'PROJECT_NAME.long_name',
#  'PROJECT_NAME._FillValue',
#  'PI_NAME',
#  'PI_NAME.long_name',
#  'PI_NAME._FillValue',
#  'STATION_PARAMETERS',
#  'STATION_PARAMETERS.long_name',
#  'STATION_PARAMETERS.conventions',
#  'STATION_PARAMETERS._FillValue',
#  'CYCLE_NUMBER',
#  'CYCLE_NUMBER.long_name',
#  'CYCLE_NUMBER.conventions',
#  'CYCLE_NUMBER._FillValue',
#  'DIRECTION',
#  'DIRECTION.long_name',
#  'DIRECTION.conventions',
#  'DIRECTION._FillValue',
#  'DATA_CENTRE',
#  'DATA_CENTRE.long_name',
#  'DATA_CENTRE.conventions',
#  'DATA_CENTRE._FillValue',
#  'DC_REFERENCE',
#  'DC_REFERENCE.long_name',
#  'DC_REFERENCE.conventions',
#  'DC_REFERENCE._FillValue',
#  'DATA_STATE_INDICATOR',
#  'DATA_STATE_INDICATOR.long_name',
#  'DATA_STATE_INDICATOR.conventions',
#  'DATA_STATE_INDICATOR._FillValue',
#  'DATA_MODE',
#  'DATA_MODE.long_name',
#  'DATA_MODE.conventions',
#  'DATA_MODE._FillValue',
#  'PLATFORM_TYPE',
#  'PLATFORM_TYPE.long_name',
#  'PLATFORM_TYPE.conventions',
#  'PLATFORM_TYPE._FillValue',
#  'FLOAT_SERIAL_NO',
#  'FLOAT_SERIAL_NO.long_name',
#  'FLOAT_SERIAL_NO._FillValue',
#  'FIRMWARE_VERSION',
#  'FIRMWARE_VERSION.long_name',
#  'FIRMWARE_VERSION._FillValue',
#  'WMO_INST_TYPE',
#  'WMO_INST_TYPE.long_name',
#  'WMO_INST_TYPE.conventions',
#  'WMO_INST_TYPE._FillValue',
#  'JULD',
#  'JULD.long_name',
#  'JULD.standard_name',
#  'JULD.units',
#  'JULD.conventions',
#  'JULD.resolution',
#  'JULD._FillValue',
#  'JULD.axis',
#  'JULD_QC',
#  'JULD_QC.long_name',
#  'JULD_QC.conventions',
#  'JULD_QC._FillValue',
#  'JULD_LOCATION',
#  'JULD_LOCATION.long_name',
#  'JULD_LOCATION.units',
#  'JULD_LOCATION.conventions',
#  'JULD_LOCATION.resolution',
#  'JULD_LOCATION._FillValue',
#  'LATITUDE',
#  'LATITUDE.long_name',
#  'LATITUDE.standard_name',
#  'LATITUDE.units',
#  'LATITUDE._FillValue',
#  'LATITUDE.valid_min',
#  'LATITUDE.valid_max',
#  'LATITUDE.axis',
#  'LONGITUDE',
#  'LONGITUDE.long_name',
#  'LONGITUDE.standard_name',
#  'LONGITUDE.units',
#  'LONGITUDE._FillValue',
#  'LONGITUDE.valid_min',
#  'LONGITUDE.valid_max',
#  'LONGITUDE.axis',
#  'POSITION_QC',
#  'POSITION_QC.long_name',
#  'POSITION_QC.conventions',
#  'POSITION_QC._FillValue',
#  'POSITIONING_SYSTEM',
#  'POSITIONING_SYSTEM.long_name',
#  'POSITIONING_SYSTEM._FillValue',
#  'PROFILE_PRES_QC',
#  'PROFILE_PRES_QC.long_name',
#  'PROFILE_PRES_QC.conventions',
#  'PROFILE_PRES_QC._FillValue',
#  'PROFILE_TEMP_QC',
#  'PROFILE_TEMP_QC.long_name',
#  'PROFILE_TEMP_QC.conventions',
#  'PROFILE_TEMP_QC._FillValue',
#  'PROFILE_PSAL_QC',
#  'PROFILE_PSAL_QC.long_name',
#  'PROFILE_PSAL_QC.conventions',
#  'PROFILE_PSAL_QC._FillValue',
#  'VERTICAL_SAMPLING_SCHEME',
#  'VERTICAL_SAMPLING_SCHEME.long_name',
#  'VERTICAL_SAMPLING_SCHEME.conventions',
#  'VERTICAL_SAMPLING_SCHEME._FillValue',
#  'CONFIG_MISSION_NUMBER',
#  'CONFIG_MISSION_NUMBER.long_name',
#  'CONFIG_MISSION_NUMBER.conventions',
#  'CONFIG_MISSION_NUMBER._FillValue',
#  'PRES',
#  'PRES.long_name',
#  'PRES.standard_name',
#  'PRES._FillValue',
#  'PRES.units',
#  'PRES.valid_min',
#  'PRES.valid_max',
#  'PRES.C_format',
#  'PRES.FORTRAN_format',
#  'PRES.resolution',
#  'PRES.axis',
#  'PRES_QC',
#  'PRES_QC.long_name',
#  'PRES_QC.conventions',
#  'PRES_QC._FillValue',
#  'PRES_ADJUSTED',
#  'PRES_ADJUSTED.long_name',
#  'PRES_ADJUSTED.standard_name',
#  'PRES_ADJUSTED._FillValue',
#  'PRES_ADJUSTED.units',
#  'PRES_ADJUSTED.valid_min',
#  'PRES_ADJUSTED.valid_max',
#  'PRES_ADJUSTED.C_format',
#  'PRES_ADJUSTED.FORTRAN_format',
#  'PRES_ADJUSTED.resolution',
#  'PRES_ADJUSTED.axis',
#  'PRES_ADJUSTED_QC',
#  'PRES_ADJUSTED_QC.long_name',
#  'PRES_ADJUSTED_QC.conventions',
#  'PRES_ADJUSTED_QC._FillValue',
#  'PRES_ADJUSTED_ERROR',
#  'PRES_ADJUSTED_ERROR.long_name',
#  'PRES_ADJUSTED_ERROR._FillValue',
#  'PRES_ADJUSTED_ERROR.units',
#  'PRES_ADJUSTED_ERROR.C_format',
#  'PRES_ADJUSTED_ERROR.FORTRAN_format',
#  'PRES_ADJUSTED_ERROR.resolution',
#  'TEMP',
#  'TEMP.long_name',
#  'TEMP.standard_name',
#  'TEMP._FillValue',
#  'TEMP.units',
#  'TEMP.valid_min',
#  'TEMP.valid_max',
#  'TEMP.C_format',
#  'TEMP.FORTRAN_format',
#  'TEMP.resolution',
#  'TEMP_QC',
#  'TEMP_QC.long_name',
#  'TEMP_QC.conventions',
#  'TEMP_QC._FillValue',
#  'TEMP_ADJUSTED',
#  'TEMP_ADJUSTED.long_name',
#  'TEMP_ADJUSTED.standard_name',
#  'TEMP_ADJUSTED._FillValue',
#  'TEMP_ADJUSTED.units',
#  'TEMP_ADJUSTED.valid_min',
#  'TEMP_ADJUSTED.valid_max',
#  'TEMP_ADJUSTED.C_format',
#  'TEMP_ADJUSTED.FORTRAN_format',
#  'TEMP_ADJUSTED.resolution',
#  'TEMP_ADJUSTED_QC',
#  'TEMP_ADJUSTED_QC.long_name',
#  'TEMP_ADJUSTED_QC.conventions',
#  'TEMP_ADJUSTED_QC._FillValue',
#  'TEMP_ADJUSTED_ERROR',
#  'TEMP_ADJUSTED_ERROR.long_name',
#  'TEMP_ADJUSTED_ERROR._FillValue',
#  'TEMP_ADJUSTED_ERROR.units',
#  'TEMP_ADJUSTED_ERROR.C_format',
#  'TEMP_ADJUSTED_ERROR.FORTRAN_format',
#  'TEMP_ADJUSTED_ERROR.resolution',
#  'PSAL',
#  'PSAL.long_name',
#  'PSAL.standard_name',
#  'PSAL._FillValue',
#  'PSAL.units',
#  'PSAL.valid_min',
#  'PSAL.valid_max',
#  'PSAL.C_format',
#  'PSAL.FORTRAN_format',
#  'PSAL.resolution',
#  'PSAL_QC',
#  'PSAL_QC.long_name',
#  'PSAL_QC.conventions',
#  'PSAL_QC._FillValue',
#  'PSAL_ADJUSTED',
#  'PSAL_ADJUSTED.long_name',
#  'PSAL_ADJUSTED.standard_name',
#  'PSAL_ADJUSTED._FillValue',
#  'PSAL_ADJUSTED.units',
#  'PSAL_ADJUSTED.valid_min',
#  'PSAL_ADJUSTED.valid_max',
#  'PSAL_ADJUSTED.C_format',
#  'PSAL_ADJUSTED.FORTRAN_format',
#  'PSAL_ADJUSTED.resolution',
#  'PSAL_ADJUSTED_QC',
#  'PSAL_ADJUSTED_QC.long_name',
#  'PSAL_ADJUSTED_QC.conventions',
#  'PSAL_ADJUSTED_QC._FillValue',
#  'PSAL_ADJUSTED_ERROR',
#  'PSAL_ADJUSTED_ERROR.long_name',
#  'PSAL_ADJUSTED_ERROR._FillValue',
#  'PSAL_ADJUSTED_ERROR.units',
#  'PSAL_ADJUSTED_ERROR.C_format',
#  'PSAL_ADJUSTED_ERROR.FORTRAN_format',
#  'PSAL_ADJUSTED_ERROR.resolution',
#  'PARAMETER',
#  'PARAMETER.long_name',
#  'PARAMETER.conventions',
#  'PARAMETER._FillValue',
#  'SCIENTIFIC_CALIB_EQUATION',
#  'SCIENTIFIC_CALIB_EQUATION.long_name',
#  'SCIENTIFIC_CALIB_EQUATION._FillValue',
#  'SCIENTIFIC_CALIB_COEFFICIENT',
#  'SCIENTIFIC_CALIB_COEFFICIENT.long_name',
#  'SCIENTIFIC_CALIB_COEFFICIENT._FillValue',
#  'SCIENTIFIC_CALIB_COMMENT',
#  'SCIENTIFIC_CALIB_COMMENT.long_name',
#  'SCIENTIFIC_CALIB_COMMENT._FillValue',
#  'SCIENTIFIC_CALIB_DATE',
#  'SCIENTIFIC_CALIB_DATE.long_name',
#  'SCIENTIFIC_CALIB_DATE.conventions',
#  'SCIENTIFIC_CALIB_DATE._FillValue',
#  'HISTORY_INSTITUTION',
#  'HISTORY_INSTITUTION.long_name',
#  'HISTORY_INSTITUTION.conventions',
#  'HISTORY_INSTITUTION._FillValue',
#  'HISTORY_STEP',
#  'HISTORY_STEP.long_name',
#  'HISTORY_STEP.conventions',
#  'HISTORY_STEP._FillValue',
#  'HISTORY_SOFTWARE',
#  'HISTORY_SOFTWARE.long_name',
#  'HISTORY_SOFTWARE.conventions',
#  'HISTORY_SOFTWARE._FillValue',
#  'HISTORY_SOFTWARE_RELEASE',
#  'HISTORY_SOFTWARE_RELEASE.long_name',
#  'HISTORY_SOFTWARE_RELEASE.conventions',
#  'HISTORY_SOFTWARE_RELEASE._FillValue',
#  'HISTORY_REFERENCE',
#  'HISTORY_REFERENCE.long_name',
#  'HISTORY_REFERENCE.conventions',
#  'HISTORY_REFERENCE._FillValue',
#  'HISTORY_DATE',
#  'HISTORY_DATE.long_name',
#  'HISTORY_DATE.conventions',
#  'HISTORY_DATE._FillValue',
#  'HISTORY_ACTION',
#  'HISTORY_ACTION.long_name',
#  'HISTORY_ACTION.conventions',
#  'HISTORY_ACTION._FillValue',
#  'HISTORY_PARAMETER',
#  'HISTORY_PARAMETER.long_name',
#  'HISTORY_PARAMETER.conventions',
#  'HISTORY_PARAMETER._FillValue',
#  'HISTORY_START_PRES',
#  'HISTORY_START_PRES.long_name',
#  'HISTORY_START_PRES._FillValue',
#  'HISTORY_START_PRES.units',
#  'HISTORY_STOP_PRES',
#  'HISTORY_STOP_PRES.long_name',
#  'HISTORY_STOP_PRES._FillValue',
#  'HISTORY_STOP_PRES.units',
#  'HISTORY_PREVIOUS_VALUE',
#  'HISTORY_PREVIOUS_VALUE.long_name',
#  'HISTORY_PREVIOUS_VALUE._FillValue',
#  'HISTORY_QCTEST',
#  'HISTORY_QCTEST.long_name',
#  'HISTORY_QCTEST.conventions',
#  'HISTORY_QCTEST._FillValue',
#  '.title',
#  '.institution',
#  '.source',
#  '.history',
#  '.references',
#  '.user_manual_version',
#  '.Conventions',
#  '.featureType',
#  '@identifier']

# %%
from datetime import datetime
min_time = datetime(2019,1,1,0,0,0)
max_time = datetime(2020,1,1,0,0,0)
client.subset("LONGITUDE","LATITUDE", "JULD", "PRES", ["TEMP", "TEMP_ADJUSTED", "DATA_TYPE"], depth_range=(0,10), time_range=(min_time, max_time)).to_pandas_dataframe()
# Out:
# Running query: {"from": "default", "select": [{"column": "LONGITUDE", "alias": null}, {"column": "LATITUDE", "alias": null}, {"column": "JULD", "alias": null}, {"column": "PRES", "alias": null}, {"column": "TEMP", "alias": null}, {"column": "TEMP_ADJUSTED", "alias": null}, {"column": "DATA_TYPE", "alias": null}], "filters": [{"column": "PRES", "gt_eq": 0, "lt_eq": 10}, {"column": "JULD", "gt_eq": "2019-01-01T00:00:00", "lt_eq": "2020-01-01T00:00:00"}], "output": {"format": "parquet"}}
#           LONGITUDE   LATITUDE        JULD  PRES       TEMP  TEMP_ADJUSTED  \
# 0         11.634520 -11.749668  1569389700   9.0  23.415001      23.415001
# 1         11.648747 -11.796965  1569476600   6.2  23.542999      23.542999
# 2         11.648747 -11.796965  1569476600   7.0  23.539000      23.539000
# 3         11.648747 -11.796965  1569476600   7.8  23.525999      23.525999
# 4         11.648747 -11.796965  1569476600   8.8  23.490999      23.490999
# ...             ...        ...         ...   ...        ...            ...
# 1076074 -167.883000  16.000000  1574131281   4.6  28.503000      28.503000
# 1076075 -168.064000  16.170000  1575062266   4.4  27.962000      27.962000
# 1076076 -168.240000  16.318000  1575973339   4.6  27.624001      27.624001
# 1076077 -168.276000  16.262000  1576905059   4.3  27.482000      27.482000
# 1076078 -168.271000  16.332000  1577817598   4.4  27.041000      27.041000
#
#                 DATA_TYPE
# 0        Argo profile
# 1        Argo profile
# 2        Argo profile
# 3        Argo profile
# 4        Argo profile
# ...                   ...
# 1076074  Argo profile
# 1076075  Argo profile
# 1076076  Argo profile
# 1076077  Argo profile
# 1076078  Argo profile
#
# [1076079 rows x 7 columns]

# %%
from datetime import datetime
min_time = datetime(2019,1,1,0,0,0)
max_time = datetime(2020,1,1,0,0,0)
client.subset("LONGITUDE","LATITUDE", "JULD", "PRES", ["TEMP", "TEMP_ADJUSTED", "DATA_TYPE"], depth_range=(0,10), time_range=(min_time, max_time)).to_netcdf('example-output.nc')
# Out:
# Running query: {"from": "default", "select": [{"column": "LONGITUDE", "alias": null}, {"column": "LATITUDE", "alias": null}, {"column": "JULD", "alias": null}, {"column": "PRES", "alias": null}, {"column": "TEMP", "alias": null}, {"column": "TEMP_ADJUSTED", "alias": null}, {"column": "DATA_TYPE", "alias": null}], "filters": [{"column": "PRES", "gt_eq": 0, "lt_eq": 10}, {"column": "JULD", "gt_eq": "2019-01-01T00:00:00", "lt_eq": "2020-01-01T00:00:00"}], "output": {"format": "parquet"}}

# %%
(client.query()
    .add_select_column("LONGITUDE")
    .add_select_column("LATITUDE")
    .add_select_column("TEMP")
    .add_select_column("TEMP_ADJUSTED")
    .add_select_column("DATA_TYPE")
    .add_select_column("JULD")
    .add_select_column("PRES")
    .add_range_filter("JULD", min_time, max_time)
    .add_range_filter("PRES", 0, 10)
    .add_is_not_null_filter("TEMP")
    .to_geo_pandas_dataframe("LONGITUDE", "LATITUDE")
)
# Out:
# Running query: {"from": "default", "select": [{"column": "LONGITUDE", "alias": null}, {"column": "LATITUDE", "alias": null}, {"column": "TEMP", "alias": null}, {"column": "TEMP_ADJUSTED", "alias": null}, {"column": "DATA_TYPE", "alias": null}, {"column": "JULD", "alias": null}, {"column": "PRES", "alias": null}], "filters": [{"column": "JULD", "gt_eq": "2019-01-01T00:00:00.000000", "lt_eq": "2020-01-01T00:00:00.000000"}, {"column": "PRES", "gt_eq": 0, "lt_eq": 10}, {"is_not_null": {"column": "TEMP"}}], "output": {"format": {"geoparquet": {"longitude_column": "LONGITUDE", "latitude_column": "LATITUDE"}}}}
#           LONGITUDE   LATITUDE       TEMP  TEMP_ADJUSTED         DATA_TYPE  \
# 0         11.634520 -11.749668  23.415001      23.415001  Argo profile
# 1         11.648747 -11.796965  23.542999      23.542999  Argo profile
# 2         11.648747 -11.796965  23.539000      23.539000  Argo profile
# 3         11.648747 -11.796965  23.525999      23.525999  Argo profile
# 4         11.648747 -11.796965  23.490999      23.490999  Argo profile
# ...             ...        ...        ...            ...               ...
# 1076055 -167.883000  16.000000  28.503000      28.503000  Argo profile
# 1076056 -168.064000  16.170000  27.962000      27.962000  Argo profile
# 1076057 -168.240000  16.318000  27.624001      27.624001  Argo profile
# 1076058 -168.276000  16.262000  27.482000      27.482000  Argo profile
# 1076059 -168.271000  16.332000  27.041000      27.041000  Argo profile
#
#                JULD  PRES                    geometry
# 0        1569389700   9.0  POINT (11.63452 -11.74967)
# 1        1569476600   6.2  POINT (11.64875 -11.79696)
# 2        1569476600   7.0  POINT (11.64875 -11.79696)
# 3        1569476600   7.8  POINT (11.64875 -11.79696)
# 4        1569476600   8.8  POINT (11.64875 -11.79696)
# ...             ...   ...                         ...
# 1076055  1574131281   4.6         POINT (-167.883 16)
# 1076056  1575062266   4.4      POINT (-168.064 16.17)
# 1076057  1575973339   4.6      POINT (-168.24 16.318)
# 1076058  1576905059   4.3     POINT (-168.276 16.262)
# 1076059  1577817598   4.4     POINT (-168.271 16.332)
#
# [1076060 rows x 8 columns]
