# %%
# %pip install beacon-api==1.0.9rc2
# Out:
# Requirement already satisfied: beacon-api==1.0.9rc2 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (1.0.9rc2)
# Requirement already satisfied: requests>=2.0.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (2.32.5)
# Requirement already satisfied: pandas>=2.0.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (2.3.3)
# Requirement already satisfied: pyarrow!=19.0.0,>=17.0.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (21.0.0)
# Requirement already satisfied: xarray>=2023.1.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (2025.9.1)
# Requirement already satisfied: netCDF4>=1.5.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (1.7.2)
# Requirement already satisfied: typing_extensions>=4.10.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (4.15.0)
# Requirement already satisfied: numpy>=1.23.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (2.3.3)
# Requirement already satisfied: geopandas>=1.0.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (1.1.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from geopandas>=1.0.0->beacon-api==1.0.9rc2) (0.11.1)
# Requirement already satisfied: packaging in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from geopandas>=1.0.0->beacon-api==1.0.9rc2) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from geopandas>=1.0.0->beacon-api==1.0.9rc2) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from geopandas>=1.0.0->beacon-api==1.0.9rc2) (2.1.2)
# Requirement already satisfied: cftime in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from netCDF4>=1.5.0->beacon-api==1.0.9rc2) (1.6.4.post1)
# Requirement already satisfied: certifi in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from netCDF4>=1.5.0->beacon-api==1.0.9rc2) (2025.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from pandas>=2.0.0->beacon-api==1.0.9rc2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from pandas>=2.0.0->beacon-api==1.0.9rc2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from pandas>=2.0.0->beacon-api==1.0.9rc2) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from requests>=2.0.0->beacon-api==1.0.9rc2) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from requests>=2.0.0->beacon-api==1.0.9rc2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from requests>=2.0.0->beacon-api==1.0.9rc2) (2.5.0)
# Requirement already satisfied: six>=1.5 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->beacon-api==1.0.9rc2) (1.17.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from beacon_api import *
client = Client("https://beacon-cmems.maris.nl", jwt_token="")
# Out:
# Connected to: https://beacon-cmems.maris.nl/ server successfully

# %%
tables = client.list_tables()
tables
# Out:
# {'default': <beacon_api.table.DataTable at 0x7f249e4d5bb0>}

# %%
tables['default'].get_table_schema()
# Out:
# __entry_key: string
# __chunk_index: uint64
# TIME: timestamp[ns]
# DEPTH: int64
# LONGITUDE: float
# LATITUDE: float
# PRES: float
# TRAJECTORY: string
# TIME_QC: float
# BATH: float
# BATH_QC: float
# POSITION_QC: float
# PRES_QC: float
# TEMP_DM: string
# ACIDZZXX: float
# PF12GCTX_QC: float
# CPHL: float
# DENS_QC: float
# PHAEFLP1: float
# ACIDZZXX_QC: float
# NTRA_DM: string
# DENS: float
# CO2AQXXX-MLM3_QC: float
# SLCA_DM: string
# P113GCTX_QC: float
# PSAL_DM: string
# ALKYZZXX_QC: float
# PHOS: float
# NTRA_QC: float
# SLCA: float
# ALKYZZXX: float
# PF12GCTX: float
# TEMP_QC: float
# TEMP: float
# PSAL: float
# PF11GCTX: float
# NTRA: float
# PHAEFLP1_QC: float
# DOX1_QC: float
# PSAL_QC: float
# CPHL_QC: float
# PHOS_QC: float
# PF11GCTX_QC: float
# PHOS_DM: string
# NTRI_QC: float
# SLCA_QC: float
# CO2AQXXX-MLM3: float
# NTRI: float
# P113GCTX: float
# DOX1: float
# .project: string
# .citation: string
# .naming_authority: string
# .license: string
# .references: string
# .update_interval: string
# .Conventions: string
# .comment: string
# .history: string
# .netcdf_version: string
# .creator_name: string
# .publisher_name: string
# .publisher_email: string
# .publisher_url: string
# .summary: string
# .wmo_platform_code: string
# .site_code: string
# .geospatial_vertical_positive: string
# .platform_code: string
# .platform_name: string
# .cdm_data_type: string
# .instrument: string
# .time_coverage_start: string
# .time_coverage_end: string
# .last_date_observation: string
# .geospatial_lat_min: string
# .geospatial_lat_max: string
# .last_latitude_observation: string
# .geospatial_lon_min: string
# .geospatial_lon_max: string
# .last_longitude_observation: string
# .id: string
# .geospatial_vertical_min: string
# .geospatial_vertical_max: string
# .keywords: string
# .keywords_vocabulary: string
# .format_version: string
# .area: string
# .data_mode: string
# .doi: string
# .ices_platform_code: string
# .publisher_institution: string
# .featureType: string
# .institution: string
# .institution_country: string
# .institution_edmo_code: string
# .source: string
# .source_platform_category_code: string
# .date_modified: string
# .quality_control_indicator: int32
# .quality_index: string
# .date_update: string
# .title: string
# .bigram: string
# TIME_QC.long_name: string
# TIME_QC.valid_min: int8
# TIME_QC.valid_max: int8
# TIME_QC.flag_meanings: string
# BATH.standard_name: string
# BATH.long_name: string
# BATH.units: string
# BATH.valid_min: double
# BATH.valid_max: double
# BATH.ancillary_variables: string
# BATH.data_mode: string
# BATH_QC.long_name: string
# BATH_QC.valid_min: int8
# BATH_QC.valid_max: int8
# BATH_QC.flag_meanings: string
# POSITION_QC.long_name: string
# POSITION_QC.valid_min: int8
# POSITION_QC.valid_max: int8
# POSITION_QC.flag_meanings: string
# PRES_QC.long_name: string
# PRES_QC.valid_min: int8
# PRES_QC.valid_max: int8
# PRES_QC.flag_meanings: string
# TEMP_DM.flag_values: string
# TEMP_DM.flag_meanings: string
# TEMP_DM.long_name: string
# ACIDZZXX.standard_name: string
# ACIDZZXX.long_name: string
# ACIDZZXX.units: string
# ACIDZZXX.valid_min: double
# ACIDZZXX.valid_max: double
# ACIDZZXX.ancillary_variables: string
# ACIDZZXX.data_mode: string
# PF12GCTX_QC.long_name: string
# PF12GCTX_QC.valid_min: int8
# PF12GCTX_QC.valid_max: int8
# PF12GCTX_QC.flag_meanings: string
# CPHL.standard_name: string
# CPHL.long_name: string
# CPHL.units: string
# CPHL.valid_min: double
# CPHL.valid_max: double
# CPHL.ancillary_variables: string
# CPHL.data_mode: string
# DENS_QC.long_name: string
# DENS_QC.valid_min: int8
# DENS_QC.valid_max: int8
# DENS_QC.flag_meanings: string
# PHAEFLP1.standard_name: string
# PHAEFLP1.long_name: string
# PHAEFLP1.units: string
# PHAEFLP1.valid_min: double
# PHAEFLP1.valid_max: double
# PHAEFLP1.ancillary_variables: string
# PHAEFLP1.data_mode: string
# ACIDZZXX_QC.long_name: string
# ACIDZZXX_QC.valid_min: int8
# ACIDZZXX_QC.valid_max: int8
# ACIDZZXX_QC.flag_meanings: string
# NTRA_DM.flag_values: string
# NTRA_DM.flag_meanings: string
# NTRA_DM.long_name: string
# DENS.standard_name: string
# DENS.long_name: string
# DENS.units: string
# DENS.valid_min: double
# DENS.valid_max: double
# DENS.ancillary_variables: string
# DENS.data_mode: string
# CO2AQXXX-MLM3_QC.long_name: string
# CO2AQXXX-MLM3_QC.valid_min: int8
# CO2AQXXX-MLM3_QC.valid_max: int8
# CO2AQXXX-MLM3_QC.flag_meanings: string
# SLCA_DM.flag_values: string
# SLCA_DM.flag_meanings: string
# SLCA_DM.long_name: string
# P113GCTX_QC.long_name: string
# P113GCTX_QC.valid_min: int8
# P113GCTX_QC.valid_max: int8
# P113GCTX_QC.flag_meanings: string
# PSAL_DM.flag_values: string
# PSAL_DM.flag_meanings: string
# PSAL_DM.long_name: string
# ALKYZZXX_QC.long_name: string
# ALKYZZXX_QC.valid_min: int8
# ALKYZZXX_QC.valid_max: int8
# ALKYZZXX_QC.flag_meanings: string
# PHOS.standard_name: string
# PHOS.long_name: string
# PHOS.units: string
# PHOS.valid_min: double
# PHOS.valid_max: double
# PHOS.ancillary_variables: string
# PHOS.data_mode: string
# NTRA_QC.long_name: string
# NTRA_QC.valid_min: int8
# NTRA_QC.valid_max: int8
# NTRA_QC.flag_meanings: string
# SLCA.standard_name: string
# SLCA.long_name: string
# SLCA.units: string
# SLCA.valid_min: double
# SLCA.valid_max: double
# SLCA.ancillary_variables: string
# SLCA.data_mode: string
# ALKYZZXX.standard_name: string
# ALKYZZXX.long_name: string
# ALKYZZXX.units: string
# ALKYZZXX.valid_min: double
# ALKYZZXX.valid_max: double
# ALKYZZXX.ancillary_variables: string
# ALKYZZXX.data_mode: string
# PF12GCTX.standard_name: string
# PF12GCTX.long_name: string
# PF12GCTX.units: string
# PF12GCTX.valid_min: double
# PF12GCTX.valid_max: double
# PF12GCTX.ancillary_variables: string
# PF12GCTX.data_mode: string
# TEMP_QC.long_name: string
# TEMP_QC.valid_min: int8
# TEMP_QC.valid_max: int8
# TEMP_QC.flag_meanings: string
# TEMP.standard_name: string
# TEMP.long_name: string
# TEMP.units: string
# TEMP.valid_min: double
# TEMP.valid_max: double
# TEMP.ancillary_variables: string
# TEMP.data_mode: string
# PSAL.standard_name: string
# PSAL.long_name: string
# PSAL.units: string
# PSAL.valid_min: double
# PSAL.valid_max: double
# PSAL.ancillary_variables: string
# PSAL.data_mode: string
# PF11GCTX.standard_name: string
# PF11GCTX.long_name: string
# PF11GCTX.units: string
# PF11GCTX.valid_min: double
# PF11GCTX.valid_max: double
# PF11GCTX.ancillary_variables: string
# PF11GCTX.data_mode: string
# NTRA.standard_name: string
# NTRA.long_name: string
# NTRA.units: string
# NTRA.valid_min: double
# NTRA.valid_max: double
# NTRA.ancillary_variables: string
# NTRA.data_mode: string
# PHAEFLP1_QC.long_name: string
# PHAEFLP1_QC.valid_min: int8
# PHAEFLP1_QC.valid_max: int8
# PHAEFLP1_QC.flag_meanings: string
# DOX1_QC.long_name: string
# DOX1_QC.valid_min: int8
# DOX1_QC.valid_max: int8
# DOX1_QC.flag_meanings: string
# PSAL_QC.long_name: string
# PSAL_QC.valid_min: int8
# PSAL_QC.valid_max: int8
# PSAL_QC.flag_meanings: string
# CPHL_QC.long_name: string
# CPHL_QC.valid_min: int8
# CPHL_QC.valid_max: int8
# CPHL_QC.flag_meanings: string
# PHOS_QC.long_name: string
# PHOS_QC.valid_min: int8
# PHOS_QC.valid_max: int8
# PHOS_QC.flag_meanings: string
# PF11GCTX_QC.long_name: string
# PF11GCTX_QC.valid_min: int8
# PF11GCTX_QC.valid_max: int8
# PF11GCTX_QC.flag_meanings: string
# PHOS_DM.flag_values: string
# PHOS_DM.flag_meanings: string
# PHOS_DM.long_name: string
# NTRI_QC.long_name: string
# NTRI_QC.valid_min: int8
# NTRI_QC.valid_max: int8
# NTRI_QC.flag_meanings: string
# SLCA_QC.long_name: string
# SLCA_QC.valid_min: int8
# SLCA_QC.valid_max: int8
# SLCA_QC.flag_meanings: string
# CO2AQXXX-MLM3.standard_name: string
# CO2AQXXX-MLM3.long_name: string
# CO2AQXXX-MLM3.units: string
# CO2AQXXX-MLM3.valid_min: double
# CO2AQXXX-MLM3.valid_max: double
# CO2AQXXX-MLM3.ancillary_variables: string
# CO2AQXXX-MLM3.data_mode: string
# NTRI.standard_name: string
# NTRI.long_name: string
# NTRI.units: string
# NTRI.valid_min: double
# NTRI.valid_max: double
# NTRI.ancillary_variables: string
# NTRI.data_mode: string
# P113GCTX.standard_name: string
# P113GCTX.long_name: string
# P113GCTX.units: string
# P113GCTX.valid_min: double
# P113GCTX.valid_max: double
# P113GCTX.ancillary_variables: string
# P113GCTX.data_mode: string
# DOX1.standard_name: string
# DOX1.long_name: string
# DOX1.units: string
# DOX1.valid_min: double
# DOX1.valid_max: double
# DOX1.ancillary_variables: string
# DOX1.data_mode: string
# DOX1_DM: string
# DOX1_DM.flag_values: string
# DOX1_DM.flag_meanings: string
# DOX1_DM.long_name: string
# DOX1.comment: string
# NTOTCAP1_QC: float
# CORGCAP1_QC: float
# AMON_QC: float
# AMON: float
# CORGCAP1: float
# NTOTCAP1: float
# NTOTCAP1_QC.long_name: string
# NTOTCAP1_QC.valid_min: int8
# NTOTCAP1_QC.valid_max: int8
# NTOTCAP1_QC.flag_meanings: string
# CORGCAP1_QC.long_name: string
# CORGCAP1_QC.valid_min: int8
# CORGCAP1_QC.valid_max: int8
# CORGCAP1_QC.flag_meanings: string
# AMON_QC.long_name: string
# AMON_QC.valid_min: int8
# AMON_QC.valid_max: int8
# AMON_QC.flag_meanings: string
# AMON.standard_name: string
# AMON.long_name: string
# AMON.units: string
# AMON.valid_min: double
# AMON.valid_max: double
# AMON.ancillary_variables: string
# AMON.data_mode: string
# CORGCAP1.standard_name: string
# CORGCAP1.long_name: string
# CORGCAP1.units: string
# CORGCAP1.valid_min: double
# CORGCAP1.valid_max: double
# CORGCAP1.ancillary_variables: string
# CORGCAP1.data_mode: string
# NTOTCAP1.standard_name: string
# NTOTCAP1.long_name: string
# NTOTCAP1.units: string
# NTOTCAP1.valid_min: double
# NTOTCAP1.valid_max: double
# NTOTCAP1.ancillary_variables: string
# NTOTCAP1.data_mode: string
# FLU2: float
# CHLT_QC: float
# FLU2_QC: float
# CHLT: float
# FLU2.standard_name: string
# FLU2.long_name: string
# FLU2.units: string
# FLU2.valid_min: double
# FLU2.valid_max: double
# FLU2.ancillary_variables: string
# FLU2.data_mode: string
# CHLT_QC.long_name: string
# CHLT_QC.valid_min: int8
# CHLT_QC.valid_max: int8
# CHLT_QC.flag_meanings: string
# FLU2_QC.long_name: string
# FLU2_QC.valid_min: int8
# FLU2_QC.valid_max: int8
# FLU2_QC.flag_meanings: string
# CHLT.standard_name: string
# CHLT.long_name: string
# CHLT.units: string
# CHLT.valid_min: double
# CHLT.valid_max: double
# CHLT.ancillary_variables: string
# CHLT.data_mode: string
# PRES_DM: string
# CNDC: float
# DOX2: float
# DOX2_QC: float
# SVEL: float
# SVEL_QC: float
# CNDC_QC: float
# SIGMA_T_QC: float
# CNDC_DM: string
# SIGMA_T: float
# PRES_DM.flag_values: string
# PRES_DM.flag_meanings: string
# PRES_DM.long_name: string
# CNDC.standard_name: string
# CNDC.long_name: string
# CNDC.units: string
# CNDC.valid_min: double
# CNDC.valid_max: double
# CNDC.ancillary_variables: string
# CNDC.data_mode: string
# DOX2.standard_name: string
# DOX2.long_name: string
# DOX2.units: string
# DOX2.valid_min: double
# DOX2.valid_max: double
# DOX2.ancillary_variables: string
# DOX2.data_mode: string
# DOX2_QC.long_name: string
# DOX2_QC.valid_min: int8
# DOX2_QC.valid_max: int8
# DOX2_QC.flag_meanings: string
# SVEL.standard_name: string
# SVEL.long_name: string
# SVEL.units: string
# SVEL.valid_min: double
# SVEL.valid_max: double
# SVEL.ancillary_variables: string
# SVEL.data_mode: string
# SVEL.comment: string
# SVEL_QC.long_name: string
# SVEL_QC.valid_min: int8
# SVEL_QC.valid_max: int8
# SVEL_QC.flag_meanings: string
# CNDC_QC.long_name: string
# CNDC_QC.valid_min: int8
# CNDC_QC.valid_max: int8
# CNDC_QC.flag_meanings: string
# SIGMA_T_QC.long_name: string
# SIGMA_T_QC.valid_min: int8
# SIGMA_T_QC.valid_max: int8
# SIGMA_T_QC.flag_meanings: string
# CNDC_DM.flag_values: string
# CNDC_DM.flag_meanings: string
# CNDC_DM.long_name: string
# SIGMA_T.standard_name: string
# SIGMA_T.long_name: string
# SIGMA_T.units: string
# SIGMA_T.valid_min: double
# SIGMA_T.valid_max: double
# SIGMA_T.ancillary_variables: string
# SIGMA_T.data_mode: string
# SIGMA_T.comment: string
# CCOMD003: float
# CCOMD003_QC: float
# DOX2.comment: string
# CCOMD003.standard_name: string
# CCOMD003.long_name: string
# CCOMD003.units: string
# CCOMD003.valid_min: double
# CCOMD003.valid_max: double
# CCOMD003.ancillary_variables: string
# CCOMD003.data_mode: string
# CCOMD003.comment: string
# FLU2.comment: string
# DENS.comment: string
# CCOMD003_QC.long_name: string
# CCOMD003_QC.valid_min: int8
# CCOMD003_QC.valid_max: int8
# CCOMD003_QC.flag_meanings: string
# TEMP.sensor_id: string
# TEMP.sensor_serial_number: string
# TEMP.instrument: string
# DOX2.sensor_id: string
# DOX2.sensor_serial_number: string
# DOX2.instrument: string
# CNDC.sensor_id: string
# CNDC.sensor_serial_number: string
# CNDC.instrument: string
# TUR4_QC: float
# CDOM_QC: float
# CDOM: float
# TUR4: float
# LGH4: float
# LGH4_QC: float
# TUR4_QC.long_name: string
# TUR4_QC.valid_min: int8
# TUR4_QC.valid_max: int8
# TUR4_QC.flag_meanings: string
# CDOM_QC.long_name: string
# CDOM_QC.valid_min: int8
# CDOM_QC.valid_max: int8
# CDOM_QC.flag_meanings: string
# CDOM.standard_name: string
# CDOM.long_name: string
# CDOM.units: string
# CDOM.valid_min: double
# CDOM.valid_max: double
# CDOM.ancillary_variables: string
# CDOM.data_mode: string
# TUR4.standard_name: string
# TUR4.long_name: string
# TUR4.units: string
# TUR4.valid_min: double
# TUR4.valid_max: double
# TUR4.ancillary_variables: string
# TUR4.data_mode: string
# LGH4.standard_name: string
# LGH4.long_name: string
# LGH4.units: string
# LGH4.valid_min: double
# LGH4.valid_max: double
# LGH4.ancillary_variables: string
# LGH4.data_mode: string
# LGH4_QC.long_name: string
# LGH4_QC.valid_min: int8
# LGH4_QC.valid_max: int8
# LGH4_QC.flag_meanings: string
# SIGTEQST: float
# SIGTEQST_QC: float
# TUR4.sensor_id: string
# TUR4.sensor_serial_number: string
# TUR4.instrument: string
# SIGTEQST.standard_name: string
# SIGTEQST.long_name: string
# SIGTEQST.units: string
# SIGTEQST.valid_min: double
# SIGTEQST.valid_max: double
# SIGTEQST.ancillary_variables: string
# SIGTEQST.data_mode: string
# SIGTEQST_QC.long_name: string
# SIGTEQST_QC.valid_min: int8
# SIGTEQST_QC.valid_max: int8
# SIGTEQST_QC.flag_meanings: string
# DOXY_QC: float
# DOXY: float
# .mission_type: string
# DOXY_QC.long_name: string
# DOXY_QC.valid_min: int8
# DOXY_QC.valid_max: int8
# DOXY_QC.flag_meanings: string
# DOXY.standard_name: string
# DOXY.long_name: string
# DOXY.units: string
# DOXY.valid_min: double
# DOXY.valid_max: double
# DOXY.ancillary_variables: string
# DOXY.data_mode: string
# PRECISE_LONGITUDE: float
# PRECISE_LATITUDE: float
# STATION: string
# NSCT: float
# NSCT_QC: float
# EWCT_QC: float
# EWCT: float
# .iso_topic_category: string
# .bottom_depth: string
# NSCT.standard_name: string
# NSCT.long_name: string
# NSCT.units: string
# NSCT.valid_min: double
# NSCT.valid_max: double
# NSCT.ancillary_variables: string
# NSCT.data_mode: string
# NSCT_QC.long_name: string
# NSCT_QC.valid_min: int8
# NSCT_QC.valid_max: int8
# NSCT_QC.flag_meanings: string
# EWCT_QC.long_name: string
# EWCT_QC.valid_min: int8
# EWCT_QC.valid_max: int8
# EWCT_QC.flag_meanings: string
# EWCT.standard_name: string
# EWCT.long_name: string
# EWCT.units: string
# EWCT.valid_min: double
# EWCT.valid_max: double
# EWCT.ancillary_variables: string
# EWCT.data_mode: string
# DEPH: float
# DEPH_QC: float
# NTRZ: float
# NTRZ_QC: float
# ALKY: float
# ALKY_QC: float
# PHTX: float
# PHTX_QC: float
# PHPH: float
# PHPH_QC: float
# .institution_references: string
# .creator_email: string
# .wmo_instrument_type: string
# .geospatial_lat_units: string
# .geospatial_lon_units: string
# .geospatial_vertical_units: string
# DEPH_QC.flag_meanings: string
# DEPH_QC.valid_min: int8
# DEPH_QC.long_name: string
# DEPH_QC.valid_max: int8
# NTRZ.units: string
# NTRZ.long_name: string
# NTRZ.valid_max: float
# NTRZ.valid_min: float
# NTRZ.standard_name: string
# NTRZ.data_mode: string
# NTRZ.ancillary_variables: string
# NTRZ_QC.flag_meanings: string
# NTRZ_QC.valid_min: int8
# NTRZ_QC.long_name: string
# NTRZ_QC.valid_max: int8
# ALKY.units: string
# ALKY.standard_name: string
# ALKY.valid_min: float
# ALKY.long_name: string
# ALKY.valid_max: float
# ALKY.data_mode: string
# ALKY.ancillary_variables: string
# ALKY_QC.flag_meanings: string
# ALKY_QC.valid_min: int8
# ALKY_QC.long_name: string
# ALKY_QC.valid_max: int8
# PHTX.valid_min: float
# PHTX.standard_name: string
# PHTX.valid_max: float
# PHTX.long_name: string
# PHTX.units: string
# PHTX.data_mode: string
# PHTX.ancillary_variables: string
# PHTX_QC.flag_meanings: string
# PHTX_QC.valid_min: int8
# PHTX_QC.long_name: string
# PHTX_QC.valid_max: int8
# PHPH.units: string
# PHPH.long_name: string
# PHPH.valid_max: float
# PHPH.valid_min: float
# PHPH.standard_name: string
# PHPH.data_mode: string
# PHPH.ancillary_variables: string
# PHPH_QC.flag_meanings: string
# PHPH_QC.valid_min: int8
# PHPH_QC.long_name: string
# PHPH_QC.valid_max: int8
# LGHT: float
# LGHT_QC: float
# LGHT.standard_name: string
# LGHT.valid_min: float
# LGHT.valid_max: float
# LGHT.long_name: string
# LGHT.units: string
# LGHT.data_mode: string
# LGHT.ancillary_variables: string
# LGHT_QC.flag_meanings: string
# LGHT_QC.valid_min: int8
# LGHT_QC.long_name: string
# LGHT_QC.valid_max: int8
# HCDT: float
# HCDT_QC: float
# WDIR: float
# WDIR_QC: float
# ATMP: float
# ATMP_QC: float
# WSPD: float
# WSPD_QC: float
# HCSP: float
# HCSP_QC: float
# DRYT: float
# DRYT_QC: float
# HCDT.valid_max: float
# HCDT.standard_name: string
# HCDT.valid_min: float
# HCDT.units: string
# HCDT.long_name: string
# HCDT.data_mode: string
# HCDT.ancillary_variables: string
# HCDT_QC.long_name: string
# HCDT_QC.valid_min: int8
# HCDT_QC.flag_meanings: string
# HCDT_QC.valid_max: int8
# WDIR.valid_min: float
# WDIR.standard_name: string
# WDIR.valid_max: float
# WDIR.long_name: string
# WDIR.units: string
# WDIR.data_mode: string
# WDIR.ancillary_variables: string
# WDIR_QC.long_name: string
# WDIR_QC.valid_min: int8
# WDIR_QC.flag_meanings: string
# WDIR_QC.valid_max: int8
# ATMP.standard_name: string
# ATMP.valid_max: float
# ATMP.valid_min: float
# ATMP.units: string
# ATMP.long_name: string
# ATMP.data_mode: string
# ATMP.ancillary_variables: string
# ATMP_QC.long_name: string
# ATMP_QC.valid_min: int8
# ATMP_QC.flag_meanings: string
# ATMP_QC.valid_max: int8
# WSPD.long_name: string
# WSPD.units: string
# WSPD.valid_min: float
# WSPD.standard_name: string
# WSPD.valid_max: float
# WSPD.data_mode: string
# WSPD.ancillary_variables: string
# WSPD_QC.long_name: string
# WSPD_QC.valid_min: int8
# WSPD_QC.flag_meanings: string
# WSPD_QC.valid_max: int8
# HCSP.units: string
# HCSP.long_name: string
# HCSP.standard_name: string
# HCSP.valid_max: float
# HCSP.valid_min: float
# HCSP.data_mode: string
# HCSP.ancillary_variables: string
# HCSP_QC.long_name: string
# HCSP_QC.valid_min: int8
# HCSP_QC.flag_meanings: string
# HCSP_QC.valid_max: int8
# DRYT.standard_name: string
# DRYT.valid_max: float
# DRYT.valid_min: float
# DRYT.units: string
# DRYT.long_name: string
# DRYT.data_mode: string
# DRYT.ancillary_variables: string
# DRYT_QC.long_name: string
# DRYT_QC.valid_min: int8
# DRYT_QC.flag_meanings: string
# DRYT_QC.valid_max: int8
# TUR2: float
# TUR2_QC: float
# GSPD: float
# GSPD_QC: float
# VTPK: float
# VTPK_QC: float
# VHM0: float
# VHM0_QC: float
# VTZA: float
# VTZA_QC: float
# VMDR: float
# VMDR_QC: float
# VEMH: float
# VEMH_QC: float
# VTPK_DM: string
# VHM0_DM: string
# VTZA_DM: string
# VMDR_DM: string
# VEMH_DM: string
# TUR2.standard_name: string
# TUR2.valid_max: float
# TUR2.valid_min: float
# TUR2.units: string
# TUR2.long_name: string
# TUR2.data_mode: string
# TUR2.ancillary_variables: string
# TUR2_QC.long_name: string
# TUR2_QC.valid_min: int8
# TUR2_QC.flag_meanings: string
# TUR2_QC.valid_max: int8
# GSPD.valid_max: float
# GSPD.standard_name: string
# GSPD.valid_min: float
# GSPD.units: string
# GSPD.long_name: string
# GSPD.data_mode: string
# GSPD.ancillary_variables: string
# GSPD_QC.long_name: string
# GSPD_QC.valid_min: int8
# GSPD_QC.flag_meanings: string
# GSPD_QC.valid_max: int8
# VTPK.long_name: string
# VTPK.units: string
# VTPK.type_of_analysis: string
# VTPK.valid_min: float
# VTPK.standard_name: string
# VTPK.valid_max: float
# VTPK.data_mode: string
# VTPK.ancillary_variables: string
# VTPK_QC.long_name: string
# VTPK_QC.valid_min: int8
# VTPK_QC.flag_meanings: string
# VTPK_QC.valid_max: int8
# VHM0.long_name: string
# VHM0.units: string
# VHM0.type_of_analysis: string
# VHM0.valid_min: float
# VHM0.standard_name: string
# VHM0.valid_max: float
# VHM0.data_mode: string
# VHM0.ancillary_variables: string
# VHM0_QC.long_name: string
# VHM0_QC.valid_min: int8
# VHM0_QC.flag_meanings: string
# VHM0_QC.valid_max: int8
# VTZA.valid_min: float
# VTZA.standard_name: string
# VTZA.valid_max: float
# VTZA.long_name: string
# VTZA.units: string
# VTZA.type_of_analysis: string
# VTZA.data_mode: string
# VTZA.ancillary_variables: string
# VTZA_QC.long_name: string
# VTZA_QC.valid_min: int8
# VTZA_QC.flag_meanings: string
# VTZA_QC.valid_max: int8
# VMDR.long_name: string
# VMDR.type_of_analysis: string
# VMDR.units: string
# VMDR.valid_min: float
# VMDR.valid_max: float
# VMDR.standard_name: string
# VMDR.data_mode: string
# VMDR.ancillary_variables: string
# VMDR_QC.long_name: string
# VMDR_QC.valid_min: int8
# VMDR_QC.flag_meanings: string
# VMDR_QC.valid_max: int8
# VEMH.valid_min: float
# VEMH.valid_max: float
# VEMH.standard_name: string
# VEMH.long_name: string
# VEMH.type_of_analysis: string
# VEMH.units: string
# VEMH.data_mode: string
# VEMH.ancillary_variables: string
# VEMH_QC.long_name: string
# VEMH_QC.valid_min: int8
# VEMH_QC.flag_meanings: string
# VEMH_QC.valid_max: int8
# VTPK_DM.flag_values: string
# VTPK_DM.long_name: string
# VTPK_DM.flag_meanings: string
# VHM0_DM.flag_values: string
# VHM0_DM.long_name: string
# VHM0_DM.flag_meanings: string
# VTZA_DM.flag_values: string
# VTZA_DM.long_name: string
# VTZA_DM.flag_meanings: string
# VMDR_DM.flag_values: string
# VMDR_DM.long_name: string
# VMDR_DM.flag_meanings: string
# VEMH_DM.flag_values: string
# VEMH_DM.long_name: string
# VEMH_DM.flag_meanings: string
# DIRECTION: string
# DIRECTION.long_name: string
# DIRECTION.flag_meanings: string
# DIRECTION.flag_values: string
# OSAT: float
# OSAT_QC: float
# OSAT.long_name: string
# OSAT.standard_name: string
# OSAT.units: string
# OSAT.ancillary_variables: string
# OSAT.data_mode: string
# OSAT_QC.long_name: string
# OSAT_QC.valid_min: int8
# OSAT_QC.valid_max: int8
# OSAT_QC.flag_meanings: string
# VAVT: float
# VAVT_QC: float
# VAVH: float
# VAVH_QC: float
# RELH: float
# RELH_QC: float
# ATMS: float
# ATMS_QC: float
# VAVT.long_name: string
# VAVT.standard_name: string
# VAVT.type_of_analysis: string
# VAVT.units: string
# VAVT.ancillary_variables: string
# VAVT.data_mode: string
# VAVT_QC.long_name: string
# VAVT_QC.valid_min: int8
# VAVT_QC.valid_max: int8
# VAVT_QC.flag_meanings: string
# VAVH.long_name: string
# VAVH.standard_name: string
# VAVH.type_of_analysis: string
# VAVH.units: string
# VAVH.ancillary_variables: string
# VAVH.data_mode: string
# VAVH_QC.long_name: string
# VAVH_QC.valid_min: int8
# VAVH_QC.valid_max: int8
# VAVH_QC.flag_meanings: string
# RELH.long_name: string
# RELH.standard_name: string
# RELH.units: string
# RELH.ancillary_variables: string
# RELH.data_mode: string
# RELH_QC.long_name: string
# RELH_QC.valid_min: int8
# RELH_QC.valid_max: int8
# RELH_QC.flag_meanings: string
# ATMS.long_name: string
# ATMS.standard_name: string
# ATMS.units: string
# ATMS.ancillary_variables: string
# ATMS.data_mode: string
# ATMS_QC.long_name: string
# ATMS_QC.valid_min: int8
# ATMS_QC.valid_max: int8
# ATMS_QC.flag_meanings: string
# DC_REFERENCE: string
# NTOT: float
# NTOT_QC: float
# TPHS: float
# TPHS_QC: float
# .coriolis_platform_code: string
# DC_REFERENCE.long_name: string
# NTOT.long_name: string
# NTOT.units: string
# NTOT.data_mode: string
# NTOT.ancillary_variables: string
# NTOT_QC.long_name: string
# NTOT_QC.valid_min: int8
# NTOT_QC.valid_max: int8
# NTOT_QC.flag_meanings: string
# TPHS.long_name: string
# TPHS.units: string
# TPHS.data_mode: string
# TPHS.ancillary_variables: string
# TPHS_QC.long_name: string
# TPHS_QC.valid_min: int8
# TPHS_QC.valid_max: int8
# TPHS_QC.flag_meanings: string
# USAL: float
# USAL_QC: float
# USAL.long_name: string
# USAL.units: string
# USAL.data_mode: string
# USAL.ancillary_variables: string
# USAL_QC.long_name: string
# USAL_QC.valid_min: int8
# USAL_QC.valid_max: int8
# USAL_QC.flag_meanings: string
# PHTP: float
# PHTP_QC: float
# PHTP.long_name: string
# PHTP.units: string
# PHTP.data_mode: string
# PHTP.ancillary_variables: string
# PHTP_QC.long_name: string
# PHTP_QC.valid_min: int8
# PHTP_QC.valid_max: int8
# PHTP_QC.flag_meanings: string
# PRES.long_name: string
# PRES.standard_name: string
# PRES.units: string
# PRES.data_mode: string
# PRES.ancillary_variables: string
# PHOW: float
# PHOW_QC: float
# PHOW.long_name: string
# PHOW.standard_name: string
# PHOW.units: string
# PHOW.data_mode: string
# PHOW.ancillary_variables: string
# PHOW_QC.long_name: string
# PHOW_QC.valid_min: int8
# PHOW_QC.valid_max: int8
# PHOW_QC.flag_meanings: string
# ALK3: float
# ALK3_QC: float
# TCO2: float
# TCO2_QC: float
# ALK3.long_name: string
# ALK3.units: string
# ALK3.data_mode: string
# ALK3.ancillary_variables: string
# ALK3_QC.long_name: string
# ALK3_QC.valid_min: int8
# ALK3_QC.valid_max: int8
# ALK3_QC.flag_meanings: string
# TCO2.long_name: string
# TCO2.units: string
# TCO2.data_mode: string
# TCO2.ancillary_variables: string
# TCO2_QC.long_name: string
# TCO2_QC.valid_min: int8
# TCO2_QC.valid_max: int8
# TCO2_QC.flag_meanings: string
# HSUL: float
# HSUL_QC: float
# SECC: float
# SECC_QC: float
# HSUL.long_name: string
# HSUL.units: string
# HSUL.data_mode: string
# HSUL.ancillary_variables: string
# HSUL_QC.long_name: string
# HSUL_QC.valid_min: int8
# HSUL_QC.valid_max: int8
# HSUL_QC.flag_meanings: string
# SECC.long_name: string
# SECC.standard_name: string
# SECC.units: string
# SECC.data_mode: string
# SECC.ancillary_variables: string
# SECC_QC.long_name: string
# SECC_QC.valid_min: int8
# SECC_QC.valid_max: int8
# SECC_QC.flag_meanings: string
# C13D: float
# C13D_QC: float
# C14D: float
# C14D_QC: float
# CFC11: float
# CFC11_QC: float
# CFC113: float
# CFC113_QC: float
# CFC12: float
# CFC12_QC: float
# HELD: float
# HELD_QC: float
# HELM: float
# HELM_QC: float
# NTAW: float
# NTAW_QC: float
# NTIW: float
# NTIW_QC: float
# PCO2: float
# PCO2_QC: float
# SLCW: float
# SLCW_QC: float
# TRIW: float
# TRIW_QC: float
# .project_edmerp_code: string
# C13D.long_name: string
# C13D.units: string
# C13D.data_mode: string
# C13D.ancillary_variables: string
# C13D_QC.long_name: string
# C13D_QC.valid_min: int8
# C13D_QC.valid_max: int8
# C13D_QC.flag_meanings: string
# C14D.long_name: string
# C14D.units: string
# C14D.data_mode: string
# C14D.ancillary_variables: string
# C14D_QC.long_name: string
# C14D_QC.valid_min: int8
# C14D_QC.valid_max: int8
# C14D_QC.flag_meanings: string
# CFC11.long_name: string
# CFC11.units: string
# CFC11.data_mode: string
# CFC11.ancillary_variables: string
# CFC11_QC.long_name: string
# CFC11_QC.valid_min: int8
# CFC11_QC.valid_max: int8
# CFC11_QC.flag_meanings: string
# CFC113.long_name: string
# CFC113.units: string
# CFC113.data_mode: string
# CFC113.ancillary_variables: string
# CFC113_QC.long_name: string
# CFC113_QC.valid_min: int8
# CFC113_QC.valid_max: int8
# CFC113_QC.flag_meanings: string
# CFC12.long_name: string
# CFC12.units: string
# CFC12.data_mode: string
# CFC12.ancillary_variables: string
# CFC12_QC.long_name: string
# CFC12_QC.valid_min: int8
# CFC12_QC.valid_max: int8
# CFC12_QC.flag_meanings: string
# HELD.long_name: string
# HELD.units: string
# HELD.data_mode: string
# HELD.ancillary_variables: string
# HELD_QC.long_name: string
# HELD_QC.valid_min: int8
# HELD_QC.valid_max: int8
# HELD_QC.flag_meanings: string
# HELM.long_name: string
# HELM.units: string
# HELM.data_mode: string
# HELM.ancillary_variables: string
# HELM_QC.long_name: string
# HELM_QC.valid_min: int8
# HELM_QC.valid_max: int8
# HELM_QC.flag_meanings: string
# NTAW.long_name: string
# NTAW.standard_name: string
# NTAW.units: string
# NTAW.data_mode: string
# NTAW.ancillary_variables: string
# NTAW_QC.long_name: string
# NTAW_QC.valid_min: int8
# NTAW_QC.valid_max: int8
# NTAW_QC.flag_meanings: string
# NTIW.long_name: string
# NTIW.standard_name: string
# NTIW.units: string
# NTIW.data_mode: string
# NTIW.ancillary_variables: string
# NTIW_QC.long_name: string
# NTIW_QC.valid_min: int8
# NTIW_QC.valid_max: int8
# NTIW_QC.flag_meanings: string
# PCO2.long_name: string
# PCO2.standard_name: string
# PCO2.units: string
# PCO2.data_mode: string
# PCO2.ancillary_variables: string
# PCO2_QC.long_name: string
# PCO2_QC.valid_min: int8
# PCO2_QC.valid_max: int8
# PCO2_QC.flag_meanings: string
# SLCW.long_name: string
# SLCW.standard_name: string
# SLCW.units: string
# SLCW.data_mode: string
# SLCW.ancillary_variables: string
# SLCW_QC.long_name: string
# SLCW_QC.valid_min: int8
# SLCW_QC.valid_max: int8
# SLCW_QC.flag_meanings: string
# TRIW.long_name: string
# TRIW.units: string
# TRIW.data_mode: string
# TRIW.ancillary_variables: string
# TRIW_QC.long_name: string
# TRIW_QC.valid_min: int8
# TRIW_QC.valid_max: int8
# TRIW_QC.flag_meanings: string
# AMOW: float
# AMOW_QC: float
# AMOW.long_name: string
# AMOW.standard_name: string
# AMOW.units: string
# AMOW.data_mode: string
# AMOW.ancillary_variables: string
# AMOW_QC.long_name: string
# AMOW_QC.valid_min: int8
# AMOW_QC.valid_max: int8
# AMOW_QC.flag_meanings: string
# ALKW: float
# ALKW_QC: float
# NEON: float
# NEON_QC: float
# NTZW: float
# NTZW_QC: float
# ALKW.long_name: string
# ALKW.standard_name: string
# ALKW.units: string
# ALKW.data_mode: string
# ALKW.ancillary_variables: string
# ALKW_QC.long_name: string
# ALKW_QC.valid_min: int8
# ALKW_QC.valid_max: int8
# ALKW_QC.flag_meanings: string
# NEON.long_name: string
# NEON.units: string
# NEON.data_mode: string
# NEON.ancillary_variables: string
# NEON_QC.long_name: string
# NEON_QC.valid_min: int8
# NEON_QC.valid_max: int8
# NEON_QC.flag_meanings: string
# NTZW.long_name: string
# NTZW.standard_name: string
# NTZW.units: string
# NTZW.data_mode: string
# NTZW.ancillary_variables: string
# NTZW_QC.long_name: string
# NTZW_QC.valid_min: int8
# NTZW_QC.valid_max: int8
# NTZW_QC.flag_meanings: string
# HELW: float
# HELW_QC: float
# NEOW: float
# NEOW_QC: float
# HELW.long_name: string
# HELW.units: string
# HELW.data_mode: string
# HELW.ancillary_variables: string
# HELW_QC.long_name: string
# HELW_QC.valid_min: int8
# HELW_QC.valid_max: int8
# HELW_QC.flag_meanings: string
# NEOW.long_name: string
# NEOW.units: string
# NEOW.data_mode: string
# NEOW.ancillary_variables: string
# NEOW_QC.long_name: string
# NEOW_QC.valid_min: int8
# NEOW_QC.valid_max: int8
# NEOW_QC.flag_meanings: string
# O18D: float
# O18D_QC: float
# O18D.long_name: string
# O18D.units: string
# O18D.data_mode: string
# O18D.ancillary_variables: string
# O18D_QC.long_name: string
# O18D_QC.valid_min: int8
# O18D_QC.valid_max: int8
# O18D_QC.flag_meanings: string
# TICW: float
# TICW_QC: float
# TICW.long_name: string
# TICW.standard_name: string
# TICW.units: string
# TICW.data_mode: string
# TICW.ancillary_variables: string
# TICW_QC.long_name: string
# TICW_QC.valid_min: int8
# TICW_QC.valid_max: int8
# TICW_QC.flag_meanings: string
# TPHP: float
# TPHP_QC: float
# TPHP.long_name: string
# TPHP.units: string
# TPHP.data_mode: string
# TPHP.ancillary_variables: string
# TPHP_QC.long_name: string
# TPHP_QC.valid_min: int8
# TPHP_QC.valid_max: int8
# TPHP_QC.flag_meanings: string
# TSMP: float
# TSMP_QC: float
# TSMP.long_name: string
# TSMP.standard_name: string
# TSMP.units: string
# TSMP.data_mode: string
# TSMP.ancillary_variables: string
# TSMP_QC.long_name: string
# TSMP_QC.valid_min: int8
# TSMP_QC.valid_max: int8
# TSMP_QC.flag_meanings: string
# ABCP: float
# ABCP_QC: float
# AXAP: float
# AXAP_QC: float
# BCCW: float
# BCCW_QC: float
# BCHA: float
# BCHA_QC: float
# BFUP: float
# BFUP_QC: float
# CHAD: float
# CHAD_QC: float
# CHBD: float
# CHBD_QC: float
# CHC3: float
# CHC3_QC: float
# CHCZ: float
# CHCZ_QC: float
# CHLB: float
# CHLB_QC: float
# CHLC: float
# CHLC_QC: float
# DXAP: float
# DXAP_QC: float
# FLUO: float
# FLUO_QC: float
# FUCP: float
# FUCP_QC: float
# HFUP: float
# HFUP_QC: float
# LUTW: float
# LUTW_QC: float
# NEXW: float
# NEXW_QC: float
# NNEF: float
# NNEF_QC: float
# PCEW: float
# PCEW_QC: float
# PERP: float
# PERP_QC: float
# PHEA: float
# PHEA_QC: float
# PHEB: float
# PHEB_QC: float
# PHEC: float
# PHEC_QC: float
# PICP: float
# PICP_QC: float
# PRCW: float
# PRCW_QC: float
# PXAP: float
# PXAP_QC: float
# SNCW: float
# SNCW_QC: float
# TXAP: float
# TXAP_QC: float
# VIOW: float
# VIOW_QC: float
# ZXAP: float
# ZXAP_QC: float
# ABCP.long_name: string
# ABCP.units: string
# ABCP.data_mode: string
# ABCP.ancillary_variables: string
# ABCP_QC.long_name: string
# ABCP_QC.valid_min: int8
# ABCP_QC.valid_max: int8
# ABCP_QC.flag_meanings: string
# AXAP.long_name: string
# AXAP.units: string
# AXAP.data_mode: string
# AXAP.ancillary_variables: string
# AXAP_QC.long_name: string
# AXAP_QC.valid_min: int8
# AXAP_QC.valid_max: int8
# AXAP_QC.flag_meanings: string
# BCCW.long_name: string
# BCCW.units: string
# BCCW.data_mode: string
# BCCW.ancillary_variables: string
# BCCW_QC.long_name: string
# BCCW_QC.valid_min: int8
# BCCW_QC.valid_max: int8
# BCCW_QC.flag_meanings: string
# BCHA.long_name: string
# BCHA.units: string
# BCHA.data_mode: string
# BCHA.ancillary_variables: string
# BCHA_QC.long_name: string
# BCHA_QC.valid_min: int8
# BCHA_QC.valid_max: int8
# BCHA_QC.flag_meanings: string
# BFUP.long_name: string
# BFUP.units: string
# BFUP.data_mode: string
# BFUP.ancillary_variables: string
# BFUP_QC.long_name: string
# BFUP_QC.valid_min: int8
# BFUP_QC.valid_max: int8
# BFUP_QC.flag_meanings: string
# CHAD.long_name: string
# CHAD.units: string
# CHAD.data_mode: string
# CHAD.ancillary_variables: string
# CHAD_QC.long_name: string
# CHAD_QC.valid_min: int8
# CHAD_QC.valid_max: int8
# CHAD_QC.flag_meanings: string
# CHBD.long_name: string
# CHBD.units: string
# CHBD.data_mode: string
# CHBD.ancillary_variables: string
# CHBD_QC.long_name: string
# CHBD_QC.valid_min: int8
# CHBD_QC.valid_max: int8
# CHBD_QC.flag_meanings: string
# CHC3.long_name: string
# CHC3.units: string
# CHC3.data_mode: string
# CHC3.ancillary_variables: string
# CHC3_QC.long_name: string
# CHC3_QC.valid_min: int8
# CHC3_QC.valid_max: int8
# CHC3_QC.flag_meanings: string
# CHCZ.long_name: string
# CHCZ.units: string
# CHCZ.data_mode: string
# CHCZ.ancillary_variables: string
# CHCZ_QC.long_name: string
# CHCZ_QC.valid_min: int8
# CHCZ_QC.valid_max: int8
# CHCZ_QC.flag_meanings: string
# CHLB.long_name: string
# CHLB.units: string
# CHLB.data_mode: string
# CHLB.ancillary_variables: string
# CHLB_QC.long_name: string
# CHLB_QC.valid_min: int8
# CHLB_QC.valid_max: int8
# CHLB_QC.flag_meanings: string
# CHLC.long_name: string
# CHLC.units: string
# CHLC.data_mode: string
# CHLC.ancillary_variables: string
# CHLC_QC.long_name: string
# CHLC_QC.valid_min: int8
# CHLC_QC.valid_max: int8
# CHLC_QC.flag_meanings: string
# DXAP.long_name: string
# DXAP.units: string
# DXAP.data_mode: string
# DXAP.ancillary_variables: string
# DXAP_QC.long_name: string
# DXAP_QC.valid_min: int8
# DXAP_QC.valid_max: int8
# DXAP_QC.flag_meanings: string
# FLUO.long_name: string
# FLUO.units: string
# FLUO.data_mode: string
# FLUO.ancillary_variables: string
# FLUO_QC.long_name: string
# FLUO_QC.valid_min: int8
# FLUO_QC.valid_max: int8
# FLUO_QC.flag_meanings: string
# FUCP.long_name: string
# FUCP.units: string
# FUCP.data_mode: string
# FUCP.ancillary_variables: string
# FUCP_QC.long_name: string
# FUCP_QC.valid_min: int8
# FUCP_QC.valid_max: int8
# FUCP_QC.flag_meanings: string
# HFUP.long_name: string
# HFUP.units: string
# HFUP.data_mode: string
# HFUP.ancillary_variables: string
# HFUP_QC.long_name: string
# HFUP_QC.valid_min: int8
# HFUP_QC.valid_max: int8
# HFUP_QC.flag_meanings: string
# LUTW.long_name: string
# LUTW.units: string
# LUTW.data_mode: string
# LUTW.ancillary_variables: string
# LUTW_QC.long_name: string
# LUTW_QC.valid_min: int8
# LUTW_QC.valid_max: int8
# LUTW_QC.flag_meanings: string
# NEXW.long_name: string
# NEXW.units: string
# NEXW.data_mode: string
# NEXW.ancillary_variables: string
# NEXW_QC.long_name: string
# NEXW_QC.valid_min: int8
# NEXW_QC.valid_max: int8
# NEXW_QC.flag_meanings: string
# NNEF.long_name: string
# NNEF.units: string
# NNEF.data_mode: string
# NNEF.ancillary_variables: string
# NNEF_QC.long_name: string
# NNEF_QC.valid_min: int8
# NNEF_QC.valid_max: int8
# NNEF_QC.flag_meanings: string
# PCEW.long_name: string
# PCEW.units: string
# PCEW.data_mode: string
# PCEW.ancillary_variables: string
# PCEW_QC.long_name: string
# PCEW_QC.valid_min: int8
# PCEW_QC.valid_max: int8
# PCEW_QC.flag_meanings: string
# PERP.long_name: string
# PERP.units: string
# PERP.data_mode: string
# PERP.ancillary_variables: string
# PERP_QC.long_name: string
# PERP_QC.valid_min: int8
# PERP_QC.valid_max: int8
# PERP_QC.flag_meanings: string
# PHEA.long_name: string
# PHEA.units: string
# PHEA.data_mode: string
# PHEA.ancillary_variables: string
# PHEA_QC.long_name: string
# PHEA_QC.valid_min: int8
# PHEA_QC.valid_max: int8
# PHEA_QC.flag_meanings: string
# PHEB.long_name: string
# PHEB.units: string
# PHEB.data_mode: string
# PHEB.ancillary_variables: string
# PHEB_QC.long_name: string
# PHEB_QC.valid_min: int8
# PHEB_QC.valid_max: int8
# PHEB_QC.flag_meanings: string
# PHEC.long_name: string
# PHEC.units: string
# PHEC.data_mode: string
# PHEC.ancillary_variables: string
# PHEC_QC.long_name: string
# PHEC_QC.valid_min: int8
# PHEC_QC.valid_max: int8
# PHEC_QC.flag_meanings: string
# PICP.long_name: string
# PICP.units: string
# PICP.data_mode: string
# PICP.ancillary_variables: string
# PICP_QC.long_name: string
# PICP_QC.valid_min: int8
# PICP_QC.valid_max: int8
# PICP_QC.flag_meanings: string
# PRCW.long_name: string
# PRCW.units: string
# PRCW.data_mode: string
# PRCW.ancillary_variables: string
# PRCW_QC.long_name: string
# PRCW_QC.valid_min: int8
# PRCW_QC.valid_max: int8
# PRCW_QC.flag_meanings: string
# PXAP.long_name: string
# PXAP.units: string
# PXAP.data_mode: string
# PXAP.ancillary_variables: string
# PXAP_QC.long_name: string
# PXAP_QC.valid_min: int8
# PXAP_QC.valid_max: int8
# PXAP_QC.flag_meanings: string
# SNCW.long_name: string
# SNCW.units: string
# SNCW.data_mode: string
# SNCW.ancillary_variables: string
# SNCW_QC.long_name: string
# SNCW_QC.valid_min: int8
# SNCW_QC.valid_max: int8
# SNCW_QC.flag_meanings: string
# TXAP.long_name: string
# TXAP.units: string
# TXAP.data_mode: string
# TXAP.ancillary_variables: string
# TXAP_QC.long_name: string
# TXAP_QC.valid_min: int8
# TXAP_QC.valid_max: int8
# TXAP_QC.flag_meanings: string
# VIOW.long_name: string
# VIOW.units: string
# VIOW.data_mode: string
# VIOW.ancillary_variables: string
# VIOW_QC.long_name: string
# VIOW_QC.valid_min: int8
# VIOW_QC.valid_max: int8
# VIOW_QC.flag_meanings: string
# ZXAP.long_name: string
# ZXAP.units: string
# ZXAP.data_mode: string
# ZXAP.ancillary_variables: string
# ZXAP_QC.long_name: string
# ZXAP_QC.valid_min: int8
# ZXAP_QC.valid_max: int8
# ZXAP_QC.flag_meanings: string
# ANXW: float
# ANXW_QC: float
# CH1P: float
# CH1P_QC: float
# CH2P: float
# CH2P_QC: float
# CPH2: float
# CPH2_QC: float
# CPH4: float
# CPH4_QC: float
# CPH6: float
# CPH6_QC: float
# CPH7: float
# CPH7_QC: float
# CYAF: float
# CYAF_QC: float
# HBAW: float
# HBAW_QC: float
# NFCW: float
# NFCW_QC: float
# NPKF: float
# NPKF_QC: float
# PCEF: float
# PCEF_QC: float
# PHE2: float
# PHE2_QC: float
# PHE4: float
# PHE4_QC: float
# PPKF: float
# PPKF_QC: float
# PRCF: float
# PRCF_QC: float
# SNCF: float
# SNCF_QC: float
# ANXW.long_name: string
# ANXW.units: string
# ANXW.data_mode: string
# ANXW.ancillary_variables: string
# ANXW_QC.long_name: string
# ANXW_QC.valid_min: int8
# ANXW_QC.valid_max: int8
# ANXW_QC.flag_meanings: string
# CH1P.long_name: string
# CH1P.units: string
# CH1P.data_mode: string
# CH1P.ancillary_variables: string
# CH1P_QC.long_name: string
# CH1P_QC.valid_min: int8
# CH1P_QC.valid_max: int8
# CH1P_QC.flag_meanings: string
# CH2P.long_name: string
# CH2P.units: string
# CH2P.data_mode: string
# CH2P.ancillary_variables: string
# CH2P_QC.long_name: string
# CH2P_QC.valid_min: int8
# CH2P_QC.valid_max: int8
# CH2P_QC.flag_meanings: string
# CPH2.long_name: string
# CPH2.units: string
# CPH2.data_mode: string
# CPH2.ancillary_variables: string
# CPH2_QC.long_name: string
# CPH2_QC.valid_min: int8
# CPH2_QC.valid_max: int8
# CPH2_QC.flag_meanings: string
# CPH4.long_name: string
# CPH4.units: string
# CPH4.data_mode: string
# CPH4.ancillary_variables: string
# CPH4_QC.long_name: string
# CPH4_QC.valid_min: int8
# CPH4_QC.valid_max: int8
# CPH4_QC.flag_meanings: string
# CPH6.long_name: string
# CPH6.units: string
# CPH6.data_mode: string
# CPH6.ancillary_variables: string
# CPH6_QC.long_name: string
# CPH6_QC.valid_min: int8
# CPH6_QC.valid_max: int8
# CPH6_QC.flag_meanings: string
# CPH7.long_name: string
# CPH7.units: string
# CPH7.data_mode: string
# CPH7.ancillary_variables: string
# CPH7_QC.long_name: string
# CPH7_QC.valid_min: int8
# CPH7_QC.valid_max: int8
# CPH7_QC.flag_meanings: string
# CYAF.long_name: string
# CYAF.units: string
# CYAF.data_mode: string
# CYAF.ancillary_variables: string
# CYAF_QC.long_name: string
# CYAF_QC.valid_min: int8
# CYAF_QC.valid_max: int8
# CYAF_QC.flag_meanings: string
# HBAW.long_name: string
# HBAW.units: string
# HBAW.data_mode: string
# HBAW.ancillary_variables: string
# HBAW_QC.long_name: string
# HBAW_QC.valid_min: int8
# HBAW_QC.valid_max: int8
# HBAW_QC.flag_meanings: string
# NFCW.long_name: string
# NFCW.units: string
# NFCW.data_mode: string
# NFCW.ancillary_variables: string
# NFCW_QC.long_name: string
# NFCW_QC.valid_min: int8
# NFCW_QC.valid_max: int8
# NFCW_QC.flag_meanings: string
# NPKF.long_name: string
# NPKF.units: string
# NPKF.data_mode: string
# NPKF.ancillary_variables: string
# NPKF_QC.long_name: string
# NPKF_QC.valid_min: int8
# NPKF_QC.valid_max: int8
# NPKF_QC.flag_meanings: string
# PCEF.long_name: string
# PCEF.units: string
# PCEF.data_mode: string
# PCEF.ancillary_variables: string
# PCEF_QC.long_name: string
# PCEF_QC.valid_min: int8
# PCEF_QC.valid_max: int8
# PCEF_QC.flag_meanings: string
# PHE2.long_name: string
# PHE2.units: string
# PHE2.data_mode: string
# PHE2.ancillary_variables: string
# PHE2_QC.long_name: string
# PHE2_QC.valid_min: int8
# PHE2_QC.valid_max: int8
# PHE2_QC.flag_meanings: string
# PHE4.long_name: string
# PHE4.units: string
# PHE4.data_mode: string
# PHE4.ancillary_variables: string
# PHE4_QC.long_name: string
# PHE4_QC.valid_min: int8
# PHE4_QC.valid_max: int8
# PHE4_QC.flag_meanings: string
# PPKF.long_name: string
# PPKF.units: string
# PPKF.data_mode: string
# PPKF.ancillary_variables: string
# PPKF_QC.long_name: string
# PPKF_QC.valid_min: int8
# PPKF_QC.valid_max: int8
# PPKF_QC.flag_meanings: string
# PRCF.long_name: string
# PRCF.units: string
# PRCF.data_mode: string
# PRCF.ancillary_variables: string
# PRCF_QC.long_name: string
# PRCF_QC.valid_min: int8
# PRCF_QC.valid_max: int8
# PRCF_QC.flag_meanings: string
# SNCF.long_name: string
# SNCF.units: string
# SNCF.data_mode: string
# SNCF.ancillary_variables: string
# SNCF_QC.long_name: string
# SNCF_QC.valid_min: int8
# SNCF_QC.valid_max: int8
# SNCF_QC.flag_meanings: string
# FCO2: float
# FCO2_QC: float
# FCO2.long_name: string
# FCO2.standard_name: string
# FCO2.units: string
# FCO2.data_mode: string
# FCO2.ancillary_variables: string
# FCO2_QC.long_name: string
# FCO2_QC.valid_min: int8
# FCO2_QC.valid_max: int8
# FCO2_QC.flag_meanings: string
# COPP: float
# COPP_QC: float
# TPAW: float
# TPAW_QC: float
# COPP.long_name: string
# COPP.units: string
# COPP.data_mode: string
# COPP.ancillary_variables: string
# COPP_QC.long_name: string
# COPP_QC.valid_min: int8
# COPP_QC.valid_max: int8
# COPP_QC.flag_meanings: string
# TPAW.long_name: string
# TPAW.units: string
# TPAW.data_mode: string
# TPAW.ancillary_variables: string
# TPAW_QC.long_name: string
# TPAW_QC.valid_min: int8
# TPAW_QC.valid_max: int8
# TPAW_QC.flag_meanings: string
# ARGN: float
# ARGN_QC: float
# CH1T: float
# CH1T_QC: float
# IC13: float
# IC13_QC: float
# ARGN.long_name: string
# ARGN.units: string
# ARGN.data_mode: string
# ARGN.ancillary_variables: string
# ARGN_QC.long_name: string
# ARGN_QC.valid_min: int8
# ARGN_QC.valid_max: int8
# ARGN_QC.flag_meanings: string
# CH1T.long_name: string
# CH1T.units: string
# CH1T.data_mode: string
# CH1T.ancillary_variables: string
# CH1T_QC.long_name: string
# CH1T_QC.valid_min: int8
# CH1T_QC.valid_max: int8
# CH1T_QC.flag_meanings: string
# IC13.long_name: string
# IC13.units: string
# IC13.data_mode: string
# IC13.ancillary_variables: string
# IC13_QC.long_name: string
# IC13_QC.valid_min: int8
# IC13_QC.valid_max: int8
# IC13_QC.flag_meanings: string
# AACP: float
# AACP_QC: float
# BBCP: float
# BBCP_QC: float
# CPH3: float
# CPH3_QC: float
# CPH5: float
# CPH5_QC: float
# DEEX: float
# DEEX_QC: float
# O18E: float
# O18E_QC: float
# OXDE: float
# OXDE_QC: float
# PHE3: float
# PHE3_QC: float
# PHE5: float
# PHE5_QC: float
# PHE6: float
# PHE6_QC: float
# AACP.long_name: string
# AACP.units: string
# AACP.data_mode: string
# AACP.ancillary_variables: string
# AACP_QC.long_name: string
# AACP_QC.valid_min: int8
# AACP_QC.valid_max: int8
# AACP_QC.flag_meanings: string
# BBCP.long_name: string
# BBCP.units: string
# BBCP.data_mode: string
# BBCP.ancillary_variables: string
# BBCP_QC.long_name: string
# BBCP_QC.valid_min: int8
# BBCP_QC.valid_max: int8
# BBCP_QC.flag_meanings: string
# CPH3.long_name: string
# CPH3.units: string
# CPH3.data_mode: string
# CPH3.ancillary_variables: string
# CPH3_QC.long_name: string
# CPH3_QC.valid_min: int8
# CPH3_QC.valid_max: int8
# CPH3_QC.flag_meanings: string
# CPH5.long_name: string
# CPH5.units: string
# CPH5.data_mode: string
# CPH5.ancillary_variables: string
# CPH5_QC.long_name: string
# CPH5_QC.valid_min: int8
# CPH5_QC.valid_max: int8
# CPH5_QC.flag_meanings: string
# DEEX.long_name: string
# DEEX.units: string
# DEEX.data_mode: string
# DEEX.ancillary_variables: string
# DEEX_QC.long_name: string
# DEEX_QC.valid_min: int8
# DEEX_QC.valid_max: int8
# DEEX_QC.flag_meanings: string
# O18E.long_name: string
# O18E.units: string
# O18E.data_mode: string
# O18E.ancillary_variables: string
# O18E_QC.long_name: string
# O18E_QC.valid_min: int8
# O18E_QC.valid_max: int8
# O18E_QC.flag_meanings: string
# OXDE.long_name: string
# OXDE.units: string
# OXDE.data_mode: string
# OXDE.ancillary_variables: string
# OXDE_QC.long_name: string
# OXDE_QC.valid_min: int8
# OXDE_QC.valid_max: int8
# OXDE_QC.flag_meanings: string
# PHE3.long_name: string
# PHE3.units: string
# PHE3.data_mode: string
# PHE3.ancillary_variables: string
# PHE3_QC.long_name: string
# PHE3_QC.valid_min: int8
# PHE3_QC.valid_max: int8
# PHE3_QC.flag_meanings: string
# PHE5.long_name: string
# PHE5.units: string
# PHE5.data_mode: string
# PHE5.ancillary_variables: string
# PHE5_QC.long_name: string
# PHE5_QC.valid_min: int8
# PHE5_QC.valid_max: int8
# PHE5_QC.flag_meanings: string
# PHE6.long_name: string
# PHE6.units: string
# PHE6.data_mode: string
# PHE6.ancillary_variables: string
# PHE6_QC.long_name: string
# PHE6_QC.valid_min: int8
# PHE6_QC.valid_max: int8
# PHE6_QC.flag_meanings: string
# MAGP: float
# MAGP_QC: float
# MAGW: float
# MAGW_QC: float
# MCDW: float
# MCDW_QC: float
# MCOW: float
# MCOW_QC: float
# MCU2: float
# MCU2_QC: float
# MNI2: float
# MNI2_QC: float
# MPBW: float
# MPBW_QC: float
# MZNW: float
# MZNW_QC: float
# MAGP.long_name: string
# MAGP.units: string
# MAGP.data_mode: string
# MAGP.ancillary_variables: string
# MAGP_QC.long_name: string
# MAGP_QC.valid_min: int8
# MAGP_QC.valid_max: int8
# MAGP_QC.flag_meanings: string
# MAGW.long_name: string
# MAGW.units: string
# MAGW.data_mode: string
# MAGW.ancillary_variables: string
# MAGW_QC.long_name: string
# MAGW_QC.valid_min: int8
# MAGW_QC.valid_max: int8
# MAGW_QC.flag_meanings: string
# MCDW.long_name: string
# MCDW.units: string
# MCDW.data_mode: string
# MCDW.ancillary_variables: string
# MCDW_QC.long_name: string
# MCDW_QC.valid_min: int8
# MCDW_QC.valid_max: int8
# MCDW_QC.flag_meanings: string
# MCOW.long_name: string
# MCOW.units: string
# MCOW.data_mode: string
# MCOW.ancillary_variables: string
# MCOW_QC.long_name: string
# MCOW_QC.valid_min: int8
# MCOW_QC.valid_max: int8
# MCOW_QC.flag_meanings: string
# MCU2.long_name: string
# MCU2.units: string
# MCU2.data_mode: string
# MCU2.ancillary_variables: string
# MCU2_QC.long_name: string
# MCU2_QC.valid_min: int8
# MCU2_QC.valid_max: int8
# MCU2_QC.flag_meanings: string
# MNI2.long_name: string
# MNI2.units: string
# MNI2.data_mode: string
# MNI2.ancillary_variables: string
# MNI2_QC.long_name: string
# MNI2_QC.valid_min: int8
# MNI2_QC.valid_max: int8
# MNI2_QC.flag_meanings: string
# MPBW.long_name: string
# MPBW.units: string
# MPBW.data_mode: string
# MPBW.ancillary_variables: string
# MPBW_QC.long_name: string
# MPBW_QC.valid_min: int8
# MPBW_QC.valid_max: int8
# MPBW_QC.flag_meanings: string
# MZNW.long_name: string
# MZNW.units: string
# MZNW.data_mode: string
# MZNW.ancillary_variables: string
# MZNW_QC.long_name: string
# MZNW_QC.valid_min: int8
# MZNW_QC.valid_max: int8
# MZNW_QC.flag_meanings: string
# FESP: float
# FESP_QC: float
# MNSP: float
# MNSP_QC: float
# PHSP: float
# PHSP_QC: float
# TUR3: float
# TUR3_QC: float
# FESP.long_name: string
# FESP.units: string
# FESP.data_mode: string
# FESP.ancillary_variables: string
# FESP_QC.long_name: string
# FESP_QC.valid_min: int8
# FESP_QC.valid_max: int8
# FESP_QC.flag_meanings: string
# MNSP.long_name: string
# MNSP.units: string
# MNSP.data_mode: string
# MNSP.ancillary_variables: string
# MNSP_QC.long_name: string
# MNSP_QC.valid_min: int8
# MNSP_QC.valid_max: int8
# MNSP_QC.flag_meanings: string
# PHSP.long_name: string
# PHSP.units: string
# PHSP.data_mode: string
# PHSP.ancillary_variables: string
# PHSP_QC.long_name: string
# PHSP_QC.valid_min: int8
# PHSP_QC.valid_max: int8
# PHSP_QC.flag_meanings: string
# TUR3.long_name: string
# TUR3.units: string
# TUR3.data_mode: string
# TUR3.ancillary_variables: string
# TUR3_QC.long_name: string
# TUR3_QC.valid_min: int8
# TUR3_QC.valid_max: int8
# TUR3_QC.flag_meanings: string
# SSAL: float
# SSAL_QC: float
# SSAL.long_name: string
# SSAL.units: string
# SSAL.data_mode: string
# SSAL.ancillary_variables: string
# SSAL_QC.long_name: string
# SSAL_QC.valid_min: int8
# SSAL_QC.valid_max: int8
# SSAL_QC.flag_meanings: string
# PHEP: float
# PHEP_QC: float
# PHEP.long_name: string
# PHEP.units: string
# PHEP.data_mode: string
# PHEP.ancillary_variables: string
# PHEP_QC.long_name: string
# PHEP_QC.valid_min: int8
# PHEP_QC.valid_max: int8
# PHEP_QC.flag_meanings: string
# DINW: float
# DINW_QC: float
# GYRW: float
# GYRW_QC: float
# DINW.long_name: string
# DINW.units: string
# DINW.data_mode: string
# DINW.ancillary_variables: string
# DINW_QC.long_name: string
# DINW_QC.valid_min: int8
# DINW_QC.valid_max: int8
# DINW_QC.flag_meanings: string
# GYRW.long_name: string
# GYRW.units: string
# GYRW.data_mode: string
# GYRW.ancillary_variables: string
# GYRW_QC.long_name: string
# GYRW_QC.valid_min: int8
# GYRW_QC.valid_max: int8
# GYRW_QC.flag_meanings: string
# DEPH.long_name: string
# DEPH.standard_name: string
# DEPH.units: string
# DEPH.valid_min: float
# DEPH.valid_max: float
# DEPH.uncertainty: string
# DEPH.reference: string
# DEPH.data_mode: string
# DEPH.ancillary_variables: string
# ...
# TURFNU_QC.valid_min: int8
# TURFNU_QC.valid_max: int8
# TURFNU_QC.flag_meanings: string
# DEPH_DM: string
# ATMP_DM: string
# CHLT_DM: string
# DRYT_DM: string
# GSPD_DM: string
# OSAT_DM: string
# PHPH_DM: string
# TURFNU_DM: string
# WDIR_DM: string
# WSPD_DM: string
# DEPH_DM.long_name: string
# DEPH_DM.flag_values: string
# DEPH_DM.flag_meanings: string
# ATMP_DM.long_name: string
# ATMP_DM.flag_values: string
# ATMP_DM.flag_meanings: string
# CHLT_DM.long_name: string
# CHLT_DM.flag_values: string
# CHLT_DM.flag_meanings: string
# DRYT_DM.long_name: string
# DRYT_DM.flag_values: string
# DRYT_DM.flag_meanings: string
# GSPD_DM.long_name: string
# GSPD_DM.flag_values: string
# GSPD_DM.flag_meanings: string
# OSAT_DM.long_name: string
# OSAT_DM.flag_values: string
# OSAT_DM.flag_meanings: string
# PHPH_DM.long_name: string
# PHPH_DM.flag_values: string
# PHPH_DM.flag_meanings: string
# TURFNU_DM.long_name: string
# TURFNU_DM.flag_values: string
# TURFNU_DM.flag_meanings: string
# WDIR_DM.long_name: string
# WDIR_DM.flag_values: string
# WDIR_DM.flag_meanings: string
# WSPD_DM.long_name: string
# WSPD_DM.flag_values: string
# WSPD_DM.flag_meanings: string
# DEWT: float
# DEWT_QC: float
# DEWT.long_name: string
# DEWT.standard_name: string
# DEWT.units: string
# DEWT.data_mode: string
# DEWT.ancillary_variables: string
# DEWT_QC.long_name: string
# DEWT_QC.valid_min: int8
# DEWT_QC.valid_max: int8
# DEWT_QC.flag_meanings: string
# VTM02: float
# VTM02_QC: float
# VTM02.type_of_analysis: string
# VTM02.long_name: string
# VTM02.standard_name: string
# VTM02.units: string
# VTM02.data_mode: string
# VTM02.ancillary_variables: string
# VTM02_QC.long_name: string
# VTM02_QC.valid_min: int8
# VTM02_QC.valid_max: int8
# VTM02_QC.flag_meanings: string
# DEWT_DM: string
# DEWT_DM.long_name: string
# DEWT_DM.flag_values: string
# DEWT_DM.flag_meanings: string
# ALTS: float
# ALTS_QC: float
# FLU3: float
# FLU3_QC: float
# GDIR: float
# GDIR_QC: float
# PRRD: float
# PRRD_QC: float
# VH110: float
# VH110_QC: float
# VPED: float
# VPED_QC: float
# ALTS.long_name: string
# ALTS.standard_name: string
# ALTS.units: string
# ALTS.data_mode: string
# ALTS.ancillary_variables: string
# ALTS_QC.long_name: string
# ALTS_QC.valid_min: int8
# ALTS_QC.valid_max: int8
# ALTS_QC.flag_meanings: string
# FLU3.long_name: string
# FLU3.units: string
# FLU3.data_mode: string
# FLU3.ancillary_variables: string
# FLU3_QC.long_name: string
# FLU3_QC.valid_min: int8
# FLU3_QC.valid_max: int8
# FLU3_QC.flag_meanings: string
# GDIR.long_name: string
# GDIR.standard_name: string
# GDIR.units: string
# GDIR.data_mode: string
# GDIR.ancillary_variables: string
# GDIR_QC.long_name: string
# GDIR_QC.valid_min: int8
# GDIR_QC.valid_max: int8
# GDIR_QC.flag_meanings: string
# PRRD.long_name: string
# PRRD.standard_name: string
# PRRD.units: string
# PRRD.data_mode: string
# PRRD.ancillary_variables: string
# PRRD_QC.long_name: string
# PRRD_QC.valid_min: int8
# PRRD_QC.valid_max: int8
# PRRD_QC.flag_meanings: string
# VH110.type_of_analysis: string
# VH110.long_name: string
# VH110.standard_name: string
# VH110.units: string
# VH110.data_mode: string
# VH110.ancillary_variables: string
# VH110_QC.long_name: string
# VH110_QC.valid_min: int8
# VH110_QC.valid_max: int8
# VH110_QC.flag_meanings: string
# VPED.type_of_analysis: string
# VPED.long_name: string
# VPED.standard_name: string
# VPED.units: string
# VPED.data_mode: string
# VPED.ancillary_variables: string
# VPED_QC.long_name: string
# VPED_QC.valid_min: int8
# VPED_QC.valid_max: int8
# VPED_QC.flag_meanings: string
# VDIR: float
# VDIR_QC: float
# VGHS: float
# VGHS_QC: float
# VGTA: float
# VGTA_QC: float
# VDIR.type_of_analysis: string
# VDIR.long_name: string
# VDIR.standard_name: string
# VDIR.units: string
# VDIR.data_mode: string
# VDIR.ancillary_variables: string
# VDIR_QC.long_name: string
# VDIR_QC.valid_min: int8
# VDIR_QC.valid_max: int8
# VDIR_QC.flag_meanings: string
# VGHS.type_of_analysis: string
# VGHS.long_name: string
# VGHS.standard_name: string
# VGHS.units: string
# VGHS.data_mode: string
# VGHS.ancillary_variables: string
# VGHS_QC.long_name: string
# VGHS_QC.valid_min: int8
# VGHS_QC.valid_max: int8
# VGHS_QC.flag_meanings: string
# VGTA.type_of_analysis: string
# VGTA.long_name: string
# VGTA.standard_name: string
# VGTA.units: string
# VGTA.data_mode: string
# VGTA.ancillary_variables: string
# VGTA_QC.long_name: string
# VGTA_QC.valid_min: int8
# VGTA_QC.valid_max: int8
# VGTA_QC.flag_meanings: string
# ESTUARY_CUR: float
# ESTUARY_CUR_QC: float
# ESTUARY_CUR.long_name: string
# ESTUARY_CUR.units: string
# ESTUARY_CUR.data_mode: string
# ESTUARY_CUR.ancillary_variables: string
# ESTUARY_CUR_QC.long_name: string
# ESTUARY_CUR_QC.valid_min: int8
# ESTUARY_CUR_QC.valid_max: int8
# ESTUARY_CUR_QC.flag_meanings: string
# VCSP: float
# VCSP_QC: float
# VCSP.long_name: string
# VCSP.standard_name: string
# VCSP.units: string
# VCSP.data_mode: string
# VCSP.ancillary_variables: string
# VCSP_QC.long_name: string
# VCSP_QC.valid_min: int8
# VCSP_QC.valid_max: int8
# VCSP_QC.flag_meanings: string
# LGH4_ADJUSTED: float
# LGH4_ADJUSTED_QC: float
# LGH4_ADJUSTED.long_name: string
# LGH4_ADJUSTED.standard_name: string
# LGH4_ADJUSTED.units: string
# LGH4_ADJUSTED.data_mode: string
# LGH4_ADJUSTED.ancillary_variables: string
# LGH4_ADJUSTED_QC.long_name: string
# LGH4_ADJUSTED_QC.valid_min: int8
# LGH4_ADJUSTED_QC.valid_max: int8
# LGH4_ADJUSTED_QC.flag_meanings: string
# IRON: float
# IRON_QC: float
# IRON.long_name: string
# IRON.units: string
# IRON.data_mode: string
# IRON.ancillary_variables: string
# IRON_QC.long_name: string
# IRON_QC.valid_min: int8
# IRON_QC.valid_max: int8
# IRON_QC.flag_meanings: string
# NLIN: float
# NLIN_QC: float
# NSIN: float
# NSIN_QC: float
# VHZA: float
# VHZA_QC: float
# VZMX: float
# VZMX_QC: float
# NLIN.long_name: string
# NLIN.standard_name: string
# NLIN.units: string
# NLIN.data_mode: string
# NLIN.ancillary_variables: string
# NLIN_QC.long_name: string
# NLIN_QC.valid_min: int8
# NLIN_QC.valid_max: int8
# NLIN_QC.flag_meanings: string
# NSIN.long_name: string
# NSIN.standard_name: string
# NSIN.units: string
# NSIN.data_mode: string
# NSIN.ancillary_variables: string
# NSIN_QC.long_name: string
# NSIN_QC.valid_min: int8
# NSIN_QC.valid_max: int8
# NSIN_QC.flag_meanings: string
# VHZA.type_of_analysis: string
# VHZA.long_name: string
# VHZA.standard_name: string
# VHZA.units: string
# VHZA.data_mode: string
# VHZA.ancillary_variables: string
# VHZA_QC.long_name: string
# VHZA_QC.valid_min: int8
# VHZA_QC.valid_max: int8
# VHZA_QC.flag_meanings: string
# VZMX.type_of_analysis: string
# VZMX.long_name: string
# VZMX.standard_name: string
# VZMX.units: string
# VZMX.data_mode: string
# VZMX.ancillary_variables: string
# VZMX_QC.long_name: string
# VZMX_QC.valid_min: int8
# VZMX_QC.valid_max: int8
# VZMX_QC.flag_meanings: string
# TEMP_CO2_ADJUSTED: float
# TEMP_CO2_ADJUSTED_QC: float
# DOX1_ADJUSTED: float
# DOX1_ADJUSTED_QC: float
# FCO2_ADJUSTED: float
# FCO2_ADJUSTED_QC: float
# FLU3_ADJUSTED: float
# FLU3_ADJUSTED_QC: float
# TEMP_CO2_ADJUSTED.long_name: string
# TEMP_CO2_ADJUSTED.units: string
# TEMP_CO2_ADJUSTED.data_mode: string
# TEMP_CO2_ADJUSTED.ancillary_variables: string
# TEMP_CO2_ADJUSTED_QC.long_name: string
# TEMP_CO2_ADJUSTED_QC.valid_min: int8
# TEMP_CO2_ADJUSTED_QC.valid_max: int8
# TEMP_CO2_ADJUSTED_QC.flag_meanings: string
# DOX1_ADJUSTED.long_name: string
# DOX1_ADJUSTED.standard_name: string
# DOX1_ADJUSTED.units: string
# DOX1_ADJUSTED.data_mode: string
# DOX1_ADJUSTED.ancillary_variables: string
# DOX1_ADJUSTED_QC.long_name: string
# DOX1_ADJUSTED_QC.valid_min: int8
# DOX1_ADJUSTED_QC.valid_max: int8
# DOX1_ADJUSTED_QC.flag_meanings: string
# FCO2_ADJUSTED.long_name: string
# FCO2_ADJUSTED.standard_name: string
# FCO2_ADJUSTED.units: string
# FCO2_ADJUSTED.data_mode: string
# FCO2_ADJUSTED.ancillary_variables: string
# FCO2_ADJUSTED_QC.long_name: string
# FCO2_ADJUSTED_QC.valid_min: int8
# FCO2_ADJUSTED_QC.valid_max: int8
# FCO2_ADJUSTED_QC.flag_meanings: string
# FLU3_ADJUSTED.long_name: string
# FLU3_ADJUSTED.units: string
# FLU3_ADJUSTED.data_mode: string
# FLU3_ADJUSTED.ancillary_variables: string
# FLU3_ADJUSTED_QC.long_name: string
# FLU3_ADJUSTED_QC.valid_min: int8
# FLU3_ADJUSTED_QC.valid_max: int8
# FLU3_ADJUSTED_QC.flag_meanings: string
# TUR4_ADJUSTED: float
# TUR4_ADJUSTED_QC: float
# TUR4_ADJUSTED.long_name: string
# TUR4_ADJUSTED.standard_name: string
# TUR4_ADJUSTED.units: string
# TUR4_ADJUSTED.data_mode: string
# TUR4_ADJUSTED.ancillary_variables: string
# TUR4_ADJUSTED_QC.long_name: string
# TUR4_ADJUSTED_QC.valid_min: int8
# TUR4_ADJUSTED_QC.valid_max: int8
# TUR4_ADJUSTED_QC.flag_meanings: string
# ACO2: float
# ACO2_QC: float
# DOWN_IRRADIANCE510: float
# DOWN_IRRADIANCE510_QC: float
# DOWN_IRRADIANCE620: float
# DOWN_IRRADIANCE620_QC: float
# DOWN_IRRADIANCE683: float
# DOWN_IRRADIANCE683_QC: float
# LINC: float
# LINC_QC: float
# PRRT: float
# PRRT_QC: float
# PSST: float
# PSST_QC: float
# SINC: float
# SINC_QC: float
# VCMX: float
# VCMX_QC: float
# WSPE: float
# WSPE_QC: float
# WSPN: float
# WSPN_QC: float
# ACO2.long_name: string
# ACO2.standard_name: string
# ACO2.units: string
# ACO2.data_mode: string
# ACO2.ancillary_variables: string
# ACO2_QC.long_name: string
# ACO2_QC.valid_min: int8
# ACO2_QC.valid_max: int8
# ACO2_QC.flag_meanings: string
# DOWN_IRRADIANCE510.long_name: string
# DOWN_IRRADIANCE510.units: string
# DOWN_IRRADIANCE510.data_mode: string
# DOWN_IRRADIANCE510.ancillary_variables: string
# DOWN_IRRADIANCE510_QC.long_name: string
# DOWN_IRRADIANCE510_QC.valid_min: int8
# DOWN_IRRADIANCE510_QC.valid_max: int8
# DOWN_IRRADIANCE510_QC.flag_meanings: string
# DOWN_IRRADIANCE620.long_name: string
# DOWN_IRRADIANCE620.units: string
# DOWN_IRRADIANCE620.data_mode: string
# DOWN_IRRADIANCE620.ancillary_variables: string
# DOWN_IRRADIANCE620_QC.long_name: string
# DOWN_IRRADIANCE620_QC.valid_min: int8
# DOWN_IRRADIANCE620_QC.valid_max: int8
# DOWN_IRRADIANCE620_QC.flag_meanings: string
# DOWN_IRRADIANCE683.long_name: string
# DOWN_IRRADIANCE683.units: string
# DOWN_IRRADIANCE683.data_mode: string
# DOWN_IRRADIANCE683.ancillary_variables: string
# DOWN_IRRADIANCE683_QC.long_name: string
# DOWN_IRRADIANCE683_QC.valid_min: int8
# DOWN_IRRADIANCE683_QC.valid_max: int8
# DOWN_IRRADIANCE683_QC.flag_meanings: string
# LINC.long_name: string
# LINC.standard_name: string
# LINC.units: string
# LINC.data_mode: string
# LINC.ancillary_variables: string
# LINC_QC.long_name: string
# LINC_QC.valid_min: int8
# LINC_QC.valid_max: int8
# LINC_QC.flag_meanings: string
# PRRT.long_name: string
# PRRT.standard_name: string
# PRRT.units: string
# PRRT.data_mode: string
# PRRT.ancillary_variables: string
# PRRT_QC.long_name: string
# PRRT_QC.valid_min: int8
# PRRT_QC.valid_max: int8
# PRRT_QC.flag_meanings: string
# PSST.long_name: string
# PSST.standard_name: string
# PSST.units: string
# PSST.data_mode: string
# PSST.ancillary_variables: string
# PSST_QC.long_name: string
# PSST_QC.valid_min: int8
# PSST_QC.valid_max: int8
# PSST_QC.flag_meanings: string
# SINC.long_name: string
# SINC.standard_name: string
# SINC.units: string
# SINC.data_mode: string
# SINC.ancillary_variables: string
# SINC_QC.long_name: string
# SINC_QC.valid_min: int8
# SINC_QC.valid_max: int8
# SINC_QC.flag_meanings: string
# VCMX.type_of_analysis: string
# VCMX.long_name: string
# VCMX.standard_name: string
# VCMX.units: string
# VCMX.data_mode: string
# VCMX.ancillary_variables: string
# VCMX_QC.long_name: string
# VCMX_QC.valid_min: int8
# VCMX_QC.valid_max: int8
# VCMX_QC.flag_meanings: string
# WSPE.long_name: string
# WSPE.standard_name: string
# WSPE.units: string
# WSPE.data_mode: string
# WSPE.ancillary_variables: string
# WSPE_QC.long_name: string
# WSPE_QC.valid_min: int8
# WSPE_QC.valid_max: int8
# WSPE_QC.flag_meanings: string
# WSPN.long_name: string
# WSPN.standard_name: string
# WSPN.units: string
# WSPN.data_mode: string
# WSPN.ancillary_variables: string
# WSPN_QC.long_name: string
# WSPN_QC.valid_min: int8
# WSPN_QC.valid_max: int8
# WSPN_QC.flag_meanings: string
# RELH_DM: string
# GDIR_DM: string
# .institution_abbreviated: string
# .network: string
# .time_coverage_duration: string
# .time_coverage_resolution: string
# .creator_url: string
# .creator_type: string
# .processing_level: string
# RELH.valid_max: float
# RELH.valid_min: float
# RELH_DM.long_name: string
# RELH_DM.flag_values: string
# RELH_DM.flag_meanings: string
# DEWT.valid_max: float
# DEWT.valid_min: float
# GDIR.valid_max: float
# GDIR.valid_min: float
# GDIR_DM.long_name: string
# GDIR_DM.flag_values: string
# GDIR_DM.flag_meanings: string
# ATMS_DM: string
# ATMS.valid_max: float
# ATMS.valid_min: float
# ATMS_DM.long_name: string
# ATMS_DM.flag_values: string
# ATMS_DM.flag_meanings: string
# DOX2_DM: string
# CPHL_DM: string
# CDOM_DM: string
# TUR4_DM: string
# VT110: float
# VT110_QC: float
# DOX2_DM.long_name: string
# DOX2_DM.flag_values: string
# DOX2_DM.flag_meanings: string
# CPHL_DM.long_name: string
# CPHL_DM.flag_values: string
# CPHL_DM.flag_meanings: string
# CDOM_DM.long_name: string
# CDOM_DM.flag_values: string
# CDOM_DM.flag_meanings: string
# TUR4_DM.long_name: string
# TUR4_DM.flag_values: string
# TUR4_DM.flag_meanings: string
# VT110.data_mode: string
# VT110.long_name: string
# VT110.standard_name: string
# VT110.type_of_analysis: string
# VT110.units: string
# VT110.valid_max: float
# VT110.valid_min: float
# VT110.ancillary_variables: string
# VT110_QC.long_name: string
# VT110_QC.valid_min: int8
# VT110_QC.valid_max: int8
# VT110_QC.flag_meanings: string
# VZMX.valid_max: float
# VZMX.valid_min: float
# VAVT.valid_max: float
# VAVT.valid_min: float
# VTM02.valid_max: float
# VTM02.valid_min: float
# VHZA.valid_max: float
# VHZA.valid_min: float
# VMDR.direction_convention: string
# VMDR.direction_reference: string
# VH110.valid_max: float
# VH110.valid_min: float
# VAVH.valid_max: float
# VAVH.valid_min: float
# VTM02_DM: string
# VZMX_DM: string
# VPED_DM: string
# VTM02_DM.long_name: string
# VTM02_DM.flag_values: string
# VTM02_DM.flag_meanings: string
# VZMX_DM.long_name: string
# VZMX_DM.flag_values: string
# VZMX_DM.flag_meanings: string
# VPED.valid_max: float
# VPED.valid_min: float
# VPED.direction_convention: string
# VPED.direction_reference: string
# VPED_DM.long_name: string
# VPED_DM.flag_values: string
# VPED_DM.flag_meanings: string
# HCSP_DM: string
# HCDT_DM: string
# PRES.valid_max: float
# PRES.valid_min: float
# HCSP_DM.long_name: string
# HCSP_DM.flag_values: string
# HCSP_DM.flag_meanings: string
# HCDT_DM.long_name: string
# HCDT_DM.flag_values: string
# HCDT_DM.flag_meanings: string
# .distribution_statement: string
# NRAD: float
# NRAD_QC: float
# NRAD.standard_name: string
# NRAD.units: string
# NRAD.long_name: string
# NRAD.data_mode: string
# NRAD.ancillary_variables: string
# NRAD_QC.valid_min: int8
# NRAD_QC.valid_max: int8
# NRAD_QC.flag_meanings: string
# NRAD_QC.long_name: string
# TUR3.standard_name: string
# .Netcdf_version: string
# FLU2_DM: string
# FLU2_DM.flag_values: string
# FLU2_DM.flag_meanings: string
# FLU2_DM.long_name: string
# LINC_DM: string
# LW: float
# LW_QC: float
# LW_DM: string
# DOWN_IRRADIANCE: float
# DOWN_IRRADIANCE_QC: float
# LINC_DM.flag_values: string
# LINC_DM.flag_meanings: string
# LINC_DM.long_name: string
# LW.standard_name: string
# LW.units: string
# LW.long_name: string
# LW.data_mode: string
# LW.ancillary_variables: string
# LW_QC.valid_min: int8
# LW_QC.valid_max: int8
# LW_QC.flag_meanings: string
# LW_QC.long_name: string
# LW_DM.flag_values: string
# LW_DM.flag_meanings: string
# LW_DM.long_name: string
# DOWN_IRRADIANCE.standard_name: string
# DOWN_IRRADIANCE.units: string
# DOWN_IRRADIANCE.long_name: string
# DOWN_IRRADIANCE.data_mode: string
# DOWN_IRRADIANCE.ancillary_variables: string
# DOWN_IRRADIANCE_QC.valid_min: int8
# DOWN_IRRADIANCE_QC.valid_max: int8
# DOWN_IRRADIANCE_QC.flag_meanings: string
# DOWN_IRRADIANCE_QC.long_name: string
# RDIN: float
# RDIN_QC: float
# RDIN.standard_name: string
# RDIN.units: string
# RDIN.long_name: string
# RDIN.data_mode: string
# RDIN.ancillary_variables: string
# RDIN_QC.valid_min: int8
# RDIN_QC.valid_max: int8
# RDIN_QC.flag_meanings: string
# RDIN_QC.long_name: string
# .citation_statement: string
# .date_created: string
# OSAT.valid_min: float
# OSAT.valid_max: float
# EWCT_DM: string
# NSCT_DM: string
# EWCT_DM.long_name: string
# EWCT_DM.flag_values: string
# EWCT_DM.flag_meanings: string
# SINC.valid_min: float
# SINC.valid_max: float
# NSCT_DM.long_name: string
# NSCT_DM.flag_values: string
# NSCT_DM.flag_meanings: string
# SINC_DM: string
# SINC_DM.long_name: string
# SINC_DM.flag_values: string
# SINC_DM.flag_meanings: string
# SHIP_SPEED: float
# SHIP_SPEED_QC: float
# SHIP_SPEED.long_name: string
# SHIP_SPEED.standard_name: string
# SHIP_SPEED.units: string
# SHIP_SPEED.data_mode: string
# SHIP_SPEED.ancillary_variables: string
# SHIP_SPEED_QC.long_name: string
# SHIP_SPEED_QC.valid_min: int8
# SHIP_SPEED_QC.valid_max: int8
# SHIP_SPEED_QC.flag_meanings: string

# %%
query_builder = (
    tables['default']
    .query()
    .add_select_column("TIME", "COMMON_TIME")
    .add_select_column("TIME_QC", "COMMON_TIME_QC")
    .add_select_column("LONGITUDE")
    .add_select_column("LONGITUDE", "COMMON_LONGITUDE")
    .add_select(SelectLiteral("degree_east", "COMMON_LONGITUDE_UNITS"))
    .add_select(SelectLiteral("longitude", "COMMON_LONGITUDE_STANDARD_NAME"))
    .add_select(SelectLiteral("SDN:P01::ALONZZ01", "COMMON_LONGITUDE_P01"))
    .add_select(SelectLiteral("SDN:P06::DEGE", "COMMON_LONGITUDE_P06"))
    .add_select_column("LATITUDE")
    .add_select_column("LATITUDE", "COMMON_LATITUDE")
    .add_select(SelectLiteral("degree_north", "COMMON_LATITUDE_UNITS"))
    .add_select(SelectLiteral("latitude", "COMMON_LATITUDE_STANDARD_NAME"))
    .add_select(SelectLiteral("SDN:P01::ALATZZ01", "COMMON_LATITUDE_P01"))
    .add_select(SelectLiteral("SDN:P06::DEGN", "COMMON_LATITUDE_P06"))
    .add_select_column("POSITION_QC")
    .add_select_column("POSITION_QC", "COMMON_POSITION_QC")
    
    .add_select_coalesced(["PRES_ADJUSTED", "PRES", "DEPH"], "COMMON_ORIGIN_DEPTH")
    .add_select_coalesced(["PRES_ADJUSTED_QC","PRES_QC","DEPH_QC"], "COMMON_ORIGIN_DEPTH_QC")
    .add_select_coalesced(["PRES_ADJUSTED.units", "PRES.units", "DEPH.units"], "COMMON_ORIGIN_DEPTH_UNITS")
    .add_select_coalesced(["PRES_ADJUSTED.standard_name", "PRES.standard_name", "DEPH.standard_name"], "COMMON_ORIGIN_DEPTH_STANDARD_NAME")
    .add_select(SelectFunction("coalesce_label", [SelectColumn("PRES"), SelectLiteral("SDN:P01::PRESPR01"), SelectColumn("DEPH"), SelectLiteral("SDN:P01::ADEPZZ01")], "COMMON_ORIGIN_DEPTH_P01"))
    .add_select(SelectFunction("coalesce_label", [SelectColumn("PRES"), SelectLiteral("SDN:P06::UPDB"), SelectColumn("DEPH"), SelectLiteral("SDN:P06::ULAA")], "COMMON_ORIGIN_DEPTH_P06"))
    
    .add_select(Functions.coalesce([Functions.map_pressure_to_depth(Functions.coalesce(["PRES_ADJUSTED", "PRES"],"pres"), "LATITUDE", "pres_harmonized"), "DEPH"], "COMMON_DEPTH"))
    .add_select_coalesced(["PRES_ADJUSTED_QC","PRES_QC","DEPH_QC"], "COMMON_DEPTH_QC")
    .add_select(SelectLiteral("m", "COMMON_DEPTH_UNITS"))
    .add_select(SelectLiteral("depth", "COMMON_DEPTH_STANDARD_NAME"))
    .add_select(SelectLiteral("SDN:P01::ADEPZZ01", "COMMON_DEPTH_P01"))
    .add_select(SelectLiteral("SDN:P06::ULAA", "COMMON_DEPTH_P06"))
)

# %%
query_builder = (
    query_builder
    .add_select_column("__entry_key")
    .add_select_column(".institution_edmo_code")
    .add_select_column(".institution_edmo_code", "COMMON_EDMO_CODE")
    .add_select(SelectLiteral("","COMMON_EDMERP_CODE"))
    .add_select_column(".featureType")
    .add_select_column(".featureType", "COMMON_FEATURE_TYPE")
    .add_select_column(".bigram")
    .add_select_column(".wmo_instrument_type")
    .add_select_column(".source_platform_category_code")
    .add_select(SelectFunction("concat", [SelectLiteral("SDN:L06::"), SelectColumn(".source_platform_category_code")], "COMMON_PLATFORM_L06"))
    .add_select_column(".id", "COMMON_ODV_TAG")
    # Set BEACON ref
    .add_select(SelectLiteral("BEACON_CMEMS_BGC", "SOURCE_BDI"))
    .add_select_column(".id","SOURCE_BDI_DATASET_ID")
)

# %%
# map chlorophyll
query_builder = (
    query_builder
    .add_select_column("CPHL")
    .add_select_column("CPHL_QC")
    .add_select_column("CPHL.units")
    .add_select_column("CPHL.standard_name")
    
    .add_select_column("CHLT")
    .add_select_column("CHLT_QC")
    .add_select_column("CHLT.units")
    .add_select_column("CHLT.standard_name")
    
    .add_select_coalesced(["CPHL", "CHLT"], "COMMON_ORIGIN_CHLOROPHYLL")
    .add_select_coalesced(["CPHL_QC", "CHLT_QC"], "COMMON_ORIGIN_CHLOROPHYLL_QC")
    .add_select_coalesced(["CPHL.units", "CHLT.units"], "COMMON_ORIGIN_CHLOROPHYLL_UNITS")
    .add_select_coalesced(["CPHL.standard_name", "CHLT.standard_name"], "COMMON_ORIGIN_CHLOROPHYLL_STANDARD_NAME")
    .add_select(SelectFunction("coalesce_label", [SelectColumn("CPHL"), SelectLiteral("SDN:P01::CPHLZZXX"), SelectColumn("CHLT"), SelectLiteral("SDN:P01::CHLTVOLU")], "COMMON_ORIGIN_CHLOROPHYLL_P01"))
    .add_select(SelectLiteral("SDN:P06::UMMC", "COMMON_ORIGIN_CHLOROPHYLL_P06"))
    
    .add_select_coalesced(["CPHL", "CHLT"], "COMMON_CHLOROPHYLL_PER_VOLUME")
    .add_select_coalesced(["CPHL_QC", "CHLT_QC"], "COMMON_CHLOROPHYLL_PER_VOLUME_QC")
    .add_select(SelectLiteral("mass_concentration_of_chlorophyll_in_sea_water", "COMMON_CHLOROPHYLL_PER_VOLUME_STANDARD_NAME"))
    .add_select(SelectLiteral("mg m-3", "COMMON_CHLOROPHYLL_PER_VOLUME_UNITS"))
    .add_select(SelectLiteral("SDN:P01::CHLTVOLU", "COMMON_CHLOROPHYLL_PER_VOLUME_P01"))
    .add_select(SelectLiteral("SDN:P06::UMMC", "COMMON_CHLOROPHYLL_PER_VOLUME_P06"))
    
    # Set instrument type
    .add_select(SelectFunction("map_cora_instrument_l05", [SelectColumn(".wmo_instrument_type")], "COMMON_CHLOROPHYLL_L05"))
    .add_select(SelectFunction("map_cora_instrument_l22", [SelectColumn(".wmo_instrument_type")], "COMMON_CHLOROPHYLL_L22"))
)

# %%
# map oxygen
query_builder = (
    query_builder
    .add_select_column("DOXY")
    .add_select_column("DOXY_QC")
    .add_select_column("DOXY.units")
    .add_select_column("DOXY.standard_name")
    
    .add_select_column("DOX1")
    .add_select_column("DOX1_QC")
    .add_select_column("DOX1.units")
    .add_select_column("DOX1.standard_name")
    
    .add_select_column("DOX2")
    .add_select_column("DOX2_QC")
    .add_select_column("DOX2.units")
    .add_select_column("DOX2.standard_name")
    
    .add_select_coalesced(["DOXY", "DOX1", "DOX2"], "COMMON_ORIGIN_OXYGEN")
    .add_select_coalesced(["DOXY_QC", "DOX1_QC", "DOX2_QC"], "COMMON_ORIGIN_OXYGEN_QC")
    .add_select_coalesced(["DOXY.units", "DOX1.units", "DOX2.units"], "COMMON_ORIGIN_OXYGEN_UNITS")
    .add_select_coalesced(["DOXY.standard_name", "DOX1.standard_name", "DOX2.standard_name"], "COMMON_ORIGIN_OXYGEN_STANDARD_NAME")
    
    .add_select(SelectFunction("coalesce_label", [SelectColumn("DOXY"), SelectLiteral("SDN:P01::DOXYZZXX"), SelectColumn("DOX1"), SelectLiteral("SDN:P01::DOXYZZXX"), SelectColumn("DOX2"), SelectLiteral("SDN:P01::DOXMZZXX")], "COMMON_ORIGIN_OXYGEN_P01"))
    .add_select(SelectFunction("coalesce_label", [SelectColumn("DOXY"), SelectLiteral("SDN:P06::UPOX"), SelectColumn("DOX1"), SelectLiteral("SDN:P06::UMLL"), SelectColumn("DOX2"), SelectLiteral("SDN:P06::KGUM")], "COMMON_ORIGIN_OXYGEN_P06"))

    .add_select(
        Functions.coalesce(
            [
                "DOXY",
                SelectFunction("map_units", [SelectLiteral("SDN:P06::UMLL"), SelectLiteral("SDN:P06::UPOX"), SelectColumn("DOX1")]), 
                SelectFunction("map_units", [SelectLiteral("SDN:P06::KGUM"), SelectLiteral("SDN:P06::UPOX"), SelectColumn("DOX2")])
            ],
        "COMMON_OXYGEN_PER_VOLUME"
        )
    )
    .add_select_coalesced(["DOXY_QC", "DOX1_QC", "DOX2_QC"], "COMMON_OXYGEN_PER_VOLUME_QC")
    .add_select(SelectLiteral("mole_concentration_of_dissolved_molecular_oxygen_in_sea_water", "COMMON_OXYGEN_PER_VOLUME_STANDARD_NAME"))
    .add_select(SelectLiteral("umol l-1", "COMMON_OXYGEN_PER_VOLUME_UNITS"))
    .add_select(SelectLiteral("SDN:P01::DOXYZZXX", "COMMON_OXYGEN_PER_VOLUME_P01"))
    .add_select(SelectLiteral("SDN:P06::UPOX", "COMMON_OXYGEN_PER_VOLUME_P06"))
    
    .add_select(
        Functions.coalesce(
            [
                SelectFunction("map_units", [SelectLiteral("SDN:P06::UPOX"), SelectLiteral("SDN:P06::KGUM"), SelectColumn("DOXY")]), 
                SelectFunction("map_units", [SelectLiteral("SDN:P06::UMLL"), SelectLiteral("SDN:P06::KGUM"), SelectColumn("DOX1")]), 
                SelectColumn("DOX2")
            ],
        "COMMON_OXYGEN_PER_MASS"
        )
    )
    .add_select_coalesced(["DOXY_QC", "DOX1_QC", "DOX2_QC"], "COMMON_OXYGEN_PER_MASS_QC")
    .add_select(SelectLiteral("moles_of_oxygen_per_unit_mass_in_sea_water", "COMMON_OXYGEN_PER_MASS_STANDARD_NAME"))
    .add_select(SelectLiteral("umol kg-1", "COMMON_OXYGEN_PER_MASS_UNITS"))
    .add_select(SelectLiteral("SDN:P01::DOXMZZXX", "COMMON_OXYGEN_PER_MASS_P01"))
    .add_select(SelectLiteral("SDN:P06::KGUM", "COMMON_OXYGEN_PER_MASS_P06"))
    
    # Set instrument type
    .add_select(SelectFunction("map_cora_instrument_l05", [SelectColumn(".wmo_instrument_type")], "COMMON_OXYGEN_L05"))
    .add_select(SelectFunction("map_cora_instrument_l22", [SelectColumn(".wmo_instrument_type")], "COMMON_OXYGEN_L22"))
)

# %%
# map nitrate
query_builder = (
    query_builder
    .add_select_column("NTRA")
    .add_select_column("NTRA_QC")
    .add_select_column("NTRA.units")
    .add_select_column("NTRA.standard_name")
    
    .add_select_column("NTAW")
    .add_select_column("NTAW_QC")
    .add_select_column("NTAW.units")
    .add_select_column("NTAW.standard_name")
    
    .add_select_coalesced(["NTRA", "NTAW"], "COMMON_ORIGIN_NITRATE")
    .add_select_coalesced(["NTRA_QC", "NTAW_QC"], "COMMON_ORIGIN_NITRATE_QC")
    .add_select_coalesced(["NTRA.units", "NTAW.units"], "COMMON_ORIGIN_NITRATE_UNITS")
    .add_select_coalesced(["NTRA.standard_name", "NTAW.standard_name"], "COMMON_ORIGIN_NITRATE_STANDARD_NAME")
    .add_select(SelectFunction("coalesce_label", [SelectColumn("NTRA"), SelectLiteral("SDN:P01::NTRAZZXX"), SelectColumn("NTAW"), SelectLiteral("SDN:P01::MDMAP005")], "COMMON_ORIGIN_NITRATE_P01"))
    .add_select(SelectFunction("coalesce_label", [SelectColumn("NTRA"), SelectLiteral("SDN:P06::UPOX"), SelectColumn("NTAW"), SelectLiteral("SDN:P06::KGUM")], "COMMON_ORIGIN_NITRATE_P06"))
    
    .add_select(
        Functions.coalesce(
            [
                "NTRA",
                SelectFunction("map_units", [SelectLiteral("SDN:P06::KGUM"), SelectLiteral("SDN:P06::UPOX"), SelectColumn("NTAW")]),
            ]
            ,"COMMON_NITRATE_PER_VOLUME"
        )
    )
    .add_select_coalesced(["NTRA_QC", "NTAW_QC"], "COMMON_NITRATE_PER_VOLUME_QC")
    .add_select(SelectLiteral("mole_concentration_of_nitrate_in_sea_water", "COMMON_NITRATE_PER_VOLUME_STANDARD_NAME"))
    .add_select(SelectLiteral("umol l-1", "COMMON_NITRATE_PER_VOLUME_UNITS"))
    .add_select(SelectLiteral("SDN:P01::NTRAZZXX", "COMMON_NITRATE_PER_VOLUME_P01"))
    .add_select(SelectLiteral("SDN:P06::UPOX", "COMMON_NITRATE_PER_VOLUME_P06"))
    
    .add_select(
        Functions.coalesce(
            [
                SelectFunction("map_units", [SelectLiteral("SDN:P06::UPOX"), SelectLiteral("SDN:P06::KGUM"), SelectColumn("NTRA")]), 
                "NTAW",
            ],"COMMON_NITRATE_PER_MASS"
        )
    )
    .add_select_coalesced(["NTRA_QC", "NTAW_QC"], "COMMON_NITRATE_PER_MASS_QC")
    .add_select(SelectLiteral("moles_of_nitrate_per_unit_mass_in_sea_water", "COMMON_NITRATE_PER_MASS_STANDARD_NAME"))
    .add_select(SelectLiteral("umol kg-1", "COMMON_NITRATE_PER_MASS_UNITS"))
    .add_select(SelectLiteral("SDN:P01::MDMAP005", "COMMON_NITRATE_PER_MASS_P01"))
    .add_select(SelectLiteral("SDN:P06::KGUM", "COMMON_NITRATE_PER_MASS_P06"))
    
    # Set instrument type
    .add_select(SelectFunction("map_cora_instrument_l05", [SelectColumn(".wmo_instrument_type")], "COMMON_NITRATE_L05"))
    .add_select(SelectFunction("map_cora_instrument_l22", [SelectColumn(".wmo_instrument_type")], "COMMON_NITRATE_L22"))
)

# %%
# MAP NITRATE + NITRITE
query_builder = (
    query_builder
    .add_select_column("NTRZ")
    .add_select_column("NTRZ_QC")
    .add_select_column("NTRZ.units")
    .add_select_column("NTRZ.standard_name")
    
    .add_select_column("NTRZ", "COMMON_ORIGIN_NITRATE_NITRITE")
    .add_select_column("NTRZ_QC", "COMMON_ORIGIN_NITRATE_NITRITE_QC")
    .add_select_column("NTRZ.units", "COMMON_ORIGIN_NITRATE_NITRITE_UNITS")
    .add_select_column("NTRZ.standard_name", "COMMON_ORIGIN_NITRATE_NITRITE_STANDARD_NAME")
    .add_select(SelectLiteral("SDN:P01::NTRZZZXX", "COMMON_ORIGIN_NITRATE_NITRITE_P01"))
    .add_select(SelectLiteral("SDN:P06::UPOX", "COMMON_ORIGIN_NITRATE_NITRITE_P06"))
    
    .add_select_column("NTRZ", "COMMON_NITRATE_NITRITE_PER_VOLUME")
    .add_select_column("NTRZ_QC", "COMMON_NITRATE_NITRATE_PER_VOLUME_QC")
    .add_select(SelectLiteral("mole_concentration_of_nitrate_and_nitrite_in_sea_water", "COMMON_NITRATE_NITRITE_PER_VOLUME_STANDARD_NAME"))
    .add_select(SelectLiteral("umol l-1", "COMMON_NITRATE_NITRITE_PER_VOLUME_UNITS"))
    .add_select(SelectLiteral("SDN:P01::NTRZZZXX", "COMMON_NITRATE_NITRITE_PER_VOLUME_P01"))
    .add_select(SelectLiteral("SDN:P06::UPOX", "COMMON_NITRATE_NITRITE_PER_VOLUME_P06"))
    
    .add_select(SelectFunction("map_units", [SelectLiteral("SDN:P06::UPOX"), SelectLiteral("SDN:P06::KGUM"), SelectColumn("NTRZ")], "COMMON_NITRATE_NITRITE_PER_MASS"))
    .add_select_column("NTRZ_QC", "COMMON_NITRATE_NITRITE_PER_MASS_QC")
    .add_select(SelectLiteral("moles_of_nitrate_and_nitrite_per_unit_mass_in_sea_water", "COMMON_NITRATE_NITRITE_PER_MASS_STANDARD_NAME"))
    .add_select(SelectLiteral("umol kg-1", "COMMON_NITRATE_NITRITE_PER_MASS_UNITS"))
    .add_select(SelectLiteral("SDN:P01::MDMAP006", "COMMON_NITRATE_NITRITE_PER_MASS_P01"))
    .add_select(SelectLiteral("SDN:P06::KGUM", "COMMON_NITRATE_NITRITE_PER_MASS_P06"))
    
    # Set instrument type
    .add_select(SelectFunction("map_cora_instrument_l05", [SelectColumn(".wmo_instrument_type")], "COMMON_NITRATE_NITRITE_L05"))
    .add_select(SelectFunction("map_cora_instrument_l22", [SelectColumn(".wmo_instrument_type")], "COMMON_NITRATE_NITRITE_L22"))
)

# %%
# map ammonium
query_builder = (
    query_builder
    .add_select_column("AMON")
    .add_select_column("AMON_QC")
    .add_select_column("AMON.units")
    .add_select_column("AMON.standard_name")
    
    .add_select_column("AMON", "COMMON_ORIGIN_AMMONIUM")
    .add_select_column("AMON_QC", "COMMON_ORIGIN_AMMONIUM_QC")
    .add_select_column("AMON.units", "COMMON_ORIGIN_AMMONIUM_UNITS")
    .add_select_column("AMON.standard_name", "COMMON_ORIGIN_AMMONIUM_STANDARD_NAME")
    .add_select(SelectLiteral("SDN:P01::AMONZZXX", "COMMON_ORIGIN_AMMONIUM_P01"))
    .add_select(SelectLiteral("SDN:P06::UPOX", "COMMON_ORIGIN_AMMONIUM_P06"))
    
    .add_select_column("AMON", "COMMON_AMMONIUM_PER_VOLUME")
    .add_select_column("AMON_QC", "COMMON_AMMONIUM_PER_VOLUME_QC")
    .add_select(SelectLiteral("mole_concentration_of_ammonium_in_sea_water", "COMMON_AMMONIUM_PER_VOLUME_STANDARD_NAME"))
    .add_select(SelectLiteral("umol l-1", "COMMON_AMMONIUM_PER_VOLUME_UNITS"))
    .add_select(SelectLiteral("SDN:P01::AMONZZXX", "COMMON_AMMONIUM_PER_VOLUME_P01"))
    .add_select(SelectLiteral("SDN:P06::UPOX", "COMMON_AMMONIUM_PER_VOLUME_P06"))
    
    .add_select(SelectFunction("map_units", [SelectLiteral("SDN:P06::UPOX"), SelectLiteral("SDN:P06::KGUM"), SelectColumn("AMON")], "COMMON_AMMONIUM_PER_MASS"))
    .add_select_column("AMON_QC", "COMMON_AMMONIUM_PER_MASS_QC")
    .add_select(SelectLiteral("moles_of_ammonium_per_unit_mass_in_sea_water", "COMMON_AMMONIUM_PER_MASS_STANDARD_NAME"))
    .add_select(SelectLiteral("umol kg-1", "COMMON_AMMONIUM_PER_MASS_UNITS"))
    .add_select(SelectLiteral("SDN:P01::MDMAP005", "COMMON_AMMONIUM_PER_MASS_P01"))
    .add_select(SelectLiteral("SDN:P06::KGUM", "COMMON_AMMONIUM_PER_MASS_P06"))
    
    # Set instrument type
    .add_select(SelectFunction("map_cora_instrument_l05", [SelectColumn(".wmo_instrument_type")], "COMMON_AMMONIUM_L05"))
    .add_select(SelectFunction("map_cora_instrument_l22", [SelectColumn(".wmo_instrument_type")], "COMMON_AMMONIUM_L22"))
)

# %%
# map phosphate
query_builder = (
    query_builder
    .add_select_column("PHOS")
    .add_select_column("PHOS_QC")
    .add_select_column("PHOS.units")
    .add_select_column("PHOS.standard_name")
    
    .add_select_column("PHOW")
    .add_select_column("PHOW_QC")
    .add_select_column("PHOW.units")
    .add_select_column("PHOW.standard_name")
    
    .add_select_coalesced(["PHOS", "PHOW"], "COMMON_ORIGIN_PHOSPHATE")
    .add_select_coalesced(["PHOS_QC", "PHOW_QC"], "COMMON_ORIGIN_PHOSPHATE_QC")
    .add_select_coalesced(["PHOS.units", "PHOW.units"], "COMMON_ORIGIN_PHOSPHATE_UNITS")
    .add_select_coalesced(["PHOS.standard_name", "PHOW.standard_name"], "COMMON_ORIGIN_PHOSPHATE_STANDARD_NAME")
    .add_select(SelectFunction("coalesce_label", [SelectColumn("PHOS"), SelectLiteral("SDN:P01::PHOSZZXX"), SelectColumn("PHOW"), SelectLiteral("SDN:P01::MDMAP906")], "COMMON_ORIGIN_PHOSPHATE_P01"))
    .add_select(SelectFunction("coalesce_label", [SelectColumn("PHOS"), SelectLiteral("SDN:P06::UPOX"), SelectColumn("PHOW"), SelectLiteral("SDN:P06::KGUM")], "COMMON_ORIGIN_PHOSPHATE_P06"))
    
    .add_select(
        Functions.coalesce(
            [
                "PHOS",
                SelectFunction("map_units", [SelectLiteral("SDN:P06::KGUM"), SelectLiteral("SDN:P06::UPOX"), SelectColumn("PHOW")]),
            ]
            ,"COMMON_PHOSPHATE_PER_VOLUME"
        )
    )
    .add_select_coalesced(["PHOS_QC", "PHOW_QC"], "COMMON_PHOSPHATE_PER_VOLUME_QC")
    .add_select(SelectLiteral("mole_concentration_of_phosphate_in_sea_water", "COMMON_PHOSPHATE_PER_VOLUME_STANDARD_NAME"))
    .add_select(SelectLiteral("umol l-1", "COMMON_PHOSPHATE_PER_VOLUME_UNITS"))
    .add_select(SelectLiteral("SDN:P01::PHOSZZXX", "COMMON_PHOSPHATE_PER_VOLUME_P01"))
    .add_select(SelectLiteral("SDN:P06::UPOX", "COMMON_PHOSPHATE_PER_VOLUME_P06"))
    
    .add_select(
        Functions.coalesce(
            [
                SelectFunction("map_units", [SelectLiteral("SDN:P06::UPOX"), SelectLiteral("SDN:P06::KGUM"), SelectColumn("PHOS")]),
                "PHOW",
            ],"COMMON_PHOSPHATE_PER_MASS"
        )
    )
    .add_select_coalesced(["PHOS_QC", "PHOW_QC"], "COMMON_PHOSPHATE_PER_MASS_QC")
    .add_select(SelectLiteral("moles_of_phosphate_per_unit_mass_in_sea_water", "COMMON_PHOSPHATE_PER_MASS_STANDARD_NAME"))
    .add_select(SelectLiteral("umol kg-1", "COMMON_PHOSPHATE_PER_MASS_UNITS"))
    .add_select(SelectLiteral("SDN:P01::MDMAP906", "COMMON_PHOSPHATE_PER_MASS_P01"))
    .add_select(SelectLiteral("SDN:P06::KGUM", "COMMON_PHOSPHATE_PER_MASS_P06"))
    
    # Set instrument type
    .add_select(SelectFunction("map_cora_instrument_l05", [SelectColumn(".wmo_instrument_type")], "COMMON_PHOSPHATE_L05"))
    .add_select(SelectFunction("map_cora_instrument_l22", [SelectColumn(".wmo_instrument_type")], "COMMON_PHOSPHATE_L22"))
)

# %%
# silicate
query_builder = (
    query_builder
    .add_select_column("SLCA")
    .add_select_column("SLCA_QC")
    .add_select_column("SLCA.units")
    .add_select_column("SLCA.standard_name")
    
    .add_select_column("SLCW")
    .add_select_column("SLCW_QC")
    .add_select_column("SLCW.units")
    .add_select_column("SLCW.standard_name")
    
    .add_select_coalesced(["SLCA", "SLCW"], "COMMON_ORIGIN_SILICATE")
    .add_select_coalesced(["SLCA_QC", "SLCW_QC"], "COMMON_ORIGIN_SILICATE_QC")
    .add_select_coalesced(["SLCA.units", "SLCW.units"], "COMMON_ORIGIN_SILICATE_UNITS")
    .add_select_coalesced(["SLCA.standard_name", "SLCW.standard_name"], "COMMON_ORIGIN_SILICATE_STANDARD_NAME")
    .add_select(SelectFunction("coalesce_label", [SelectColumn("SLCA"), SelectLiteral("SDN:P01::SLCAZZXX"), SelectColumn("SLCW"), SelectLiteral("SDN:P01::MDMAP012")], "COMMON_ORIGIN_SILICATE_P01"))
    .add_select(SelectFunction("coalesce_label", [SelectColumn("SLCA"), SelectLiteral("SDN:P06::UPOX"), SelectColumn("SLCW"), SelectLiteral("SDN:P06::KGUM")], "COMMON_ORIGIN_SILICATE_P06"))
    
    .add_select(
        Functions.coalesce(
            [
                "SLCA", 
                SelectFunction("map_units", [SelectLiteral("SDN:P06::KGUM"), SelectLiteral("SDN:P06::UPOX"), SelectColumn("SLCW")]), 
            ]
            ,"COMMON_SILICATE_PER_VOLUME"
        )
    )
    .add_select_coalesced(["SLCA_QC", "SLCW_QC"],"COMMON_SILICATE_PER_VOLUME_QC")
    .add_select(SelectLiteral("mole_concentration_of_silicate_in_sea_water", "COMMON_SILICATE_PER_VOLUME_STANDARD_NAME"))
    .add_select(SelectLiteral("umol l-1", "COMMON_SILICATE_PER_VOLUME_UNITS"))
    .add_select(SelectLiteral("SDN:P01::SLCAZZXX", "COMMON_SILICATE_PER_VOLUME_P01"))
    .add_select(SelectLiteral("SDN:P06::UPOX", "COMMON_SILICATE_PER_VOLUME_P06"))
    
    .add_select(
        Functions.coalesce(
            [
                SelectFunction("map_units", [SelectLiteral("SDN:P06::UPOX"), SelectLiteral("SDN:P06::KGUM"), SelectColumn("SLCA")]),
                "SLCW",
            ],"COMMON_SILICATE_PER_MASS"
        )
    )
    .add_select_coalesced(["SLCA_QC", "SLCW_QC"],"COMMON_SILICATE_PER_MASS_QC")
    .add_select(SelectLiteral("moles_of_nitrate_per_unit_mass_in_sea_water", "COMMON_SILICATE_PER_MASS_STANDARD_NAME"))
    .add_select(SelectLiteral("umol kg-1", "COMMON_SILICATE_PER_MASS_UNITS"))
    .add_select(SelectLiteral("SDN:P01::MDMAP012", "COMMON_SILICATE_PER_MASS_P01"))
    .add_select(SelectLiteral("SDN:P06::KGUM", "COMMON_SILICATE_PER_MASS_P06"))
    
    # Set instrument type
    .add_select(SelectFunction("map_cora_instrument_l05", [SelectColumn(".wmo_instrument_type")], "COMMON_SILICATE_L05"))
    .add_select(SelectFunction("map_cora_instrument_l22", [SelectColumn(".wmo_instrument_type")], "COMMON_SILICATE_L22"))
)

# %%
# map temperature
query_builder = (
    query_builder
    .add_select_column("TEMP")
    .add_select_column("TEMP_QC")
    .add_select_column("TEMP.units")
    .add_select_column("TEMP.standard_name")
    
    .add_select_column("TEMP_ADJUSTED")
    .add_select_column("TEMP_ADJUSTED_QC")
    .add_select_column("TEMP_ADJUSTED.units")
    .add_select_column("TEMP_ADJUSTED.standard_name")
    
    .add_select_coalesced(["TEMP", "TEMP_ADJUSTED"], "COMMON_ORIGIN_TEMPERATURE")
    .add_select_coalesced(["TEMP_QC", "TEMP_ADJUSTED_QC"], "COMMON_ORIGIN_TEMPERATURE_QC")
    .add_select_coalesced(["TEMP.units", "TEMP_ADJUSTED.units"], "COMMON_ORIGIN_TEMPERATURE_UNITS")
    .add_select_coalesced(["TEMP.standard_name", "TEMP_ADJUSTED.standard_name"], "COMMON_ORIGIN_TEMPERATURE_STANDARD_NAME")
    .add_select(SelectLiteral("SDN:P01::TEMPPR01", "COMMON_ORIGIN_TEMPERATURE_P01"))
    .add_select(SelectLiteral("SDN:P06::UPAA", "COMMON_ORIGIN_TEMPERATURE_P06"))
    
    .add_select_coalesced(["TEMP", "TEMP_ADJUSTED"], "COMMON_TEMPERATURE")
    .add_select_coalesced(["TEMP_QC", "TEMP_ADJUSTED_QC"], "COMMON_TEMPERATURE_QC")
    .add_select(SelectLiteral("degree_C", "COMMON_TEMPERATURE_UNITS"))
    .add_select(SelectLiteral("sea_water_temperature", "COMMON_TEMPERATURE_STANDARD_NAME"))
    .add_select(SelectLiteral("SDN:P01::TEMPPR01", "COMMON_TEMPERATURE_P01"))
    .add_select(SelectLiteral("SDN:P06::UPAA", "COMMON_TEMPERATURE_P06"))
    
    # Set instrument type
    .add_select(SelectFunction("map_cora_instrument_l05", [SelectColumn(".wmo_instrument_type")], "COMMON_TEMPERATURE_L05"))
    .add_select(SelectFunction("map_cora_instrument_l22", [SelectColumn(".wmo_instrument_type")], "COMMON_TEMPERATURE_L22"))
)

# %%
# map salinity
query_builder = (
    query_builder
    .add_select_column("PSAL")
    .add_select_column("PSAL_QC")
    .add_select_column("PSAL.units")
    .add_select_column("PSAL.standard_name")
    
    .add_select_column("PSAL_ADJUSTED")
    .add_select_column("PSAL_ADJUSTED_QC")
    .add_select_column("PSAL_ADJUSTED.units")
    .add_select_column("PSAL_ADJUSTED.standard_name")
    
    .add_select_coalesced(["PSAL", "PSAL_ADJUSTED"], "COMMON_ORIGIN_SALINITY")
    .add_select_coalesced(["PSAL_QC", "PSAL_ADJUSTED_QC"], "COMMON_ORIGIN_SALINITY_QC")
    .add_select_coalesced(["PSAL.units", "PSAL_ADJUSTED.units"], "COMMON_ORIGIN_SALINITY_UNITS")
    .add_select_coalesced(["PSAL.standard_name", "PSAL_ADJUSTED.standard_name"], "COMMON_ORIGIN_SALINITY_STANDARD_NAME")
    .add_select(SelectLiteral("SDN:P01::PSLTZZ01", "COMMON_ORIGIN_SALINITY_P01"))
    .add_select(SelectLiteral("SDN:P06::UUUU", "COMMON_ORIGIN_SALINITY_P06"))
    
    .add_select_coalesced(["PSAL", "PSAL_ADJUSTED"], "COMMON_SALINITY")
    .add_select_coalesced(["PSAL_QC", "PSAL_ADJUSTED_QC"], "COMMON_SALINITY_QC")
    .add_select(SelectLiteral("sea_water_salinity", "COMMON_SALINITY_STANDARD_NAME"))
    .add_select(SelectLiteral("1e-3", "COMMON_SALINITY_UNITS"))
    .add_select(SelectLiteral("SDN:P01::PSLTZZ01", "COMMON_SALINITY_P01"))
    .add_select(SelectLiteral("SDN:P06::UUUU", "COMMON_SALINITY_P06"))
    
    # Set instrument type
    .add_select(SelectFunction("map_cora_instrument_l05", [SelectColumn(".wmo_instrument_type")], "COMMON_SALINITY_L05"))
    .add_select(SelectFunction("map_cora_instrument_l22", [SelectColumn(".wmo_instrument_type")], "COMMON_SALINITY_L22"))
)

# %%
import os 
import json

# Make output dir
output_dir = "./output"
os.makedirs(output_dir, exist_ok=True)
# for each year between 1950 and 2025
for year in range(1950, 2025):
    print(f"Processing year {year}")
    query_builder.filters = []
    query_builder = query_builder.add_range_filter("COMMON_TIME", f"{year}-01-01T00:00:00Z", f"{year}-12-31T23:59:59Z")
    query_builder = (
        query_builder
        .add_filter(OrFilter([
            IsNotNullFilter("COMMON_ORIGIN_CHLOROPHYLL"),
            IsNotNullFilter("COMMON_ORIGIN_OXYGEN"),
            IsNotNullFilter("COMMON_ORIGIN_NITRATE"),
            IsNotNullFilter("COMMON_ORIGIN_NITRATE_NITRITE"),
            IsNotNullFilter("COMMON_ORIGIN_AMMONIUM"),
            IsNotNullFilter("COMMON_ORIGIN_PHOSPHATE"),
            IsNotNullFilter("COMMON_ORIGIN_SILICATE"),
        ]))
    )
    output_file = os.path.join(output_dir, f"cmems_bgc_{year}.parquet")
    try:
        query_builder.to_parquet(output_file)
        print(f"Saved to {output_file}")
    except Exception as e:
        print(f"Failed to process year {year}: {e}")
# Out:
# Processing year 1950
# Running query: {"from": "default", "select": [{"column": "TIME", "alias": "COMMON_TIME"}, {"column": "TIME_QC", "alias": "COMMON_TIME_QC"}, {"column": "LONGITUDE", "alias": null}, {"column": "LONGITUDE", "alias": "COMMON_LONGITUDE"}, {"value": "degree_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "LATITUDE", "alias": null}, {"column": "LATITUDE", "alias": "COMMON_LATITUDE"}, {"value": "degree_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "POSITION_QC", "alias": null}, {"column": "POSITION_QC", "alias": "COMMON_POSITION_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}, {"column": "DEPH", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "DEPH.units", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "DEPH.standard_name", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P01::PRESPR01", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P01::ADEPZZ01", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P06::UPDB", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P06::ULAA", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"function": "coalesce", "args": [{"function": "pressure_to_depth_teos_10", "args": [{"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}], "alias": "pres"}, {"column": "LATITUDE", "alias": null}], "alias": "pres_harmonized"}, {"column": "DEPH", "alias": null}], "alias": "COMMON_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"column": ".institution_edmo_code", "alias": null}, {"column": ".institution_edmo_code", "alias": "COMMON_EDMO_CODE"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"column": ".featureType", "alias": null}, {"column": ".featureType", "alias": "COMMON_FEATURE_TYPE"}, {"column": ".bigram", "alias": null}, {"column": ".wmo_instrument_type", "alias": null}, {"column": ".source_platform_category_code", "alias": null}, {"function": "concat", "args": [{"value": "SDN:L06::", "alias": null}, {"column": ".source_platform_category_code", "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"column": ".id", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_CMEMS_BGC", "alias": "SOURCE_BDI"}, {"column": ".id", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": "CPHL", "alias": null}, {"column": "CPHL_QC", "alias": null}, {"column": "CPHL.units", "alias": null}, {"column": "CPHL.standard_name", "alias": null}, {"column": "CHLT", "alias": null}, {"column": "CHLT_QC", "alias": null}, {"column": "CHLT.units", "alias": null}, { ...
# Saved to ./output/cmems_bgc_1950.parquet
# Processing year 1951
# Running query: {"from": "default", "select": [{"column": "TIME", "alias": "COMMON_TIME"}, {"column": "TIME_QC", "alias": "COMMON_TIME_QC"}, {"column": "LONGITUDE", "alias": null}, {"column": "LONGITUDE", "alias": "COMMON_LONGITUDE"}, {"value": "degree_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "LATITUDE", "alias": null}, {"column": "LATITUDE", "alias": "COMMON_LATITUDE"}, {"value": "degree_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "POSITION_QC", "alias": null}, {"column": "POSITION_QC", "alias": "COMMON_POSITION_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}, {"column": "DEPH", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "DEPH.units", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "DEPH.standard_name", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P01::PRESPR01", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P01::ADEPZZ01", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P06::UPDB", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P06::ULAA", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"function": "coalesce", "args": [{"function": "pressure_to_depth_teos_10", "args": [{"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}], "alias": "pres"}, {"column": "LATITUDE", "alias": null}], "alias": "pres_harmonized"}, {"column": "DEPH", "alias": null}], "alias": "COMMON_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"column": ".institution_edmo_code", "alias": null}, {"column": ".institution_edmo_code", "alias": "COMMON_EDMO_CODE"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"column": ".featureType", "alias": null}, {"column": ".featureType", "alias": "COMMON_FEATURE_TYPE"}, {"column": ".bigram", "alias": null}, {"column": ".wmo_instrument_type", "alias": null}, {"column": ".source_platform_category_code", "alias": null}, {"function": "concat", "args": [{"value": "SDN:L06::", "alias": null}, {"column": ".source_platform_category_code", "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"column": ".id", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_CMEMS_BGC", "alias": "SOURCE_BDI"}, {"column": ".id", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": "CPHL", "alias": null}, {"column": "CPHL_QC", "alias": null}, {"column": "CPHL.units", "alias": null}, {"column": "CPHL.standard_name", "alias": null}, {"column": "CHLT", "alias": null}, {"column": "CHLT_QC", "alias": null}, {"column": "CHLT.units", "alias": null}, { ...
# Saved to ./output/cmems_bgc_1951.parquet
# Processing year 1952
# Running query: {"from": "default", "select": [{"column": "TIME", "alias": "COMMON_TIME"}, {"column": "TIME_QC", "alias": "COMMON_TIME_QC"}, {"column": "LONGITUDE", "alias": null}, {"column": "LONGITUDE", "alias": "COMMON_LONGITUDE"}, {"value": "degree_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "LATITUDE", "alias": null}, {"column": "LATITUDE", "alias": "COMMON_LATITUDE"}, {"value": "degree_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "POSITION_QC", "alias": null}, {"column": "POSITION_QC", "alias": "COMMON_POSITION_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}, {"column": "DEPH", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "DEPH.units", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "DEPH.standard_name", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P01::PRESPR01", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P01::ADEPZZ01", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P06::UPDB", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P06::ULAA", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"function": "coalesce", "args": [{"function": "pressure_to_depth_teos_10", "args": [{"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}], "alias": "pres"}, {"column": "LATITUDE", "alias": null}], "alias": "pres_harmonized"}, {"column": "DEPH", "alias": null}], "alias": "COMMON_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"column": ".institution_edmo_code", "alias": null}, {"column": ".institution_edmo_code", "alias": "COMMON_EDMO_CODE"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"column": ".featureType", "alias": null}, {"column": ".featureType", "alias": "COMMON_FEATURE_TYPE"}, {"column": ".bigram", "alias": null}, {"column": ".wmo_instrument_type", "alias": null}, {"column": ".source_platform_category_code", "alias": null}, {"function": "concat", "args": [{"value": "SDN:L06::", "alias": null}, {"column": ".source_platform_category_code", "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"column": ".id", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_CMEMS_BGC", "alias": "SOURCE_BDI"}, {"column": ".id", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": "CPHL", "alias": null}, {"column": "CPHL_QC", "alias": null}, {"column": "CPHL.units", "alias": null}, {"column": "CPHL.standard_name", "alias": null}, {"column": "CHLT", "alias": null}, {"column": "CHLT_QC", "alias": null}, {"column": "CHLT.units", "alias": null}, { ...
# Saved to ./output/cmems_bgc_1952.parquet
# Processing year 1953
# Running query: {"from": "default", "select": [{"column": "TIME", "alias": "COMMON_TIME"}, {"column": "TIME_QC", "alias": "COMMON_TIME_QC"}, {"column": "LONGITUDE", "alias": null}, {"column": "LONGITUDE", "alias": "COMMON_LONGITUDE"}, {"value": "degree_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "LATITUDE", "alias": null}, {"column": "LATITUDE", "alias": "COMMON_LATITUDE"}, {"value": "degree_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "POSITION_QC", "alias": null}, {"column": "POSITION_QC", "alias": "COMMON_POSITION_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}, {"column": "DEPH", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "DEPH.units", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "DEPH.standard_name", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P01::PRESPR01", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P01::ADEPZZ01", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P06::UPDB", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P06::ULAA", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"function": "coalesce", "args": [{"function": "pressure_to_depth_teos_10", "args": [{"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}], "alias": "pres"}, {"column": "LATITUDE", "alias": null}], "alias": "pres_harmonized"}, {"column": "DEPH", "alias": null}], "alias": "COMMON_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"column": ".institution_edmo_code", "alias": null}, {"column": ".institution_edmo_code", "alias": "COMMON_EDMO_CODE"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"column": ".featureType", "alias": null}, {"column": ".featureType", "alias": "COMMON_FEATURE_TYPE"}, {"column": ".bigram", "alias": null}, {"column": ".wmo_instrument_type", "alias": null}, {"column": ".source_platform_category_code", "alias": null}, {"function": "concat", "args": [{"value": "SDN:L06::", "alias": null}, {"column": ".source_platform_category_code", "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"column": ".id", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_CMEMS_BGC", "alias": "SOURCE_BDI"}, {"column": ".id", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": "CPHL", "alias": null}, {"column": "CPHL_QC", "alias": null}, {"column": "CPHL.units", "alias": null}, {"column": "CPHL.standard_name", "alias": null}, {"column": "CHLT", "alias": null}, {"column": "CHLT_QC", "alias": null}, {"column": "CHLT.units", "alias": null}, { ...
# Saved to ./output/cmems_bgc_1953.parquet
# Processing year 1954
# Running query: {"from": "default", "select": [{"column": "TIME", "alias": "COMMON_TIME"}, {"column": "TIME_QC", "alias": "COMMON_TIME_QC"}, {"column": "LONGITUDE", "alias": null}, {"column": "LONGITUDE", "alias": "COMMON_LONGITUDE"}, {"value": "degree_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "LATITUDE", "alias": null}, {"column": "LATITUDE", "alias": "COMMON_LATITUDE"}, {"value": "degree_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "POSITION_QC", "alias": null}, {"column": "POSITION_QC", "alias": "COMMON_POSITION_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}, {"column": "DEPH", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "DEPH.units", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "DEPH.standard_name", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P01::PRESPR01", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P01::ADEPZZ01", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P06::UPDB", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P06::ULAA", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"function": "coalesce", "args": [{"function": "pressure_to_depth_teos_10", "args": [{"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}], "alias": "pres"}, {"column": "LATITUDE", "alias": null}], "alias": "pres_harmonized"}, {"column": "DEPH", "alias": null}], "alias": "COMMON_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"column": ".institution_edmo_code", "alias": null}, {"column": ".institution_edmo_code", "alias": "COMMON_EDMO_CODE"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"column": ".featureType", "alias": null}, {"column": ".featureType", "alias": "COMMON_FEATURE_TYPE"}, {"column": ".bigram", "alias": null}, {"column": ".wmo_instrument_type", "alias": null}, {"column": ".source_platform_category_code", "alias": null}, {"function": "concat", "args": [{"value": "SDN:L06::", "alias": null}, {"column": ".source_platform_category_code", "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"column": ".id", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_CMEMS_BGC", "alias": "SOURCE_BDI"}, {"column": ".id", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": "CPHL", "alias": null}, {"column": "CPHL_QC", "alias": null}, {"column": "CPHL.units", "alias": null}, {"column": "CPHL.standard_name", "alias": null}, {"column": "CHLT", "alias": null}, {"column": "CHLT_QC", "alias": null}, {"column": "CHLT.units", "alias": null}, { ...
# Saved to ./output/cmems_bgc_1954.parquet
# Processing year 1955
# Running query: {"from": "default", "select": [{"column": "TIME", "alias": "COMMON_TIME"}, {"column": "TIME_QC", "alias": "COMMON_TIME_QC"}, {"column": "LONGITUDE", "alias": null}, {"column": "LONGITUDE", "alias": "COMMON_LONGITUDE"}, {"value": "degree_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "LATITUDE", "alias": null}, {"column": "LATITUDE", "alias": "COMMON_LATITUDE"}, {"value": "degree_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "POSITION_QC", "alias": null}, {"column": "POSITION_QC", "alias": "COMMON_POSITION_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}, {"column": "DEPH", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "DEPH.units", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "DEPH.standard_name", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P01::PRESPR01", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P01::ADEPZZ01", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P06::UPDB", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P06::ULAA", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"function": "coalesce", "args": [{"function": "pressure_to_depth_teos_10", "args": [{"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}], "alias": "pres"}, {"column": "LATITUDE", "alias": null}], "alias": "pres_harmonized"}, {"column": "DEPH", "alias": null}], "alias": "COMMON_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"column": ".institution_edmo_code", "alias": null}, {"column": ".institution_edmo_code", "alias": "COMMON_EDMO_CODE"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"column": ".featureType", "alias": null}, {"column": ".featureType", "alias": "COMMON_FEATURE_TYPE"}, {"column": ".bigram", "alias": null}, {"column": ".wmo_instrument_type", "alias": null}, {"column": ".source_platform_category_code", "alias": null}, {"function": "concat", "args": [{"value": "SDN:L06::", "alias": null}, {"column": ".source_platform_category_code", "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"column": ".id", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_CMEMS_BGC", "alias": "SOURCE_BDI"}, {"column": ".id", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": "CPHL", "alias": null}, {"column": "CPHL_QC", "alias": null}, {"column": "CPHL.units", "alias": null}, {"column": "CPHL.standard_name", "alias": null}, {"column": "CHLT", "alias": null}, {"column": "CHLT_QC", "alias": null}, {"column": "CHLT.units", "alias": null}, { ...
# Saved to ./output/cmems_bgc_1955.parquet
# Processing year 1956
# Running query: {"from": "default", "select": [{"column": "TIME", "alias": "COMMON_TIME"}, {"column": "TIME_QC", "alias": "COMMON_TIME_QC"}, {"column": "LONGITUDE", "alias": null}, {"column": "LONGITUDE", "alias": "COMMON_LONGITUDE"}, {"value": "degree_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "LATITUDE", "alias": null}, {"column": "LATITUDE", "alias": "COMMON_LATITUDE"}, {"value": "degree_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "POSITION_QC", "alias": null}, {"column": "POSITION_QC", "alias": "COMMON_POSITION_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}, {"column": "DEPH", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "DEPH.units", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "DEPH.standard_name", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P01::PRESPR01", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P01::ADEPZZ01", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P06::UPDB", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P06::ULAA", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"function": "coalesce", "args": [{"function": "pressure_to_depth_teos_10", "args": [{"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}], "alias": "pres"}, {"column": "LATITUDE", "alias": null}], "alias": "pres_harmonized"}, {"column": "DEPH", "alias": null}], "alias": "COMMON_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"column": ".institution_edmo_code", "alias": null}, {"column": ".institution_edmo_code", "alias": "COMMON_EDMO_CODE"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"column": ".featureType", "alias": null}, {"column": ".featureType", "alias": "COMMON_FEATURE_TYPE"}, {"column": ".bigram", "alias": null}, {"column": ".wmo_instrument_type", "alias": null}, {"column": ".source_platform_category_code", "alias": null}, {"function": "concat", "args": [{"value": "SDN:L06::", "alias": null}, {"column": ".source_platform_category_code", "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"column": ".id", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_CMEMS_BGC", "alias": "SOURCE_BDI"}, {"column": ".id", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": "CPHL", "alias": null}, {"column": "CPHL_QC", "alias": null}, {"column": "CPHL.units", "alias": null}, {"column": "CPHL.standard_name", "alias": null}, {"column": "CHLT", "alias": null}, {"column": "CHLT_QC", "alias": null}, {"column": "CHLT.units", "alias": null}, { ...
# Saved to ./output/cmems_bgc_1956.parquet
# Processing year 1957
# Running query: {"from": "default", "select": [{"column": "TIME", "alias": "COMMON_TIME"}, {"column": "TIME_QC", "alias": "COMMON_TIME_QC"}, {"column": "LONGITUDE", "alias": null}, {"column": "LONGITUDE", "alias": "COMMON_LONGITUDE"}, {"value": "degree_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "LATITUDE", "alias": null}, {"column": "LATITUDE", "alias": "COMMON_LATITUDE"}, {"value": "degree_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "POSITION_QC", "alias": null}, {"column": "POSITION_QC", "alias": "COMMON_POSITION_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}, {"column": "DEPH", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "DEPH.units", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "DEPH.standard_name", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P01::PRESPR01", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P01::ADEPZZ01", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P06::UPDB", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P06::ULAA", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"function": "coalesce", "args": [{"function": "pressure_to_depth_teos_10", "args": [{"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}], "alias": "pres"}, {"column": "LATITUDE", "alias": null}], "alias": "pres_harmonized"}, {"column": "DEPH", "alias": null}], "alias": "COMMON_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"column": ".institution_edmo_code", "alias": null}, {"column": ".institution_edmo_code", "alias": "COMMON_EDMO_CODE"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"column": ".featureType", "alias": null}, {"column": ".featureType", "alias": "COMMON_FEATURE_TYPE"}, {"column": ".bigram", "alias": null}, {"column": ".wmo_instrument_type", "alias": null}, {"column": ".source_platform_category_code", "alias": null}, {"function": "concat", "args": [{"value": "SDN:L06::", "alias": null}, {"column": ".source_platform_category_code", "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"column": ".id", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_CMEMS_BGC", "alias": "SOURCE_BDI"}, {"column": ".id", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": "CPHL", "alias": null}, {"column": "CPHL_QC", "alias": null}, {"column": "CPHL.units", "alias": null}, {"column": "CPHL.standard_name", "alias": null}, {"column": "CHLT", "alias": null}, {"column": "CHLT_QC", "alias": null}, {"column": "CHLT.units", "alias": null}, { ...
# Saved to ./output/cmems_bgc_1957.parquet
# Processing year 1958
# Running query: {"from": "default", "select": [{"column": "TIME", "alias": "COMMON_TIME"}, {"column": "TIME_QC", "alias": "COMMON_TIME_QC"}, {"column": "LONGITUDE", "alias": null}, {"column": "LONGITUDE", "alias": "COMMON_LONGITUDE"}, {"value": "degree_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "LATITUDE", "alias": null}, {"column": "LATITUDE", "alias": "COMMON_LATITUDE"}, {"value": "degree_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "POSITION_QC", "alias": null}, {"column": "POSITION_QC", "alias": "COMMON_POSITION_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}, {"column": "DEPH", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "DEPH.units", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "DEPH.standard_name", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P01::PRESPR01", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P01::ADEPZZ01", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P06::UPDB", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P06::ULAA", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"function": "coalesce", "args": [{"function": "pressure_to_depth_teos_10", "args": [{"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}], "alias": "pres"}, {"column": "LATITUDE", "alias": null}], "alias": "pres_harmonized"}, {"column": "DEPH", "alias": null}], "alias": "COMMON_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"column": ".institution_edmo_code", "alias": null}, {"column": ".institution_edmo_code", "alias": "COMMON_EDMO_CODE"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"column": ".featureType", "alias": null}, {"column": ".featureType", "alias": "COMMON_FEATURE_TYPE"}, {"column": ".bigram", "alias": null}, {"column": ".wmo_instrument_type", "alias": null}, {"column": ".source_platform_category_code", "alias": null}, {"function": "concat", "args": [{"value": "SDN:L06::", "alias": null}, {"column": ".source_platform_category_code", "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"column": ".id", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_CMEMS_BGC", "alias": "SOURCE_BDI"}, {"column": ".id", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": "CPHL", "alias": null}, {"column": "CPHL_QC", "alias": null}, {"column": "CPHL.units", "alias": null}, {"column": "CPHL.standard_name", "alias": null}, {"column": "CHLT", "alias": null}, {"column": "CHLT_QC", "alias": null}, {"column": "CHLT.units", "alias": null}, { ...
# Saved to ./output/cmems_bgc_1958.parquet
# Processing year 1959
# Running query: {"from": "default", "select": [{"column": "TIME", "alias": "COMMON_TIME"}, {"column": "TIME_QC", "alias": "COMMON_TIME_QC"}, {"column": "LONGITUDE", "alias": null}, {"column": "LONGITUDE", "alias": "COMMON_LONGITUDE"}, {"value": "degree_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "LATITUDE", "alias": null}, {"column": "LATITUDE", "alias": "COMMON_LATITUDE"}, {"value": "degree_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "POSITION_QC", "alias": null}, {"column": "POSITION_QC", "alias": "COMMON_POSITION_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}, {"column": "DEPH", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "DEPH.units", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "DEPH.standard_name", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P01::PRESPR01", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P01::ADEPZZ01", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P06::UPDB", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P06::ULAA", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"function": "coalesce", "args": [{"function": "pressure_to_depth_teos_10", "args": [{"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}], "alias": "pres"}, {"column": "LATITUDE", "alias": null}], "alias": "pres_harmonized"}, {"column": "DEPH", "alias": null}], "alias": "COMMON_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"column": ".institution_edmo_code", "alias": null}, {"column": ".institution_edmo_code", "alias": "COMMON_EDMO_CODE"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"column": ".featureType", "alias": null}, {"column": ".featureType", "alias": "COMMON_FEATURE_TYPE"}, {"column": ".bigram", "alias": null}, {"column": ".wmo_instrument_type", "alias": null}, {"column": ".source_platform_category_code", "alias": null}, {"function": "concat", "args": [{"value": "SDN:L06::", "alias": null}, {"column": ".source_platform_category_code", "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"column": ".id", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_CMEMS_BGC", "alias": "SOURCE_BDI"}, {"column": ".id", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": "CPHL", "alias": null}, {"column": "CPHL_QC", "alias": null}, {"column": "CPHL.units", "alias": null}, {"column": "CPHL.standard_name", "alias": null}, {"column": "CHLT", "alias": null}, {"column": "CHLT_QC", "alias": null}, {"column": "CHLT.units", "alias": null}, { ...
# Saved to ./output/cmems_bgc_1959.parquet
# Processing year 1960
# Running query: {"from": "default", "select": [{"column": "TIME", "alias": "COMMON_TIME"}, {"column": "TIME_QC", "alias": "COMMON_TIME_QC"}, {"column": "LONGITUDE", "alias": null}, {"column": "LONGITUDE", "alias": "COMMON_LONGITUDE"}, {"value": "degree_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "LATITUDE", "alias": null}, {"column": "LATITUDE", "alias": "COMMON_LATITUDE"}, {"value": "degree_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "POSITION_QC", "alias": null}, {"column": "POSITION_QC", "alias": "COMMON_POSITION_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}, {"column": "DEPH", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "DEPH.units", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "DEPH.standard_name", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P01::PRESPR01", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P01::ADEPZZ01", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P06::UPDB", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P06::ULAA", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"function": "coalesce", "args": [{"function": "pressure_to_depth_teos_10", "args": [{"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}], "alias": "pres"}, {"column": "LATITUDE", "alias": null}], "alias": "pres_harmonized"}, {"column": "DEPH", "alias": null}], "alias": "COMMON_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"column": ".institution_edmo_code", "alias": null}, {"column": ".institution_edmo_code", "alias": "COMMON_EDMO_CODE"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"column": ".featureType", "alias": null}, {"column": ".featureType", "alias": "COMMON_FEATURE_TYPE"}, {"column": ".bigram", "alias": null}, {"column": ".wmo_instrument_type", "alias": null}, {"column": ".source_platform_category_code", "alias": null}, {"function": "concat", "args": [{"value": "SDN:L06::", "alias": null}, {"column": ".source_platform_category_code", "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"column": ".id", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_CMEMS_BGC", "alias": "SOURCE_BDI"}, {"column": ".id", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": "CPHL", "alias": null}, {"column": "CPHL_QC", "alias": null}, {"column": "CPHL.units", "alias": null}, {"column": "CPHL.standard_name", "alias": null}, {"column": "CHLT", "alias": null}, {"column": "CHLT_QC", "alias": null}, {"column": "CHLT.units", "alias": null}, { ...
# Saved to ./output/cmems_bgc_1960.parquet
# Processing year 1961
# ...
# Saved to ./output/cmems_bgc_2021.parquet
# Processing year 2022
# Running query: {"from": "default", "select": [{"column": "TIME", "alias": "COMMON_TIME"}, {"column": "TIME_QC", "alias": "COMMON_TIME_QC"}, {"column": "LONGITUDE", "alias": null}, {"column": "LONGITUDE", "alias": "COMMON_LONGITUDE"}, {"value": "degree_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "LATITUDE", "alias": null}, {"column": "LATITUDE", "alias": "COMMON_LATITUDE"}, {"value": "degree_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "POSITION_QC", "alias": null}, {"column": "POSITION_QC", "alias": "COMMON_POSITION_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}, {"column": "DEPH", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "DEPH.units", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "DEPH.standard_name", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P01::PRESPR01", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P01::ADEPZZ01", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P06::UPDB", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P06::ULAA", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"function": "coalesce", "args": [{"function": "pressure_to_depth_teos_10", "args": [{"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}], "alias": "pres"}, {"column": "LATITUDE", "alias": null}], "alias": "pres_harmonized"}, {"column": "DEPH", "alias": null}], "alias": "COMMON_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"column": ".institution_edmo_code", "alias": null}, {"column": ".institution_edmo_code", "alias": "COMMON_EDMO_CODE"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"column": ".featureType", "alias": null}, {"column": ".featureType", "alias": "COMMON_FEATURE_TYPE"}, {"column": ".bigram", "alias": null}, {"column": ".wmo_instrument_type", "alias": null}, {"column": ".source_platform_category_code", "alias": null}, {"function": "concat", "args": [{"value": "SDN:L06::", "alias": null}, {"column": ".source_platform_category_code", "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"column": ".id", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_CMEMS_BGC", "alias": "SOURCE_BDI"}, {"column": ".id", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": "CPHL", "alias": null}, {"column": "CPHL_QC", "alias": null}, {"column": "CPHL.units", "alias": null}, {"column": "CPHL.standard_name", "alias": null}, {"column": "CHLT", "alias": null}, {"column": "CHLT_QC", "alias": null}, {"column": "CHLT.units", "alias": null}, { ...
# Saved to ./output/cmems_bgc_2022.parquet
# Processing year 2023
# Running query: {"from": "default", "select": [{"column": "TIME", "alias": "COMMON_TIME"}, {"column": "TIME_QC", "alias": "COMMON_TIME_QC"}, {"column": "LONGITUDE", "alias": null}, {"column": "LONGITUDE", "alias": "COMMON_LONGITUDE"}, {"value": "degree_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "LATITUDE", "alias": null}, {"column": "LATITUDE", "alias": "COMMON_LATITUDE"}, {"value": "degree_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "POSITION_QC", "alias": null}, {"column": "POSITION_QC", "alias": "COMMON_POSITION_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}, {"column": "DEPH", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "DEPH.units", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "DEPH.standard_name", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P01::PRESPR01", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P01::ADEPZZ01", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P06::UPDB", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P06::ULAA", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"function": "coalesce", "args": [{"function": "pressure_to_depth_teos_10", "args": [{"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}], "alias": "pres"}, {"column": "LATITUDE", "alias": null}], "alias": "pres_harmonized"}, {"column": "DEPH", "alias": null}], "alias": "COMMON_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"column": ".institution_edmo_code", "alias": null}, {"column": ".institution_edmo_code", "alias": "COMMON_EDMO_CODE"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"column": ".featureType", "alias": null}, {"column": ".featureType", "alias": "COMMON_FEATURE_TYPE"}, {"column": ".bigram", "alias": null}, {"column": ".wmo_instrument_type", "alias": null}, {"column": ".source_platform_category_code", "alias": null}, {"function": "concat", "args": [{"value": "SDN:L06::", "alias": null}, {"column": ".source_platform_category_code", "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"column": ".id", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_CMEMS_BGC", "alias": "SOURCE_BDI"}, {"column": ".id", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": "CPHL", "alias": null}, {"column": "CPHL_QC", "alias": null}, {"column": "CPHL.units", "alias": null}, {"column": "CPHL.standard_name", "alias": null}, {"column": "CHLT", "alias": null}, {"column": "CHLT_QC", "alias": null}, {"column": "CHLT.units", "alias": null}, { ...
# Saved to ./output/cmems_bgc_2023.parquet
# Processing year 2024
# Running query: {"from": "default", "select": [{"column": "TIME", "alias": "COMMON_TIME"}, {"column": "TIME_QC", "alias": "COMMON_TIME_QC"}, {"column": "LONGITUDE", "alias": null}, {"column": "LONGITUDE", "alias": "COMMON_LONGITUDE"}, {"value": "degree_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "LATITUDE", "alias": null}, {"column": "LATITUDE", "alias": "COMMON_LATITUDE"}, {"value": "degree_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "POSITION_QC", "alias": null}, {"column": "POSITION_QC", "alias": "COMMON_POSITION_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}, {"column": "DEPH", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "DEPH.units", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "DEPH.standard_name", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P01::PRESPR01", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P01::ADEPZZ01", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P06::UPDB", "alias": null}, {"column": "DEPH", "alias": null}, {"value": "SDN:P06::ULAA", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"function": "coalesce", "args": [{"function": "pressure_to_depth_teos_10", "args": [{"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}], "alias": "pres"}, {"column": "LATITUDE", "alias": null}], "alias": "pres_harmonized"}, {"column": "DEPH", "alias": null}], "alias": "COMMON_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"column": ".institution_edmo_code", "alias": null}, {"column": ".institution_edmo_code", "alias": "COMMON_EDMO_CODE"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"column": ".featureType", "alias": null}, {"column": ".featureType", "alias": "COMMON_FEATURE_TYPE"}, {"column": ".bigram", "alias": null}, {"column": ".wmo_instrument_type", "alias": null}, {"column": ".source_platform_category_code", "alias": null}, {"function": "concat", "args": [{"value": "SDN:L06::", "alias": null}, {"column": ".source_platform_category_code", "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"column": ".id", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_CMEMS_BGC", "alias": "SOURCE_BDI"}, {"column": ".id", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": "CPHL", "alias": null}, {"column": "CPHL_QC", "alias": null}, {"column": "CPHL.units", "alias": null}, {"column": "CPHL.standard_name", "alias": null}, {"column": "CHLT", "alias": null}, {"column": "CHLT_QC", "alias": null}, {"column": "CHLT.units", "alias": null}, { ...
# Saved to ./output/cmems_bgc_2024.parquet
