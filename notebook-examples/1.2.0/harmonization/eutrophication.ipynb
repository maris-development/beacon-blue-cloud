# %%
from beacon_api import *

# %%
client = Client("https://beacon-wb2-eutrophication.maris.nl",jwt_token="eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJodHRwczpcL1wvZGF0YS5ibHVlLWNsb3VkLm9yZyIsImF1ZCI6Imh0dHBzOlwvXC9kYXRhLmJsdWUtY2xvdWQub3JnIiwiaWF0IjoxNzI5NTA3NTE4LCJleHAiOjE3NjEwNDM1MTgsInVzciI6MTU2LCJpZCI6InNpbW9uYS5zaW1vbmNlbGxpQGluZ3YuaXQiLCJlcF9vcmdhbmlzYXRpb24iOiJJTkdWIn0.u0f-7RMxzQD5F8KAFpnP0YcNflvi3Rbk_zz7rsa9H-c")
# Out:
# Connected to: https://beacon-wb2-eutrophication.maris.nl/ server successfully

# %%
client.available_columns()
# Out:
# ['COMMON_TIME',
#  'COMMON_TIME_QC',
#  'LONGITUDE',
#  'COMMON_LONGITUDE',
#  'COMMON_LONGITUDE_UNITS',
#  'COMMON_LONGITUDE_STANDARD_NAME',
#  'COMMON_LONGITUDE_P01',
#  'COMMON_LONGITUDE_P06',
#  'LATITUDE',
#  'COMMON_LATITUDE',
#  'COMMON_LATITUDE_UNITS',
#  'COMMON_LATITUDE_STANDARD_NAME',
#  'COMMON_LATITUDE_P01',
#  'COMMON_LATITUDE_P06',
#  'POSITION_QC',
#  'COMMON_POSITION_QC',
#  'COMMON_ORIGIN_DEPTH',
#  'COMMON_ORIGIN_DEPTH_QC',
#  'COMMON_ORIGIN_DEPTH_UNITS',
#  'COMMON_ORIGIN_DEPTH_STANDARD_NAME',
#  'COMMON_ORIGIN_DEPTH_P01',
#  'COMMON_ORIGIN_DEPTH_P06',
#  'COMMON_DEPTH',
#  'COMMON_DEPTH_QC',
#  'COMMON_DEPTH_UNITS',
#  'COMMON_DEPTH_STANDARD_NAME',
#  'COMMON_DEPTH_P01',
#  'COMMON_DEPTH_P06',
#  '.institution_edmo_code',
#  'COMMON_EDMO_CODE',
#  'COMMON_EDMERP_CODE',
#  '.featureType',
#  'COMMON_FEATURE_TYPE',
#  '.bigram',
#  '.wmo_instrument_type',
#  '.source_platform_category_code',
#  'COMMON_PLATFORM_L06',
#  'COMMON_ODV_TAG',
#  'SOURCE_BDI',
# ...

# %%
df = (client.query()
    .add_select_column("SOURCE_BDI")
    .add_select_column("SOURCE_BDI_DATASET_ID")
    .add_select_column("COMMON_DEPTH")
    .add_equals_filter("SOURCE_BDI", "BEACON_CMEMS_BGC")
    .add_is_null_filter("SOURCE_BDI_DATASET_ID")
    .to_pandas_dataframe()
)
# Out:
# Running query: {"from": "default", "select": [{"column": "SOURCE_BDI", "alias": null}, {"column": "SOURCE_BDI_DATASET_ID", "alias": null}, {"column": "COMMON_DEPTH", "alias": null}], "filters": [{"column": "SOURCE_BDI", "eq": "BEACON_CMEMS_BGC"}, {"is_null": {"column": "SOURCE_BDI_DATASET_ID"}}], "output": {"format": "parquet"}}
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[12], line 7
#       1 df = (client.query()
#       2     .add_select_column("SOURCE_BDI")
#       3     .add_select_column("SOURCE_BDI_DATASET_ID")
#       4     .add_select_column("COMMON_DEPTH")
#       5     .add_equals_filter("SOURCE_BDI", "BEACON_CMEMS_BGC")
#       6     .add_is_null_filter("SOURCE_BDI_DATASET_ID")
# ----> 7     .to_pandas_dataframe()
#       8 )
#
# File ~/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages/beacon_api/query.py:831, in Query.to_pandas_dataframe(self)
# ...

# %%
df_cmems = df[df['SOURCE_BDI'] == 'BEACON_CMEMS_BGC']

# %%
df_cmems
# Out:
#                  SOURCE_BDI SOURCE_BDI_DATASET_ID  COMMON_DEPTH
# 0          BEACON_CMEMS_BGC         GL_PR_BO_ESMV      0.000000
# 1          BEACON_CMEMS_BGC         GL_PR_BO_ESMV     10.000000
# 2          BEACON_CMEMS_BGC         GL_PR_BO_ESMV     17.000000
# 3          BEACON_CMEMS_BGC         GL_PR_BO_ESMV      0.000000
# 4          BEACON_CMEMS_BGC         GL_PR_BO_ESMV     10.000000
# ...                     ...                   ...           ...
# 175211425  BEACON_CMEMS_BGC         GL_PR_CT_DBBH      0.000000
# 175211426  BEACON_CMEMS_BGC         GL_PR_CT_DBBH      4.949138
# 175211427  BEACON_CMEMS_BGC         GL_PR_CT_DBBH      9.898157
# 175211428  BEACON_CMEMS_BGC         GL_PR_CT_DBBH     14.847055
# 175211429  BEACON_CMEMS_BGC         GL_PR_CT_DBBH     19.795833
#
# [175211430 rows x 3 columns]

# %%
df['SOURCE_BDI_DATASET_ID'].value_counts()
# Out:
# SOURCE_BDI_DATASET_ID
# GL_TS_MO_ooi-gs-gs01sumo_1    12352855
# GL_PR_GL_EXGL0006             10641006
# NO_TS_MO_6600024               5283780
# NO_TS_MO_1000044               4497682
# IR_TS_MO_6201039               3369180
#                                 ...
# GL_PR_BO_OCL0035                     1
# BS_PR_BO_ANEBG3                      1
# GL_TS_BO_EXEC0380                    1
# GL_TS_BO_EXEC0319                    1
# BS_PR_BO_Z16                         1
# Name: count, Length: 7745, dtype: int64

# %%
df['SOURCE_BDI_DATASET_ID'].isnull().sum()
# Out:
# np.int64(0)
