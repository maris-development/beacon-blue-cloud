# %%
from beacon_api import *

# %%
client = Client("https://beacon-wb1-ts.maris.nl",jwt_token="eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJodHRwczpcL1wvZGF0YS5ibHVlLWNsb3VkLm9yZyIsImF1ZCI6Imh0dHBzOlwvXC9kYXRhLmJsdWUtY2xvdWQub3JnIiwiaWF0IjoxNzI5NTA3NTE4LCJleHAiOjE3NjEwNDM1MTgsInVzciI6MTU2LCJpZCI6InNpbW9uYS5zaW1vbmNlbGxpQGluZ3YuaXQiLCJlcF9vcmdhbmlzYXRpb24iOiJJTkdWIn0.u0f-7RMxzQD5F8KAFpnP0YcNflvi3Rbk_zz7rsa9H-c")
# Out:
# Connected to: https://beacon-wb1-ts.maris.nl/ server successfully

# %%
client.available_columns()
# Out:
# ['__entry_key',
#  'SOURCE_BDI',
#  'SOURCE_BDI_DATASET_ID',
#  'PLATFORM_NUMBER',
#  'CYCLE_NUMBER',
#  'WMO_INST_TYPE',
#  '.featureType',
#  'COMMON_FEATURE_TYPE',
#  'COMMON_ODV_TAG',
#  'COMMON_PLATFORM_L06',
#  'JULD',
#  'JULD_QC',
#  'COMMON_TIME',
#  'COMMON_TIME_QC',
#  'LATITUDE',
#  'LATITUDE.standard_name',
#  'LATITUDE.units',
#  'COMMON_LATITUDE',
#  'COMMON_LATITUDE_UNITS',
#  'COMMON_LATITUDE_STANDARD_NAME',
#  'COMMON_LATITUDE_P01',
#  'COMMON_LATITUDE_P06',
#  'LONGITUDE',
#  'LONGITUDE.standard_name',
#  'LONGITUDE.units',
#  'COMMON_LONGITUDE',
#  'COMMON_LONGITUDE_UNITS',
#  'COMMON_LONGITUDE_STANDARD_NAME',
#  'COMMON_LONGITUDE_P01',
#  'COMMON_LONGITUDE_P06',
#  'POSITION_QC',
#  'COMMON_POSITION_QC',
#  'PRES',
#  'PRES_ADJUSTED',
#  'PRES.units',
#  'PRES_ADJUSTED.units',
#  'PRES_QC',
#  'PRES_ADJUSTED_QC',
#  'COMMON_ORIGIN_DEPTH',
#  'COMMON_ORIGIN_DEPTH_QC',
#  'COMMON_ORIGIN_DEPTH_UNITS',
#  'COMMON_ORIGIN_DEPTH_STANDARD_NAME',
# ...
