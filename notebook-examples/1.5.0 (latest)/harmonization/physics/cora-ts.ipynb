# %%
# %pip install beacon-api --upgrade
# Out:
# Requirement already satisfied: beacon-api==1.0.9rc2 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (1.0.9rc2)
# Requirement already satisfied: requests>=2.0.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (2.32.5)
# Requirement already satisfied: pandas>=2.0.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (2.3.3)
# Requirement already satisfied: pyarrow!=19.0.0,>=17.0.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (21.0.0)
# Requirement already satisfied: xarray>=2023.1.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (2025.9.1)
# Requirement already satisfied: netCDF4>=1.5.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (1.7.2)
# Requirement already satisfied: typing_extensions>=4.10.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (4.15.0)
# Requirement already satisfied: numpy>=1.23.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (2.3.3)
# Requirement already satisfied: geopandas>=1.0.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (1.1.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from geopandas>=1.0.0->beacon-api==1.0.9rc2) (0.11.1)
# Requirement already satisfied: packaging in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from geopandas>=1.0.0->beacon-api==1.0.9rc2) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from geopandas>=1.0.0->beacon-api==1.0.9rc2) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from geopandas>=1.0.0->beacon-api==1.0.9rc2) (2.1.2)
# Requirement already satisfied: cftime in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from netCDF4>=1.5.0->beacon-api==1.0.9rc2) (1.6.4.post1)
# Requirement already satisfied: certifi in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from netCDF4>=1.5.0->beacon-api==1.0.9rc2) (2025.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from pandas>=2.0.0->beacon-api==1.0.9rc2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from pandas>=2.0.0->beacon-api==1.0.9rc2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from pandas>=2.0.0->beacon-api==1.0.9rc2) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from requests>=2.0.0->beacon-api==1.0.9rc2) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from requests>=2.0.0->beacon-api==1.0.9rc2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from requests>=2.0.0->beacon-api==1.0.9rc2) (2.5.0)
# Requirement already satisfied: six>=1.5 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->beacon-api==1.0.9rc2) (1.17.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from beacon_api import *
client = Client("https://beacon-cora-ts.maris.nl", jwt_token="<your_jwt_token_here>")
# Out:
# Connected to: https://beacon-cora-ts.maris.nl/ server successfully

# %%
tables = client.list_tables()
tables
# Out:
# {'default': <beacon_api.table.DataTable at 0x7fd5c4cdf8f0>}

# %%
tables['default'].get_table_schema()
# Out:
# __entry_key: string
# PLATFORM_NUMBER: string
# PLATFORM_NUMBER._FillValue: string
# PLATFORM_NUMBER.long_name: string
# STATION_PARAMETERS: string
# STATION_PARAMETERS._FillValue: string
# STATION_PARAMETERS.long_name: string
# STATION_PARAMETERS.conventions: string
# DC_REFERENCE: string
# DC_REFERENCE._FillValue: string
# DC_REFERENCE.long_name: string
# DC_REFERENCE.conventions: string
# DATA_MODE: string
# DATA_MODE._FillValue: string
# DATA_MODE.long_name: string
# DATA_MODE.conventions: string
# WMO_INST_TYPE: string
# WMO_INST_TYPE._FillValue: string
# WMO_INST_TYPE.long_name: string
# WMO_INST_TYPE.conventions: string
# TIME: timestamp[ms]
# TIME._FillValue: double
# TIME.long_name: string
# TIME.standard_name: string
# TIME.units: string
# TIME.valid_min: double
# TIME.valid_max: double
# TIME.uncertanity: string
# TIME.ancillary_variables: string
# TIME.calendar: string
# TIME.axis: string
# TIME_QC: int8
# TIME_QC._FillValue: int8
# TIME_QC.long_name: string
# TIME_QC.conventions: string
# TIME_QC.flag_values: string
# TIME_QC.valid_min: int8
# TIME_QC.valid_max: int8
# TIME_QC.flag_meanings: string
# LATITUDE: double
# LATITUDE._FillValue: double
# LATITUDE.long_name: string
# LATITUDE.standard_name: string
# LATITUDE.units: string
# LATITUDE.valid_min: double
# LATITUDE.valid_max: double
# LATITUDE.uncertanity: string
# LATITUDE.axis: string
# LONGITUDE: double
# LONGITUDE._FillValue: double
# LONGITUDE.long_name: string
# LONGITUDE.standard_name: string
# LONGITUDE.units: string
# LONGITUDE.valid_min: double
# LONGITUDE.valid_max: double
# LONGITUDE.uncertanity: string
# LONGITUDE.axis: string
# POSITION_QC: int8
# POSITION_QC._FillValue: int8
# POSITION_QC.long_name: string
# POSITION_QC.conventions: string
# POSITION_QC.flag_values: string
# POSITION_QC.valid_min: int8
# POSITION_QC.valid_max: int8
# POSITION_QC.flag_meanings: string
# PRES: float
# PRES._FillValue: float
# PRES.long_name: string
# PRES.standard_name: string
# PRES.units: string
# PRES.positive: string
# PRES.ancillary_variables: string
# PRES.axis: string
# PRES_QC: int8
# PRES_QC._FillValue: int8
# PRES_QC.long_name: string
# PRES_QC.conventions: string
# PRES_QC.flag_values: string
# PRES_QC.valid_min: int8
# PRES_QC.valid_max: int8
# PRES_QC.flag_meanings: string
# DEPH: float
# DEPH._FillValue: float
# DEPH.long_name: string
# DEPH.standard_name: string
# DEPH.units: string
# DEPH.valid_min: float
# DEPH.valid_max: float
# DEPH.reference: string
# DEPH.uncertainty: string
# DEPH.ancillary_variables: string
# DEPH.axis: string
# DEPH_QC: int8
# DEPH_QC._FillValue: int8
# DEPH_QC.long_name: string
# DEPH_QC.conventions: string
# DEPH_QC.flag_values: string
# DEPH_QC.valid_min: int8
# DEPH_QC.valid_max: int8
# DEPH_QC.flag_meanings: string
# PSAL: float
# PSAL._FillValue: float
# PSAL.long_name: string
# PSAL.standard_name: string
# PSAL.units: double
# PSAL.ancillary_variables: string
# PSAL_QC: int8
# PSAL_QC._FillValue: int8
# PSAL_QC.long_name: string
# PSAL_QC.conventions: string
# PSAL_QC.flag_values: string
# PSAL_QC.valid_min: int8
# PSAL_QC.valid_max: int8
# PSAL_QC.flag_meanings: string
# TEMP: float
# TEMP._FillValue: float
# TEMP.long_name: string
# TEMP.standard_name: string
# TEMP.units: string
# TEMP.ancillary_variables: string
# TEMP_QC: int8
# TEMP_QC._FillValue: int8
# TEMP_QC.long_name: string
# TEMP_QC.conventions: string
# TEMP_QC.flag_values: string
# TEMP_QC.valid_min: int8
# TEMP_QC.valid_max: int8
# TEMP_QC.flag_meanings: string
# PROFILE_QC: int8
# PROFILE_QC._FillValue: int8
# PROFILE_QC.long_name: string
# PROFILE_QC.conventions: string
# PROFILE_QC.flag_values: string
# PROFILE_QC.valid_min: int8
# PROFILE_QC.valid_max: int8
# PROFILE_QC.flag_meanings: string
# INSTITUTION: string
# INSTITUTION._FillValue: string
# INSTITUTION_EDMO_CODE: string
# INSTITUTION_EDMO_CODE._FillValue: string
# PROBE_TYPE: int8
# PROBE_TYPE._FillValue: int8
# PROBE_TYPE.long_name: string
# PROBE_TYPE.covention: string
# .title: string
# .date_update: string
# .reference_date_time: string
# .doi: string
# .pi_name: string
# .qc_manual: string
# .file_author: string
# .contact: string
# .netcdf_version: string
# .format_version: string
# .dataset_user_manual_version: string
# .dataset_quality_information_document_version: string
# .dataset_synthesis_quality_overview_document_version: string
# .dataset_release_date: string
# .extraction_date: string
# .references: string
# .geospatial_vertical_positive: string
# .Conventions: string
# .bigram: string
# DEPH_ADJUSTED: float
# DEPH_ADJUSTED._FillValue: float
# DEPH_ADJUSTED.long_name: string
# DEPH_ADJUSTED.standard_name: string
# DEPH_ADJUSTED.units: string
# DEPH_ADJUSTED.valid_min: float
# DEPH_ADJUSTED.valid_max: float
# DEPH_ADJUSTED.reference: string
# DEPH_ADJUSTED.uncertainty: string
# DEPH_ADJUSTED.ancillary_variables: string
# DEPH_ADJUSTED.axis: string
# DEPH_ADJUSTED_QC: int8
# DEPH_ADJUSTED_QC._FillValue: int8
# DEPH_ADJUSTED_QC.long_name: string
# DEPH_ADJUSTED_QC.conventions: string
# DEPH_ADJUSTED_QC.flag_values: string
# DEPH_ADJUSTED_QC.valid_min: int8
# DEPH_ADJUSTED_QC.valid_max: int8
# DEPH_ADJUSTED_QC.flag_meanings: string
# TEMP_ADJUSTED: float
# TEMP_ADJUSTED._FillValue: float
# TEMP_ADJUSTED.long_name: string
# TEMP_ADJUSTED.standard_name: string
# TEMP_ADJUSTED.units: string
# TEMP_ADJUSTED.ancillary_variables: string
# TEMP_ADJUSTED_QC: int8
# TEMP_ADJUSTED_QC._FillValue: int8
# TEMP_ADJUSTED_QC.long_name: string
# TEMP_ADJUSTED_QC.conventions: string
# TEMP_ADJUSTED_QC.flag_values: string
# TEMP_ADJUSTED_QC.valid_min: int8
# TEMP_ADJUSTED_QC.valid_max: int8
# TEMP_ADJUSTED_QC.flag_meanings: string
# PSAL_ADJUSTED: float
# PSAL_ADJUSTED._FillValue: float
# PSAL_ADJUSTED.long_name: string
# PSAL_ADJUSTED.standard_name: string
# PSAL_ADJUSTED.units: double
# PSAL_ADJUSTED.ancillary_variables: string
# PSAL_ADJUSTED_QC: int8
# PSAL_ADJUSTED_QC._FillValue: int8
# PSAL_ADJUSTED_QC.long_name: string
# PSAL_ADJUSTED_QC.conventions: string
# PSAL_ADJUSTED_QC.flag_values: string
# PSAL_ADJUSTED_QC.valid_min: int8
# PSAL_ADJUSTED_QC.valid_max: int8
# PSAL_ADJUSTED_QC.flag_meanings: string
# PRES_ADJUSTED: float
# PRES_ADJUSTED._FillValue: float
# PRES_ADJUSTED.long_name: string
# PRES_ADJUSTED.standard_name: string
# PRES_ADJUSTED.units: string
# PRES_ADJUSTED.positive: string
# PRES_ADJUSTED.ancillary_variables: string
# PRES_ADJUSTED.axis: string
# PRES_ADJUSTED_QC: int8
# PRES_ADJUSTED_QC._FillValue: int8
# PRES_ADJUSTED_QC.long_name: string
# PRES_ADJUSTED_QC.conventions: string
# PRES_ADJUSTED_QC.flag_values: string
# PRES_ADJUSTED_QC.valid_min: int8
# PRES_ADJUSTED_QC.valid_max: int8
# PRES_ADJUSTED_QC.flag_meanings: string
# PSAL_ADJUSTED_ERROR: float
# PSAL_ADJUSTED_ERROR._FillValue: float
# PSAL_ADJUSTED_ERROR.long_name: string
# PSAL_ADJUSTED_ERROR.units: string
# TEMP_ADJUSTED_ERROR: float
# TEMP_ADJUSTED_ERROR._FillValue: float
# TEMP_ADJUSTED_ERROR.long_name: string
# TEMP_ADJUSTED_ERROR.units: string

# %%
# METADATA
from datetime import datetime, timezone
dt_str = datetime.now(timezone.utc).strftime("%Y-%m-%dT%H:%M:%SZ")

query_builder = tables['default'].query()
query_builder = (
    query_builder
    .add_select_column("__entry_key")
    
    .add_select(SelectLiteral("BEACON_CORA_TS", alias="SOURCE_BDI"))
    .add_select(SelectLiteral("2026-01-12T00:00:00Z", "COMMON_BDI_SNAPSHOT_DATE"))
    .add_select(SelectLiteral("1.5.0", "COMMON_BDI_MONOLITH_VERSION"))
    .add_select(SelectLiteral(dt_str, "COMMON_HARMONIZATION_DATE"))
    
    .add_select(SelectColumn("DC_REFERENCE", alias="SOURCE_BDI_DATASET_ID"))
    .add_select(SelectColumn("PLATFORM_NUMBER"))
    .add_select(SelectColumn("DC_REFERENCE"))
    .add_select(SelectColumn("WMO_INST_TYPE"))
    .add_select(SelectColumn("INSTITUTION_EDMO_CODE"))
    .add_select(SelectColumn(".bigram"))
    .add_select(SelectColumn("INSTITUTION_EDMO_CODE", alias="COMMON_EDMO_CODE"))
    .add_select(SelectFunction("concat", [SelectColumn("__entry_key"), SelectColumn("DC_REFERENCE")], "COMMON_ODV_TAG"))
    .add_select(SelectFunction("map_cmems_bigram_l06", [SelectColumn(".bigram"),SelectFunction("btrim",[SelectColumn("WMO_INST_TYPE")])], alias="COMMON_PLATFORM_L06"))
    .add_select(
        SelectFunction("coalesce", 
            [
               SelectFunction("map_c17", [SelectColumn("PLATFORM_NUMBER")]), 
               SelectFunction("map_call_sign_c17", [SelectColumn("PLATFORM_NUMBER"), SelectColumn("TIME")])
            ], 
            alias="COMMON_PLATFORM_C17")
        )
)

# %%
query_builder = (
    query_builder
    .add_select(SelectColumn("TIME"))
    .add_select(SelectColumn("TIME_QC"))
    .add_select(SelectColumn("TIME", alias="COMMON_TIME"))
    .add_select(SelectColumn("TIME_QC", alias="COMMON_TIME_QC"))
    
    .add_select(SelectColumn("LATITUDE"))
    .add_select(SelectColumn("LATITUDE.standard_name"))
    .add_select(SelectColumn("LATITUDE.units"))
    .add_select(SelectColumn("LATITUDE", alias="COMMON_LATITUDE"))
    .add_select(SelectLiteral("degrees_north", "COMMON_LATITUDE_UNITS"))
    .add_select(SelectLiteral("Latitude", "COMMON_LATITUDE_STANDARD_NAME"))
    .add_select(SelectLiteral("SDN:P01::ALATZZ01", "COMMON_LATITUDE_P01"))
    .add_select(SelectLiteral("SDN:P06::DEGN", "COMMON_LATITUDE_P06"))
    
    .add_select(SelectColumn("LONGITUDE"))
    .add_select(SelectColumn("LONGITUDE.standard_name"))
    .add_select(SelectColumn("LONGITUDE.units"))
    .add_select(SelectColumn("LONGITUDE", alias="COMMON_LONGITUDE"))
    .add_select(SelectLiteral("degrees_east", "COMMON_LONGITUDE_UNITS"))
    .add_select(SelectLiteral("Longitude", "COMMON_LONGITUDE_STANDARD_NAME"))
    .add_select(SelectLiteral("SDN:P01::ALONZZ01", "COMMON_LONGITUDE_P01"))
    .add_select(SelectLiteral("SDN:P06::DEGE", "COMMON_LONGITUDE_P06"))
    
    .add_select(SelectColumn("POSITION_QC"))
    .add_select(SelectColumn("POSITION_QC", alias="COMMON_POSITION_QC"))
    
    # DEPTH
    
    .add_select_column("PRES")
    .add_select_column("PRES_ADJUSTED")
    .add_select_column("PRES.standard_name")
    .add_select_column("PRES_ADJUSTED.standard_name")
    .add_select_column("PRES.units")
    .add_select_column("PRES_ADJUSTED.units")
    .add_select_column("PRES_QC")
    .add_select_column("PRES_ADJUSTED_QC")
    .add_select_column("DEPH")
    .add_select_column("DEPH_ADJUSTED")
    .add_select_column("DEPH_QC")
    .add_select_column("DEPH_ADJUSTED_QC")
    .add_select_column("DEPH.standard_name")
    .add_select_column("DEPH_ADJUSTED.standard_name")
    .add_select_column("DEPH.units")
    .add_select_column("DEPH_ADJUSTED.units")
    
    # COALESCED DEPTH
    .add_select_coalesced(["PRES_ADJUSTED", "PRES", "DEPH"], "COMMON_ORIGIN_DEPTH")
    .add_select_coalesced(["PRES_ADJUSTED_QC","PRES_QC","DEPH_QC"], "COMMON_ORIGIN_DEPTH_QC")
    .add_select_coalesced(["PRES_ADJUSTED.units", "PRES.units", "DEPH.units"], "COMMON_ORIGIN_DEPTH_UNITS")
    .add_select_coalesced(["PRES_ADJUSTED.standard_name", "PRES.standard_name", "DEPH.standard_name"], "COMMON_ORIGIN_DEPTH_STANDARD_NAME")
    .add_select(SelectFunction("coalesce_label", [SelectColumn("PRES"), SelectLiteral("SDN:P01::PRESPR01"), SelectColumn("DEPH"), SelectLiteral("SDN:P01::ADEPZZ01")], "COMMON_ORIGIN_DEPTH_P01"))
    .add_select(SelectFunction("coalesce_label", [SelectColumn("PRES"), SelectLiteral("SDN:P06::UPDB"), SelectColumn("DEPH"), SelectLiteral("SDN:P06::ULAA")], "COMMON_ORIGIN_DEPTH_P06"))
    
    .add_select(Functions.coalesce([Functions.map_pressure_to_depth(Functions.coalesce(["PRES_ADJUSTED", "PRES"],"pres"), "LATITUDE", "pres_harmonized"), "DEPH"], "COMMON_DEPTH"))
    .add_select_coalesced(["PRES_ADJUSTED_QC","PRES_QC","DEPH_QC"], "COMMON_DEPTH_QC")
    .add_select(SelectLiteral("m", "COMMON_DEPTH_UNITS"))
    .add_select(SelectLiteral("depth", "COMMON_DEPTH_STANDARD_NAME"))
    .add_select(SelectLiteral("SDN:P01::ADEPZZ01", "COMMON_DEPTH_P01"))
    .add_select(SelectLiteral("SDN:P06::ULAA", "COMMON_DEPTH_P06"))
    
)

# %%
# map temperature
query_builder = (
    query_builder
    .add_select_column("TEMP")
    .add_select_column("TEMP_QC")
    .add_select_column("TEMP.units")
    .add_select_column("TEMP.standard_name")
    
    .add_select_column("TEMP_ADJUSTED")
    .add_select_column("TEMP_ADJUSTED_QC")
    .add_select_column("TEMP_ADJUSTED.units")
    .add_select_column("TEMP_ADJUSTED.standard_name")
    
    .add_select_coalesced(["TEMP", "TEMP_ADJUSTED"], "COMMON_ORIGIN_TEMPERATURE")
    .add_select_coalesced(["TEMP_QC", "TEMP_ADJUSTED_QC"], "COMMON_ORIGIN_TEMPERATURE_QC")
    .add_select_coalesced(["TEMP.units", "TEMP_ADJUSTED.units"], "COMMON_ORIGIN_TEMPERATURE_UNITS")
    .add_select_coalesced(["TEMP.standard_name", "TEMP_ADJUSTED.standard_name"], "COMMON_ORIGIN_TEMPERATURE_STANDARD_NAME")
    .add_select(SelectLiteral("SDN:P01::TEMPPR01", "COMMON_ORIGIN_TEMPERATURE_P01"))
    .add_select(SelectLiteral("SDN:P06::UPAA", "COMMON_ORIGIN_TEMPERATURE_P06"))
    
    .add_select_coalesced(["TEMP", "TEMP_ADJUSTED"], "COMMON_TEMPERATURE")
    .add_select_coalesced(["TEMP_QC", "TEMP_ADJUSTED_QC"], "COMMON_TEMPERATURE_QC")
    .add_select(SelectLiteral("degree_C", "COMMON_TEMPERATURE_UNITS"))
    .add_select(SelectLiteral("sea_water_temperature", "COMMON_TEMPERATURE_STANDARD_NAME"))
    .add_select(SelectLiteral("SDN:P01::TEMPPR01", "COMMON_TEMPERATURE_P01"))
    .add_select(SelectLiteral("SDN:P06::UPAA", "COMMON_TEMPERATURE_P06"))
    
    # Set instrument type
    .add_select(
        SelectFunction("coalesce", [
            SelectFunction("map_wmo_instrument_type_l05", [SelectFunction("btrim",[SelectColumn("WMO_INST_TYPE")])]),
            SelectFunction("map_l22_l05", [SelectFunction("map_wmo_instrument_type_l22", [SelectFunction("btrim",[SelectColumn("WMO_INST_TYPE")])])]),
            SelectFunction("map_cmems_bigram_l05", [SelectColumn(".bigram")])
            ], "COMMON_TEMPERATURE_L05"))
    .add_select(SelectFunction("map_wmo_instrument_type_l22", [SelectFunction("btrim",[SelectColumn("WMO_INST_TYPE")])], "COMMON_TEMPERATURE_L22"))
)

# %%
# map salinity
query_builder = (
    query_builder
    .add_select_column("PSAL")
    .add_select_column("PSAL_QC")
    .add_select_column("PSAL.units")
    .add_select_column("PSAL.standard_name")
    
    .add_select_column("PSAL_ADJUSTED")
    .add_select_column("PSAL_ADJUSTED_QC")
    .add_select_column("PSAL_ADJUSTED.units")
    .add_select_column("PSAL_ADJUSTED.standard_name")
    
    .add_select_coalesced(["PSAL", "PSAL_ADJUSTED"], "COMMON_ORIGIN_SALINITY")
    .add_select_coalesced(["PSAL_QC", "PSAL_ADJUSTED_QC"], "COMMON_ORIGIN_SALINITY_QC")
    .add_select_coalesced(["PSAL.units", "PSAL_ADJUSTED.units"], "COMMON_ORIGIN_SALINITY_UNITS")
    .add_select_coalesced(["PSAL.standard_name", "PSAL_ADJUSTED.standard_name"], "COMMON_ORIGIN_SALINITY_STANDARD_NAME")
    .add_select(SelectLiteral("SDN:P01::PSLTZZ01", "COMMON_ORIGIN_SALINITY_P01"))
    .add_select(SelectLiteral("SDN:P06::UUUU", "COMMON_ORIGIN_SALINITY_P06"))
    
    .add_select_coalesced(["PSAL", "PSAL_ADJUSTED"], "COMMON_SALINITY")
    .add_select_coalesced(["PSAL_QC", "PSAL_ADJUSTED_QC"], "COMMON_SALINITY_QC")
    .add_select(SelectLiteral("sea_water_practical_salinity", "COMMON_SALINITY_STANDARD_NAME"))
    .add_select(SelectLiteral("dimensionless", "COMMON_SALINITY_UNITS"))
    .add_select(SelectLiteral("SDN:P01::PSLTZZ01", "COMMON_SALINITY_P01"))
    .add_select(SelectLiteral("SDN:P06::UUUU", "COMMON_SALINITY_P06"))
    
    # Set instrument type
    .add_select(
        SelectFunction("coalesce", [
            SelectFunction("map_wmo_instrument_type_l05", [SelectFunction("btrim",[SelectColumn("WMO_INST_TYPE")])]),
            SelectFunction("map_l22_l05", [SelectFunction("map_wmo_instrument_type_l22", [SelectFunction("btrim",[SelectColumn("WMO_INST_TYPE")])])]),
            SelectFunction("map_cmems_bigram_l05", [SelectColumn(".bigram")])
            ], "COMMON_SALINITY_L05"))
    .add_select(SelectFunction("map_wmo_instrument_type_l22", [SelectFunction("btrim",[SelectColumn("WMO_INST_TYPE")])], "COMMON_SALINITY_L22"))
)

# %%
import os 
import json

# Make output dir
output_dir = "./output"
os.makedirs(output_dir, exist_ok=True)
# for each year between 1950 and 2025
for year in range(1950, 2026):
    print(f"Processing year {year}")
    query_builder.filters = []
    query_builder = query_builder.add_range_filter("TIME", f"{year}-01-01T00:00:00Z", f"{year}-12-31T23:59:59Z")
    query_builder = (
        query_builder
        .add_filter(OrFilter([
            IsNotNullFilter("TEMP"),
            IsNotNullFilter("PSAL"),
        ]))
    )
    output_file = os.path.join(output_dir, f"cora_ts_{year}.parquet")
    try:
        query_builder.to_parquet(output_file)
        print(f"Saved to {output_file}")
    except Exception as e:
        print(f"Failed to process year {year}: {e}")
# Out:
# Processing year 2020
# Running query: {"from": "default", "select": [{"column": "__entry_key", "alias": null}, {"value": "BEACON_CORA_TS", "alias": "SOURCE_BDI"}, {"column": "DC_REFERENCE", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": "PLATFORM_NUMBER", "alias": null}, {"column": "DC_REFERENCE", "alias": null}, {"column": "WMO_INST_TYPE", "alias": null}, {"column": "INSTITUTION_EDMO_CODE", "alias": null}, {"column": ".bigram", "alias": null}, {"column": "INSTITUTION_EDMO_CODE", "alias": "COMMON_EDMO_CODE"}, {"function": "concat", "args": [{"column": "__entry_key", "alias": null}, {"column": "DC_REFERENCE", "alias": null}], "alias": "COMMON_ODV_TAG"}, {"function": "map_cmems_bigram_l06", "args": [{"column": ".bigram", "alias": null}, {"function": "btrim", "args": [{"column": "WMO_INST_TYPE", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"function": "coalesce", "args": [{"function": "map_c17", "args": [{"column": "PLATFORM_NUMBER", "alias": null}], "alias": null}, {"function": "map_call_sign_c17", "args": [{"column": "PLATFORM_NUMBER", "alias": null}, {"column": "TIME", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_C17"}, {"column": "TIME", "alias": null}, {"column": "TIME_QC", "alias": null}, {"column": "TIME", "alias": "COMMON_TIME"}, {"column": "TIME_QC", "alias": "COMMON_TIME_QC"}, {"column": "LATITUDE", "alias": null}, {"column": "LATITUDE.standard_name", "alias": null}, {"column": "LATITUDE.units", "alias": null}, {"column": "LATITUDE", "alias": "COMMON_LATITUDE"}, {"value": "degrees_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "Latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "LONGITUDE", "alias": null}, {"column": "LONGITUDE.standard_name", "alias": null}, {"column": "LONGITUDE.units", "alias": null}, {"column": "LONGITUDE", "alias": "COMMON_LONGITUDE"}, {"value": "degrees_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "Longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "POSITION_QC", "alias": null}, {"column": "POSITION_QC", "alias": "COMMON_POSITION_QC"}, {"column": "PRES", "alias": null}, {"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "DEPH", "alias": null}, {"column": "DEPH_ADJUSTED", "alias": null}, {"column": "DEPH_QC", "alias": null}, {"column": "DEPH_ADJUSTED_QC", "alias": null}, {"column": "DEPH.standard_name", "alias": null}, {"column": "DEPH_ADJUSTED.standard_name", "alias": null}, {"column": "DEPH.units", "alias": null}, {"column": "DEPH_ADJUSTED.units", "alias": null}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}, {"column": "DEPH", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "DEPH.units", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "DEPH.standard_name", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P01::PRESPR01", "alias": null}, {"column": "DEPH", "alias" ...
# Saved to ./output/cora_ts_2020.parquet
# Processing year 2021
# Running query: {"from": "default", "select": [{"column": "__entry_key", "alias": null}, {"value": "BEACON_CORA_TS", "alias": "SOURCE_BDI"}, {"column": "DC_REFERENCE", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": "PLATFORM_NUMBER", "alias": null}, {"column": "DC_REFERENCE", "alias": null}, {"column": "WMO_INST_TYPE", "alias": null}, {"column": "INSTITUTION_EDMO_CODE", "alias": null}, {"column": ".bigram", "alias": null}, {"column": "INSTITUTION_EDMO_CODE", "alias": "COMMON_EDMO_CODE"}, {"function": "concat", "args": [{"column": "__entry_key", "alias": null}, {"column": "DC_REFERENCE", "alias": null}], "alias": "COMMON_ODV_TAG"}, {"function": "map_cmems_bigram_l06", "args": [{"column": ".bigram", "alias": null}, {"function": "btrim", "args": [{"column": "WMO_INST_TYPE", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"function": "coalesce", "args": [{"function": "map_c17", "args": [{"column": "PLATFORM_NUMBER", "alias": null}], "alias": null}, {"function": "map_call_sign_c17", "args": [{"column": "PLATFORM_NUMBER", "alias": null}, {"column": "TIME", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_C17"}, {"column": "TIME", "alias": null}, {"column": "TIME_QC", "alias": null}, {"column": "TIME", "alias": "COMMON_TIME"}, {"column": "TIME_QC", "alias": "COMMON_TIME_QC"}, {"column": "LATITUDE", "alias": null}, {"column": "LATITUDE.standard_name", "alias": null}, {"column": "LATITUDE.units", "alias": null}, {"column": "LATITUDE", "alias": "COMMON_LATITUDE"}, {"value": "degrees_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "Latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "LONGITUDE", "alias": null}, {"column": "LONGITUDE.standard_name", "alias": null}, {"column": "LONGITUDE.units", "alias": null}, {"column": "LONGITUDE", "alias": "COMMON_LONGITUDE"}, {"value": "degrees_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "Longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "POSITION_QC", "alias": null}, {"column": "POSITION_QC", "alias": "COMMON_POSITION_QC"}, {"column": "PRES", "alias": null}, {"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "DEPH", "alias": null}, {"column": "DEPH_ADJUSTED", "alias": null}, {"column": "DEPH_QC", "alias": null}, {"column": "DEPH_ADJUSTED_QC", "alias": null}, {"column": "DEPH.standard_name", "alias": null}, {"column": "DEPH_ADJUSTED.standard_name", "alias": null}, {"column": "DEPH.units", "alias": null}, {"column": "DEPH_ADJUSTED.units", "alias": null}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}, {"column": "DEPH", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "DEPH.units", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "DEPH.standard_name", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P01::PRESPR01", "alias": null}, {"column": "DEPH", "alias" ...
# Saved to ./output/cora_ts_2021.parquet
# Processing year 2022
# Running query: {"from": "default", "select": [{"column": "__entry_key", "alias": null}, {"value": "BEACON_CORA_TS", "alias": "SOURCE_BDI"}, {"column": "DC_REFERENCE", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": "PLATFORM_NUMBER", "alias": null}, {"column": "DC_REFERENCE", "alias": null}, {"column": "WMO_INST_TYPE", "alias": null}, {"column": "INSTITUTION_EDMO_CODE", "alias": null}, {"column": ".bigram", "alias": null}, {"column": "INSTITUTION_EDMO_CODE", "alias": "COMMON_EDMO_CODE"}, {"function": "concat", "args": [{"column": "__entry_key", "alias": null}, {"column": "DC_REFERENCE", "alias": null}], "alias": "COMMON_ODV_TAG"}, {"function": "map_cmems_bigram_l06", "args": [{"column": ".bigram", "alias": null}, {"function": "btrim", "args": [{"column": "WMO_INST_TYPE", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"function": "coalesce", "args": [{"function": "map_c17", "args": [{"column": "PLATFORM_NUMBER", "alias": null}], "alias": null}, {"function": "map_call_sign_c17", "args": [{"column": "PLATFORM_NUMBER", "alias": null}, {"column": "TIME", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_C17"}, {"column": "TIME", "alias": null}, {"column": "TIME_QC", "alias": null}, {"column": "TIME", "alias": "COMMON_TIME"}, {"column": "TIME_QC", "alias": "COMMON_TIME_QC"}, {"column": "LATITUDE", "alias": null}, {"column": "LATITUDE.standard_name", "alias": null}, {"column": "LATITUDE.units", "alias": null}, {"column": "LATITUDE", "alias": "COMMON_LATITUDE"}, {"value": "degrees_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "Latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "LONGITUDE", "alias": null}, {"column": "LONGITUDE.standard_name", "alias": null}, {"column": "LONGITUDE.units", "alias": null}, {"column": "LONGITUDE", "alias": "COMMON_LONGITUDE"}, {"value": "degrees_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "Longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "POSITION_QC", "alias": null}, {"column": "POSITION_QC", "alias": "COMMON_POSITION_QC"}, {"column": "PRES", "alias": null}, {"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "DEPH", "alias": null}, {"column": "DEPH_ADJUSTED", "alias": null}, {"column": "DEPH_QC", "alias": null}, {"column": "DEPH_ADJUSTED_QC", "alias": null}, {"column": "DEPH.standard_name", "alias": null}, {"column": "DEPH_ADJUSTED.standard_name", "alias": null}, {"column": "DEPH.units", "alias": null}, {"column": "DEPH_ADJUSTED.units", "alias": null}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}, {"column": "DEPH", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "DEPH.units", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "DEPH.standard_name", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P01::PRESPR01", "alias": null}, {"column": "DEPH", "alias" ...
# Saved to ./output/cora_ts_2022.parquet
# Processing year 2023
# Running query: {"from": "default", "select": [{"column": "__entry_key", "alias": null}, {"value": "BEACON_CORA_TS", "alias": "SOURCE_BDI"}, {"column": "DC_REFERENCE", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": "PLATFORM_NUMBER", "alias": null}, {"column": "DC_REFERENCE", "alias": null}, {"column": "WMO_INST_TYPE", "alias": null}, {"column": "INSTITUTION_EDMO_CODE", "alias": null}, {"column": ".bigram", "alias": null}, {"column": "INSTITUTION_EDMO_CODE", "alias": "COMMON_EDMO_CODE"}, {"function": "concat", "args": [{"column": "__entry_key", "alias": null}, {"column": "DC_REFERENCE", "alias": null}], "alias": "COMMON_ODV_TAG"}, {"function": "map_cmems_bigram_l06", "args": [{"column": ".bigram", "alias": null}, {"function": "btrim", "args": [{"column": "WMO_INST_TYPE", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"function": "coalesce", "args": [{"function": "map_c17", "args": [{"column": "PLATFORM_NUMBER", "alias": null}], "alias": null}, {"function": "map_call_sign_c17", "args": [{"column": "PLATFORM_NUMBER", "alias": null}, {"column": "TIME", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_C17"}, {"column": "TIME", "alias": null}, {"column": "TIME_QC", "alias": null}, {"column": "TIME", "alias": "COMMON_TIME"}, {"column": "TIME_QC", "alias": "COMMON_TIME_QC"}, {"column": "LATITUDE", "alias": null}, {"column": "LATITUDE.standard_name", "alias": null}, {"column": "LATITUDE.units", "alias": null}, {"column": "LATITUDE", "alias": "COMMON_LATITUDE"}, {"value": "degrees_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "Latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "LONGITUDE", "alias": null}, {"column": "LONGITUDE.standard_name", "alias": null}, {"column": "LONGITUDE.units", "alias": null}, {"column": "LONGITUDE", "alias": "COMMON_LONGITUDE"}, {"value": "degrees_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "Longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "POSITION_QC", "alias": null}, {"column": "POSITION_QC", "alias": "COMMON_POSITION_QC"}, {"column": "PRES", "alias": null}, {"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "DEPH", "alias": null}, {"column": "DEPH_ADJUSTED", "alias": null}, {"column": "DEPH_QC", "alias": null}, {"column": "DEPH_ADJUSTED_QC", "alias": null}, {"column": "DEPH.standard_name", "alias": null}, {"column": "DEPH_ADJUSTED.standard_name", "alias": null}, {"column": "DEPH.units", "alias": null}, {"column": "DEPH_ADJUSTED.units", "alias": null}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}, {"column": "DEPH", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "DEPH.units", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "DEPH.standard_name", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P01::PRESPR01", "alias": null}, {"column": "DEPH", "alias" ...
# Saved to ./output/cora_ts_2023.parquet
# Processing year 2024
# Running query: {"from": "default", "select": [{"column": "__entry_key", "alias": null}, {"value": "BEACON_CORA_TS", "alias": "SOURCE_BDI"}, {"column": "DC_REFERENCE", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": "PLATFORM_NUMBER", "alias": null}, {"column": "DC_REFERENCE", "alias": null}, {"column": "WMO_INST_TYPE", "alias": null}, {"column": "INSTITUTION_EDMO_CODE", "alias": null}, {"column": ".bigram", "alias": null}, {"column": "INSTITUTION_EDMO_CODE", "alias": "COMMON_EDMO_CODE"}, {"function": "concat", "args": [{"column": "__entry_key", "alias": null}, {"column": "DC_REFERENCE", "alias": null}], "alias": "COMMON_ODV_TAG"}, {"function": "map_cmems_bigram_l06", "args": [{"column": ".bigram", "alias": null}, {"function": "btrim", "args": [{"column": "WMO_INST_TYPE", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"function": "coalesce", "args": [{"function": "map_c17", "args": [{"column": "PLATFORM_NUMBER", "alias": null}], "alias": null}, {"function": "map_call_sign_c17", "args": [{"column": "PLATFORM_NUMBER", "alias": null}, {"column": "TIME", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_C17"}, {"column": "TIME", "alias": null}, {"column": "TIME_QC", "alias": null}, {"column": "TIME", "alias": "COMMON_TIME"}, {"column": "TIME_QC", "alias": "COMMON_TIME_QC"}, {"column": "LATITUDE", "alias": null}, {"column": "LATITUDE.standard_name", "alias": null}, {"column": "LATITUDE.units", "alias": null}, {"column": "LATITUDE", "alias": "COMMON_LATITUDE"}, {"value": "degrees_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "Latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "LONGITUDE", "alias": null}, {"column": "LONGITUDE.standard_name", "alias": null}, {"column": "LONGITUDE.units", "alias": null}, {"column": "LONGITUDE", "alias": "COMMON_LONGITUDE"}, {"value": "degrees_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "Longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "POSITION_QC", "alias": null}, {"column": "POSITION_QC", "alias": "COMMON_POSITION_QC"}, {"column": "PRES", "alias": null}, {"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "DEPH", "alias": null}, {"column": "DEPH_ADJUSTED", "alias": null}, {"column": "DEPH_QC", "alias": null}, {"column": "DEPH_ADJUSTED_QC", "alias": null}, {"column": "DEPH.standard_name", "alias": null}, {"column": "DEPH_ADJUSTED.standard_name", "alias": null}, {"column": "DEPH.units", "alias": null}, {"column": "DEPH_ADJUSTED.units", "alias": null}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}, {"column": "DEPH", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}, {"column": "DEPH_QC", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.units", "alias": null}, {"column": "PRES.units", "alias": null}, {"column": "DEPH.units", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED.standard_name", "alias": null}, {"column": "PRES.standard_name", "alias": null}, {"column": "DEPH.standard_name", "alias": null}], "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"function": "coalesce_label", "args": [{"column": "PRES", "alias": null}, {"value": "SDN:P01::PRESPR01", "alias": null}, {"column": "DEPH", "alias" ...
# Failed to process year 2024: Query returned no content
