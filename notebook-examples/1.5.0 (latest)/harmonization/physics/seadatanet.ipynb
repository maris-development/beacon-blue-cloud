# %%
# %pip install beacon-api --upgrade
# Out:
# Requirement already satisfied: beacon-api in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (1.0.9rc2)
# Collecting beacon-api
#   Downloading beacon_api-1.2.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: requests>=2.0.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api) (2.32.5)
# Requirement already satisfied: pandas>=2.0.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api) (2.3.3)
# Requirement already satisfied: pyarrow!=19.0.0,>=17.0.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api) (21.0.0)
# Requirement already satisfied: xarray>=2023.1.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api) (2025.9.0)
# Collecting fsspec>=2023.1.0 (from beacon-api)
#   Downloading fsspec-2026.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting dask>=2023.1.0 (from beacon-api)
#   Downloading dask-2026.1.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting zarr>=2.18 (from beacon-api)
#   Using cached zarr-3.1.5-py3-none-any.whl.metadata (10 kB)
# Collecting networkx>=3.0.0 (from beacon-api)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api) (3.10.7)
# Requirement already satisfied: netCDF4>=1.5.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api) (1.7.2)
# Requirement already satisfied: typing_extensions>=4.10.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api) (4.15.0)
# Requirement already satisfied: numpy>=1.23.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api) (2.3.4)
# Requirement already satisfied: geopandas>=1.1.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon-api) (1.1.1)
# Collecting deprecated>=1.2.14 (from beacon-api)
#   Using cached deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting click>=8.1 (from dask>=2023.1.0->beacon-api)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting cloudpickle>=3.0.0 (from dask>=2023.1.0->beacon-api)
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from dask>=2023.1.0->beacon-api) (25.0)
# Collecting partd>=1.4.0 (from dask>=2023.1.0->beacon-api)
#   Using cached partd-1.4.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting pyyaml>=5.3.1 (from dask>=2023.1.0->beacon-api)
#   Using cached pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting toolz>=0.12.0 (from dask>=2023.1.0->beacon-api)
#   Using cached toolz-1.1.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting wrapt<3,>=1.10 (from deprecated>=1.2.14->beacon-api)
#   Using cached wrapt-2.0.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Requirement already satisfied: pyogrio>=0.7.2 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from geopandas>=1.1.0->beacon-api) (0.11.1)
# Requirement already satisfied: pyproj>=3.5.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from geopandas>=1.1.0->beacon-api) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from geopandas>=1.1.0->beacon-api) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.0.0->beacon-api) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.0.0->beacon-api) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.0.0->beacon-api) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.0.0->beacon-api) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.0.0->beacon-api) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.0.0->beacon-api) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.0.0->beacon-api) (2.9.0.post0)
# Requirement already satisfied: cftime in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from netCDF4>=1.5.0->beacon-api) (1.6.4.post1)
# Requirement already satisfied: certifi in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from netCDF4>=1.5.0->beacon-api) (2025.8.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from pandas>=2.0.0->beacon-api) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from pandas>=2.0.0->beacon-api) (2025.2)
# Collecting locket (from partd>=1.4.0->dask>=2023.1.0->beacon-api)
#   Using cached locket-1.0.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: six>=1.5 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->beacon-api) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from requests>=2.0.0->beacon-api) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from requests>=2.0.0->beacon-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from requests>=2.0.0->beacon-api) (2.5.0)
# Collecting donfig>=0.8 (from zarr>=2.18->beacon-api)
#   Using cached donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Collecting google-crc32c>=1.5 (from zarr>=2.18->beacon-api)
#   Using cached google_crc32c-1.8.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (1.7 kB)
# Collecting numcodecs>=0.14 (from zarr>=2.18->beacon-api)
#   Using cached numcodecs-0.16.5-cp313-cp313-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Downloading beacon_api-1.2.0-py3-none-any.whl (31 kB)
# Downloading dask-2026.1.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 43.9 MB/s  0:00:00
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Using cached wrapt-2.0.1-cp313-cp313-macosx_11_0_arm64.whl (61 kB)
# Downloading fsspec-2026.1.0-py3-none-any.whl (201 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached partd-1.4.2-py3-none-any.whl (18 kB)
# Using cached pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl (173 kB)
# Using cached toolz-1.1.0-py3-none-any.whl (58 kB)
# Using cached zarr-3.1.5-py3-none-any.whl (284 kB)
# Using cached donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Using cached google_crc32c-1.8.0-cp313-cp313-macosx_12_0_arm64.whl (31 kB)
# Using cached numcodecs-0.16.5-cp313-cp313-macosx_11_0_arm64.whl (1.1 MB)
# Using cached locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: wrapt, toolz, pyyaml, numcodecs, networkx, locket, google-crc32c, fsspec, cloudpickle, click, partd, donfig, deprecated, zarr, dask, beacon-api
#   Attempting uninstall: beacon-api━━━━━━━━━╺━━━━ 14/16 [dask]]kx]
#     Found existing installation: beacon-api 1.0.9rc2m━━━━ 14/16 [dask]
#     Uninstalling beacon-api-1.0.9rc2:━━╺━━━━ 14/16 [dask]
#       Successfully uninstalled beacon-api-1.0.9rc2━━━━ 14/16 [dask]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [beacon-api]m [dask]
# Successfully installed beacon-api-1.2.0 click-8.3.1 cloudpickle-3.1.2 dask-2026.1.1 deprecated-1.3.1 donfig-0.8.1.post1 fsspec-2026.1.0 google-crc32c-1.8.0 locket-1.0.0 networkx-3.6.1 numcodecs-0.16.5 partd-1.4.2 pyyaml-6.0.3 toolz-1.1.0 wrapt-2.0.1 zarr-3.1.5
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from beacon_api import *
client = Client("https://beacon-cdi.maris.nl", jwt_token="<your_jwt_token_here>")

# %%
tables = client.list_tables()
tables

# %%
tables['default'].get_table_schema()

# %%
# METADATA
from datetime import datetime, timezone
dt_str = datetime.now(timezone.utc).strftime("%Y-%m-%dT%H:%M:%SZ")

query_builder = tables['default'].query()
query_builder = (
    query_builder
    .add_select_column("__entry_key")
    .add_select(SelectLiteral("BEACON_SEADATANET", alias="SOURCE_BDI"))
    .add_select(SelectFunction("concat", [SelectColumn("SDN_EDMO_CODE"), SelectColumn("SDN_LOCAL_CDI_ID")], alias="SOURCE_BDI_DATASET_ID"))
    .add_select(SelectColumn("SDN_LOCAL_CDI_ID"))
    .add_select(SelectColumn("SDN_EDMO_CODE"))
    
    .add_select(SelectLiteral("2026-01-16T00:00:00Z", "COMMON_BDI_SNAPSHOT_DATE"))
    .add_select(SelectLiteral("1.5.0", "COMMON_BDI_MONOLITH_VERSION"))
    .add_select(SelectLiteral(dt_str, "COMMON_HARMONIZATION_DATE"))

    .add_select_column(".csr_platform_code")
    .add_select_column(".csr_platform_code", "COMMON_CSR")
    .add_select(SelectColumn(".instrument___gear_type"))
    .add_select(SelectColumn(".featureType"))
    .add_select(SelectColumn(".featureType", alias="COMMON_FEATURE_TYPE"))
    .add_select(SelectColumn(".originator", alias="COMMON_EDMO_CODE"))
    .add_select(SelectFunction("concat", [SelectColumn("SDN_EDMO_CODE"), SelectColumn("SDN_LOCAL_CDI_ID")], "COMMON_ODV_TAG"))
    .add_select(SelectColumn(".platform_type"))
    .add_select(SelectFunction("map_seadatanet_platform_l06", [SelectColumn(".platform_type")], alias="COMMON_PLATFORM_L06"))
    .add_select(SelectFunction("nvl2", [
        SelectColumn(".csr_platform_code"),
        SelectFunction("concat", [
            SelectLiteral("SDN:C17::"),
            SelectColumn(".csr_platform_code")
            ]),
        SelectLiteral("")
        ],
        alias="COMMON_PLATFORM_C17"))
    
)

# %%
query_builder = (
    query_builder
    .add_select(SelectColumn("TIME"))
    .add_select(SelectColumn("TIME_SEADATANET_QC"))
    .add_select(SelectColumn("TIME", alias="COMMON_TIME"))
    .add_select(SelectFunction("cast_int8_as_char",[SelectColumn("TIME_SEADATANET_QC")], alias="COMMON_TIME_QC"))

    .add_select(SelectColumn("LATITUDE"))
    .add_select(SelectColumn("LATITUDE.standard_name"))
    .add_select(SelectColumn("LATITUDE.units"))
    .add_select(SelectColumn("LATITUDE", alias="COMMON_LATITUDE"))
    .add_select(SelectLiteral("degrees_north", "COMMON_LATITUDE_UNITS"))
    .add_select(SelectLiteral("Latitude", "COMMON_LATITUDE_STANDARD_NAME"))
    .add_select(SelectLiteral("SDN:P01::ALATZZ01", "COMMON_LATITUDE_P01"))
    .add_select(SelectLiteral("SDN:P06::DEGN", "COMMON_LATITUDE_P06"))
    
    .add_select(SelectColumn("LONGITUDE"))
    .add_select(SelectColumn("LONGITUDE.standard_name"))
    .add_select(SelectColumn("LONGITUDE.units"))
    .add_select(SelectColumn("LONGITUDE", alias="COMMON_LONGITUDE"))
    .add_select(SelectLiteral("degrees_east", "COMMON_LONGITUDE_UNITS"))
    .add_select(SelectLiteral("Longitude", "COMMON_LONGITUDE_STANDARD_NAME"))
    .add_select(SelectLiteral("SDN:P01::ALONZZ01", "COMMON_LONGITUDE_P01"))
    .add_select(SelectLiteral("SDN:P06::DEGE", "COMMON_LONGITUDE_P06"))
    
    .add_select(SelectColumn("POSITION_SEADATANET_QC"))
    .add_select(SelectFunction("cast_int8_as_char",[SelectColumn("POSITION_SEADATANET_QC")], alias="COMMON_POSITION_QC"))
    
    # DEPTH
    .add_select_column("PRES")
    .add_select_column("PRESPR01")
    .add_select_column("PRESPS02")
    .add_select_column("DEPTH")
    .add_select_column("ADEPZZ01")
    .add_select_column("DEPH")
    .add_select_column("DEPHPR01")
    
    .add_select_coalesced(["PRES", "PRESPR01", "PRESPS02", "DEPTH", "ADEPZZ01", "DEPH", "DEPHPR01"], alias="COMMON_ORIGIN_DEPTH")
    .add_select(SelectFunction("cast_int8_as_char", [
        Functions.coalesce(["PRES_SEADATANET_QC", 
                            "PRESPR01_SEADATANET_QC", 
                            "PRESPS02_SEADATANET_QC", 
                            "DEPTH_SEADATANET_QC", 
                            "ADEPZZ01_SEADATANET_QC", 
                            "DEPH_SEADATANET_QC", 
                            "DEPHPR01_SEADATANET_QC"], "merged_depth_qc")], 
                            alias="COMMON_ORIGIN_DEPTH_QC"))
    # COALESCED DEPTH
    .add_select(
        Functions.coalesce(
            [
                Functions.map_pressure_to_depth(
                    Functions.coalesce(["PRES",
                                        "PRESPR01",
                                        "PRESPS02"], alias = 'PRESSURE'),
                    "LATITUDE",
                    alias="depth_from_pres",
                ),  "DEPTH",
                    "ADEPZZ01",
                    "DEPH",
                    "DEPHPR01"
            ],
            alias="COMMON_DEPTH",
        )
    )
    .add_select(SelectFunction("cast_int8_as_char", [
        Functions.coalesce(["PRES_SEADATANET_QC", 
                            "PRESPR01_SEADATANET_QC", 
                            "PRESPS02_SEADATANET_QC", 
                            "DEPTH_SEADATANET_QC", 
                            "ADEPZZ01_SEADATANET_QC", 
                            "DEPH_SEADATANET_QC", 
                            "DEPHPR01_SEADATANET_QC"], "merged_depth_qc")], 
                            alias="COMMON_DEPTH_QC"))
    .add_select(SelectLiteral("m", "COMMON_DEPTH_UNITS"))
    .add_select(SelectLiteral("depth", "COMMON_DEPTH_STANDARD_NAME"))
    .add_select(SelectLiteral("SDN:P01::ADEPZZ01", "COMMON_DEPTH_P01"))
    .add_select(SelectLiteral("SDN:P06::ULAA", "COMMON_DEPTH_P06"))
)

# %%
# TEMPERATURE
query_builder = (
    query_builder
    .add_select_coalesced([
                "PSSTTS01",
                "TEMPBT01",
                "TEMPCC01",
                "TEMPCC02",
                "TEMPCU01",
                "TEMPCU02",
                "TEMPDTNX",
                "TEMPET01",
                "TEMPHG01",
                "TEMPHG02",
                "TEMPHGNX",
                "TEMPHU01",
                "TEMPMT01",
                "TEMPP901",
                "TEMPPR01",
                "TEMPRTNX",
                "TEMPS601",
                "TEMPS901",
                "TEMPST01",
                "TEMPST02",
                "TEMPSU01",
                "TEMPSZ01",
                "TEMPTC01",
                "TEMPTC02",
                "TMCLCCI1",
                "TMCLCCL1"], 
                alias="COMMON_TEMPERATURE")
    .add_select(SelectFunction("cast_int8_as_char", [
        Functions.coalesce(["PSSTTS01_SEADATANET_QC",
                "TEMPCC01_SEADATANET_QC",
                "TEMPCC02_SEADATANET_QC",
                "TEMPCU01_SEADATANET_QC",
                "TEMPCU02_SEADATANET_QC",
                "TEMPDTNX_SEADATANET_QC",
                "TEMPET01_SEADATANET_QC",
                "TEMPHG01_SEADATANET_QC",
                "TEMPHG02_SEADATANET_QC",
                "TEMPHGNX_SEADATANET_QC",
                "TEMPHU01_SEADATANET_QC",
                "TEMPMT01_SEADATANET_QC",
                "TEMPP901_SEADATANET_QC",
                "TEMPPR01_SEADATANET_QC",
                "TEMPRTNX_SEADATANET_QC",
                "TEMPS601_SEADATANET_QC",
                "TEMPS901_SEADATANET_QC",
                "TEMPST01_SEADATANET_QC",
                "TEMPST02_SEADATANET_QC",
                "TEMPSU01_SEADATANET_QC",
                "TEMPSZ01_SEADATANET_QC",
                "TEMPTC01_SEADATANET_QC",
                "TEMPTC02_SEADATANET_QC",
                "TMCLCCI1_SEADATANET_QC",
                "TMCLCCL1_SEADATANET_QC"], "merged_temperature_qc")],
                alias="COMMON_TEMPERATURE_QC"))
    .add_select(SelectLiteral("degree_C", "COMMON_TEMPERATURE_UNITS"))
    .add_select(SelectLiteral("sea_water_temperature", "COMMON_TEMPERATURE_STANDARD_NAME"))
    .add_select(SelectLiteral("SDN:P01::TEMPPR01", "COMMON_TEMPERATURE_P01"))
    .add_select(SelectLiteral("SDN:P06::UPAA", "COMMON_TEMPERATURE_P06"))
    .add_select(SelectFunction("map_seadatanet_instrument_l05", [SelectColumn(".instrument___gear_type")], alias="COMMON_TEMPERATURE_L05"))
)

# %%
# SALINITY
query_builder = (
    query_builder
    .add_select_coalesced([
                "ASLTZZ01",
                "ODSDM021",
                "PSALBSTX",
                "PSALCC01",
                "PSALCC02",
                "PSALCU01",
                "PSALCU02",
                "PSALPR01",
                "PSALPR02",
                "PSALST01",
                "PSALSU01",
                "PSALSZ01",
                "PSALTC01",
                "PSALTC02",
                "PSALZZXX",
                "PSCLCCI1",
                "PSCLCCL1",
                "PSLTZZ01",
                "SSALAGT1",
                "SSALBSTX",
                "SSALPR01",
                "SSALSG01",
                "SSALST01",], 
                alias="COMMON_SALINITY")

    .add_select(SelectFunction("cast_int8_as_char", [Functions.coalesce(["ASLTZZ01_SEADATANET_QC",
                "ODSDM021_SEADATANET_QC",
                "PSALBSTX_SEADATANET_QC",
                "PSALCC01_SEADATANET_QC",
                "PSALCC02_SEADATANET_QC",
                "PSALCU01_SEADATANET_QC",
                "PSALCU02_SEADATANET_QC",
                "PSALPR01_SEADATANET_QC",
                "PSALPR02_SEADATANET_QC",
                "PSALST01_SEADATANET_QC",
                "PSALSU01_SEADATANET_QC",
                "PSALSZ01_SEADATANET_QC",
                "PSALTC01_SEADATANET_QC",
                "PSALTC02_SEADATANET_QC",
                "PSALZZXX_SEADATANET_QC",
                "PSCLCCI1_SEADATANET_QC",
                "PSCLCCL1_SEADATANET_QC",
                "PSLTZZ01_SEADATANET_QC",
                "SSALAGT1_SEADATANET_QC",
                "SSALBSTX_SEADATANET_QC",
                "SSALPR01_SEADATANET_QC",
                "SSALSG01_SEADATANET_QC",
                "SSALST01_SEADATANET_QC"], "merged_salinity_qc")], 
                alias="COMMON_SALINITY_QC"))
    .add_select(SelectLiteral("sea_water_practical_salinity", "COMMON_SALINITY_STANDARD_NAME"))
    .add_select(SelectLiteral("dimensionless", "COMMON_SALINITY_UNITS"))
    .add_select(SelectLiteral("SDN:P01::PSLTZZ01", "COMMON_SALINITY_P01"))
    .add_select(SelectLiteral("SDN:P06::UUUU", "COMMON_SALINITY_P06"))
    .add_select(SelectFunction("map_seadatanet_instrument_l05", [SelectColumn(".instrument___gear_type")], alias="COMMON_SALINITY_L05"))
)

# %%
import os 
import json

# Make output dir
output_dir = "./output"
os.makedirs(output_dir, exist_ok=True)
# for each year between 1950 and 2025
for year in range(1950, 2026):
    print(f"Processing year {year}")
    query_builder.filters = []
    query_builder = query_builder.add_range_filter("COMMON_TIME", f"{year}-01-01T00:00:00Z", f"{year}-12-31T23:59:59Z")
    query_builder = (
        query_builder.add_filter(OrFilter([
            IsNotNullFilter("COMMON_TEMPERATURE"),
            IsNotNullFilter("COMMON_SALINITY"),
        ]))
    )
    
    output_file = os.path.join(output_dir, f"seadatanet_{year}.parquet")
    try:
        query_builder.to_parquet(output_file)
        print(f"Saved to {output_file}")
    except Exception as e:
        print(f"Failed to process year {year}: {e}")
