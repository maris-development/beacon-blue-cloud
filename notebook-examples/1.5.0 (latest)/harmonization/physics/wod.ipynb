# %%
# %pip install beacon-api --upgrade
# Out:
# Requirement already satisfied: beacon-api==1.0.9rc2 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (1.0.9rc2)
# Requirement already satisfied: requests>=2.0.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (2.32.5)
# Requirement already satisfied: pandas>=2.0.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (2.3.3)
# Requirement already satisfied: pyarrow!=19.0.0,>=17.0.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (21.0.0)
# Requirement already satisfied: xarray>=2023.1.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (2025.9.1)
# Requirement already satisfied: netCDF4>=1.5.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (1.7.2)
# Requirement already satisfied: typing_extensions>=4.10.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (4.15.0)
# Requirement already satisfied: numpy>=1.23.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (2.3.3)
# Requirement already satisfied: geopandas>=1.0.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from beacon-api==1.0.9rc2) (1.1.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from geopandas>=1.0.0->beacon-api==1.0.9rc2) (0.11.1)
# Requirement already satisfied: packaging in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from geopandas>=1.0.0->beacon-api==1.0.9rc2) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from geopandas>=1.0.0->beacon-api==1.0.9rc2) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from geopandas>=1.0.0->beacon-api==1.0.9rc2) (2.1.2)
# Requirement already satisfied: cftime in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from netCDF4>=1.5.0->beacon-api==1.0.9rc2) (1.6.4.post1)
# Requirement already satisfied: certifi in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from netCDF4>=1.5.0->beacon-api==1.0.9rc2) (2025.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from pandas>=2.0.0->beacon-api==1.0.9rc2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from pandas>=2.0.0->beacon-api==1.0.9rc2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from pandas>=2.0.0->beacon-api==1.0.9rc2) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from requests>=2.0.0->beacon-api==1.0.9rc2) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from requests>=2.0.0->beacon-api==1.0.9rc2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from requests>=2.0.0->beacon-api==1.0.9rc2) (2.5.0)
# Requirement already satisfied: six>=1.5 in /home/maris/git/beacon-blue-cloud/myenv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->beacon-api==1.0.9rc2) (1.17.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from beacon_api import *
client = Client("https://beacon-wod.maris.nl", jwt_token="<your_jwt_token_here>")
# Out:
# Connected to: https://beacon-wod.maris.nl/ server successfully

# %%
tables = client.list_tables()
tables
# Out:
# {'easy-wod': <beacon_api.table.DataTable at 0x7f9f101065d0>,
#  'default': <beacon_api.table.DataTable at 0x7f9e8f74cbf0>}

# %%
tables['default'].get_table_schema()
# Out:
# __entry_key: string
# lat: float
# lat.standard_name: string
# lat.long_name: string
# lat.lat_units: string
# lon: float
# lon.standard_name: string
# lon.long_name: string
# lon.lon_units: string
# time: timestamp[ms]
# time.standard_name: string
# time.long_name: string
# time.units: string
# cast: int32
# cast.comment: string
# country: string
# WOD_cruise_identifier: string
# WOD_cruise_identifier.comment: string
# WOD_cruise_identifier.long_name: string
# originators_cruise_identifier: string
# wod_unique_cast: int32
# wod_unique_cast.cf_role: string
# lat.units: string
# lat.axis: string
# lon.units: string
# lon.axis: string
# time.axis: string
# date: int32
# date.long_name: string
# date.comment: string
# GMT_time: float
# GMT_time.long_name: string
# Access_no: int32
# Access_no.long_name: string
# Access_no.units: string
# Access_no.comment: string
# Project: string
# Project.long_name: string
# Project.comment: string
# Platform: string
# Platform.long_name: string
# Platform.comment: string
# Orig_Stat_Num: int32
# Orig_Stat_Num.long_name: string
# Orig_Stat_Num.comment: string
# dataset: string
# dataset.long_name: string
# z: float
# z.standard_name: string
# z.long_name: string
# z.units: string
# z.positive: string
# z_WODflag: int16
# z_sigfig: int16
# Temperature: float
# Temperature.long_name: string
# Temperature.standard_name: string
# Temperature.units: string
# Temperature.coordinates: string
# Temperature.grid_mapping: string
# Temperature_sigfigs: int16
# Temperature_WODflag: int16
# Temperature_WODflag.flag_definitions: string
# Temperature_WODprofileflag: int16
# Temperature_WODprofileflag.flag_definitions: string
# Temperature_Instrument: string
# Temperature_Instrument.long_name: string
# Temperature_Instrument.comment: string
# Salinity: float
# Salinity.long_name: string
# Salinity.standard_name: string
# Salinity_sigfigs: int16
# Salinity_WODflag: int16
# Salinity_WODflag.flag_definitions: string
# Salinity_WODprofileflag: int16
# Salinity_WODprofileflag.flag_definitions: string
# Salinity_Instrument: string
# Salinity_Instrument.long_name: string
# Salinity_Instrument.comment: string
# Pressure: float
# Pressure.long_name: string
# Pressure.standard_name: string
# Pressure.units: string
# Pressure.coordinates: string
# Pressure.grid_mapping: string
# Pressure_sigfigs: int16
# crs: int32
# crs.grid_mapping_name: string
# crs.epsg_code: string
# crs.longitude_of_prime_meridian: float
# crs.semi_major_axis: float
# crs.inverse_flattening: float
# WODf: int16
# WODf.long_name: string
# WODf.flag_meanings: string
# WODfp: int16
# WODfp.long_name: string
# WODfp.flag_meanings: string
# WODfd: int16
# WODfd.long_name: string
# WODfd.flag_meanings: string
# .flag_definitions: string
# .institution: string
# .source: string
# .references: string
# .title: string
# .summary: string
# .id: string
# .naming authority: string
# .geospatial_lat_min: float
# .geospatial_lat_max: float
# .geospatial_lat_resolution: string
# .geospatial_lon_min: float
# .geospatial_lon_max: float
# .geospatial_lon_resolution: string
# .geospatial_vertical_min: float
# .geospatial_vertical_max: float
# .geospatial_vertical_positive: string
# .geospatial_vertical_units: string
# .creator_name: string
# .creator_email: string
# .creator_url: string
# .project: string
# .acknowledgements: string
# .processing_level: string
# .keywords: string
# .keywords_vocabulary: string
# .date_created: string
# .date_modified: string
# .publisher_name: string
# .publisher_url: string
# .publisher_email: string
# .history: string
# .license: string
# .standard_name_vocabulary: string
# .featureType: string
# .cdm_data_type: string
# .Conventions: string
# dbase_orig: string
# dbase_orig.long_name: string
# dbase_orig.comment: string
# Ocean_Vehicle: string
# Ocean_Vehicle.comment: string
# Temperature_uncalibrated: int32
# Temperature_uncalibrated.comment: string
# real_time: string
# real_time.long_name: string
# real_time.comment: string
# Bottom_Depth: float
# Bottom_Depth.long_name: string
# Bottom_Depth.units: string
# Institute: string
# Institute.long_name: string
# Institute.comment: string
# Cast_Tow_number: int32
# Cast_Tow_number.long_name: string
# Cast_Tow_number.comment: string
# Cast_Direction: string
# Cast_Direction.long_name: string
# Tow_segment: int32
# Tow_segment.comment: string
# Chlorophyll: float
# Chlorophyll.long_name: string
# Chlorophyll.standard_name: string
# Chlorophyll.units: string
# Chlorophyll.coordinates: string
# Chlorophyll.grid_mapping: string
# Chlorophyll_sigfigs: int16
# Chlorophyll_WODflag: int16
# Chlorophyll_WODflag.flag_definitions: string
# Chlorophyll_WODprofileflag: int16
# Chlorophyll_WODprofileflag.flag_definitions: string
# Chlorophyll_Instrument: string
# Chlorophyll_Instrument.long_name: string
# Chlorophyll_Instrument.comment: string
# Chlorophyll_Method: string
# Chlorophyll_Method.comment: string
# Oxygen: float
# Oxygen.long_name: string
# Oxygen.standard_name: string
# Oxygen.units: string
# Oxygen.coordinates: string
# Oxygen.grid_mapping: string
# Oxygen_sigfigs: int16
# Oxygen_WODflag: int16
# Oxygen_WODflag.flag_definitions: string
# Oxygen_WODprofileflag: int16
# Oxygen_WODprofileflag.flag_definitions: string
# Oxygen_Instrument: string
# Oxygen_Instrument.long_name: string
# Oxygen_Instrument.comment: string
# Oxygen_Original_units: string
# Oxygen_Original_units.comment: string
# Wave_Height: string
# Wave_Height.long_name: string
# Wave_Height.units: string
# Wind_Force: string
# Wind_Force.long_name: string
# Wind_Force.units: string
# Wave_Period: string
# Wave_Period.long_name: string
# Wave_Period.units: string
# Wind_Direction: string
# Wind_Direction.long_name: string
# Wind_Direction.units: string
# Barometric_Pres: float
# Barometric_Pres.long_name: string
# Barometric_Pres.units: string
# Dry_Bulb_Temp: float
# Dry_Bulb_Temp.long_name: string
# Dry_Bulb_Temp.units: string
# Wet_Bulb_Temp: float
# Wet_Bulb_Temp.long_name: string
# Wet_Bulb_Temp.units: string
# Weather_Condition: string
# Weather_Condition.long_name: string
# Weather_Condition.comment: string
# Cloud_Cover: string
# Cloud_Cover.long_name: string
# Cloud_Cover.units: string
# Wind_Speed: float
# Wind_Speed.long_name: string
# Wind_Speed.units: string
# Chlorophyll_uncalibrated: int32
# Chlorophyll_uncalibrated.comment: string
# WMO_ID: int32
# WMO_ID.long_name: string
# origflagset: string
# origflagset.comment: string
# z_origflag: int16
# z_origflag.flag_definitions: string
# Temperature_origflag: int16
# Temperature_origflag.flag_definitions: string
# Salinity_origflag: int16
# Salinity_origflag.flag_definitions: string
# Oflag: int32
# Oflag.long_name: string
# Oflag.flag_values: string
# Oflag.flag_meanings: string
# Recorder: string
# Recorder.long_name: string
# Recorder.units: string
# Recorder.comment: string
# Chlorophyll_origflag: int16
# Chlorophyll_origflag.flag_definitions: string
# Oxygen_origflag: int16
# Oxygen_origflag.flag_definitions: string
# Temperature_Adjustment: float
# Temperature_Adjustment.comment: string
# Salinity_Adjustment: float
# Salinity_Adjustment.comment: string
# Pressure_Instrument: string
# Pressure_Instrument.long_name: string
# Pressure_Instrument.comment: string
# Wave_Direction: string
# Wave_Direction.long_name: string
# Wave_Direction.units: string
# Ref_Surf_Temp: float
# Ref_Surf_Temp.units: string
# Ref_Surf_Temp.comment: string
# Surf_Salinity: float
# Surf_Salinity.long_name: string
# Surf_Salinity.comment: string
# Chlorophyll_Original_units: string
# Chlorophyll_Original_units.comment: string
# pCO2: float
# pCO2.long_name: string
# pCO2.standard_name: string
# pCO2.units: string
# pCO2.coordinates: string
# pCO2.grid_mapping: string
# pCO2_sigfigs: int16
# pCO2_WODflag: int16
# pCO2_WODflag.flag_definitions: string
# Temperature_data_mode: string
# Temperature_data_mode.comment: string
# Salinity_data_mode: string
# Salinity_data_mode.comment: string
# Pressure_data_mode: string
# Pressure_data_mode.comment: string
# Pressure_Adjustment: float
# Pressure_Adjustment.comment: string
# Temperature_prime_min_dep: float
# Temperature_prime_min_dep.comment: string
# Salinity_prime_min_dep: float
# Salinity_prime_min_dep.comment: string
# Oxygen_Adjustment: float
# Oxygen_Adjustment.comment: string
# Oxygen_data_mode: string
# Oxygen_data_mode.comment: string
# pH: float
# pH.long_name: string
# pH.standard_name: string
# pH_sigfigs: int16
# pH_WODflag: int16
# pH_WODflag.flag_definitions: string
# pH_origflag: int16
# pH_origflag.flag_definitions: string
# pH_WODprofileflag: int16
# pH_WODprofileflag.flag_definitions: string
# pH_data_mode: string
# pH_data_mode.comment: string
# Chlorophyll_Adjustment: float
# Chlorophyll_Adjustment.comment: string
# Chlorophyll_data_mode: string
# Chlorophyll_data_mode.comment: string
# pH_Adjustment: float
# pH_Adjustment.comment: string
# Nitrate: float
# Nitrate.long_name: string
# Nitrate.standard_name: string
# Nitrate.units: string
# Nitrate.coordinates: string
# Nitrate.grid_mapping: string
# Nitrate_sigfigs: int16
# Nitrate_WODflag: int16
# Nitrate_WODflag.flag_definitions: string
# Nitrate_origflag: int16
# Nitrate_origflag.flag_definitions: string
# Nitrate_WODprofileflag: int16
# Nitrate_WODprofileflag.flag_definitions: string
# Nitrate_Adjustment: float
# Nitrate_Adjustment.comment: string
# Transmissiv: float
# Transmissiv.long_name: string
# Transmissiv.units: string
# Transmissiv.coordinates: string
# Transmissiv.grid_mapping: string
# Transmissiv_sigfigs: int16
# Transmissiv_WODflag: int16
# Transmissiv_WODflag.flag_definitions: string
# Transmissiv_origflag: int16
# Transmissiv_origflag.flag_definitions: string
# Nitrate_data_mode: string
# Nitrate_data_mode.comment: string
# Transmissiv_data_mode: string
# Transmissiv_data_mode.comment: string
# originators_station_identifier: string
# originators_station_identifier.long_name: string
# needs_z_fix: string
# needs_z_fix.long_name: string
# needs_z_fix.units: string
# needs_z_fix.comment: string
# Digit_Method: string
# Digit_Method.long_name: string
# Digit_Method.comment: string
# Digit_Interval: string
# Digit_Interval.long_name: string
# Data_Storage: string
# Data_Storage.long_name: string
# .long_name: string
# .comment: string
# Cal_Depth: float
# Cal_Depth.long_name: string
# Cal_Depth.units: string
# Cal_Temp: float
# Cal_Temp.long_name: string
# Cal_Temp.units: string
# Sea_State: string
# Sea_State.long_name: string
# Sea_State.units: string
# Water_Color: string
# Water_Color.long_name: string
# Water_Color.units: string
# Weather_Stat: string
# Weather_Stat.long_name: string
# Weather_Stat.comment: string
# depth_eq: string
# depth_eq.long_name: string
# depth_eq.comment: string
# Cloud_Type: string
# Cloud_Type.long_name: string
# Cloud_Type.units: string
# Ref_Type: string
# Ref_Type.long_name: string
# Ref_Type.comment: string
# Water_Transpar: float
# Water_Transpar.long_name: string
# Water_Transpar.units: string
# Water_Transpar.comment: string
# Year_made: int32
# Year_made.long_name: string
# Year_made.units: string
# Primary_Investigator: string
# Primary_Investigator_VAR: string
# XBT_Wait: float
# XBT_Wait.comment: string
# XBT_Freq: float
# XBT_Freq.comment: string
# Visibility: string
# Visibility.long_name: string
# Visibility.units: string
# Launch_height: float
# Launch_height.long_name: string
# Launch_height.units: string
# Temperature_Access_no: int32
# Temperature_Access_no.long_name: string
# Temperature_Access_no.units: string
# Temperature_Access_no.comment: string
# sensor_depth: float
# sensor_depth.long_name: string
# sensor_depth.units: string
# Odflag: int32
# Odflag.long_name: string
# Odflag.flag_values: string
# Odflag.flag_meanings: string
# ARGOS_last_fix: float
# ARGOS_last_fix.units: string
# ARGOS_next_fix: float
# ARGOS_next_fix.units: string
# ARGOS_fix: string
# ARGOS_fix.units: string
# ARGOS_fix.comment: string
# Cast_Duration: float
# Cast_Duration.long_name: string
# Cast_Duration.units: string
# Absol_Humidity: float
# Absol_Humidity.long_name: string
# Absol_Humidity.units: string
# Conductivit: float
# Conductivit.long_name: string
# Conductivit.units: string
# Conductivit.coordinates: string
# Conductivit.grid_mapping: string
# Conductivit_sigfigs: int16
# Conductivit_WODflag: int16
# Conductivit_WODflag.flag_definitions: string
# Conductivit_Instrument: string
# Conductivit_Instrument.long_name: string
# Conductivit_Instrument.comment: string
# High_res_pair: int32
# High_res_pair.long_name: string
# High_res_pair.comment: string
# Temperature_Scale: string
# Temperature_Scale.long_name: string
# Salinity_Scale: string
# Salinity_Scale.long_name: string
# Transmissiv_Instrument: string
# Transmissiv_Instrument.long_name: string
# Transmissiv_Instrument.comment: string
# Salinity_uncalibrated: int32
# Salinity_uncalibrated.comment: string
# Transmissiv_uncalibrated: int32
# Transmissiv_uncalibrated.comment: string
# Oxygen_uncalibrated: int32
# Oxygen_uncalibrated.comment: string
# Transmissiv_Original_units: string
# Transmissiv_Original_units.comment: string
# Conductivit_Conductivity_stand: int32
# Conductivit_Conductivity_stand.comment: string
# Oxygen_Access_no: int32
# Oxygen_Access_no.long_name: string
# Oxygen_Access_no.units: string
# Oxygen_Access_no.comment: string
# Pathlength: float
# Pathlength.long_name: string
# Salinity_Access_no: int32
# Salinity_Access_no.long_name: string
# Salinity_Access_no.units: string
# Salinity_Access_no.comment: string
# Transmissiv_Access_no: int32
# Transmissiv_Access_no.long_name: string
# Transmissiv_Access_no.units: string
# Transmissiv_Access_no.comment: string
# Conductivit_Access_no: int32
# Conductivit_Access_no.long_name: string
# Conductivit_Access_no.units: string
# Conductivit_Access_no.comment: string
# Pressure_Access_no: int32
# Pressure_Access_no.long_name: string
# Pressure_Access_no.units: string
# Pressure_Access_no.comment: string
# Temperature_Institute: string
# Temperature_Institute.long_name: string
# Temperature_Institute.comment: string
# Salinity_Institute: string
# Salinity_Institute.long_name: string
# Salinity_Institute.comment: string
# Pressure_uncalibrated: int32
# Pressure_uncalibrated.comment: string
# Conductivit_origflag: int16
# Conductivit_origflag.flag_definitions: string
# Chlorophyll_Access_no: int32
# Chlorophyll_Access_no.long_name: string
# Chlorophyll_Access_no.units: string
# Chlorophyll_Access_no.comment: string
# Oxygen_Institute: string
# Oxygen_Institute.long_name: string
# Oxygen_Institute.comment: string
# Salinity_Project: string
# Salinity_Project.long_name: string
# Salinity_Project.comment: string
# Depth_unit: string
# Depth_unit.comment: string
# Temperature_Original_units: string
# Temperature_Original_units.comment: string
# Oxygen_Method: string
# Oxygen_Method.comment: string
# Transmissiv_Method: string
# Transmissiv_Method.comment: string
# Chlorophyll_Units_special: string
# Chlorophyll_Units_special.comment: string
# Conductivit_Original_units: string
# Conductivit_Original_units.comment: string
# Conductivit_uncalibrated: int32
# Conductivit_uncalibrated.comment: string
# pH_Instrument: string
# pH_Instrument.long_name: string
# pH_Instrument.comment: string
# Temp_Corr: float
# Temp_Corr.long_name: string
# Temp_Corr.units: string
# Dep_of_Corr: float
# Dep_of_Corr.long_name: string
# Dep_of_Corr.units: string
# Dep_of_Corr.comment: string
# Mesh_size: float
# Mesh_size.long_name: string
# Mesh_size.units: string
# Type_tow: string
# Type_tow.long_name: string
# Type_tow.units: string
# Type_tow.comment: string
# Gear_code: string
# Gear_code.long_name: string
# Gear_code.comment: string
# net_mouth_area: float
# net_mouth_area.long_name: string
# net_mouth_area.units: string
# net_mouth_area.comment: string
# Preservation: string
# Preservation.long_name: string
# Preservation.units: string
# Preservation.comment: string
# Taxon_count_001: float
# Taxon_count_001.comment: string
# Taxon_count_001.WOD_name: string
# Taxon_count_001.Param_number: int32
# Taxon_count_001.upper_depth: float
# Taxon_count_001.lower_depth: float
# Taxon_count_001.Taxon_lifestage: string
# Taxon_count_001.Taxon_sex_code: string
# Taxon_count_001.Units: string
# Taxon_count_001.PGC_group_code: int32
# Taxon_count_002: float
# Taxon_count_002.comment: string
# Taxon_count_002.WOD_name: string
# Taxon_count_002.Param_number: int32
# Taxon_count_002.upper_depth: float
# Taxon_count_002.lower_depth: float
# Taxon_count_002.Taxon_lifestage: string
# Taxon_count_002.Taxon_sex_code: string
# Taxon_count_002.Units: string
# Taxon_count_002.PGC_group_code: int32
# Taxon_count_003: float
# Taxon_count_003.comment: string
# Taxon_count_003.WOD_name: string
# Taxon_count_003.Param_number: int32
# Taxon_count_003.upper_depth: float
# Taxon_count_003.lower_depth: float
# Taxon_count_003.Taxon_lifestage: string
# Taxon_count_003.Taxon_sex_code: string
# Taxon_count_003.Units: string
# Taxon_count_003.PGC_group_code: int32
# Taxon_count_004: float
# Taxon_count_004.comment: string
# Taxon_count_004.WOD_name: string
# Taxon_count_004.Param_number: int32
# Taxon_count_004.upper_depth: float
# Taxon_count_004.lower_depth: float
# Taxon_count_004.Taxon_lifestage: string
# Taxon_count_004.Taxon_sex_code: string
# Taxon_count_004.Units: string
# Taxon_count_004.PGC_group_code: int32
# Taxon_count_005: float
# Taxon_count_005.comment: string
# Taxon_count_005.WOD_name: string
# Taxon_count_005.Param_number: int32
# Taxon_count_005.upper_depth: float
# Taxon_count_005.lower_depth: float
# Taxon_count_005.Taxon_lifestage: string
# Taxon_count_005.Taxon_sex_code: string
# Taxon_count_005.Units: string
# Taxon_count_005.PGC_group_code: int32
# Taxon_count_006: float
# Taxon_count_006.comment: string
# Taxon_count_006.WOD_name: string
# Taxon_count_006.Param_number: int32
# Taxon_count_006.upper_depth: float
# Taxon_count_006.lower_depth: float
# Taxon_count_006.Taxon_lifestage: string
# Taxon_count_006.Units: string
# Taxon_count_006.PGC_group_code: int32
# Taxon_count_007: float
# Taxon_count_007.comment: string
# Taxon_count_007.WOD_name: string
# Taxon_count_007.Param_number: int32
# Taxon_count_007.upper_depth: float
# Taxon_count_007.lower_depth: float
# Taxon_count_007.Taxon_lifestage: string
# Taxon_count_007.Units: string
# Taxon_count_007.PGC_group_code: int32
# Taxon_count_008: float
# Taxon_count_008.comment: string
# Taxon_count_008.WOD_name: string
# Taxon_count_008.Param_number: int32
# Taxon_count_008.upper_depth: float
# Taxon_count_008.lower_depth: float
# Taxon_count_008.Taxon_lifestage: string
# Taxon_count_008.Units: string
# Taxon_count_008.PGC_group_code: int32
# Taxon_count_009: float
# Taxon_count_009.comment: string
# Taxon_count_009.WOD_name: string
# Taxon_count_009.Param_number: int32
# Taxon_count_009.upper_depth: float
# Taxon_count_009.lower_depth: float
# Taxon_count_009.Taxon_lifestage: string
# Taxon_count_009.Units: string
# Taxon_count_009.PGC_group_code: int32
# Taxon_count_010: float
# Taxon_count_010.comment: string
# Taxon_count_010.WOD_name: string
# Taxon_count_010.Param_number: int32
# Taxon_count_010.upper_depth: float
# Taxon_count_010.lower_depth: float
# Taxon_count_010.Taxon_lifestage: string
# Taxon_count_010.Units: string
# Taxon_count_010.PGC_group_code: int32
# Taxon_count_011: float
# Taxon_count_011.comment: string
# Taxon_count_011.WOD_name: string
# Taxon_count_011.Param_number: int32
# Taxon_count_011.upper_depth: float
# Taxon_count_011.lower_depth: float
# Taxon_count_011.Taxon_lifestage: string
# Taxon_count_011.Units: string
# Taxon_count_011.PGC_group_code: int32
# Taxon_count_012: float
# Taxon_count_012.comment: string
# Taxon_count_012.WOD_name: string
# Taxon_count_012.Param_number: int32
# Taxon_count_012.upper_depth: float
# Taxon_count_012.lower_depth: float
# Taxon_count_012.Taxon_lifestage: string
# Taxon_count_012.Units: string
# Taxon_count_012.PGC_group_code: int32
# Taxon_count_013: float
# Taxon_count_013.comment: string
# Taxon_count_013.WOD_name: string
# Taxon_count_013.Param_number: int32
# Taxon_count_013.upper_depth: float
# Taxon_count_013.lower_depth: float
# Taxon_count_013.Taxon_lifestage: string
# Taxon_count_013.Units: string
# Taxon_count_013.PGC_group_code: int32
# Taxon_count_014: float
# Taxon_count_014.comment: string
# Taxon_count_014.WOD_name: string
# Taxon_count_014.Param_number: int32
# Taxon_count_014.upper_depth: float
# Taxon_count_014.lower_depth: float
# Taxon_count_014.Taxon_lifestage: string
# Taxon_count_014.Units: string
# Taxon_count_014.PGC_group_code: int32
# Taxon_count_015: float
# Taxon_count_015.comment: string
# Taxon_count_015.WOD_name: string
# Taxon_count_015.Param_number: int32
# Taxon_count_015.upper_depth: float
# Taxon_count_015.lower_depth: float
# Taxon_count_015.Units: string
# Taxon_count_015.PGC_group_code: int32
# Taxon_count_016: float
# Taxon_count_016.comment: string
# Taxon_count_016.WOD_name: string
# Taxon_count_016.Param_number: int32
# Taxon_count_016.upper_depth: float
# Taxon_count_016.lower_depth: float
# Taxon_count_016.Units: string
# Taxon_count_016.PGC_group_code: int32
# Taxon_count_017: float
# Taxon_count_017.comment: string
# Taxon_count_017.WOD_name: string
# Taxon_count_017.Param_number: int32
# Taxon_count_017.upper_depth: float
# Taxon_count_017.lower_depth: float
# Taxon_count_017.Taxon_lifestage: string
# Taxon_count_017.Taxon_sex_code: string
# Taxon_count_017.Units: string
# Taxon_count_017.PGC_group_code: int32
# Taxon_count_018: float
# Taxon_count_018.comment: string
# Taxon_count_018.WOD_name: string
# Taxon_count_018.Param_number: int32
# Taxon_count_018.upper_depth: float
# Taxon_count_018.lower_depth: float
# Taxon_count_018.Taxon_lifestage: string
# Taxon_count_018.Taxon_sex_code: string
# Taxon_count_018.Units: string
# Taxon_count_018.PGC_group_code: int32
# Taxon_count_019: float
# Taxon_count_019.comment: string
# Taxon_count_019.WOD_name: string
# Taxon_count_019.Param_number: int32
# Taxon_count_019.upper_depth: float
# Taxon_count_019.lower_depth: float
# Taxon_count_019.Taxon_lifestage: string
# Taxon_count_019.Taxon_sex_code: string
# Taxon_count_019.Units: string
# Taxon_count_019.PGC_group_code: int32
# Taxon_count_020: float
# Taxon_count_020.comment: string
# Taxon_count_020.WOD_name: string
# Taxon_count_020.Param_number: int32
# Taxon_count_020.upper_depth: float
# Taxon_count_020.lower_depth: float
# Taxon_count_020.Taxon_lifestage: string
# Taxon_count_020.Taxon_sex_code: string
# Taxon_count_020.Units: string
# Taxon_count_020.PGC_group_code: int32
# Taxon_count_021: float
# Taxon_count_021.comment: string
# Taxon_count_021.WOD_name: string
# Taxon_count_021.Param_number: int32
# Taxon_count_021.upper_depth: float
# Taxon_count_021.lower_depth: float
# Taxon_count_021.Taxon_lifestage: string
# Taxon_count_021.Units: string
# Taxon_count_021.PGC_group_code: int32
# Taxon_count_022: float
# Taxon_count_022.comment: string
# Taxon_count_022.WOD_name: string
# Taxon_count_022.Param_number: int32
# Taxon_count_022.upper_depth: float
# Taxon_count_022.lower_depth: float
# Taxon_count_022.Taxon_lifestage: string
# Taxon_count_022.Units: string
# Taxon_count_022.PGC_group_code: int32
# Taxon_count_023: float
# Taxon_count_023.comment: string
# Taxon_count_023.WOD_name: string
# Taxon_count_023.Param_number: int32
# Taxon_count_023.upper_depth: float
# Taxon_count_023.lower_depth: float
# Taxon_count_023.Taxon_lifestage: string
# Taxon_count_023.Units: string
# Taxon_count_023.PGC_group_code: int32
# Taxon_count_024: float
# Taxon_count_024.comment: string
# Taxon_count_024.WOD_name: string
# Taxon_count_024.Param_number: int32
# Taxon_count_024.upper_depth: float
# Taxon_count_024.lower_depth: float
# Taxon_count_024.Taxon_lifestage: string
# Taxon_count_024.Units: string
# Taxon_count_024.PGC_group_code: int32
# Taxon_count_025: float
# Taxon_count_025.comment: string
# Taxon_count_025.WOD_name: string
# Taxon_count_025.Param_number: int32
# Taxon_count_025.upper_depth: float
# Taxon_count_025.lower_depth: float
# Taxon_count_025.Units: string
# Taxon_count_025.PGC_group_code: int32
# Taxon_count_026: float
# Taxon_count_026.comment: string
# Taxon_count_026.WOD_name: string
# Taxon_count_026.Param_number: int32
# Taxon_count_026.upper_depth: float
# Taxon_count_026.lower_depth: float
# Taxon_count_026.Taxon_lifestage: string
# Taxon_count_026.Taxon_sex_code: string
# Taxon_count_026.Units: string
# Taxon_count_026.PGC_group_code: int32
# Taxon_count_027: float
# Taxon_count_027.comment: string
# Taxon_count_027.WOD_name: string
# Taxon_count_027.Param_number: int32
# Taxon_count_027.upper_depth: float
# Taxon_count_027.lower_depth: float
# Taxon_count_027.Taxon_lifestage: string
# Taxon_count_027.Taxon_sex_code: string
# Taxon_count_027.Units: string
# Taxon_count_027.PGC_group_code: int32
# Taxon_count_028: float
# Taxon_count_028.comment: string
# Taxon_count_028.WOD_name: string
# Taxon_count_028.Param_number: int32
# Taxon_count_028.upper_depth: float
# Taxon_count_028.lower_depth: float
# Taxon_count_028.Taxon_lifestage: string
# Taxon_count_028.Taxon_sex_code: string
# Taxon_count_028.Units: string
# Taxon_count_028.PGC_group_code: int32
# Taxon_count_029: float
# Taxon_count_029.comment: string
# Taxon_count_029.WOD_name: string
# Taxon_count_029.Param_number: int32
# Taxon_count_029.upper_depth: float
# Taxon_count_029.lower_depth: float
# Taxon_count_029.Taxon_lifestage: string
# Taxon_count_029.Taxon_sex_code: string
# Taxon_count_029.Units: string
# Taxon_count_029.PGC_group_code: int32
# Taxon_count_030: float
# Taxon_count_030.comment: string
# Taxon_count_030.WOD_name: string
# Taxon_count_030.Param_number: int32
# Taxon_count_030.upper_depth: float
# Taxon_count_030.lower_depth: float
# Taxon_count_030.Taxon_lifestage: string
# Taxon_count_030.Taxon_sex_code: string
# Taxon_count_030.Units: string
# Taxon_count_030.PGC_group_code: int32
# Taxon_count_031: float
# Taxon_count_031.comment: string
# Taxon_count_031.WOD_name: string
# Taxon_count_031.Param_number: int32
# Taxon_count_031.upper_depth: float
# Taxon_count_031.lower_depth: float
# Taxon_count_031.Taxon_lifestage: string
# Taxon_count_031.Units: string
# Taxon_count_031.PGC_group_code: int32
# Taxon_count_032: float
# Taxon_count_032.comment: string
# Taxon_count_032.WOD_name: string
# Taxon_count_032.Param_number: int32
# Taxon_count_032.upper_depth: float
# Taxon_count_032.lower_depth: float
# Taxon_count_032.Taxon_lifestage: string
# Taxon_count_032.Units: string
# Taxon_count_032.PGC_group_code: int32
# Taxon_count_033: float
# Taxon_count_033.comment: string
# Taxon_count_033.WOD_name: string
# Taxon_count_033.Param_number: int32
# Taxon_count_033.upper_depth: float
# Taxon_count_033.lower_depth: float
# Taxon_count_033.Taxon_lifestage: string
# Taxon_count_033.Units: string
# Taxon_count_033.PGC_group_code: int32
# Taxon_count_034: float
# Taxon_count_034.comment: string
# Taxon_count_034.WOD_name: string
# Taxon_count_034.Param_number: int32
# Taxon_count_034.upper_depth: float
# Taxon_count_034.lower_depth: float
# Taxon_count_034.Taxon_lifestage: string
# Taxon_count_034.Taxon_sex_code: string
# Taxon_count_034.Units: string
# Taxon_count_034.PGC_group_code: int32
# Taxon_count_035: float
# Taxon_count_035.comment: string
# Taxon_count_035.WOD_name: string
# Taxon_count_035.Param_number: int32
# Taxon_count_035.upper_depth: float
# Taxon_count_035.lower_depth: float
# Taxon_count_035.Taxon_lifestage: string
# Taxon_count_035.Taxon_sex_code: string
# Taxon_count_035.Units: string
# Taxon_count_035.PGC_group_code: int32
# Taxon_count_036: float
# Taxon_count_036.comment: string
# Taxon_count_036.WOD_name: string
# Taxon_count_036.Param_number: int32
# Taxon_count_036.upper_depth: float
# Taxon_count_036.lower_depth: float
# Taxon_count_036.Taxon_lifestage: string
# Taxon_count_036.Taxon_sex_code: string
# Taxon_count_036.Units: string
# Taxon_count_036.PGC_group_code: int32
# Taxon_count_037: float
# Taxon_count_037.comment: string
# Taxon_count_037.WOD_name: string
# Taxon_count_037.Param_number: int32
# Taxon_count_037.upper_depth: float
# Taxon_count_037.lower_depth: float
# Taxon_count_037.Taxon_lifestage: string
# Taxon_count_037.Units: string
# Taxon_count_037.PGC_group_code: int32
# Taxon_count_038: float
# Taxon_count_038.comment: string
# Taxon_count_038.WOD_name: string
# Taxon_count_038.Param_number: int32
# Taxon_count_038.upper_depth: float
# Taxon_count_038.lower_depth: float
# Taxon_count_038.Taxon_lifestage: string
# Taxon_count_038.Units: string
# Taxon_count_038.PGC_group_code: int32
# Taxon_count_039: float
# Taxon_count_039.comment: string
# Taxon_count_039.WOD_name: string
# Taxon_count_039.Param_number: int32
# Taxon_count_039.upper_depth: float
# Taxon_count_039.lower_depth: float
# Taxon_count_039.Taxon_lifestage: string
# Taxon_count_039.Units: string
# Taxon_count_039.PGC_group_code: int32
# Taxon_count_040: float
# Taxon_count_040.comment: string
# Taxon_count_040.WOD_name: string
# Taxon_count_040.Param_number: int32
# Taxon_count_040.upper_depth: float
# Taxon_count_040.lower_depth: float
# Taxon_count_040.Taxon_lifestage: string
# Taxon_count_040.Taxon_sex_code: string
# Taxon_count_040.Units: string
# Taxon_count_040.PGC_group_code: int32
# Taxon_count_041: float
# Taxon_count_041.comment: string
# Taxon_count_041.WOD_name: string
# Taxon_count_041.Param_number: int32
# Taxon_count_041.upper_depth: float
# Taxon_count_041.lower_depth: float
# Taxon_count_041.Taxon_lifestage: string
# Taxon_count_041.Taxon_sex_code: string
# Taxon_count_041.Units: string
# Taxon_count_041.PGC_group_code: int32
# Taxon_count_042: float
# Taxon_count_042.comment: string
# Taxon_count_042.WOD_name: string
# Taxon_count_042.Param_number: int32
# Taxon_count_042.upper_depth: float
# Taxon_count_042.lower_depth: float
# Taxon_count_042.Taxon_lifestage: string
# Taxon_count_042.Taxon_sex_code: string
# Taxon_count_042.Units: string
# Taxon_count_042.PGC_group_code: int32
# Taxon_count_043: float
# Taxon_count_043.comment: string
# Taxon_count_043.WOD_name: string
# Taxon_count_043.Param_number: int32
# Taxon_count_043.upper_depth: float
# Taxon_count_043.lower_depth: float
# Taxon_count_043.Taxon_lifestage: string
# Taxon_count_043.Taxon_sex_code: string
# Taxon_count_043.Units: string
# Taxon_count_043.PGC_group_code: int32
# Taxon_count_044: float
# Taxon_count_044.comment: string
# Taxon_count_044.WOD_name: string
# Taxon_count_044.Param_number: int32
# Taxon_count_044.upper_depth: float
# Taxon_count_044.lower_depth: float
# Taxon_count_044.Taxon_lifestage: string
# Taxon_count_044.Taxon_sex_code: string
# Taxon_count_044.Units: string
# Taxon_count_044.PGC_group_code: int32
# Taxon_count_045: float
# Taxon_count_045.comment: string
# Taxon_count_045.WOD_name: string
# Taxon_count_045.Param_number: int32
# Taxon_count_045.upper_depth: float
# Taxon_count_045.lower_depth: float
# Taxon_count_045.Taxon_lifestage: string
# Taxon_count_045.Taxon_sex_code: string
# Taxon_count_045.Units: string
# Taxon_count_045.PGC_group_code: int32
# Taxon_count_046: float
# Taxon_count_046.comment: string
# Taxon_count_046.WOD_name: string
# Taxon_count_046.Param_number: int32
# Taxon_count_046.upper_depth: float
# Taxon_count_046.lower_depth: float
# Taxon_count_046.Taxon_lifestage: string
# Taxon_count_046.Units: string
# Taxon_count_046.PGC_group_code: int32
# Taxon_count_047: float
# Taxon_count_047.comment: string
# Taxon_count_047.WOD_name: string
# Taxon_count_047.Param_number: int32
# Taxon_count_047.upper_depth: float
# Taxon_count_047.lower_depth: float
# Taxon_count_047.Taxon_lifestage: string
# Taxon_count_047.Units: string
# Taxon_count_047.PGC_group_code: int32
# Taxon_count_048: float
# Taxon_count_048.comment: string
# Taxon_count_048.WOD_name: string
# Taxon_count_048.Param_number: int32
# Taxon_count_048.upper_depth: float
# Taxon_count_048.lower_depth: float
# Taxon_count_048.Taxon_lifestage: string
# Taxon_count_048.Units: string
# Taxon_count_048.PGC_group_code: int32
# Taxon_count_049: float
# Taxon_count_049.comment: string
# Taxon_count_049.WOD_name: string
# Taxon_count_049.Param_number: int32
# Taxon_count_049.upper_depth: float
# Taxon_count_049.lower_depth: float
# Taxon_count_049.Taxon_lifestage: string
# Taxon_count_049.Units: string
# Taxon_count_049.PGC_group_code: int32
# Taxon_count_050: float
# Taxon_count_050.comment: string
# Taxon_count_050.WOD_name: string
# Taxon_count_050.Param_number: int32
# Taxon_count_050.upper_depth: float
# Taxon_count_050.lower_depth: float
# Taxon_count_050.Taxon_lifestage: string
# Taxon_count_050.Units: string
# Taxon_count_050.PGC_group_code: int32
# Taxon_count_051: float
# Taxon_count_051.comment: string
# Taxon_count_051.WOD_name: string
# Taxon_count_051.Param_number: int32
# Taxon_count_051.upper_depth: float
# Taxon_count_051.lower_depth: float
# Taxon_count_051.Taxon_lifestage: string
# Taxon_count_051.Units: string
# Taxon_count_051.PGC_group_code: int32
# Taxon_count_052: float
# Taxon_count_052.comment: string
# Taxon_count_052.WOD_name: string
# Taxon_count_052.Param_number: int32
# Taxon_count_052.upper_depth: float
# Taxon_count_052.lower_depth: float
# Taxon_count_052.Taxon_lifestage: string
# Taxon_count_052.Units: string
# Taxon_count_052.PGC_group_code: int32
# Taxon_count_053: float
# Taxon_count_053.comment: string
# Taxon_count_053.WOD_name: string
# Taxon_count_053.Param_number: int32
# Taxon_count_053.upper_depth: float
# Taxon_count_053.lower_depth: float
# Taxon_count_053.Taxon_lifestage: string
# Taxon_count_053.Units: string
# Taxon_count_053.PGC_group_code: int32
# Taxon_count_054: float
# Taxon_count_054.comment: string
# Taxon_count_054.WOD_name: string
# Taxon_count_054.Param_number: int32
# Taxon_count_054.upper_depth: float
# Taxon_count_054.lower_depth: float
# Taxon_count_054.Taxon_lifestage: string
# Taxon_count_054.Units: string
# Taxon_count_054.PGC_group_code: int32
# Taxon_count_055: float
# Taxon_count_055.comment: string
# Taxon_count_055.WOD_name: string
# Taxon_count_055.Param_number: int32
# Taxon_count_055.upper_depth: float
# Taxon_count_055.lower_depth: float
# Taxon_count_055.Taxon_lifestage: string
# Taxon_count_055.Units: string
# Taxon_count_055.PGC_group_code: int32
# Taxon_count_056: float
# Taxon_count_056.comment: string
# Taxon_count_056.WOD_name: string
# Taxon_count_056.Param_number: int32
# Taxon_count_056.upper_depth: float
# Taxon_count_056.lower_depth: float
# Taxon_count_056.Taxon_lifestage: string
# Taxon_count_056.Units: string
# Taxon_count_056.PGC_group_code: int32
# Taxon_count_057: float
# Taxon_count_057.comment: string
# Taxon_count_057.WOD_name: string
# Taxon_count_057.Param_number: int32
# Taxon_count_057.upper_depth: float
# Taxon_count_057.lower_depth: float
# Taxon_count_057.Taxon_lifestage: string
# Taxon_count_057.Units: string
# Taxon_count_057.PGC_group_code: int32
# Taxon_count_058: float
# Taxon_count_058.comment: string
# Taxon_count_058.WOD_name: string
# Taxon_count_058.Param_number: int32
# Taxon_count_058.upper_depth: float
# Taxon_count_058.lower_depth: float
# Taxon_count_058.Taxon_lifestage: string
# Taxon_count_058.Units: string
# Taxon_count_058.PGC_group_code: int32
# Taxon_count_059: float
# Taxon_count_059.comment: string
# Taxon_count_059.WOD_name: string
# Taxon_count_059.Param_number: int32
# Taxon_count_059.upper_depth: float
# Taxon_count_059.lower_depth: float
# Taxon_count_059.Taxon_lifestage: string
# Taxon_count_059.Units: string
# Taxon_count_059.PGC_group_code: int32
# Taxon_count_060: float
# Taxon_count_060.comment: string
# Taxon_count_060.WOD_name: string
# Taxon_count_060.Param_number: int32
# Taxon_count_060.upper_depth: float
# Taxon_count_060.lower_depth: float
# Taxon_count_060.Taxon_lifestage: string
# Taxon_count_060.Units: string
# Taxon_count_060.PGC_group_code: int32
# Taxon_count_061: float
# Taxon_count_061.comment: string
# Taxon_count_061.WOD_name: string
# Taxon_count_061.Param_number: int32
# Taxon_count_061.upper_depth: float
# Taxon_count_061.lower_depth: float
# Taxon_count_061.Taxon_lifestage: string
# Taxon_count_061.Units: string
# Taxon_count_061.PGC_group_code: int32
# Taxon_count_062: float
# Taxon_count_062.comment: string
# Taxon_count_062.WOD_name: string
# Taxon_count_062.Param_number: int32
# Taxon_count_062.upper_depth: float
# Taxon_count_062.lower_depth: float
# Taxon_count_062.Taxon_lifestage: string
# Taxon_count_062.Units: string
# Taxon_count_062.PGC_group_code: int32
# Taxon_count_063: float
# Taxon_count_063.comment: string
# Taxon_count_063.WOD_name: string
# Taxon_count_063.Param_number: int32
# Taxon_count_063.upper_depth: float
# Taxon_count_063.lower_depth: float
# Taxon_count_063.Units: string
# Taxon_count_063.PGC_group_code: int32
# Taxon_count_006.Taxon_sex_code: string
# Taxon_count_007.Taxon_sex_code: string
# Taxon_count_015.Taxon_lifestage: string
# Taxon_count_016.Taxon_lifestage: string
# Taxon_count_025.Taxon_lifestage: string
# Taxon_count_025.Taxon_sex_code: string
# Taxon_count_046.Taxon_sex_code: string
# Taxon_count_063.Taxon_lifestage: string
# Taxon_count_064: float
# Taxon_count_064.comment: string
# Taxon_count_064.WOD_name: string
# Taxon_count_064.Param_number: int32
# Taxon_count_064.upper_depth: float
# Taxon_count_064.lower_depth: float
# Taxon_count_064.Taxon_lifestage: string
# Taxon_count_064.Units: string
# Taxon_count_064.PGC_group_code: int32
# Taxon_count_065: float
# Taxon_count_065.comment: string
# Taxon_count_065.WOD_name: string
# Taxon_count_065.Param_number: int32
# Taxon_count_065.upper_depth: float
# Taxon_count_065.lower_depth: float
# Taxon_count_065.Units: string
# Taxon_count_065.PGC_group_code: int32
# Taxon_count_066: float
# Taxon_count_066.comment: string
# Taxon_count_066.WOD_name: string
# Taxon_count_066.Param_number: int32
# Taxon_count_066.upper_depth: float
# Taxon_count_066.lower_depth: float
# Taxon_count_066.Units: string
# Taxon_count_066.PGC_group_code: int32
# Taxon_count_011.Taxon_sex_code: string
# Taxon_count_012.Taxon_sex_code: string
# Taxon_count_037.Taxon_sex_code: string
# Taxon_count_038.Taxon_sex_code: string
# Taxon_count_067: float
# Taxon_count_067.comment: string
# Taxon_count_067.WOD_name: string
# Taxon_count_067.Param_number: int32
# Taxon_count_067.upper_depth: float
# Taxon_count_067.lower_depth: float
# Taxon_count_067.Units: string
# Taxon_count_067.PGC_group_code: int32
# Taxon_count_068: float
# Taxon_count_068.comment: string
# Taxon_count_068.WOD_name: string
# Taxon_count_068.Param_number: int32
# Taxon_count_068.upper_depth: float
# Taxon_count_068.lower_depth: float
# Taxon_count_068.Taxon_lifestage: string
# Taxon_count_068.Units: string
# Taxon_count_068.PGC_group_code: int32
# Taxon_count_001.Param_number_(`,): int32
# Taxon_count_001.upper_depth_(`,): float
# Taxon_count_001.lower_depth_(`,): float
# Taxon_count_001.Taxon_lifestage_(`,): string
# Taxon_count_001.Taxon_sex_code_(`,): string
# Taxon_count_001.Units_(`,): string
# Taxon_count_001.PGC_group_code_(`,): int32
# Taxon_count_002.Param_number_(`,): int32
# Taxon_count_002.upper_depth_(`,): float
# Taxon_count_002.lower_depth_(`,): float
# Taxon_count_002.Taxon_lifestage_(`,): string
# Taxon_count_002.Taxon_sex_code_(`,): string
# Taxon_count_002.Units_(`,): string
# Taxon_count_002.PGC_group_code_(`,): int32
# Taxon_count_003.Param_number_(`,): int32
# Taxon_count_003.upper_depth_(`,): float
# Taxon_count_003.lower_depth_(`,): float
# Taxon_count_003.Taxon_lifestage_(`,): string
# Taxon_count_003.Units_(`,): string
# Taxon_count_003.PGC_group_code_(`,): int32
# Taxon_count_004.Param_number_(`,): int32
# Taxon_count_004.upper_depth_(`,): float
# Taxon_count_004.lower_depth_(`,): float
# Taxon_count_004.Taxon_lifestage_(`,): string
# Taxon_count_004.Units_(`,): string
# Taxon_count_004.PGC_group_code_(`,): int32
# Taxon_count_005.Param_number_(`,): int32
# Taxon_count_005.upper_depth_(`,): float
# Taxon_count_005.lower_depth_(`,): float
# Taxon_count_005.Units_(`,): string
# Taxon_count_005.PGC_group_code_(`,): int32
# Taxon_count_006.Param_number_(`,): int32
# Taxon_count_006.upper_depth_(`,): float
# Taxon_count_006.lower_depth_(`,): float
# Taxon_count_006.Taxon_lifestage_(`,): string
# Taxon_count_006.Taxon_sex_code_(`,): string
# Taxon_count_006.Units_(`,): string
# Taxon_count_006.PGC_group_code_(`,): int32
# Taxon_count_007.Param_number_(`,): int32
# Taxon_count_007.upper_depth_(`,): float
# Taxon_count_007.lower_depth_(`,): float
# Taxon_count_007.Taxon_lifestage_(`,): string
# Taxon_count_007.Taxon_sex_code_(`,): string
# Taxon_count_007.Units_(`,): string
# Taxon_count_007.PGC_group_code_(`,): int32
# Taxon_count_008.Param_number_(`,): int32
# Taxon_count_008.upper_depth_(`,): float
# Taxon_count_008.lower_depth_(`,): float
# Taxon_count_008.Taxon_lifestage_(`,): string
# Taxon_count_008.Units_(`,): string
# Taxon_count_008.PGC_group_code_(`,): int32
# Taxon_count_009.Param_number_(`,): int32
# Taxon_count_009.upper_depth_(`,): float
# Taxon_count_009.lower_depth_(`,): float
# Taxon_count_009.Taxon_lifestage_(`,): string
# Taxon_count_009.Units_(`,): string
# Taxon_count_009.PGC_group_code_(`,): int32
# Taxon_count_010.Param_number_(`,): int32
# Taxon_count_010.upper_depth_(`,): float
# Taxon_count_010.lower_depth_(`,): float
# Taxon_count_010.Taxon_lifestage_(`,): string
# Taxon_count_010.Units_(`,): string
# Taxon_count_010.PGC_group_code_(`,): int32
# Taxon_count_011.Param_number_(`,): int32
# Taxon_count_011.upper_depth_(`,): float
# Taxon_count_011.lower_depth_(`,): float
# Taxon_count_011.Taxon_lifestage_(`,): string
# Taxon_count_011.Units_(`,): string
# Taxon_count_011.PGC_group_code_(`,): int32
# Taxon_count_012.Param_number_(`,): int32
# Taxon_count_012.upper_depth_(`,): float
# Taxon_count_012.lower_depth_(`,): float
# Taxon_count_012.Taxon_lifestage_(`,): string
# Taxon_count_012.Units_(`,): string
# Taxon_count_012.PGC_group_code_(`,): int32
# Taxon_count_013.Param_number_(`,): int32
# Taxon_count_013.upper_depth_(`,): float
# Taxon_count_013.lower_depth_(`,): float
# Taxon_count_013.Taxon_lifestage_(`,): string
# Taxon_count_013.Units_(`,): string
# Taxon_count_013.PGC_group_code_(`,): int32
# Taxon_count_014.Param_number_(`,): int32
# Taxon_count_014.upper_depth_(`,): float
# Taxon_count_014.lower_depth_(`,): float
# Taxon_count_014.Taxon_lifestage_(`,): string
# Taxon_count_014.Taxon_sex_code_(`,): string
# Taxon_count_014.Units_(`,): string
# Taxon_count_014.PGC_group_code_(`,): int32
# Taxon_count_015.Param_number_(`,): int32
# Taxon_count_015.upper_depth_(`,): float
# Taxon_count_015.lower_depth_(`,): float
# Taxon_count_015.Taxon_lifestage_(`,): string
# Taxon_count_015.Taxon_sex_code_(`,): string
# Taxon_count_015.Units_(`,): string
# Taxon_count_015.PGC_group_code_(`,): int32
# Taxon_count_016.Param_number_(`,): int32
# Taxon_count_016.upper_depth_(`,): float
# Taxon_count_016.lower_depth_(`,): float
# Taxon_count_016.Taxon_lifestage_(`,): string
# Taxon_count_016.Units_(`,): string
# Taxon_count_016.PGC_group_code_(`,): int32
# Taxon_count_017.Param_number_(`,): int32
# Taxon_count_017.upper_depth_(`,): float
# Taxon_count_017.lower_depth_(`,): float
# Taxon_count_017.Taxon_lifestage_(`,): string
# Taxon_count_017.Units_(`,): string
# Taxon_count_017.PGC_group_code_(`,): int32
# Taxon_count_018.Param_number_(`,): int32
# Taxon_count_018.upper_depth_(`,): float
# Taxon_count_018.lower_depth_(`,): float
# Taxon_count_018.Units_(`,): string
# Taxon_count_018.PGC_group_code_(`,): int32
# Taxon_count_019.Param_number_(`,): int32
# Taxon_count_019.upper_depth_(`,): float
# Taxon_count_019.lower_depth_(`,): float
# Taxon_count_019.Units_(`,): string
# Taxon_count_019.PGC_group_code_(`,): int32
# Taxon_count_020.Param_number_(`,): int32
# Taxon_count_020.upper_depth_(`,): float
# Taxon_count_020.lower_depth_(`,): float
# Taxon_count_020.Taxon_lifestage_(`,): string
# Taxon_count_020.Units_(`,): string
# Taxon_count_020.PGC_group_code_(`,): int32
# Taxon_count_021.Param_number_(`,): int32
# Taxon_count_021.upper_depth_(`,): float
# Taxon_count_021.lower_depth_(`,): float
# Taxon_count_021.Taxon_lifestage_(`,): string
# Taxon_count_021.Taxon_sex_code_(`,): string
# Taxon_count_021.Units_(`,): string
# Taxon_count_021.PGC_group_code_(`,): int32
# Taxon_count_022.Param_number_(`,): int32
# Taxon_count_022.upper_depth_(`,): float
# Taxon_count_022.lower_depth_(`,): float
# Taxon_count_022.Taxon_lifestage_(`,): string
# Taxon_count_022.Taxon_sex_code_(`,): string
# Taxon_count_022.Units_(`,): string
# Taxon_count_022.PGC_group_code_(`,): int32
# Taxon_count_023.Param_number_(`,): int32
# Taxon_count_023.upper_depth_(`,): float
# Taxon_count_023.lower_depth_(`,): float
# Taxon_count_023.Taxon_lifestage_(`,): string
# Taxon_count_023.Units_(`,): string
# Taxon_count_023.PGC_group_code_(`,): int32
# Taxon_count_024.Param_number_(`,): int32
# Taxon_count_024.upper_depth_(`,): float
# Taxon_count_024.lower_depth_(`,): float
# Taxon_count_024.Taxon_lifestage_(`,): string
# Taxon_count_024.Units_(`,): string
# Taxon_count_024.PGC_group_code_(`,): int32
# Taxon_count_025.Param_number_(`,): int32
# Taxon_count_025.upper_depth_(`,): float
# Taxon_count_025.lower_depth_(`,): float
# Taxon_count_025.Units_(`,): string
# Taxon_count_025.PGC_group_code_(`,): int32
# Taxon_count_026.Param_number_(`,): int32
# Taxon_count_026.upper_depth_(`,): float
# Taxon_count_026.lower_depth_(`,): float
# Taxon_count_026.Units_(`,): string
# Taxon_count_026.PGC_group_code_(`,): int32
# Taxon_count_027.Param_number_(`,): int32
# Taxon_count_027.upper_depth_(`,): float
# Taxon_count_027.lower_depth_(`,): float
# Taxon_count_027.Taxon_lifestage_(`,): string
# Taxon_count_027.Units_(`,): string
# Taxon_count_027.PGC_group_code_(`,): int32
# Taxon_count_028.Param_number_(`,): int32
# Taxon_count_028.upper_depth_(`,): float
# Taxon_count_028.lower_depth_(`,): float
# Taxon_count_028.Taxon_lifestage_(`,): string
# Taxon_count_028.Units_(`,): string
# Taxon_count_028.PGC_group_code_(`,): int32
# Taxon_count_029.Param_number_(`,): int32
# Taxon_count_029.upper_depth_(`,): float
# Taxon_count_029.lower_depth_(`,): float
# Taxon_count_029.Taxon_lifestage_(`,): string
# Taxon_count_029.Units_(`,): string
# Taxon_count_029.PGC_group_code_(`,): int32
# Taxon_count_030.Param_number_(`,): int32
# Taxon_count_030.upper_depth_(`,): float
# Taxon_count_030.lower_depth_(`,): float
# Taxon_count_030.Taxon_lifestage_(`,): string
# Taxon_count_030.Units_(`,): string
# Taxon_count_030.PGC_group_code_(`,): int32
# Taxon_count_031.Param_number_(`,): int32
# Taxon_count_031.upper_depth_(`,): float
# Taxon_count_031.lower_depth_(`,): float
# Taxon_count_031.Taxon_lifestage_(`,): string
# Taxon_count_031.Units_(`,): string
# Taxon_count_031.PGC_group_code_(`,): int32
# Taxon_count_032.Param_number_(`,): int32
# Taxon_count_032.upper_depth_(`,): float
# Taxon_count_032.lower_depth_(`,): float
# Taxon_count_032.Units_(`,): string
# Taxon_count_032.PGC_group_code_(`,): int32
# Taxon_count_033.Param_number_(`,): int32
# Taxon_count_033.upper_depth_(`,): float
# Taxon_count_033.lower_depth_(`,): float
# Taxon_count_033.Taxon_lifestage_(`,): string
# Taxon_count_033.Taxon_sex_code_(`,): string
# Taxon_count_033.Units_(`,): string
# Taxon_count_033.PGC_group_code_(`,): int32
# Taxon_count_034.Param_number_(`,): int32
# Taxon_count_034.upper_depth_(`,): float
# Taxon_count_034.lower_depth_(`,): float
# Taxon_count_034.Taxon_lifestage_(`,): string
# Taxon_count_034.Taxon_sex_code_(`,): string
# Taxon_count_034.Units_(`,): string
# Taxon_count_034.PGC_group_code_(`,): int32
# Taxon_count_035.Param_number_(`,): int32
# Taxon_count_035.upper_depth_(`,): float
# Taxon_count_035.lower_depth_(`,): float
# Taxon_count_035.Taxon_lifestage_(`,): string
# Taxon_count_035.Taxon_sex_code_(`,): string
# Taxon_count_035.Units_(`,): string
# Taxon_count_035.PGC_group_code_(`,): int32
# Taxon_count_036.Param_number_(`,): int32
# Taxon_count_036.upper_depth_(`,): float
# Taxon_count_036.lower_depth_(`,): float
# Taxon_count_036.Taxon_lifestage_(`,): string
# Taxon_count_036.Taxon_sex_code_(`,): string
# Taxon_count_036.Units_(`,): string
# Taxon_count_036.PGC_group_code_(`,): int32
# Taxon_count_037.Param_number_(`,): int32
# Taxon_count_037.upper_depth_(`,): float
# Taxon_count_037.lower_depth_(`,): float
# Taxon_count_037.Taxon_lifestage_(`,): string
# Taxon_count_037.Units_(`,): string
# Taxon_count_037.PGC_group_code_(`,): int32
# Taxon_count_038.Param_number_(`,): int32
# Taxon_count_038.upper_depth_(`,): float
# Taxon_count_038.lower_depth_(`,): float
# Taxon_count_038.Taxon_lifestage_(`,): string
# Taxon_count_038.Units_(`,): string
# Taxon_count_038.PGC_group_code_(`,): int32
# Taxon_count_039.Param_number_(`,): int32
# Taxon_count_039.upper_depth_(`,): float
# Taxon_count_039.lower_depth_(`,): float
# Taxon_count_039.Taxon_lifestage_(`,): string
# Taxon_count_039.Units_(`,): string
# Taxon_count_039.PGC_group_code_(`,): int32
# Taxon_count_040.Param_number_(`,): int32
# Taxon_count_040.upper_depth_(`,): float
# Taxon_count_040.lower_depth_(`,): float
# Taxon_count_040.Taxon_lifestage_(`,): string
# Taxon_count_040.Taxon_sex_code_(`,): string
# Taxon_count_040.Units_(`,): string
# Taxon_count_040.PGC_group_code_(`,): int32
# Taxon_count_041.Param_number_(`,): int32
# Taxon_count_041.upper_depth_(`,): float
# Taxon_count_041.lower_depth_(`,): float
# Taxon_count_041.Taxon_lifestage_(`,): string
# Taxon_count_041.Taxon_sex_code_(`,): string
# Taxon_count_041.Units_(`,): string
# Taxon_count_041.PGC_group_code_(`,): int32
# Taxon_count_042.Param_number_(`,): int32
# Taxon_count_042.upper_depth_(`,): float
# Taxon_count_042.lower_depth_(`,): float
# Taxon_count_042.Taxon_lifestage_(`,): string
# Taxon_count_042.Taxon_sex_code_(`,): string
# Taxon_count_042.Units_(`,): string
# Taxon_count_042.PGC_group_code_(`,): int32
# Taxon_count_043.Param_number_(`,): int32
# Taxon_count_043.upper_depth_(`,): float
# Taxon_count_043.lower_depth_(`,): float
# Taxon_count_043.Taxon_lifestage_(`,): string
# Taxon_count_043.Taxon_sex_code_(`,): string
# Taxon_count_043.Units_(`,): string
# Taxon_count_043.PGC_group_code_(`,): int32
# Taxon_count_044.Param_number_(`,): int32
# Taxon_count_044.upper_depth_(`,): float
# Taxon_count_044.lower_depth_(`,): float
# Taxon_count_044.Taxon_lifestage_(`,): string
# Taxon_count_044.Units_(`,): string
# Taxon_count_044.PGC_group_code_(`,): int32
# Taxon_count_045.Param_number_(`,): int32
# Taxon_count_045.upper_depth_(`,): float
# Taxon_count_045.lower_depth_(`,): float
# Taxon_count_045.Taxon_lifestage_(`,): string
# Taxon_count_045.Units_(`,): string
# Taxon_count_045.PGC_group_code_(`,): int32
# Taxon_count_046.upper_depth_(`,): float
# ...
# Taxon_count_159.Param_number: int32
# Taxon_count_165.Param_number: int32
# Taxon_count_166.Param_number: int32
# Taxon_count_167.Param_number: int32
# Taxon_count_168.Param_number: int32
# Taxon_count_173.Param_number: int32
# Taxon_count_081.Taxon_modifier: string
# Taxon_count_082.Taxon_modifier: string
# Taxon_count_083.Taxon_modifier: string
# Taxon_count_084.Taxon_modifier: string
# Taxon_count_137.Taxon_modifier: string
# Taxon_count_138.Taxon_modifier: string
# Taxon_count_139.Taxon_modifier: string
# Taxon_count_140.Taxon_modifier: string
# Taxon_count_053.Taxon_modifier_(`,): string
# Taxon_count_054.Taxon_modifier_(`,): string
# Taxon_count_093.Taxon_modifier_(`,): string
# Taxon_count_094.Taxon_modifier_(`,): string
# Taxon_count_095.Taxon_modifier_(`,): string
# Taxon_count_096.Taxon_modifier_(`,): string
# Taxon_count_169.Taxon_modifier_(`,): string
# Taxon_count_170.Taxon_modifier_(`,): string
# Taxon_count_171.Taxon_modifier_(`,): string
# Taxon_count_172.Taxon_modifier_(`,): string
# Taxon_count_147.Taxon_modifier_(`,): string
# Taxon_count_148.Taxon_modifier_(`,): string
# Taxon_present_041.Taxon_modifier_(`,): string
# Taxon_count_161.Taxon_modifier_(`,): string
# Taxon_count_162.Taxon_modifier_(`,): string
# Taxon_count_163.Taxon_modifier_(`,): string
# Taxon_count_164.Taxon_modifier_(`,): string
# Taxon_count_105.Taxon_modifier_(`,): string
# Taxon_count_106.Taxon_modifier_(`,): string
# Taxon_count_107.Taxon_modifier_(`,): string
# Taxon_count_108.Taxon_modifier_(`,): string
# Taxon_count_115.Taxon_modifier_(`,): string
# Taxon_count_116.Taxon_modifier_(`,): string
# Taxon_count_097.Taxon_modifier_(`,): string
# Taxon_count_098.Taxon_modifier_(`,): string
# Taxon_count_099.Taxon_modifier_(`,): string
# Taxon_count_100.Taxon_modifier_(`,): string
# Taxon_count_153.Taxon_modifier_(`,): string
# Taxon_count_154.Taxon_modifier_(`,): string
# Taxon_count_155.Taxon_modifier_(`,): string
# Taxon_count_156.Taxon_modifier_(`,): string
# Taxon_count_121.Taxon_modifier_(`,): string
# Taxon_count_122.Taxon_modifier_(`,): string
# Taxon_count_123.Taxon_modifier_(`,): string
# Taxon_count_124.Taxon_modifier_(`,): string
# Taxon_count_125.Taxon_modifier_(`,): string
# Taxon_count_126.Taxon_modifier_(`,): string
# Taxon_count_127.Taxon_modifier_(`,): string
# Taxon_count_128.Taxon_modifier_(`,): string
# Taxon_count_100.Taxon_modifier: string
# Taxon_count_105.Taxon_modifier: string
# Taxon_count_106.Taxon_modifier: string
# Taxon_count_107.Taxon_modifier: string
# Taxon_count_108.Taxon_modifier: string
# Taxon_count_161.Taxon_modifier: string
# Taxon_count_162.Taxon_modifier: string
# Taxon_count_163.Taxon_modifier: string
# Taxon_count_164.Taxon_modifier: string
# Taxon_present_042.Taxon_modifier_(`,): string
# Taxon_present_039.Taxon_modifier_(`,): string
# Taxon_present_039.Taxon_modifier: string
# Taxon_present_038.Taxon_modifier_(`,): string
# Taxon_present_043.Taxon_modifier_(`,): string
# Taxon_present_035.Taxon_modifier: string
# Taxon_present_052.Taxon_modifier: string
# Taxon_present_035.Taxon_modifier_(`,): string
# Taxon_present_037.Taxon_modifier_(`,): string
# Taxon_present_048.Taxon_modifier_(`,): string
# Taxon_count_072.Taxon_modifier: string
# Ammonia_Original_units: string
# Ammonia_Original_units.comment: string
# POC_origflag: int16
# POC_origflag.flag_definitions: string
# Phaeophytin_Original_units: string
# Phaeophytin_Original_units.comment: string
# Salinity_STDWater_batch: int32
# Salinity_STDWater_batch.comment: string
# CFC11_Access_no: int32
# CFC11_Access_no.long_name: string
# CFC11_Access_no.units: string
# CFC11_Access_no.comment: string
# CFC12_Access_no: int32
# CFC12_Access_no.long_name: string
# CFC12_Access_no.units: string
# CFC12_Access_no.comment: string
# CFC113_Access_no: int32
# CFC113_Access_no.long_name: string
# CFC113_Access_no.units: string
# CFC113_Access_no.comment: string
# Taxon_count_027.Taxon_sex_code_(`,): string
# Taxon_count_059.Taxon_sex_code: string
# Taxon_count_031.Taxon_sex_code: string
# Taxon_count_076.Taxon_sex_code: string
# Taxon_count_077.Taxon_sex_code: string
# Taxon_present_070.Param_number_(`,): int32
# Taxon_present_071.Param_number_(`,): int32
# water_sampler: string
# water_sampler.comment: string
# Oxy18: float
# Oxy18.long_name: string
# Oxy18.units: string
# Oxy18.coordinates: string
# Oxy18.grid_mapping: string
# Oxy18_sigfigs: int16
# Oxy18_WODflag: int16
# Oxy18_WODflag.flag_definitions: string
# Oxy18_origflag: int16
# Oxy18_origflag.flag_definitions: string
# Taxon_count_080.Taxon_sex_code_(`,): string
# Taxon_count_081.Taxon_sex_code_(`,): string
# Taxon_count_086.Taxon_sex_code_(`,): string
# Taxon_count_087.Taxon_sex_code_(`,): string
# Taxon_count_088.Taxon_sex_code_(`,): string
# Taxon_count_089.Taxon_sex_code_(`,): string
# Taxon_count_014.Taxon_sex_code: string
# Taxon_count_015.Taxon_sex_code: string
# Taxon_present_049.Taxon_modifier_(`,): string
# Taxon_volume_003: float
# Taxon_volume_003.comment: string
# Taxon_volume_003.WOD_name: string
# Taxon_volume_003.Param_number: int32
# Taxon_volume_003.Units: string
# Taxon_volume_003.PGC_group_code: int32
# Taxon_present_077.Param_number: int32
# Taxon_present_054.Taxon_modifier: string
# Neon: float
# Neon.long_name: string
# Neon.units: string
# Neon.coordinates: string
# Neon.grid_mapping: string
# Neon_sigfigs: int16
# Neon_WODflag: int16
# Neon_WODflag.flag_definitions: string
# Neon_origflag: int16
# Neon_origflag.flag_definitions: string
# Taxon_count_012.Taxon_sex_code_(`,): string
# Taxon_count_013.Taxon_sex_code_(`,): string
# Taxon_count_105.Taxon_sex_code_(`,): string
# Taxon_count_106.Taxon_sex_code_(`,): string
# Taxon_count_107.Taxon_sex_code_(`,): string
# Taxon_count_111.Taxon_lifestage_(`,): string
# Taxon_present_050.Taxon_modifier_(`,): string
# Taxon_count_059.Taxon_modifier: string
# Taxon_count_060.Taxon_modifier: string
# Taxon_count_070.Taxon_modifier: string
# Taxon_count_071.Taxon_modifier: string
# Taxon_count_093.Taxon_modifier: string
# Taxon_count_094.Taxon_modifier: string
# Taxon_count_095.Taxon_modifier: string
# Taxon_count_096.Taxon_modifier: string
# Taxon_count_073.Taxon_modifier: string
# Taxon_count_074.Taxon_modifier: string
# Taxon_count_109.Taxon_modifier: string
# Taxon_count_110.Taxon_modifier: string
# Taxon_count_111.Taxon_modifier: string
# Taxon_count_112.Taxon_modifier: string
# Taxon_count_165.Taxon_modifier: string
# Taxon_count_166.Taxon_modifier: string
# Taxon_count_167.Taxon_modifier: string
# Taxon_count_168.Taxon_modifier: string
# Taxon_count_089.Taxon_modifier_(`,): string
# Taxon_count_090.Taxon_modifier_(`,): string
# Taxon_count_129.Taxon_modifier_(`,): string
# Taxon_count_130.Taxon_modifier_(`,): string
# Taxon_count_131.Taxon_modifier_(`,): string
# Taxon_count_132.Taxon_modifier_(`,): string
# Taxon_count_065.Taxon_modifier_(`,): string
# Taxon_count_066.Taxon_modifier_(`,): string
# Taxon_count_077.Taxon_modifier_(`,): string
# Taxon_count_078.Taxon_modifier_(`,): string
# Taxon_count_125.Taxon_modifier: string
# Taxon_count_126.Taxon_modifier: string
# Taxon_count_127.Taxon_modifier: string
# Taxon_count_128.Taxon_modifier: string
# Taxon_count_141.Taxon_modifier: string
# Taxon_count_142.Taxon_modifier: string
# Taxon_count_143.Taxon_modifier: string
# Taxon_count_144.Taxon_modifier: string
# Taxon_count_103.Taxon_modifier_(`,): string
# Taxon_count_104.Taxon_modifier_(`,): string
# Taxon_present_044.Taxon_modifier: string
# Taxon_present_044.Taxon_modifier_(`,): string
# Taxon_count_096.Taxon_sex_code: string
# Taxon_count_097.Taxon_sex_code_(`,): string
# Taxon_count_098.Taxon_sex_code_(`,): string
# Taxon_count_097.Taxon_sex_code: string
# Taxon_count_098.Taxon_sex_code: string
# Taxon_count_099.Taxon_sex_code: string
# Taxon_count_104.Taxon_lifestage: string
# Taxon_count_105.Taxon_lifestage: string
# Taxon_count_106.Taxon_lifestage: string
# Taxon_count_090.Taxon_sex_code_(`,): string
# Taxon_count_091.Taxon_sex_code_(`,): string
# Taxon_count_011.Taxon_sex_code_(`,): string
# Taxon_count_099.Taxon_sex_code_(`,): string
# Taxon_count_100.Taxon_sex_code_(`,): string
# Taxon_count_008.Taxon_sex_code: string
# Taxon_count_009.Taxon_sex_code: string
# Taxon_count_010.Taxon_sex_code: string
# Taxon_count_030.Taxon_sex_code_(`,): string
# Taxon_count_031.Taxon_sex_code_(`,): string
# DeltaC13: float
# DeltaC13.long_name: string
# DeltaC13.units: string
# DeltaC13.coordinates: string
# DeltaC13.grid_mapping: string
# DeltaC13_sigfigs: int16
# DeltaC13_WODflag: int16
# DeltaC13_WODflag.flag_definitions: string
# DeltaC13_origflag: int16
# DeltaC13_origflag.flag_definitions: string
# Taxon_present_061.Taxon_modifier: string
# Taxon_present_063.Taxon_modifier: string
# Taxon_count_113.Taxon_modifier: string
# Taxon_count_114.Taxon_modifier: string
# Taxon_count_115.Taxon_modifier: string
# Taxon_count_116.Taxon_modifier: string
# Taxon_count_103.Taxon_modifier: string
# Taxon_count_104.Taxon_modifier: string
# Taxon_count_173.Taxon_modifier: string
# Taxon_count_133.Taxon_modifier: string
# Taxon_count_134.Taxon_modifier: string
# Taxon_count_135.Taxon_modifier: string
# Taxon_count_136.Taxon_modifier: string
# Taxon_count_151.Taxon_modifier: string
# Taxon_count_152.Taxon_modifier: string
# Taxon_present_051.Taxon_modifier_(`,): string
# Taxon_present_060.Taxon_modifier: string
# Ammonia_Method: string
# Ammonia_Method.comment: string
# Taxon_count_010.Taxon_sex_code_(`,): string
# Taxon_count_112.Taxon_lifestage_(`,): string
# Taxon_count_112.Taxon_sex_code_(`,): string
# Taxon_count_113.Taxon_lifestage_(`,): string
# Taxon_count_113.Taxon_sex_code_(`,): string
# Taxon_count_114.Taxon_lifestage_(`,): string
# Taxon_count_114.Taxon_sex_code_(`,): string
# Taxon_count_115.Taxon_lifestage_(`,): string
# Taxon_count_115.Taxon_sex_code_(`,): string
# Taxon_count_116.Taxon_lifestage_(`,): string
# Taxon_count_117.Taxon_lifestage_(`,): string
# Taxon_count_118.Taxon_lifestage_(`,): string
# Taxon_count_102.Taxon_sex_code: string
# Taxon_count_103.Taxon_sex_code: string
# Taxon_count_104.Taxon_sex_code: string
# Taxon_count_105.Taxon_sex_code: string
# Taxon_count_106.Taxon_sex_code: string
# Taxon_count_107.Taxon_lifestage: string
# Taxon_count_107.Taxon_sex_code: string
# Taxon_count_108.Taxon_lifestage: string
# Taxon_count_109.Taxon_lifestage: string
# Taxon_count_110.Taxon_lifestage: string
# Taxon_count_111.Taxon_lifestage: string
# Taxon_count_112.Taxon_lifestage: string
# Taxon_count_113.Taxon_lifestage: string
# Taxon_count_114.Taxon_lifestage: string
# Taxon_count_115.Taxon_lifestage: string
# Taxon_count_116.Taxon_lifestage: string
# Taxon_count_117.Taxon_lifestage: string
# Taxon_count_118.Taxon_lifestage: string
# Taxon_count_119.Taxon_lifestage: string
# Taxon_count_120.Taxon_lifestage: string
# Taxon_count_121.Taxon_lifestage: string
# Taxon_count_122.Taxon_lifestage: string
# Taxon_count_123.Taxon_lifestage: string
# Taxon_count_124.Taxon_lifestage: string
# Taxon_count_128.Taxon_lifestage: string
# Taxon_count_128.Taxon_sex_code: string
# Taxon_count_129.Taxon_lifestage: string
# Taxon_count_129.Taxon_sex_code: string
# Taxon_count_130.Taxon_lifestage: string
# Taxon_count_130.Taxon_sex_code: string
# Taxon_count_131.Taxon_lifestage: string
# Taxon_count_132.Taxon_lifestage: string
# Taxon_count_092.Taxon_sex_code_(`,): string
# Taxon_present_040.Taxon_modifier_(`,): string
# DeltaHe3_Method: string
# DeltaHe3_Method.comment: string
# CFC11_Method: string
# CFC11_Method.comment: string
# CFC12_Method: string
# CFC12_Method.comment: string
# Taxon_present_058.Taxon_modifier: string
# Taxon_present_047.Taxon_modifier: string
# Oxy18_Access_no: int32
# Oxy18_Access_no.long_name: string
# Oxy18_Access_no.units: string
# Oxy18_Access_no.comment: string
# tCO2_Access_no: int32
# tCO2_Access_no.long_name: string
# tCO2_Access_no.units: string
# tCO2_Access_no.comment: string
# DOC_Access_no: int32
# DOC_Access_no.long_name: string
# DOC_Access_no.units: string
# DOC_Access_no.comment: string
# Taxon_count_100.Taxon_sex_code: string
# Taxon_count_108.Taxon_sex_code: string
# Taxon_count_109.Taxon_sex_code: string
# Taxon_count_110.Taxon_sex_code: string
# Taxon_count_111.Taxon_sex_code: string
# Taxon_count_118.Taxon_sex_code_(`,): string
# Taxon_count_119.Taxon_lifestage_(`,): string
# Taxon_count_119.Taxon_sex_code_(`,): string
# Taxon_count_120.Taxon_lifestage_(`,): string
# Taxon_count_120.Taxon_sex_code_(`,): string
# Taxon_count_121.Taxon_lifestage_(`,): string
# Taxon_count_121.Taxon_sex_code_(`,): string
# Taxon_count_122.Taxon_lifestage_(`,): string
# Taxon_count_122.Taxon_sex_code_(`,): string
# Taxon_count_123.Taxon_lifestage_(`,): string
# Taxon_count_123.Taxon_sex_code_(`,): string
# Taxon_count_124.Taxon_lifestage_(`,): string
# Taxon_count_125.Taxon_lifestage_(`,): string
# Taxon_count_126.Taxon_lifestage_(`,): string
# Taxon_count_127.Taxon_lifestage_(`,): string
# Taxon_count_128.Taxon_lifestage_(`,): string
# Taxon_count_129.Taxon_lifestage_(`,): string
# TotalPhos_Instrument: string
# TotalPhos_Instrument.long_name: string
# TotalPhos_Instrument.comment: string
# POC_Instrument: string
# POC_Instrument.long_name: string
# POC_Instrument.comment: string
# POC_Method: string
# POC_Method.comment: string
# NO2NO3_Method: string
# NO2NO3_Method.comment: string
# Taxon_count_165.Taxon_modifier_(`,): string
# Taxon_count_166.Taxon_modifier_(`,): string
# Taxon_count_167.Taxon_modifier_(`,): string
# Taxon_count_168.Taxon_modifier_(`,): string
# Taxon_present_059.Taxon_modifier: string
# Taxon_dry_mass_006: float
# Taxon_dry_mass_006.comment: string
# Taxon_dry_mass_006.WOD_name: string
# Taxon_dry_mass_006.upper_depth: float
# Taxon_dry_mass_006.lower_depth: float
# Taxon_dry_mass_006.Taxon_lifestage: string
# Taxon_dry_mass_006.Size_min: string
# Taxon_dry_mass_006.Units: string
# Taxon_dry_mass_006.CBV_calc_meth: float
# Taxon_dry_mass_006.PGC_group_code: int32
# Taxon_present_077.Taxon_modifier: string
# CFC11_Institute: string
# CFC11_Institute.long_name: string
# CFC11_Institute.comment: string
# CFC11_Instrument: string
# CFC11_Instrument.long_name: string
# CFC11_Instrument.comment: string
# CFC11_Original_units: string
# CFC11_Original_units.comment: string
# CFC12_Institute: string
# CFC12_Institute.long_name: string
# CFC12_Institute.comment: string
# CFC12_Instrument: string
# CFC12_Instrument.long_name: string
# CFC12_Instrument.comment: string
# CFC12_Original_units: string
# CFC12_Original_units.comment: string
# CFC113_Institute: string
# CFC113_Institute.long_name: string
# CFC113_Institute.comment: string
# CFC113_Instrument: string
# CFC113_Instrument.long_name: string
# CFC113_Instrument.comment: string
# CFC113_Method: string
# CFC113_Method.comment: string
# CFC113_Original_units: string
# CFC113_Original_units.comment: string
# pCO2_origflag: int16
# pCO2_origflag.flag_definitions: string
# pCO2_Access_no: int32
# pCO2_Access_no.long_name: string
# pCO2_Access_no.units: string
# pCO2_Access_no.comment: string
# Taxon_present_048.Taxon_modifier: string
# Taxon_present_046.Taxon_modifier: string
# Taxon_present_046.Taxon_modifier_(`,): string
# Taxon_present_050.Taxon_modifier: string
# integrated_Primary_Prod_001: float
# integrated_Primary_Prod_001.comment: string
# integrated_Primary_Prod_001.WOD_name: string
# integrated_Primary_Prod_001.upper_depth_(|): float
# integrated_Primary_Prod_001.lower_depth_(|): float
# integrated_Primary_Prod_001.Units_(|): string
# integrated_Primary_Prod_001.Spc_Meas_Method_(|): string
# Taxon_present_045.Taxon_modifier: string
# Taxon_dry_mass_005.Taxon_lifestage: string
# Taxon_dry_mass_005.Size_min: string
# TotalPhos_origflag: int16
# TotalPhos_origflag.flag_definitions: string
# Taxon_present_049.Taxon_modifier: string
# Taxon_present_045.Taxon_modifier_(`,): string
# Taxon_present_059.Taxon_modifier_(`,): string
# Taxon_present_054.Taxon_modifier_(`,): string
# Salinity_Method: string
# Salinity_Method.comment: string
# tCO2_STDWater_batch: int32
# tCO2_STDWater_batch.comment: string
# Ammonia_Access_no: int32
# Ammonia_Access_no.long_name: string
# Ammonia_Access_no.units: string
# Ammonia_Access_no.comment: string
# Argon: float
# Argon.long_name: string
# Argon.units: string
# Argon.coordinates: string
# Argon.grid_mapping: string
# Argon_sigfigs: int16
# Argon_WODflag: int16
# Argon_WODflag.flag_definitions: string
# Argon_origflag: int16
# Argon_origflag.flag_definitions: string
# Argon_Original_units: string
# Argon_Original_units.comment: string
# Ship_speed: float
# Ship_speed.long_name: string
# Ship_speed.units: string
# Ship_speed.comment: string
# ARGOS_ID: int32
# ARGOS_ID.comment: string
# pressure_hys: float
# pressure_hys.long_name: string
# pressure_hys.units: string
# pressure_hys.comment: string

# %%
WOD_FILL_VALUE = -10000000000.0

# %%
query_builder = tables['default'].query()
query_builder = (
    query_builder
    .add_select_column("__entry_key")
    .add_select_column("time")
    .add_select_column("time", "COMMON_TIME")
    .add_select_column("lon")
    .add_select_column("lon.units")
    .add_select_column("lon", "COMMON_LONGITUDE")
    .add_select(SelectLiteral("degrees_east", "COMMON_LONGITUDE_UNITS"))
    .add_select(SelectLiteral("Longitude", "COMMON_LONGITUDE_STANDARD_NAME"))
    .add_select(SelectLiteral("SDN:P01::ALONZZ01", "COMMON_LONGITUDE_P01"))
    .add_select(SelectLiteral("SDN:P06::DEGE", "COMMON_LONGITUDE_P06"))
    .add_select_column("lat")
    .add_select_column("lat.units")
    .add_select_column("lat", "COMMON_LATITUDE")
    .add_select(SelectLiteral("degrees_north", "COMMON_LATITUDE_UNITS"))
    .add_select(SelectLiteral("Latitude", "COMMON_LATITUDE_STANDARD_NAME"))
    .add_select(SelectLiteral("SDN:P01::ALATZZ01", "COMMON_LATITUDE_P01"))
    .add_select(SelectLiteral("SDN:P06::DEGN", "COMMON_LATITUDE_P06"))
    .add_select_column("z")
    .add_select_column("z.units")
    .add_select_column("z_WODflag")
    .add_select_column("z", "COMMON_ORIGIN_DEPTH")
    .add_select_column("z_WODflag", "COMMON_ORIGIN_DEPTH_QC")
    .add_select(SelectLiteral("m", "COMMON_ORIGIN_DEPTH_UNITS"))
    .add_select(SelectLiteral("Depth", "COMMON_ORIGIN_DEPTH_STANDARD_NAME"))
    .add_select(SelectLiteral("SDN:P01::ADEPZZ01", "COMMON_ORIGIN_DEPTH_P01"))
    .add_select(SelectLiteral("SDN:P06::ULAA", "COMMON_ORIGIN_DEPTH_P06"))
    .add_select_column("z", "COMMON_DEPTH")
    .add_select(SelectFunction("map_wod_quality_flag", [SelectColumn("z_WODflag")], "COMMON_DEPTH_QC"))
    .add_select(SelectLiteral("m", "COMMON_DEPTH_UNITS"))
    .add_select(SelectLiteral("depth", "COMMON_DEPTH_STANDARD_NAME"))
    .add_select(SelectLiteral("SDN:P01::ADEPZZ01", "COMMON_DEPTH_P01"))
    .add_select(SelectLiteral("SDN:P06::ULAA", "COMMON_DEPTH_P06"))
)

# %%
from datetime import datetime, timezone
dt_str = datetime.now(timezone.utc).strftime("%Y-%m-%dT%H:%M:%SZ")

query_builder = (
    query_builder
    .add_select(SelectLiteral("", "COMMON_EDMERP_CODE"))
    .add_select(SelectLiteral("", "COMMON_EDMO_CODE"))
    .add_select(SelectFunction("map_c17_l06", [SelectFunction("map_wod_platform_c17", [SelectColumn("Platform")])], "COMMON_PLATFORM_L06"))
    .add_select(SelectFunction("map_wod_platform_c17", [SelectColumn("Platform")], "COMMON_PLATFORM_C17"))
    .add_select(SelectColumn("wod_unique_cast", "COMMON_ODV_TAG"))
    .add_select(SelectLiteral("BEACON_WOD", "SOURCE_BDI"))
    .add_select(SelectColumn("wod_unique_cast", "SOURCE_BDI_DATASET_ID"))
    .add_select(SelectColumn(".featureType"))
    .add_select(SelectLiteral("profile", alias="COMMON_FEATURE_TYPE"))
    
    .add_select(SelectLiteral("2025-04-01T00:00:00Z", "COMMON_BDI_SNAPSHOT_DATE"))
    .add_select(SelectLiteral("1.5.0", "COMMON_BDI_MONOLITH_VERSION"))
    .add_select(SelectLiteral(dt_str, "COMMON_HARMONIZATION_DATE"))
    
    .add_select_column("dataset")
    .add_select_column(".institution")
    .add_select_column("Platform")
    .add_select_column("country")
    .add_select_column("WOD_cruise_identifier")
    .add_select_column("wod_unique_cast")
)

# %%
# Temperature
query_builder = (
    query_builder
    .add_select(SelectColumn("Temperature"))
    .add_select(SelectColumn("Temperature_WODflag"))
    .add_select(SelectColumn("Temperature.units"))
    
    .add_select(SelectColumn("Temperature", "COMMON_ORIGIN_TEMPERATURE"))
    .add_select(SelectColumn("Temperature_WODflag", "COMMON_ORIGIN_TEMPERATURE_QC"))
    .add_select(SelectColumn("Temperature.standard_name", "COMMON_ORIGIN_TEMPERATURE_STANDARD_NAME"))
    .add_select(SelectColumn("Temperature.units", "COMMON_ORIGIN_TEMPERATURE_UNITS"))
    .add_select(SelectLiteral("SDN:P01::TEMPPR01", "COMMON_ORIGIN_TEMPERATURE_P01"))
    .add_select(SelectLiteral("SDN:P06::UPAA", "COMMON_ORIGIN_TEMPERATURE_P06"))
    # MAP COMMON Temperature
    .add_select(SelectFunction("nullif", [SelectColumn("Temperature"), SelectLiteral(-10000000000.0)], "COMMON_TEMPERATURE"))
    .add_select(SelectFunction("map_wod_quality_flag", [SelectColumn("Temperature_WODflag")], "COMMON_TEMPERATURE_QC"))
    .add_select(SelectLiteral("sea_water_temperature", "COMMON_TEMPERATURE_STANDARD_NAME"))
    .add_select(SelectLiteral("degree_C", "COMMON_TEMPERATURE_UNITS"))
    .add_select(SelectLiteral("SDN:P01::TEMPPR01", "COMMON_TEMPERATURE_P01"))
    .add_select(SelectLiteral("SDN:P06::UPAA", "COMMON_TEMPERATURE_P06"))
    # MAP COMMON Temperature INSTRUMENTS
    .add_select(
        SelectFunction("coalesce", [
            SelectFunction("map_wod_instrument_l05", [SelectColumn("Temperature_Instrument")]),
            SelectFunction("map_l22_l05", [SelectFunction("map_wod_instrument_l22", [SelectColumn("Temperature_Instrument")])])
            ], "COMMON_TEMPERATURE_L05"))
    .add_select(SelectFunction("map_wod_instrument_l22", [SelectColumn("Temperature_Instrument")], "COMMON_TEMPERATURE_L22"))
    .add_select(SelectFunction("map_wod_instrument_l33", [SelectColumn("Temperature_Instrument")], "COMMON_TEMPERATURE_L33"))
    .add_select(SelectColumn("Temperature_Instrument"))
)

# %%
# Salinity
query_builder = (
    query_builder
    .add_select(SelectColumn("Salinity"))
    .add_select(SelectColumn("Salinity_WODflag"))
    .add_select(SelectColumn("Salinity", "COMMON_ORIGIN_SALINITY"))
    .add_select(SelectColumn("Salinity_WODflag", "COMMON_ORIGIN_SALINITY_QC"))
    .add_select(SelectColumn("Salinity.standard_name", "COMMON_ORIGIN_SALINITY_STANDARD_NAME"))
    .add_select(SelectLiteral("", "COMMON_ORIGIN_SALINITY_UNITS"))
    .add_select(SelectLiteral("SDN:P01::PSLTZZ01", "COMMON_ORIGIN_SALINITY_P01"))
    .add_select(SelectLiteral("SDN:P06::UUUU", "COMMON_ORIGIN_SALINITY_P06"))
    # MAP COMMON Salinity
    .add_select(SelectFunction("nullif", [SelectColumn("Salinity"), SelectLiteral(-10000000000.0)], "COMMON_SALINITY"))
    .add_select(SelectFunction("map_wod_quality_flag", [SelectColumn("Salinity_WODflag")], "COMMON_SALINITY_QC"))
    .add_select(SelectLiteral("sea_water_practical_salinity", "COMMON_SALINITY_STANDARD_NAME"))
    .add_select(SelectLiteral("dimensionless", "COMMON_SALINITY_UNITS"))
    .add_select(SelectLiteral("SDN:P01::PSLTZZ01", "COMMON_SALINITY_P01"))
    .add_select(SelectLiteral("SDN:P06::UUUU", "COMMON_SALINITY_P06"))
    # Instruments
    .add_select(
        SelectFunction("coalesce", [
            SelectFunction("map_wod_instrument_l05", [SelectColumn("Salinity_Instrument")]),
            SelectFunction("map_l22_l05", [SelectFunction("map_wod_instrument_l22", [SelectColumn("Salinity_Instrument")])])
            ], "COMMON_SALINITY_L05"))
    .add_select(SelectFunction("map_wod_instrument_l22", [SelectColumn("Salinity_Instrument")], "COMMON_SALINITY_L22"))
    .add_select(SelectFunction("map_wod_instrument_l33", [SelectColumn("Salinity_Instrument")], "COMMON_SALINITY_L33"))
    .add_select(SelectColumn("Salinity_Instrument"))
)

# %%
import os 
import json

# Make output dir
output_dir = "./output"
os.makedirs(output_dir, exist_ok=True)
# for each year between 1950 and 2025
for year in range(1950, 2026):
    print(f"Processing year {year}")
    query_builder.filters = []
    query_builder = query_builder.add_range_filter("COMMON_TIME", f"{year}-01-01T00:00:00Z", f"{year}-12-31T23:59:59Z")
    query_builder = (
        query_builder.add_filter(OrFilter([
            IsNotNullFilter("Temperature"),
            IsNotNullFilter("Salinity"),
        ]))
    )
    
    output_file = os.path.join(output_dir, f"wod_{year}.parquet")
    try:
        query_builder.to_parquet(output_file)
        print(f"Saved to {output_file}")
    except Exception as e:
        print(f"Failed to process year {year}: {e}")
# Out:
# Processing year 1950
# Running query: {"from": "default", "select": [{"column": "__entry_key", "alias": null}, {"column": "time", "alias": null}, {"column": "time", "alias": "COMMON_TIME"}, {"column": "lon", "alias": null}, {"column": "lon.units", "alias": null}, {"column": "lon", "alias": "COMMON_LONGITUDE"}, {"value": "degrees_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "Longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "lat", "alias": null}, {"column": "lat.units", "alias": null}, {"column": "lat", "alias": "COMMON_LATITUDE"}, {"value": "degrees_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "Latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "z", "alias": null}, {"column": "z.units", "alias": null}, {"column": "z_WODflag", "alias": null}, {"column": "z", "alias": "COMMON_ORIGIN_DEPTH"}, {"column": "z_WODflag", "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"value": "m", "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"value": "Depth", "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"column": "z", "alias": "COMMON_DEPTH"}, {"function": "map_wod_quality_flag", "args": [{"column": "z_WODflag", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"value": "", "alias": "COMMON_EDMO_CODE"}, {"function": "map_c17_l06", "args": [{"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": "COMMON_PLATFORM_C17"}, {"column": "wod_unique_cast", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_WOD", "alias": "SOURCE_BDI"}, {"column": "wod_unique_cast", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": ".featureType", "alias": null}, {"value": "profile", "alias": "COMMON_FEATURE_TYPE"}, {"column": "dataset", "alias": null}, {"column": ".institution", "alias": null}, {"column": "Platform", "alias": null}, {"column": "country", "alias": null}, {"column": "WOD_cruise_identifier", "alias": null}, {"column": "wod_unique_cast", "alias": null}, {"column": "Temperature", "alias": null}, {"column": "Temperature_WODflag", "alias": null}, {"column": "Temperature.units", "alias": null}, {"column": "Temperature", "alias": "COMMON_ORIGIN_TEMPERATURE"}, {"column": "Temperature_WODflag", "alias": "COMMON_ORIGIN_TEMPERATURE_QC"}, {"column": "Temperature.standard_name", "alias": "COMMON_ORIGIN_TEMPERATURE_STANDARD_NAME"}, {"column": "Temperature.units", "alias": "COMMON_ORIGIN_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_ORIGIN_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_ORIGIN_TEMPERATURE_P06"}, {"function": "nullif", "args": [{"column": "Temperature", "alias": null}, {"value": -10000000000.0, "alias": null}], "alias": "COMMON_TEMPERATURE"}, {"function": "map_wod_quality_flag", "args": [{"column": "Temperature_WODflag", "alias": null}], "alias": "COMMON_TEMPERATURE_QC"}, {"value": "sea_water_temperature", "alias": "COMMON_TEMPERATURE_STANDARD_NAME"}, {"value": "degree_C", "alias": "COMMON_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_TEMPERATURE_P06"}, {"function": "coalesce", "args": [{"function": "map_wod_instrument_l05", "args": [{"column": "Temperature_Instrument", "alias": null}], "alias": null}, {"function": "map_l22_l05" ...
# Saved to ./output/wod_1950.parquet
# Processing year 1951
# Running query: {"from": "default", "select": [{"column": "__entry_key", "alias": null}, {"column": "time", "alias": null}, {"column": "time", "alias": "COMMON_TIME"}, {"column": "lon", "alias": null}, {"column": "lon.units", "alias": null}, {"column": "lon", "alias": "COMMON_LONGITUDE"}, {"value": "degrees_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "Longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "lat", "alias": null}, {"column": "lat.units", "alias": null}, {"column": "lat", "alias": "COMMON_LATITUDE"}, {"value": "degrees_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "Latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "z", "alias": null}, {"column": "z.units", "alias": null}, {"column": "z_WODflag", "alias": null}, {"column": "z", "alias": "COMMON_ORIGIN_DEPTH"}, {"column": "z_WODflag", "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"value": "m", "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"value": "Depth", "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"column": "z", "alias": "COMMON_DEPTH"}, {"function": "map_wod_quality_flag", "args": [{"column": "z_WODflag", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"value": "", "alias": "COMMON_EDMO_CODE"}, {"function": "map_c17_l06", "args": [{"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": "COMMON_PLATFORM_C17"}, {"column": "wod_unique_cast", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_WOD", "alias": "SOURCE_BDI"}, {"column": "wod_unique_cast", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": ".featureType", "alias": null}, {"value": "profile", "alias": "COMMON_FEATURE_TYPE"}, {"column": "dataset", "alias": null}, {"column": ".institution", "alias": null}, {"column": "Platform", "alias": null}, {"column": "country", "alias": null}, {"column": "WOD_cruise_identifier", "alias": null}, {"column": "wod_unique_cast", "alias": null}, {"column": "Temperature", "alias": null}, {"column": "Temperature_WODflag", "alias": null}, {"column": "Temperature.units", "alias": null}, {"column": "Temperature", "alias": "COMMON_ORIGIN_TEMPERATURE"}, {"column": "Temperature_WODflag", "alias": "COMMON_ORIGIN_TEMPERATURE_QC"}, {"column": "Temperature.standard_name", "alias": "COMMON_ORIGIN_TEMPERATURE_STANDARD_NAME"}, {"column": "Temperature.units", "alias": "COMMON_ORIGIN_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_ORIGIN_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_ORIGIN_TEMPERATURE_P06"}, {"function": "nullif", "args": [{"column": "Temperature", "alias": null}, {"value": -10000000000.0, "alias": null}], "alias": "COMMON_TEMPERATURE"}, {"function": "map_wod_quality_flag", "args": [{"column": "Temperature_WODflag", "alias": null}], "alias": "COMMON_TEMPERATURE_QC"}, {"value": "sea_water_temperature", "alias": "COMMON_TEMPERATURE_STANDARD_NAME"}, {"value": "degree_C", "alias": "COMMON_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_TEMPERATURE_P06"}, {"function": "coalesce", "args": [{"function": "map_wod_instrument_l05", "args": [{"column": "Temperature_Instrument", "alias": null}], "alias": null}, {"function": "map_l22_l05" ...
# Saved to ./output/wod_1951.parquet
# Processing year 1952
# Running query: {"from": "default", "select": [{"column": "__entry_key", "alias": null}, {"column": "time", "alias": null}, {"column": "time", "alias": "COMMON_TIME"}, {"column": "lon", "alias": null}, {"column": "lon.units", "alias": null}, {"column": "lon", "alias": "COMMON_LONGITUDE"}, {"value": "degrees_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "Longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "lat", "alias": null}, {"column": "lat.units", "alias": null}, {"column": "lat", "alias": "COMMON_LATITUDE"}, {"value": "degrees_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "Latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "z", "alias": null}, {"column": "z.units", "alias": null}, {"column": "z_WODflag", "alias": null}, {"column": "z", "alias": "COMMON_ORIGIN_DEPTH"}, {"column": "z_WODflag", "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"value": "m", "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"value": "Depth", "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"column": "z", "alias": "COMMON_DEPTH"}, {"function": "map_wod_quality_flag", "args": [{"column": "z_WODflag", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"value": "", "alias": "COMMON_EDMO_CODE"}, {"function": "map_c17_l06", "args": [{"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": "COMMON_PLATFORM_C17"}, {"column": "wod_unique_cast", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_WOD", "alias": "SOURCE_BDI"}, {"column": "wod_unique_cast", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": ".featureType", "alias": null}, {"value": "profile", "alias": "COMMON_FEATURE_TYPE"}, {"column": "dataset", "alias": null}, {"column": ".institution", "alias": null}, {"column": "Platform", "alias": null}, {"column": "country", "alias": null}, {"column": "WOD_cruise_identifier", "alias": null}, {"column": "wod_unique_cast", "alias": null}, {"column": "Temperature", "alias": null}, {"column": "Temperature_WODflag", "alias": null}, {"column": "Temperature.units", "alias": null}, {"column": "Temperature", "alias": "COMMON_ORIGIN_TEMPERATURE"}, {"column": "Temperature_WODflag", "alias": "COMMON_ORIGIN_TEMPERATURE_QC"}, {"column": "Temperature.standard_name", "alias": "COMMON_ORIGIN_TEMPERATURE_STANDARD_NAME"}, {"column": "Temperature.units", "alias": "COMMON_ORIGIN_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_ORIGIN_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_ORIGIN_TEMPERATURE_P06"}, {"function": "nullif", "args": [{"column": "Temperature", "alias": null}, {"value": -10000000000.0, "alias": null}], "alias": "COMMON_TEMPERATURE"}, {"function": "map_wod_quality_flag", "args": [{"column": "Temperature_WODflag", "alias": null}], "alias": "COMMON_TEMPERATURE_QC"}, {"value": "sea_water_temperature", "alias": "COMMON_TEMPERATURE_STANDARD_NAME"}, {"value": "degree_C", "alias": "COMMON_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_TEMPERATURE_P06"}, {"function": "coalesce", "args": [{"function": "map_wod_instrument_l05", "args": [{"column": "Temperature_Instrument", "alias": null}], "alias": null}, {"function": "map_l22_l05" ...
# Saved to ./output/wod_1952.parquet
# Processing year 1953
# Running query: {"from": "default", "select": [{"column": "__entry_key", "alias": null}, {"column": "time", "alias": null}, {"column": "time", "alias": "COMMON_TIME"}, {"column": "lon", "alias": null}, {"column": "lon.units", "alias": null}, {"column": "lon", "alias": "COMMON_LONGITUDE"}, {"value": "degrees_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "Longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "lat", "alias": null}, {"column": "lat.units", "alias": null}, {"column": "lat", "alias": "COMMON_LATITUDE"}, {"value": "degrees_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "Latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "z", "alias": null}, {"column": "z.units", "alias": null}, {"column": "z_WODflag", "alias": null}, {"column": "z", "alias": "COMMON_ORIGIN_DEPTH"}, {"column": "z_WODflag", "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"value": "m", "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"value": "Depth", "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"column": "z", "alias": "COMMON_DEPTH"}, {"function": "map_wod_quality_flag", "args": [{"column": "z_WODflag", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"value": "", "alias": "COMMON_EDMO_CODE"}, {"function": "map_c17_l06", "args": [{"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": "COMMON_PLATFORM_C17"}, {"column": "wod_unique_cast", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_WOD", "alias": "SOURCE_BDI"}, {"column": "wod_unique_cast", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": ".featureType", "alias": null}, {"value": "profile", "alias": "COMMON_FEATURE_TYPE"}, {"column": "dataset", "alias": null}, {"column": ".institution", "alias": null}, {"column": "Platform", "alias": null}, {"column": "country", "alias": null}, {"column": "WOD_cruise_identifier", "alias": null}, {"column": "wod_unique_cast", "alias": null}, {"column": "Temperature", "alias": null}, {"column": "Temperature_WODflag", "alias": null}, {"column": "Temperature.units", "alias": null}, {"column": "Temperature", "alias": "COMMON_ORIGIN_TEMPERATURE"}, {"column": "Temperature_WODflag", "alias": "COMMON_ORIGIN_TEMPERATURE_QC"}, {"column": "Temperature.standard_name", "alias": "COMMON_ORIGIN_TEMPERATURE_STANDARD_NAME"}, {"column": "Temperature.units", "alias": "COMMON_ORIGIN_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_ORIGIN_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_ORIGIN_TEMPERATURE_P06"}, {"function": "nullif", "args": [{"column": "Temperature", "alias": null}, {"value": -10000000000.0, "alias": null}], "alias": "COMMON_TEMPERATURE"}, {"function": "map_wod_quality_flag", "args": [{"column": "Temperature_WODflag", "alias": null}], "alias": "COMMON_TEMPERATURE_QC"}, {"value": "sea_water_temperature", "alias": "COMMON_TEMPERATURE_STANDARD_NAME"}, {"value": "degree_C", "alias": "COMMON_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_TEMPERATURE_P06"}, {"function": "coalesce", "args": [{"function": "map_wod_instrument_l05", "args": [{"column": "Temperature_Instrument", "alias": null}], "alias": null}, {"function": "map_l22_l05" ...
# Saved to ./output/wod_1953.parquet
# Processing year 1954
# Running query: {"from": "default", "select": [{"column": "__entry_key", "alias": null}, {"column": "time", "alias": null}, {"column": "time", "alias": "COMMON_TIME"}, {"column": "lon", "alias": null}, {"column": "lon.units", "alias": null}, {"column": "lon", "alias": "COMMON_LONGITUDE"}, {"value": "degrees_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "Longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "lat", "alias": null}, {"column": "lat.units", "alias": null}, {"column": "lat", "alias": "COMMON_LATITUDE"}, {"value": "degrees_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "Latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "z", "alias": null}, {"column": "z.units", "alias": null}, {"column": "z_WODflag", "alias": null}, {"column": "z", "alias": "COMMON_ORIGIN_DEPTH"}, {"column": "z_WODflag", "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"value": "m", "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"value": "Depth", "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"column": "z", "alias": "COMMON_DEPTH"}, {"function": "map_wod_quality_flag", "args": [{"column": "z_WODflag", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"value": "", "alias": "COMMON_EDMO_CODE"}, {"function": "map_c17_l06", "args": [{"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": "COMMON_PLATFORM_C17"}, {"column": "wod_unique_cast", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_WOD", "alias": "SOURCE_BDI"}, {"column": "wod_unique_cast", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": ".featureType", "alias": null}, {"value": "profile", "alias": "COMMON_FEATURE_TYPE"}, {"column": "dataset", "alias": null}, {"column": ".institution", "alias": null}, {"column": "Platform", "alias": null}, {"column": "country", "alias": null}, {"column": "WOD_cruise_identifier", "alias": null}, {"column": "wod_unique_cast", "alias": null}, {"column": "Temperature", "alias": null}, {"column": "Temperature_WODflag", "alias": null}, {"column": "Temperature.units", "alias": null}, {"column": "Temperature", "alias": "COMMON_ORIGIN_TEMPERATURE"}, {"column": "Temperature_WODflag", "alias": "COMMON_ORIGIN_TEMPERATURE_QC"}, {"column": "Temperature.standard_name", "alias": "COMMON_ORIGIN_TEMPERATURE_STANDARD_NAME"}, {"column": "Temperature.units", "alias": "COMMON_ORIGIN_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_ORIGIN_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_ORIGIN_TEMPERATURE_P06"}, {"function": "nullif", "args": [{"column": "Temperature", "alias": null}, {"value": -10000000000.0, "alias": null}], "alias": "COMMON_TEMPERATURE"}, {"function": "map_wod_quality_flag", "args": [{"column": "Temperature_WODflag", "alias": null}], "alias": "COMMON_TEMPERATURE_QC"}, {"value": "sea_water_temperature", "alias": "COMMON_TEMPERATURE_STANDARD_NAME"}, {"value": "degree_C", "alias": "COMMON_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_TEMPERATURE_P06"}, {"function": "coalesce", "args": [{"function": "map_wod_instrument_l05", "args": [{"column": "Temperature_Instrument", "alias": null}], "alias": null}, {"function": "map_l22_l05" ...
# Saved to ./output/wod_1954.parquet
# Processing year 1955
# Running query: {"from": "default", "select": [{"column": "__entry_key", "alias": null}, {"column": "time", "alias": null}, {"column": "time", "alias": "COMMON_TIME"}, {"column": "lon", "alias": null}, {"column": "lon.units", "alias": null}, {"column": "lon", "alias": "COMMON_LONGITUDE"}, {"value": "degrees_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "Longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "lat", "alias": null}, {"column": "lat.units", "alias": null}, {"column": "lat", "alias": "COMMON_LATITUDE"}, {"value": "degrees_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "Latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "z", "alias": null}, {"column": "z.units", "alias": null}, {"column": "z_WODflag", "alias": null}, {"column": "z", "alias": "COMMON_ORIGIN_DEPTH"}, {"column": "z_WODflag", "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"value": "m", "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"value": "Depth", "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"column": "z", "alias": "COMMON_DEPTH"}, {"function": "map_wod_quality_flag", "args": [{"column": "z_WODflag", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"value": "", "alias": "COMMON_EDMO_CODE"}, {"function": "map_c17_l06", "args": [{"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": "COMMON_PLATFORM_C17"}, {"column": "wod_unique_cast", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_WOD", "alias": "SOURCE_BDI"}, {"column": "wod_unique_cast", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": ".featureType", "alias": null}, {"value": "profile", "alias": "COMMON_FEATURE_TYPE"}, {"column": "dataset", "alias": null}, {"column": ".institution", "alias": null}, {"column": "Platform", "alias": null}, {"column": "country", "alias": null}, {"column": "WOD_cruise_identifier", "alias": null}, {"column": "wod_unique_cast", "alias": null}, {"column": "Temperature", "alias": null}, {"column": "Temperature_WODflag", "alias": null}, {"column": "Temperature.units", "alias": null}, {"column": "Temperature", "alias": "COMMON_ORIGIN_TEMPERATURE"}, {"column": "Temperature_WODflag", "alias": "COMMON_ORIGIN_TEMPERATURE_QC"}, {"column": "Temperature.standard_name", "alias": "COMMON_ORIGIN_TEMPERATURE_STANDARD_NAME"}, {"column": "Temperature.units", "alias": "COMMON_ORIGIN_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_ORIGIN_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_ORIGIN_TEMPERATURE_P06"}, {"function": "nullif", "args": [{"column": "Temperature", "alias": null}, {"value": -10000000000.0, "alias": null}], "alias": "COMMON_TEMPERATURE"}, {"function": "map_wod_quality_flag", "args": [{"column": "Temperature_WODflag", "alias": null}], "alias": "COMMON_TEMPERATURE_QC"}, {"value": "sea_water_temperature", "alias": "COMMON_TEMPERATURE_STANDARD_NAME"}, {"value": "degree_C", "alias": "COMMON_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_TEMPERATURE_P06"}, {"function": "coalesce", "args": [{"function": "map_wod_instrument_l05", "args": [{"column": "Temperature_Instrument", "alias": null}], "alias": null}, {"function": "map_l22_l05" ...
# Saved to ./output/wod_1955.parquet
# Processing year 1956
# Running query: {"from": "default", "select": [{"column": "__entry_key", "alias": null}, {"column": "time", "alias": null}, {"column": "time", "alias": "COMMON_TIME"}, {"column": "lon", "alias": null}, {"column": "lon.units", "alias": null}, {"column": "lon", "alias": "COMMON_LONGITUDE"}, {"value": "degrees_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "Longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "lat", "alias": null}, {"column": "lat.units", "alias": null}, {"column": "lat", "alias": "COMMON_LATITUDE"}, {"value": "degrees_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "Latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "z", "alias": null}, {"column": "z.units", "alias": null}, {"column": "z_WODflag", "alias": null}, {"column": "z", "alias": "COMMON_ORIGIN_DEPTH"}, {"column": "z_WODflag", "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"value": "m", "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"value": "Depth", "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"column": "z", "alias": "COMMON_DEPTH"}, {"function": "map_wod_quality_flag", "args": [{"column": "z_WODflag", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"value": "", "alias": "COMMON_EDMO_CODE"}, {"function": "map_c17_l06", "args": [{"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": "COMMON_PLATFORM_C17"}, {"column": "wod_unique_cast", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_WOD", "alias": "SOURCE_BDI"}, {"column": "wod_unique_cast", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": ".featureType", "alias": null}, {"value": "profile", "alias": "COMMON_FEATURE_TYPE"}, {"column": "dataset", "alias": null}, {"column": ".institution", "alias": null}, {"column": "Platform", "alias": null}, {"column": "country", "alias": null}, {"column": "WOD_cruise_identifier", "alias": null}, {"column": "wod_unique_cast", "alias": null}, {"column": "Temperature", "alias": null}, {"column": "Temperature_WODflag", "alias": null}, {"column": "Temperature.units", "alias": null}, {"column": "Temperature", "alias": "COMMON_ORIGIN_TEMPERATURE"}, {"column": "Temperature_WODflag", "alias": "COMMON_ORIGIN_TEMPERATURE_QC"}, {"column": "Temperature.standard_name", "alias": "COMMON_ORIGIN_TEMPERATURE_STANDARD_NAME"}, {"column": "Temperature.units", "alias": "COMMON_ORIGIN_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_ORIGIN_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_ORIGIN_TEMPERATURE_P06"}, {"function": "nullif", "args": [{"column": "Temperature", "alias": null}, {"value": -10000000000.0, "alias": null}], "alias": "COMMON_TEMPERATURE"}, {"function": "map_wod_quality_flag", "args": [{"column": "Temperature_WODflag", "alias": null}], "alias": "COMMON_TEMPERATURE_QC"}, {"value": "sea_water_temperature", "alias": "COMMON_TEMPERATURE_STANDARD_NAME"}, {"value": "degree_C", "alias": "COMMON_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_TEMPERATURE_P06"}, {"function": "coalesce", "args": [{"function": "map_wod_instrument_l05", "args": [{"column": "Temperature_Instrument", "alias": null}], "alias": null}, {"function": "map_l22_l05" ...
# Saved to ./output/wod_1956.parquet
# Processing year 1957
# Running query: {"from": "default", "select": [{"column": "__entry_key", "alias": null}, {"column": "time", "alias": null}, {"column": "time", "alias": "COMMON_TIME"}, {"column": "lon", "alias": null}, {"column": "lon.units", "alias": null}, {"column": "lon", "alias": "COMMON_LONGITUDE"}, {"value": "degrees_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "Longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "lat", "alias": null}, {"column": "lat.units", "alias": null}, {"column": "lat", "alias": "COMMON_LATITUDE"}, {"value": "degrees_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "Latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "z", "alias": null}, {"column": "z.units", "alias": null}, {"column": "z_WODflag", "alias": null}, {"column": "z", "alias": "COMMON_ORIGIN_DEPTH"}, {"column": "z_WODflag", "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"value": "m", "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"value": "Depth", "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"column": "z", "alias": "COMMON_DEPTH"}, {"function": "map_wod_quality_flag", "args": [{"column": "z_WODflag", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"value": "", "alias": "COMMON_EDMO_CODE"}, {"function": "map_c17_l06", "args": [{"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": "COMMON_PLATFORM_C17"}, {"column": "wod_unique_cast", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_WOD", "alias": "SOURCE_BDI"}, {"column": "wod_unique_cast", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": ".featureType", "alias": null}, {"value": "profile", "alias": "COMMON_FEATURE_TYPE"}, {"column": "dataset", "alias": null}, {"column": ".institution", "alias": null}, {"column": "Platform", "alias": null}, {"column": "country", "alias": null}, {"column": "WOD_cruise_identifier", "alias": null}, {"column": "wod_unique_cast", "alias": null}, {"column": "Temperature", "alias": null}, {"column": "Temperature_WODflag", "alias": null}, {"column": "Temperature.units", "alias": null}, {"column": "Temperature", "alias": "COMMON_ORIGIN_TEMPERATURE"}, {"column": "Temperature_WODflag", "alias": "COMMON_ORIGIN_TEMPERATURE_QC"}, {"column": "Temperature.standard_name", "alias": "COMMON_ORIGIN_TEMPERATURE_STANDARD_NAME"}, {"column": "Temperature.units", "alias": "COMMON_ORIGIN_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_ORIGIN_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_ORIGIN_TEMPERATURE_P06"}, {"function": "nullif", "args": [{"column": "Temperature", "alias": null}, {"value": -10000000000.0, "alias": null}], "alias": "COMMON_TEMPERATURE"}, {"function": "map_wod_quality_flag", "args": [{"column": "Temperature_WODflag", "alias": null}], "alias": "COMMON_TEMPERATURE_QC"}, {"value": "sea_water_temperature", "alias": "COMMON_TEMPERATURE_STANDARD_NAME"}, {"value": "degree_C", "alias": "COMMON_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_TEMPERATURE_P06"}, {"function": "coalesce", "args": [{"function": "map_wod_instrument_l05", "args": [{"column": "Temperature_Instrument", "alias": null}], "alias": null}, {"function": "map_l22_l05" ...
# Saved to ./output/wod_1957.parquet
# Processing year 1958
# Running query: {"from": "default", "select": [{"column": "__entry_key", "alias": null}, {"column": "time", "alias": null}, {"column": "time", "alias": "COMMON_TIME"}, {"column": "lon", "alias": null}, {"column": "lon.units", "alias": null}, {"column": "lon", "alias": "COMMON_LONGITUDE"}, {"value": "degrees_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "Longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "lat", "alias": null}, {"column": "lat.units", "alias": null}, {"column": "lat", "alias": "COMMON_LATITUDE"}, {"value": "degrees_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "Latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "z", "alias": null}, {"column": "z.units", "alias": null}, {"column": "z_WODflag", "alias": null}, {"column": "z", "alias": "COMMON_ORIGIN_DEPTH"}, {"column": "z_WODflag", "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"value": "m", "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"value": "Depth", "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"column": "z", "alias": "COMMON_DEPTH"}, {"function": "map_wod_quality_flag", "args": [{"column": "z_WODflag", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"value": "", "alias": "COMMON_EDMO_CODE"}, {"function": "map_c17_l06", "args": [{"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": "COMMON_PLATFORM_C17"}, {"column": "wod_unique_cast", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_WOD", "alias": "SOURCE_BDI"}, {"column": "wod_unique_cast", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": ".featureType", "alias": null}, {"value": "profile", "alias": "COMMON_FEATURE_TYPE"}, {"column": "dataset", "alias": null}, {"column": ".institution", "alias": null}, {"column": "Platform", "alias": null}, {"column": "country", "alias": null}, {"column": "WOD_cruise_identifier", "alias": null}, {"column": "wod_unique_cast", "alias": null}, {"column": "Temperature", "alias": null}, {"column": "Temperature_WODflag", "alias": null}, {"column": "Temperature.units", "alias": null}, {"column": "Temperature", "alias": "COMMON_ORIGIN_TEMPERATURE"}, {"column": "Temperature_WODflag", "alias": "COMMON_ORIGIN_TEMPERATURE_QC"}, {"column": "Temperature.standard_name", "alias": "COMMON_ORIGIN_TEMPERATURE_STANDARD_NAME"}, {"column": "Temperature.units", "alias": "COMMON_ORIGIN_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_ORIGIN_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_ORIGIN_TEMPERATURE_P06"}, {"function": "nullif", "args": [{"column": "Temperature", "alias": null}, {"value": -10000000000.0, "alias": null}], "alias": "COMMON_TEMPERATURE"}, {"function": "map_wod_quality_flag", "args": [{"column": "Temperature_WODflag", "alias": null}], "alias": "COMMON_TEMPERATURE_QC"}, {"value": "sea_water_temperature", "alias": "COMMON_TEMPERATURE_STANDARD_NAME"}, {"value": "degree_C", "alias": "COMMON_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_TEMPERATURE_P06"}, {"function": "coalesce", "args": [{"function": "map_wod_instrument_l05", "args": [{"column": "Temperature_Instrument", "alias": null}], "alias": null}, {"function": "map_l22_l05" ...
# Saved to ./output/wod_1958.parquet
# Processing year 1959
# Running query: {"from": "default", "select": [{"column": "__entry_key", "alias": null}, {"column": "time", "alias": null}, {"column": "time", "alias": "COMMON_TIME"}, {"column": "lon", "alias": null}, {"column": "lon.units", "alias": null}, {"column": "lon", "alias": "COMMON_LONGITUDE"}, {"value": "degrees_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "Longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "lat", "alias": null}, {"column": "lat.units", "alias": null}, {"column": "lat", "alias": "COMMON_LATITUDE"}, {"value": "degrees_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "Latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "z", "alias": null}, {"column": "z.units", "alias": null}, {"column": "z_WODflag", "alias": null}, {"column": "z", "alias": "COMMON_ORIGIN_DEPTH"}, {"column": "z_WODflag", "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"value": "m", "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"value": "Depth", "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"column": "z", "alias": "COMMON_DEPTH"}, {"function": "map_wod_quality_flag", "args": [{"column": "z_WODflag", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"value": "", "alias": "COMMON_EDMO_CODE"}, {"function": "map_c17_l06", "args": [{"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": "COMMON_PLATFORM_C17"}, {"column": "wod_unique_cast", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_WOD", "alias": "SOURCE_BDI"}, {"column": "wod_unique_cast", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": ".featureType", "alias": null}, {"value": "profile", "alias": "COMMON_FEATURE_TYPE"}, {"column": "dataset", "alias": null}, {"column": ".institution", "alias": null}, {"column": "Platform", "alias": null}, {"column": "country", "alias": null}, {"column": "WOD_cruise_identifier", "alias": null}, {"column": "wod_unique_cast", "alias": null}, {"column": "Temperature", "alias": null}, {"column": "Temperature_WODflag", "alias": null}, {"column": "Temperature.units", "alias": null}, {"column": "Temperature", "alias": "COMMON_ORIGIN_TEMPERATURE"}, {"column": "Temperature_WODflag", "alias": "COMMON_ORIGIN_TEMPERATURE_QC"}, {"column": "Temperature.standard_name", "alias": "COMMON_ORIGIN_TEMPERATURE_STANDARD_NAME"}, {"column": "Temperature.units", "alias": "COMMON_ORIGIN_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_ORIGIN_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_ORIGIN_TEMPERATURE_P06"}, {"function": "nullif", "args": [{"column": "Temperature", "alias": null}, {"value": -10000000000.0, "alias": null}], "alias": "COMMON_TEMPERATURE"}, {"function": "map_wod_quality_flag", "args": [{"column": "Temperature_WODflag", "alias": null}], "alias": "COMMON_TEMPERATURE_QC"}, {"value": "sea_water_temperature", "alias": "COMMON_TEMPERATURE_STANDARD_NAME"}, {"value": "degree_C", "alias": "COMMON_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_TEMPERATURE_P06"}, {"function": "coalesce", "args": [{"function": "map_wod_instrument_l05", "args": [{"column": "Temperature_Instrument", "alias": null}], "alias": null}, {"function": "map_l22_l05" ...
# Saved to ./output/wod_1959.parquet
# Processing year 1960
# Running query: {"from": "default", "select": [{"column": "__entry_key", "alias": null}, {"column": "time", "alias": null}, {"column": "time", "alias": "COMMON_TIME"}, {"column": "lon", "alias": null}, {"column": "lon.units", "alias": null}, {"column": "lon", "alias": "COMMON_LONGITUDE"}, {"value": "degrees_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "Longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "lat", "alias": null}, {"column": "lat.units", "alias": null}, {"column": "lat", "alias": "COMMON_LATITUDE"}, {"value": "degrees_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "Latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "z", "alias": null}, {"column": "z.units", "alias": null}, {"column": "z_WODflag", "alias": null}, {"column": "z", "alias": "COMMON_ORIGIN_DEPTH"}, {"column": "z_WODflag", "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"value": "m", "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"value": "Depth", "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"column": "z", "alias": "COMMON_DEPTH"}, {"function": "map_wod_quality_flag", "args": [{"column": "z_WODflag", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"value": "", "alias": "COMMON_EDMO_CODE"}, {"function": "map_c17_l06", "args": [{"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": "COMMON_PLATFORM_C17"}, {"column": "wod_unique_cast", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_WOD", "alias": "SOURCE_BDI"}, {"column": "wod_unique_cast", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": ".featureType", "alias": null}, {"value": "profile", "alias": "COMMON_FEATURE_TYPE"}, {"column": "dataset", "alias": null}, {"column": ".institution", "alias": null}, {"column": "Platform", "alias": null}, {"column": "country", "alias": null}, {"column": "WOD_cruise_identifier", "alias": null}, {"column": "wod_unique_cast", "alias": null}, {"column": "Temperature", "alias": null}, {"column": "Temperature_WODflag", "alias": null}, {"column": "Temperature.units", "alias": null}, {"column": "Temperature", "alias": "COMMON_ORIGIN_TEMPERATURE"}, {"column": "Temperature_WODflag", "alias": "COMMON_ORIGIN_TEMPERATURE_QC"}, {"column": "Temperature.standard_name", "alias": "COMMON_ORIGIN_TEMPERATURE_STANDARD_NAME"}, {"column": "Temperature.units", "alias": "COMMON_ORIGIN_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_ORIGIN_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_ORIGIN_TEMPERATURE_P06"}, {"function": "nullif", "args": [{"column": "Temperature", "alias": null}, {"value": -10000000000.0, "alias": null}], "alias": "COMMON_TEMPERATURE"}, {"function": "map_wod_quality_flag", "args": [{"column": "Temperature_WODflag", "alias": null}], "alias": "COMMON_TEMPERATURE_QC"}, {"value": "sea_water_temperature", "alias": "COMMON_TEMPERATURE_STANDARD_NAME"}, {"value": "degree_C", "alias": "COMMON_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_TEMPERATURE_P06"}, {"function": "coalesce", "args": [{"function": "map_wod_instrument_l05", "args": [{"column": "Temperature_Instrument", "alias": null}], "alias": null}, {"function": "map_l22_l05" ...
# Saved to ./output/wod_1960.parquet
# Processing year 1961
# ...
# Saved to ./output/wod_2021.parquet
# Processing year 2022
# Running query: {"from": "default", "select": [{"column": "__entry_key", "alias": null}, {"column": "time", "alias": null}, {"column": "time", "alias": "COMMON_TIME"}, {"column": "lon", "alias": null}, {"column": "lon.units", "alias": null}, {"column": "lon", "alias": "COMMON_LONGITUDE"}, {"value": "degrees_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "Longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "lat", "alias": null}, {"column": "lat.units", "alias": null}, {"column": "lat", "alias": "COMMON_LATITUDE"}, {"value": "degrees_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "Latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "z", "alias": null}, {"column": "z.units", "alias": null}, {"column": "z_WODflag", "alias": null}, {"column": "z", "alias": "COMMON_ORIGIN_DEPTH"}, {"column": "z_WODflag", "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"value": "m", "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"value": "Depth", "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"column": "z", "alias": "COMMON_DEPTH"}, {"function": "map_wod_quality_flag", "args": [{"column": "z_WODflag", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"value": "", "alias": "COMMON_EDMO_CODE"}, {"function": "map_c17_l06", "args": [{"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": "COMMON_PLATFORM_C17"}, {"column": "wod_unique_cast", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_WOD", "alias": "SOURCE_BDI"}, {"column": "wod_unique_cast", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": ".featureType", "alias": null}, {"value": "profile", "alias": "COMMON_FEATURE_TYPE"}, {"column": "dataset", "alias": null}, {"column": ".institution", "alias": null}, {"column": "Platform", "alias": null}, {"column": "country", "alias": null}, {"column": "WOD_cruise_identifier", "alias": null}, {"column": "wod_unique_cast", "alias": null}, {"column": "Temperature", "alias": null}, {"column": "Temperature_WODflag", "alias": null}, {"column": "Temperature.units", "alias": null}, {"column": "Temperature", "alias": "COMMON_ORIGIN_TEMPERATURE"}, {"column": "Temperature_WODflag", "alias": "COMMON_ORIGIN_TEMPERATURE_QC"}, {"column": "Temperature.standard_name", "alias": "COMMON_ORIGIN_TEMPERATURE_STANDARD_NAME"}, {"column": "Temperature.units", "alias": "COMMON_ORIGIN_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_ORIGIN_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_ORIGIN_TEMPERATURE_P06"}, {"function": "nullif", "args": [{"column": "Temperature", "alias": null}, {"value": -10000000000.0, "alias": null}], "alias": "COMMON_TEMPERATURE"}, {"function": "map_wod_quality_flag", "args": [{"column": "Temperature_WODflag", "alias": null}], "alias": "COMMON_TEMPERATURE_QC"}, {"value": "sea_water_temperature", "alias": "COMMON_TEMPERATURE_STANDARD_NAME"}, {"value": "degree_C", "alias": "COMMON_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_TEMPERATURE_P06"}, {"function": "coalesce", "args": [{"function": "map_wod_instrument_l05", "args": [{"column": "Temperature_Instrument", "alias": null}], "alias": null}, {"function": "map_l22_l05" ...
# Saved to ./output/wod_2022.parquet
# Processing year 2023
# Running query: {"from": "default", "select": [{"column": "__entry_key", "alias": null}, {"column": "time", "alias": null}, {"column": "time", "alias": "COMMON_TIME"}, {"column": "lon", "alias": null}, {"column": "lon.units", "alias": null}, {"column": "lon", "alias": "COMMON_LONGITUDE"}, {"value": "degrees_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "Longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "lat", "alias": null}, {"column": "lat.units", "alias": null}, {"column": "lat", "alias": "COMMON_LATITUDE"}, {"value": "degrees_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "Latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "z", "alias": null}, {"column": "z.units", "alias": null}, {"column": "z_WODflag", "alias": null}, {"column": "z", "alias": "COMMON_ORIGIN_DEPTH"}, {"column": "z_WODflag", "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"value": "m", "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"value": "Depth", "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"column": "z", "alias": "COMMON_DEPTH"}, {"function": "map_wod_quality_flag", "args": [{"column": "z_WODflag", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"value": "", "alias": "COMMON_EDMO_CODE"}, {"function": "map_c17_l06", "args": [{"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": "COMMON_PLATFORM_C17"}, {"column": "wod_unique_cast", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_WOD", "alias": "SOURCE_BDI"}, {"column": "wod_unique_cast", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": ".featureType", "alias": null}, {"value": "profile", "alias": "COMMON_FEATURE_TYPE"}, {"column": "dataset", "alias": null}, {"column": ".institution", "alias": null}, {"column": "Platform", "alias": null}, {"column": "country", "alias": null}, {"column": "WOD_cruise_identifier", "alias": null}, {"column": "wod_unique_cast", "alias": null}, {"column": "Temperature", "alias": null}, {"column": "Temperature_WODflag", "alias": null}, {"column": "Temperature.units", "alias": null}, {"column": "Temperature", "alias": "COMMON_ORIGIN_TEMPERATURE"}, {"column": "Temperature_WODflag", "alias": "COMMON_ORIGIN_TEMPERATURE_QC"}, {"column": "Temperature.standard_name", "alias": "COMMON_ORIGIN_TEMPERATURE_STANDARD_NAME"}, {"column": "Temperature.units", "alias": "COMMON_ORIGIN_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_ORIGIN_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_ORIGIN_TEMPERATURE_P06"}, {"function": "nullif", "args": [{"column": "Temperature", "alias": null}, {"value": -10000000000.0, "alias": null}], "alias": "COMMON_TEMPERATURE"}, {"function": "map_wod_quality_flag", "args": [{"column": "Temperature_WODflag", "alias": null}], "alias": "COMMON_TEMPERATURE_QC"}, {"value": "sea_water_temperature", "alias": "COMMON_TEMPERATURE_STANDARD_NAME"}, {"value": "degree_C", "alias": "COMMON_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_TEMPERATURE_P06"}, {"function": "coalesce", "args": [{"function": "map_wod_instrument_l05", "args": [{"column": "Temperature_Instrument", "alias": null}], "alias": null}, {"function": "map_l22_l05" ...
# Saved to ./output/wod_2023.parquet
# Processing year 2024
# Running query: {"from": "default", "select": [{"column": "__entry_key", "alias": null}, {"column": "time", "alias": null}, {"column": "time", "alias": "COMMON_TIME"}, {"column": "lon", "alias": null}, {"column": "lon.units", "alias": null}, {"column": "lon", "alias": "COMMON_LONGITUDE"}, {"value": "degrees_east", "alias": "COMMON_LONGITUDE_UNITS"}, {"value": "Longitude", "alias": "COMMON_LONGITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALONZZ01", "alias": "COMMON_LONGITUDE_P01"}, {"value": "SDN:P06::DEGE", "alias": "COMMON_LONGITUDE_P06"}, {"column": "lat", "alias": null}, {"column": "lat.units", "alias": null}, {"column": "lat", "alias": "COMMON_LATITUDE"}, {"value": "degrees_north", "alias": "COMMON_LATITUDE_UNITS"}, {"value": "Latitude", "alias": "COMMON_LATITUDE_STANDARD_NAME"}, {"value": "SDN:P01::ALATZZ01", "alias": "COMMON_LATITUDE_P01"}, {"value": "SDN:P06::DEGN", "alias": "COMMON_LATITUDE_P06"}, {"column": "z", "alias": null}, {"column": "z.units", "alias": null}, {"column": "z_WODflag", "alias": null}, {"column": "z", "alias": "COMMON_ORIGIN_DEPTH"}, {"column": "z_WODflag", "alias": "COMMON_ORIGIN_DEPTH_QC"}, {"value": "m", "alias": "COMMON_ORIGIN_DEPTH_UNITS"}, {"value": "Depth", "alias": "COMMON_ORIGIN_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_ORIGIN_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_ORIGIN_DEPTH_P06"}, {"column": "z", "alias": "COMMON_DEPTH"}, {"function": "map_wod_quality_flag", "args": [{"column": "z_WODflag", "alias": null}], "alias": "COMMON_DEPTH_QC"}, {"value": "m", "alias": "COMMON_DEPTH_UNITS"}, {"value": "depth", "alias": "COMMON_DEPTH_STANDARD_NAME"}, {"value": "SDN:P01::ADEPZZ01", "alias": "COMMON_DEPTH_P01"}, {"value": "SDN:P06::ULAA", "alias": "COMMON_DEPTH_P06"}, {"value": "", "alias": "COMMON_EDMERP_CODE"}, {"value": "", "alias": "COMMON_EDMO_CODE"}, {"function": "map_c17_l06", "args": [{"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": null}], "alias": "COMMON_PLATFORM_L06"}, {"function": "map_wod_platform_c17", "args": [{"column": "Platform", "alias": null}], "alias": "COMMON_PLATFORM_C17"}, {"column": "wod_unique_cast", "alias": "COMMON_ODV_TAG"}, {"value": "BEACON_WOD", "alias": "SOURCE_BDI"}, {"column": "wod_unique_cast", "alias": "SOURCE_BDI_DATASET_ID"}, {"column": ".featureType", "alias": null}, {"value": "profile", "alias": "COMMON_FEATURE_TYPE"}, {"column": "dataset", "alias": null}, {"column": ".institution", "alias": null}, {"column": "Platform", "alias": null}, {"column": "country", "alias": null}, {"column": "WOD_cruise_identifier", "alias": null}, {"column": "wod_unique_cast", "alias": null}, {"column": "Temperature", "alias": null}, {"column": "Temperature_WODflag", "alias": null}, {"column": "Temperature.units", "alias": null}, {"column": "Temperature", "alias": "COMMON_ORIGIN_TEMPERATURE"}, {"column": "Temperature_WODflag", "alias": "COMMON_ORIGIN_TEMPERATURE_QC"}, {"column": "Temperature.standard_name", "alias": "COMMON_ORIGIN_TEMPERATURE_STANDARD_NAME"}, {"column": "Temperature.units", "alias": "COMMON_ORIGIN_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_ORIGIN_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_ORIGIN_TEMPERATURE_P06"}, {"function": "nullif", "args": [{"column": "Temperature", "alias": null}, {"value": -10000000000.0, "alias": null}], "alias": "COMMON_TEMPERATURE"}, {"function": "map_wod_quality_flag", "args": [{"column": "Temperature_WODflag", "alias": null}], "alias": "COMMON_TEMPERATURE_QC"}, {"value": "sea_water_temperature", "alias": "COMMON_TEMPERATURE_STANDARD_NAME"}, {"value": "degree_C", "alias": "COMMON_TEMPERATURE_UNITS"}, {"value": "SDN:P01::TEMPPR01", "alias": "COMMON_TEMPERATURE_P01"}, {"value": "SDN:P06::UPAA", "alias": "COMMON_TEMPERATURE_P06"}, {"function": "coalesce", "args": [{"function": "map_wod_instrument_l05", "args": [{"column": "Temperature_Instrument", "alias": null}], "alias": null}, {"function": "map_l22_l05" ...
# Saved to ./output/wod_2024.parquet
