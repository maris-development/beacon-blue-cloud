# %% [markdown]
# ### Install the beacon_api package to interact with the Beacon Data Lake API
#
# You can find the package on PyPI: https://pypi.org/project/beacon-api/
#
# If you run into any issues, please refer to the GitHub repository: https://github.com/maris-development/beacon
#
# Documentation for the beacon_api package can be found here: https://maris-development.github.io/beacon/docs/1.2.0/query-docs/getting-started.html#python
#
# Documentation for the Beacon Data Lake technology can be found here: https://maris-development.github.io/beacon/

# %%
# %pip install beacon_api --upgrade
from beacon_api import * # Import the Beacon API client
import os
# Out:
# Requirement already satisfied: beacon_api in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (1.0.7)
# Requirement already satisfied: requests>=2.0.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon_api) (2.32.4)
# Requirement already satisfied: pandas>=2.0.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon_api) (2.3.1)
# Requirement already satisfied: pyarrow>=17.0.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon_api) (20.0.0)
# Requirement already satisfied: xarray>=2023.1.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon_api) (2025.7.1)
# Requirement already satisfied: netCDF4>=1.5.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon_api) (1.7.2)
# Requirement already satisfied: typing_extensions>=4.10.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from beacon_api) (4.14.1)
# Requirement already satisfied: cftime in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from netCDF4>=1.5.0->beacon_api) (1.6.4.post1)
# Requirement already satisfied: certifi in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from netCDF4>=1.5.0->beacon_api) (2025.7.14)
# Requirement already satisfied: numpy in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from netCDF4>=1.5.0->beacon_api) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from pandas>=2.0.0->beacon_api) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from pandas>=2.0.0->beacon_api) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from pandas>=2.0.0->beacon_api) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->beacon_api) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from requests>=2.0.0->beacon_api) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from requests>=2.0.0->beacon_api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from requests>=2.0.0->beacon_api) (2.5.0)
# Requirement already satisfied: packaging>=24.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from xarray>=2023.1.0->beacon_api) (25.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### In order to get access to the Beacon endpoint, you will need a token.
#
# The notebook will fetch the Token for you when running in the D4science VRE.
# If you are running the notebook outside the D4Science VRE you will need to get the token from the D4science VRE and fill it in manually.

# %%
TOKEN = os.getenv('D4SCIENCE_TOKEN') # This will fetch the token from the VRE environment.
# If you want to run this notebook locally, you can set the TOKEN variable directly here:
#TOKEN = "<your_token>" # Get your token from https://blue-cloud.d4science.org/group/blue-cloudlab/authorization. Simply press "Get Token" and copy the token here.
BEACON_INSTANCE_URL = "https://beacon-argo.maris.nl" # Can optionally be replaced with the Beacon running on D4Science: https://beacon-argo.d4science.org

# %% [markdown]
# #### Connect to the Beacon Data Lake

# %%
if TOKEN is None:
    raise ValueError("TOKEN is not set. Please set the TOKEN variable with your actual token.")
client = Client(BEACON_INSTANCE_URL, jwt_token=TOKEN)
# Out:
# Connected to: https://beacon-argo.maris.nl/ server successfully

# %% [markdown]
# #### List the available columns and their data types (e.g., string, integer) that can be queried.

# %%
available_columns = client.available_columns_with_data_type()
# Search for all available columns where the column name contains a specific keyword or part of it
search_keyword = "TEMP"
matching_columns = [col.name for col in available_columns if search_keyword.lower() in col.name.lower()]
matching_columns
# Out:
# ['PROFILE_TEMP_QC',
#  'PROFILE_TEMP_QC.long_name',
#  'PROFILE_TEMP_QC.conventions',
#  'PROFILE_TEMP_QC._FillValue',
#  'TEMP',
#  'TEMP.long_name',
#  'TEMP.standard_name',
#  'TEMP._FillValue',
#  'TEMP.units',
#  'TEMP.valid_min',
#  'TEMP.valid_max',
#  'TEMP.C_format',
#  'TEMP.FORTRAN_format',
#  'TEMP.resolution',
#  'TEMP_QC',
#  'TEMP_QC.long_name',
#  'TEMP_QC.conventions',
#  'TEMP_QC._FillValue',
#  'TEMP_ADJUSTED',
#  'TEMP_ADJUSTED.long_name',
#  'TEMP_ADJUSTED.standard_name',
#  'TEMP_ADJUSTED._FillValue',
#  'TEMP_ADJUSTED.units',
#  'TEMP_ADJUSTED.valid_min',
#  'TEMP_ADJUSTED.valid_max',
#  'TEMP_ADJUSTED.C_format',
#  'TEMP_ADJUSTED.FORTRAN_format',
#  'TEMP_ADJUSTED.resolution',
#  'TEMP_ADJUSTED_QC',
#  'TEMP_ADJUSTED_QC.long_name',
#  'TEMP_ADJUSTED_QC.conventions',
#  'TEMP_ADJUSTED_QC._FillValue',
#  'TEMP_ADJUSTED_ERROR',
#  'TEMP_ADJUSTED_ERROR.long_name',
#  'TEMP_ADJUSTED_ERROR._FillValue',
#  'TEMP_ADJUSTED_ERROR.units',
#  'TEMP_ADJUSTED_ERROR.C_format',
#  'TEMP_ADJUSTED_ERROR.FORTRAN_format',
#  'TEMP_ADJUSTED_ERROR.resolution']

# %% [markdown]
# #### Build a query

# %%
# Input parameters
regionname = "Med"
BDI = "ARGO"
mindate = "2020-01-01T00:00:00"
maxdate = "2020-12-31T23:59:59"
minlon = -8
maxlon = 36.5
minlat = 30
maxlat = 46
mindepth = 0
maxdepth = 150
output_file_name = f"{BDI}_{regionname}_{mindate}_{maxdate}"

# Here we build the query step by step. First we select the columns we want to retrieve, then we add the filters and finally we specify the output format.
query_builder = client.query()

query_builder.add_select_column("JULD", alias="TIME")  # Select the columns you want to retrieve
query_builder.add_select_column("JULD_QC", alias="TIME_QC")
query_builder.add_select_column("LONGITUDE") 
query_builder.add_select_column("LATITUDE")
query_builder.add_select_column("POSITION_QC") 
query_builder.add_select_column("PLATFORM_NUMBER") 
query_builder.add_select_column("CYCLE_NUMBER") 
# Add a new column "depth" which is calculated from the first non-null value from PRES_ADJUSTED or PRES column and then converts it to depth using the map_pressure_to_depth function
query_builder.add_select_coalesced(["PRES_ADJUSTED", "PRES"], alias="PRES")
query_builder.add_select_coalesced(["PRES_ADJUSTED_QC","PRES_QC"], alias="PRES_QC")

query_builder.add_select_coalesced(["TEMP_ADJUSTED", "TEMP"], alias="TEMPERATURE")  
query_builder.add_select_coalesced(["TEMP_ADJUSTED_QC","TEMP_QC"], alias="TEMPERATURE_QC") 
query_builder.add_select_coalesced(["PSAL_ADJUSTED", "PSAL"], alias="SALINITY")
query_builder.add_select_coalesced(["PSAL_ADJUSTED_QC","PSAL_QC"], alias="SALINITY_QC")

## Add the filters
query_builder.add_range_filter("TIME", mindate, maxdate)  # You can adjust the date range as needed. The format is ISO 8601.
query_builder.add_equals_filter("TIME_QC", "1")  # Only good quality time
query_builder.add_range_filter("LATITUDE", minlat, maxlat)  # Latitude range from -90 to 90 (you can adjust as needed)
query_builder.add_range_filter("LONGITUDE", minlon, maxlon)  # Longitude range
query_builder.add_equals_filter("POSITION_QC", "1")  # Only good quality position
query_builder.add_equals_filter("PRES_QC", "1")  # Only good quality
query_builder.add_range_filter("PRES", mindepth, maxdepth)  # Depth range from 0 to 2000 meters (you can adjust as needed)
query_builder.add_is_not_null_filter("TEMPERATURE")  # Ensure Temperature is not null
query_builder.add_equals_filter("TEMPERATURE_QC", "1")  # Only good quality temperature
query_builder.add_is_not_null_filter("SALINITY")  # Ensure Salinity is not null
query_builder.add_equals_filter("SALINITY_QC", "1")  # Ensure Salinity QC is good


df = query_builder.to_pandas_dataframe()
df
# Out:
# Running query: {"from": "default", "select": [{"column": "JULD", "alias": "TIME"}, {"column": "JULD_QC", "alias": "TIME_QC"}, {"column": "LONGITUDE", "alias": null}, {"column": "LATITUDE", "alias": null}, {"column": "POSITION_QC", "alias": null}, {"column": "PLATFORM_NUMBER", "alias": null}, {"column": "CYCLE_NUMBER", "alias": null}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}], "alias": "PRES"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}], "alias": "PRES_QC"}, {"function": "coalesce", "args": [{"column": "TEMP_ADJUSTED", "alias": null}, {"column": "TEMP", "alias": null}], "alias": "TEMPERATURE"}, {"function": "coalesce", "args": [{"column": "TEMP_ADJUSTED_QC", "alias": null}, {"column": "TEMP_QC", "alias": null}], "alias": "TEMPERATURE_QC"}, {"function": "coalesce", "args": [{"column": "PSAL_ADJUSTED", "alias": null}, {"column": "PSAL", "alias": null}], "alias": "SALINITY"}, {"function": "coalesce", "args": [{"column": "PSAL_ADJUSTED_QC", "alias": null}, {"column": "PSAL_QC", "alias": null}], "alias": "SALINITY_QC"}], "filters": [{"column": "TIME", "gt_eq": "2020-01-01T00:00:00", "lt_eq": "2020-12-31T23:59:59"}, {"column": "TIME_QC", "eq": "1"}, {"column": "LATITUDE", "gt_eq": 30, "lt_eq": 46}, {"column": "LONGITUDE", "gt_eq": -8, "lt_eq": 36.5}, {"column": "POSITION_QC", "eq": "1"}, {"column": "PRES_QC", "eq": "1"}, {"column": "PRES", "gt_eq": 0, "lt_eq": 150}, {"is_not_null": {"column": "TEMPERATURE"}}, {"column": "TEMPERATURE_QC", "eq": "1"}, {"is_not_null": {"column": "SALINITY"}}, {"column": "SALINITY_QC", "eq": "1"}], "output": {"format": "parquet"}}
#                           TIME TIME_QC  LONGITUDE   LATITUDE POSITION_QC  \
# 0      2020-10-28 16:01:59.999       1  14.880203  35.598142           1
# 1      2020-10-28 16:01:59.999       1  14.880203  35.598142           1
# 2      2020-10-28 16:01:59.999       1  14.880203  35.598142           1
# 3      2020-10-28 16:01:59.999       1  14.880203  35.598142           1
# 4      2020-10-28 16:01:59.999       1  14.880203  35.598142           1
# ...                        ...     ...        ...        ...         ...
# 640482 2020-12-27 13:14:00.000       1  18.185938  42.088702           1
# 640483 2020-12-27 13:14:00.000       1  18.185938  42.088702           1
# 640484 2020-12-27 13:14:00.000       1  18.185938  42.088702           1
# 640485 2020-12-27 13:14:00.000       1  18.185938  42.088702           1
# 640486 2020-12-27 13:14:00.000       1  18.185938  42.088702           1
#
#        PLATFORM_NUMBER  CYCLE_NUMBER        PRES PRES_QC  TEMPERATURE  \
# 0              6903788             1   10.500000       1    22.829000
# 1              6903788             1   11.700000       1    22.827999
# 2              6903788             1   12.800000       1    22.832001
# 3              6903788             1   14.100000       1    22.833000
# 4              6903788             1   15.000000       1    22.833000
# ...                ...           ...         ...     ...          ...
# 640482         6903250           176  140.899994       1    15.000000
# 640483         6903250           176  143.000000       1    14.993000
# 640484         6903250           176  145.100006       1    14.989000
# 640485         6903250           176  147.000000       1    14.981000
# 640486         6903250           176  148.899994       1    14.969000
#
#        TEMPERATURE_QC   SALINITY SALINITY_QC
# 0                   1  37.998001           1
# 1                   1  37.999001           1
# 2                   1  37.998001           1
# 3                   1  37.998001           1
# 4                   1  37.998001           1
# ...               ...        ...         ...
# 640482              1  39.014999           1
# 640483              1  39.014000           1
# 640484              1  39.013000           1
# 640485              1  39.013000           1
# 640486              1  39.009998           1
#
# [640487 rows x 13 columns]

# %% [markdown]
# #### Plotting can be done using the pandas dataframe in combination with matplotlib or other plotting libraries.
#
# You can also just use the pandas dataframe if you do not need the geometry column.

# %%
# %pip install cartopy --upgrade
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt

parameter = "TEMPERATURE"
fig = plt.figure(figsize=(15, 12))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent([minlon, maxlon, minlat, maxlat], crs=ccrs.PlateCarree())  # (west, east, south, north)

ax.coastlines(resolution="10m")
ax.gridlines(draw_labels=True)

sc = ax.scatter(df["LONGITUDE"], df["LATITUDE"], c=df[parameter], cmap="jet", s=20, transform=ccrs.PlateCarree())

ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.RIVERS)     
ax.add_feature(cfeature.BORDERS)   
ax.add_feature(cfeature.LAKES, alpha=0.1) 

cbar = plt.colorbar(sc, ax=ax, orientation="vertical", shrink=0.6, label=parameter)
cbar.set_label(f"{parameter} [C]")

plt.title(f"{regionname} {BDI} {parameter} {mindate}-{maxdate}  {mindepth}-{maxdepth}m")

plt.show()
# Out:
# Requirement already satisfied: cartopy in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (0.25.0)
# Requirement already satisfied: numpy>=1.23 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from cartopy) (2.3.1)
# Requirement already satisfied: matplotlib>=3.6 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from cartopy) (3.10.3)
# Requirement already satisfied: shapely>=2.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from cartopy) (2.1.1)
# Requirement already satisfied: packaging>=21 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from cartopy) (25.0)
# Requirement already satisfied: pyshp>=2.3 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.3.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from cartopy) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.6->cartopy) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.6->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.6->cartopy) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.6->cartopy) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.6->cartopy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.6->cartopy) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from matplotlib>=3.6->cartopy) (2.9.0.post0)
# Requirement already satisfied: certifi in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from pyproj>=3.3.1->cartopy) (2025.7.14)
# Requirement already satisfied: six>=1.5 in /Users/robinkooyman/git/beacon-blue-cloud/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
parameter = "SALINITY"
fig = plt.figure(figsize=(15, 12))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent([minlon, maxlon, minlat, maxlat], crs=ccrs.PlateCarree())  # (west, east, south, north)

ax.coastlines(resolution="10m")
ax.gridlines(draw_labels=True)

sc = ax.scatter(df["LONGITUDE"], df["LATITUDE"], c=df[parameter], cmap="jet", s=20, transform=ccrs.PlateCarree())

ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.RIVERS)     
ax.add_feature(cfeature.BORDERS)   
ax.add_feature(cfeature.LAKES, alpha=0.1) 

cbar = plt.colorbar(sc, ax=ax, orientation="vertical", shrink=0.6)
cbar.set_label(f"{parameter}")

plt.title(f"{regionname} {BDI} {parameter}  {mindate}-{maxdate}  {mindepth}-{maxdepth}m")

plt.show()
