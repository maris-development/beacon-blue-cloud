# %% [markdown]
# ### Install the beacon_api package to interact with the Beacon Data Lake API
#
# You can find the package on PyPI: https://pypi.org/project/beacon-api/
#
# If you run into any issues, please refer to the GitHub repository: https://github.com/maris-development/beacon
#
# Documentation for the beacon_api package can be found here: https://maris-development.github.io/beacon/docs/1.2.0/query-docs/getting-started.html#python
#
# Documentation for the Beacon Data Lake technology can be found here: https://maris-development.github.io/beacon/

# %%
# %pip install beacon_api --upgrade
from beacon_api import * # Import the Beacon API client
import os
# Out:
# Collecting beacon_api
#   Using cached beacon_api-1.0.4-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from beacon_api) (2.31.0)
# Requirement already satisfied: pandas>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from beacon_api) (2.2.3)
# Collecting pyarrow>=19.0.1 (from beacon_api)
#   Using cached pyarrow-21.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (42.7 MB)
# Requirement already satisfied: networkx>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from beacon_api) (3.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from beacon_api) (3.9.4)
# Collecting xarray>=2025.1.0 (from beacon_api)
#   Using cached xarray-2025.6.1-py3-none-any.whl (1.3 MB)
# Requirement already satisfied: netCDF4>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from beacon_api) (1.7.2)
# Collecting geopandas>=1.1.0 (from beacon_api)
#   Using cached geopandas-1.1.1-py3-none-any.whl (338 kB)
# Requirement already satisfied: typing_extensions>=4.10.0 in /opt/conda/lib/python3.10/site-packages (from beacon_api) (4.12.2)
# Collecting lonboard>=0.10.4 (from beacon_api)
#   Downloading lonboard-0.12.1-py3-none-any.whl (928 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 928.2/928.2 kB 21.0 MB/s eta 0:00:00a 0:00:01
# Collecting palettable>=3.3.0 (from beacon_api)
#   Using cached palettable-3.3.3-py2.py3-none-any.whl (332 kB)
# Requirement already satisfied: zarr>=2.18 in /opt/conda/lib/python3.10/site-packages (from beacon_api) (2.18.3)
# Requirement already satisfied: numpy>=1.24 in /opt/conda/lib/python3.10/site-packages (from geopandas>=1.1.0->beacon_api) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/conda/lib/python3.10/site-packages (from geopandas>=1.1.0->beacon_api) (0.10.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from geopandas>=1.1.0->beacon_api) (23.2)
# Requirement already satisfied: pyproj>=3.5.0 in /opt/conda/lib/python3.10/site-packages (from geopandas>=1.1.0->beacon_api) (3.6.1)
# Requirement already satisfied: shapely>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from geopandas>=1.1.0->beacon_api) (2.0.7)
# Collecting anywidget~=0.9.0 (from lonboard>=0.10.4->beacon_api)
#   Using cached anywidget-0.9.18-py3-none-any.whl (220 kB)
# Collecting arro3-compute>=0.4.1 (from lonboard>=0.10.4->beacon_api)
#   Using cached arro3_compute-0.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
# Collecting arro3-core>=0.4.1 (from lonboard>=0.10.4->beacon_api)
#   Using cached arro3_core-0.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
# Collecting arro3-io>=0.4.1 (from lonboard>=0.10.4->beacon_api)
#   Using cached arro3_io-0.6.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.0 MB)
# Collecting geoarrow-rust-core>=0.5.2 (from lonboard>=0.10.4->beacon_api)
#   Using cached geoarrow_rust_core-0.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
# Requirement already satisfied: ipywidgets>=7.6.0 in /opt/conda/lib/python3.10/site-packages (from lonboard>=0.10.4->beacon_api) (8.0.6)
# Requirement already satisfied: traitlets>=5.7.1 in /opt/conda/lib/python3.10/site-packages (from lonboard>=0.10.4->beacon_api) (5.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->beacon_api) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->beacon_api) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->beacon_api) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->beacon_api) (1.4.4)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->beacon_api) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->beacon_api) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->beacon_api) (2.8.2)
# Requirement already satisfied: cftime in /opt/conda/lib/python3.10/site-packages (from netCDF4>=1.5.0->beacon_api) (1.6.4)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from netCDF4>=1.5.0->beacon_api) (2024.12.14)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.0.0->beacon_api) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=2.0.0->beacon_api) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.0.0->beacon_api) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.0.0->beacon_api) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.0.0->beacon_api) (2.0.2)
# Requirement already satisfied: asciitree in /opt/conda/lib/python3.10/site-packages (from zarr>=2.18->beacon_api) (0.3.3)
# Requirement already satisfied: numcodecs>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from zarr>=2.18->beacon_api) (0.13.1)
# Requirement already satisfied: fasteners in /opt/conda/lib/python3.10/site-packages (from zarr>=2.18->beacon_api) (0.19)
# Collecting psygnal>=0.8.1 (from anywidget~=0.9.0->lonboard>=0.10.4->beacon_api)
#   Using cached psygnal-0.14.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (853 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (6.23.1)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (8.13.2)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (4.0.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /opt/conda/lib/python3.10/site-packages (from ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (3.0.7)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->beacon_api) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (8.2.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (1.5.6)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (25.0.2)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (6.3.2)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (0.18.2)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (2.19.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (3.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (2.2.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6.0->lonboard>=0.10.4->beacon_api) (0.2.2)
# Installing collected packages: pyarrow, psygnal, palettable, arro3-core, geoarrow-rust-core, arro3-io, arro3-compute, xarray, geopandas, anywidget, lonboard, beacon_api
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 19.0.0
#     Uninstalling pyarrow-19.0.0:
#       Successfully uninstalled pyarrow-19.0.0
#   Attempting uninstall: xarray
#     Found existing installation: xarray 2024.2.0
#     Uninstalling xarray-2024.2.0:
#       Successfully uninstalled xarray-2024.2.0
#   Attempting uninstall: geopandas
#     Found existing installation: geopandas 1.0.1
#     Uninstalling geopandas-1.0.1:
#       Successfully uninstalled geopandas-1.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# argopy 1.0.0 requires xarray<2024.3,>=0.18, but you have xarray 2025.6.1 which is incompatible.
# scikit-mobility 1.3.1 requires folium==0.12.1.post1, but you have folium 0.19.4 which is incompatible.
# scikit-mobility 1.3.1 requires geojson<3.0.0,>=2.5.0, but you have geojson 3.2.0 which is incompatible.
# scikit-mobility 1.3.1 requires geopandas<0.11.0,>=0.10.2, but you have geopandas 1.1.1 which is incompatible.
# scikit-mobility 1.3.1 requires h3<4.0.0,>=3.7.3, but you have h3 4.2.1 which is incompatible.
# scikit-mobility 1.3.1 requires pandas<2.0.0,>=1.1.5, but you have pandas 2.2.3 which is incompatible.
# scikit-mobility 1.3.1 requires python-igraph<0.10.0,>=0.9.1, but you have python-igraph 0.11.8 which is incompatible.
# scikit-mobility 1.3.1 requires statsmodels<0.14.0,>=0.13.0, but you have statsmodels 0.14.4 which is incompatible.
# Successfully installed anywidget-0.9.18 arro3-compute-0.6.3 arro3-core-0.6.3 arro3-io-0.6.3 beacon_api-1.0.4 geoarrow-rust-core-0.5.2 geopandas-1.1.1 lonboard-0.12.1 palettable-3.3.3 psygnal-0.14.1 pyarrow-21.0.0 xarray-2025.6.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### In order to get access to the Beacon endpoint, you will need a token.
#
# The notebook will fetch the Token for you when running in the D4science VRE.
# If you are running the notebook outside the D4Science VRE you will need to get the token from the D4science VRE and fill it in manually.

# %%
TOKEN = os.getenv('D4SCIENCE_TOKEN') # This will fetch the token from the VRE environment.
# If you want to run this notebook locally, you can set the TOKEN variable directly here:
#TOKEN = "<your_token>" # Get your token from https://blue-cloud.d4science.org/group/blue-cloudlab/authorization. Simply press "Get Token" and copy the token here.
BEACON_INSTANCE_URL = "https://beacon-argo.maris.nl" # Can optionally be replaced with the Beacon running on D4Science: https://beacon-argo.d4science.org

# %% [markdown]
# #### Connect to the Beacon Data Lake

# %%
if TOKEN is None:
    raise ValueError("TOKEN is not set. Please set the TOKEN variable with your actual token.")
client = Client(BEACON_INSTANCE_URL, jwt_token=TOKEN)
# Out:
# Connected to: https://beacon-argo.maris.nl/ server successfully

# %% [markdown]
# #### List the available columns and their data types (e.g., string, integer) that can be queried.

# %%
available_columns = client.available_columns_with_data_type()
# Search for all available columns where the column name contains a specific keyword or part of it
search_keyword = "TEMP"
matching_columns = [col.name for col in available_columns if search_keyword.lower() in col.name.lower()]
matching_columns
# Out:
# ['PROFILE_TEMP_QC',
#  'PROFILE_TEMP_QC.long_name',
#  'PROFILE_TEMP_QC.conventions',
#  'PROFILE_TEMP_QC._FillValue',
#  'TEMP',
#  'TEMP.long_name',
#  'TEMP.standard_name',
#  'TEMP._FillValue',
#  'TEMP.units',
#  'TEMP.valid_min',
#  'TEMP.valid_max',
#  'TEMP.C_format',
#  'TEMP.FORTRAN_format',
#  'TEMP.resolution',
#  'TEMP_QC',
#  'TEMP_QC.long_name',
#  'TEMP_QC.conventions',
#  'TEMP_QC._FillValue',
#  'TEMP_ADJUSTED',
#  'TEMP_ADJUSTED.long_name',
#  'TEMP_ADJUSTED.standard_name',
#  'TEMP_ADJUSTED._FillValue',
#  'TEMP_ADJUSTED.units',
#  'TEMP_ADJUSTED.valid_min',
#  'TEMP_ADJUSTED.valid_max',
#  'TEMP_ADJUSTED.C_format',
#  'TEMP_ADJUSTED.FORTRAN_format',
#  'TEMP_ADJUSTED.resolution',
#  'TEMP_ADJUSTED_QC',
#  'TEMP_ADJUSTED_QC.long_name',
#  'TEMP_ADJUSTED_QC.conventions',
#  'TEMP_ADJUSTED_QC._FillValue',
#  'TEMP_ADJUSTED_ERROR',
#  'TEMP_ADJUSTED_ERROR.long_name',
#  'TEMP_ADJUSTED_ERROR._FillValue',
#  'TEMP_ADJUSTED_ERROR.units',
#  'TEMP_ADJUSTED_ERROR.C_format',
#  'TEMP_ADJUSTED_ERROR.FORTRAN_format',
#  'TEMP_ADJUSTED_ERROR.resolution']

# %% [markdown]
# #### Build a query

# %%
# Input parameters
regionname = "Med"
BDI = "ARGO"
mindate = "2020-01-01T00:00:00"
maxdate = "2020-12-31T23:59:59"
minlon = -8
maxlon = 36.5
minlat = 30
maxlat = 46
AOI_POLY = [
    (-9.50, 30.00),
    (-9.50, 39.00),
    (-0.80, 43.20),
    (16.00, 46.50),
    (36.50, 38.00),
    (36.50, 30.00),
    (-9.50, 30.00)
]
mindepth = 0
maxdepth = 150
format = "pandas" # Options are: pandas, geopandas, netcdf, zarr, parquet, geoparquet, odv, arrow, csv
output_file_name = f"{BDI}_{regionname}_{mindate}_{maxdate}"
df = None
gdf = None


# Here we build the query step by step. First we select the columns we want to retrieve, then we add the filters and finally we specify the output format.
query_builder = client.query()

query_builder.add_select_column("JULD", alias="TIME")  # Select the columns you want to retrieve
query_builder.add_select_column("JULD_QC", alias="TIME_QC")
query_builder.add_select_column("LONGITUDE") 
query_builder.add_select_column("LATITUDE")
query_builder.add_select_column("POSITION_QC") 
query_builder.add_select_column("PLATFORM_NUMBER") 
query_builder.add_select_column("CYCLE_NUMBER") 
query_builder.add_select_column("WMO_INST_TYPE") 
query_builder.add_select_column("DATA_TYPE")
query_builder.add_select_column("__entry_key")
query_builder.add_select_column(".featureType", alias="feature_type")
# Add a new column "depth" which is calculated from the first non-null value from PRES_ADJUSTED or PRES column and then converts it to depth using the map_pressure_to_depth function
query_builder.add_select(Functions.map_pressure_to_depth(Functions.coalesce(["PRES_ADJUSTED", "PRES"], alias="pres_merged"), "LATITUDE", alias="DEPTH"))
query_builder.add_select_coalesced(["PRES_ADJUSTED_QC","PRES_QC"], alias="DEPTH_QC")
query_builder.add_select_column("PROFILE_PRES_QC")

query_builder.add_select_coalesced(["TEMP_ADJUSTED", "TEMP"], alias="TEMPERATURE")  
query_builder.add_select_coalesced(["TEMP_ADJUSTED_QC","TEMP_QC"], alias="TEMPERATURE_QC") 
query_builder.add_select_column("PROFILE_TEMP_QC") 
query_builder.add_select_coalesced(["PSAL_ADJUSTED", "PSAL"], alias="SALINITY")
query_builder.add_select_coalesced(["PSAL_ADJUSTED_QC","PSAL_QC"], alias="SALINITY_QC")
query_builder.add_select_column("PROFILE_PSAL_QC")

## Add the filters
query_builder.add_range_filter("TIME", mindate, maxdate)  # You can adjust the date range as needed. The format is ISO 8601.
query_builder.add_equals_filter("TIME_QC", "1")  # Only good quality time
query_builder.add_range_filter("DEPTH", mindepth, maxdepth)  # Depth range from 0 to 50 meters (you can adjust as needed)
query_builder.add_range_filter("LATITUDE", minlat, maxlat)  # Latitude range from -90 to 90 (you can adjust as needed)
query_builder.add_range_filter("LONGITUDE", minlon, maxlon)  # Longitude range
query_builder.add_polygon_filter("LONGITUDE","LATITUDE", AOI_POLY)  # Define a polygon area (you can adjust the coordinates as needed)
query_builder.add_equals_filter("POSITION_QC", "1")  # Only good quality position
query_builder.add_is_not_null_filter("TEMPERATURE")  # Ensure Temperature is not null
query_builder.add_equals_filter("TEMPERATURE_QC", "1")  # Only good quality temperature
query_builder.add_is_not_null_filter("SALINITY")  # Ensure Salinity is not
query_builder.add_equals_filter("SALINITY_QC", "1")  # Only good quality salinity
query_builder.add_is_not_null_filter("DEPTH")  # Ensure Depth is not null
query_builder.add_equals_filter("DEPTH_QC", "1")  # Only good quality
query_builder.add_range_filter("DEPTH", mindepth, maxdepth)  # Depth range from 0 to 2000 meters (you can adjust as needed)

# Add the output format
if format == "pandas":
    df = query_builder.to_pandas_dataframe()
elif format == "geopandas":
    gdf = query_builder.to_geo_pandas_dataframe(longitude_column="LONGITUDE", latitude_column="LATITUDE")
elif format == "netcdf":
    query_builder.to_netcdf(output_file_name + ".nc")
elif format == "zarr":
    query_builder.to_zarr(output_file_name + ".zarr")
elif format == "parquet":
    query_builder.to_parquet(output_file_name + ".parquet")
elif format == "geoparquet":
    query_builder.to_geoparquet(output_file_name + ".parquet", longitude_column="LONGITUDE", latitude_column="LATITUDE")
elif format == "odv":
    odv_output = Odv(
        longitude_column=OdvDataColumn("LONGITUDE"),
        latitude_column=OdvDataColumn("LATITUDE"),
        time_column=OdvDataColumn("TIME"),
        depth_column=OdvDataColumn("DEPTH", qf_column="DEPTH_QC"),
        data_columns=[
            OdvDataColumn("TEMPERATURE", qf_column="TEMPERATURE_QC"),
            OdvDataColumn("SALINITY", qf_column="SALINITY_QC"),
        ],
        metadata_columns=[
            OdvDataColumn("PLATFORM_NUMBER"),
            OdvDataColumn("CYCLE_NUMBER"),
            OdvDataColumn("WMO_INST_TYPE"),
            OdvDataColumn("DATA_TYPE"),
        ],
        qf_schema="SEADATANET",
        key_column="__entry_key",
        feature_type_column="feature_type",
    )
    query_builder.to_odv(odv_output, output_file_name + ".zip")
# Out:
# Running query: {"from": "default", "select": [{"column": "JULD", "alias": "TIME"}, {"column": "JULD_QC", "alias": "TIME_QC"}, {"column": "LONGITUDE", "alias": null}, {"column": "LATITUDE", "alias": null}, {"column": "POSITION_QC", "alias": null}, {"column": "PLATFORM_NUMBER", "alias": null}, {"column": "CYCLE_NUMBER", "alias": null}, {"column": "WMO_INST_TYPE", "alias": null}, {"column": "DATA_TYPE", "alias": null}, {"column": "__entry_key", "alias": null}, {"column": ".featureType", "alias": "feature_type"}, {"function": "pressure_to_depth_teos_10", "args": [{"function": "coalesce", "args": [{"column": "PRES_ADJUSTED", "alias": null}, {"column": "PRES", "alias": null}], "alias": "pres_merged"}, {"column": "LATITUDE", "alias": null}], "alias": "DEPTH"}, {"function": "coalesce", "args": [{"column": "PRES_ADJUSTED_QC", "alias": null}, {"column": "PRES_QC", "alias": null}], "alias": "DEPTH_QC"}, {"column": "PROFILE_PRES_QC", "alias": null}, {"function": "coalesce", "args": [{"column": "TEMP_ADJUSTED", "alias": null}, {"column": "TEMP", "alias": null}], "alias": "TEMPERATURE"}, {"function": "coalesce", "args": [{"column": "TEMP_ADJUSTED_QC", "alias": null}, {"column": "TEMP_QC", "alias": null}], "alias": "TEMPERATURE_QC"}, {"column": "PROFILE_TEMP_QC", "alias": null}, {"function": "coalesce", "args": [{"column": "PSAL_ADJUSTED", "alias": null}, {"column": "PSAL", "alias": null}], "alias": "SALINITY"}, {"function": "coalesce", "args": [{"column": "PSAL_ADJUSTED_QC", "alias": null}, {"column": "PSAL_QC", "alias": null}], "alias": "SALINITY_QC"}, {"column": "PROFILE_PSAL_QC", "alias": null}], "filters": [{"column": "TIME", "gt_eq": "2020-01-01T00:00:00", "lt_eq": "2020-12-31T23:59:59"}, {"column": "TIME_QC", "eq": "1"}, {"column": "DEPTH", "gt_eq": 0, "lt_eq": 150}, {"column": "LATITUDE", "gt_eq": 30, "lt_eq": 46}, {"column": "LONGITUDE", "gt_eq": -8, "lt_eq": 36.5}, {"longitude_query_parameter": "LONGITUDE", "latitude_query_parameter": "LATITUDE", "geometry": {"coordinates": [[[-9.5, 30.0], [-9.5, 39.0], [-0.8, 43.2], [16.0, 46.5], [36.5, 38.0], [36.5, 30.0], [-9.5, 30.0]]], "type": "Polygon"}}, {"column": "POSITION_QC", "eq": "1"}, {"is_not_null": {"column": "TEMPERATURE"}}, {"column": "TEMPERATURE_QC", "eq": "1"}, {"is_not_null": {"column": "SALINITY"}}, {"column": "SALINITY_QC", "eq": "1"}, {"is_not_null": {"column": "DEPTH"}}, {"column": "DEPTH_QC", "eq": "1"}, {"column": "DEPTH", "gt_eq": 0, "lt_eq": 150}], "output": {"format": "parquet"}}

# %% [markdown]
# #### If `geopandas` or `pandas` is selected as output format, the data will be loaded into a dataframe for further analysis.

# %%
if df is not None:
    display(df)
# Out:
#                           TIME TIME_QC  LONGITUDE   LATITUDE POSITION_QC  \
# 0      2020-01-05 10:17:00.000       1   7.209660  38.762217           1
# 1      2020-01-05 10:17:00.000       1   7.209660  38.762217           1
# 2      2020-01-05 10:17:00.000       1   7.209660  38.762217           1
# 3      2020-01-05 10:17:00.000       1   7.209660  38.762217           1
# 4      2020-01-05 10:17:00.000       1   7.209660  38.762217           1
# ...                        ...     ...        ...        ...         ...
# 611560 2020-12-30 05:54:29.999       1  29.729328  33.172448           1
# 611561 2020-12-30 05:54:29.999       1  29.729328  33.172448           1
# 611562 2020-12-30 05:54:29.999       1  29.729328  33.172448           1
# 611563 2020-12-30 05:54:29.999       1  29.729328  33.172448           1
# 611564 2020-12-30 05:54:29.999       1  29.729328  33.172448           1
#
#        PLATFORM_NUMBER  CYCLE_NUMBER WMO_INST_TYPE     DATA_TYPE  \
# 0              6901774            85           836  Argo profile
# 1              6901774            85           836  Argo profile
# 2              6901774            85           836  Argo profile
# 3              6901774            85           836  Argo profile
# 4              6901774            85           836  Argo profile
# ...                ...           ...           ...           ...
# 611560         6903245           159           844  Argo profile
# 611561         6903245           159           844  Argo profile
# 611562         6903245           159           844  Argo profile
# 611563         6903245           159           844  Argo profile
# 611564         6903245           159           844  Argo profile
#
#             __entry_key       feature_type       DEPTH DEPTH_QC  \
# 0       6901774_prof.nc  trajectoryProfile    2.381868        1
# 1       6901774_prof.nc  trajectoryProfile    2.878087        1
# 2       6901774_prof.nc  trajectoryProfile    3.374305        1
# 3       6901774_prof.nc  trajectoryProfile    4.465980        1
# 4       6901774_prof.nc  trajectoryProfile    5.458406        1
# ...                 ...                ...         ...      ...
# 611560  6903245_prof.nc  trajectoryProfile  104.628763        1
# 611561  6903245_prof.nc  trajectoryProfile  114.354334        1
# 611562  6903245_prof.nc  trajectoryProfile  124.674848        1
# 611563  6903245_prof.nc  trajectoryProfile  134.498702        1
# 611564  6903245_prof.nc  trajectoryProfile  144.222863        1
#
#        PROFILE_PRES_QC  TEMPERATURE TEMPERATURE_QC PROFILE_TEMP_QC   SALINITY  \
# 0                    A    15.926000              1               A  37.277180
# 1                    A    15.926000              1               A  37.278191
# 2                    A    15.926000              1               A  37.278191
# 3                    A    15.925000              1               A  37.277180
# 4                    A    15.926000              1               A  37.278191
# ...                ...          ...            ...             ...        ...
# 611560               A    16.694000              1               A  39.093830
# 611561               A    16.577999              1               A  39.114830
# 611562               A    16.469000              1               A  39.127811
# 611563               A    16.356001              1               A  39.139801
# 611564               A    16.228001              1               A  39.143799
#
#        SALINITY_QC PROFILE_PSAL_QC
# 0                1               A
# 1                1               A
# 2                1               A
# 3                1               A
# 4                1               A
# ...            ...             ...
# 611560           1               A
# 611561           1               A
# 611562           1               A
# 611563           1               A
# 611564           1               A
#
# [611565 rows x 20 columns]

# %%
if gdf is not None:
    display(gdf)

# %% [markdown]
# #### Plotting can be done using the pandas dataframe in combination with matplotlib or other plotting libraries.
#
# You can also just use the pandas dataframe if you do not need the geometry column.

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt

parameter = "TEMPERATURE"
fig = plt.figure(figsize=(15, 12))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent([minlon, maxlon, minlat, maxlat], crs=ccrs.PlateCarree())  # (west, east, south, north)

ax.coastlines(resolution="10m")
ax.gridlines(draw_labels=True)

sc = ax.scatter(df["LONGITUDE"], df["LATITUDE"], c=df[parameter], cmap="jet", s=20, transform=ccrs.PlateCarree())

ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.RIVERS)     
ax.add_feature(cfeature.BORDERS)   
ax.add_feature(cfeature.LAKES, alpha=0.1) 

cbar = plt.colorbar(sc, ax=ax, orientation="vertical", shrink=0.6, label=parameter)
cbar.set_label(f"{parameter} [C]")

plt.title(f"{regionname} {BDI} {parameter} {mindate}-{maxdate}  {mindepth}-{maxdepth}m")

plt.show()

# %%
parameter = "SALINITY"
fig = plt.figure(figsize=(15, 12))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent([minlon, maxlon, minlat, maxlat], crs=ccrs.PlateCarree())  # (west, east, south, north)

ax.coastlines(resolution="10m")
ax.gridlines(draw_labels=True)

sc = ax.scatter(df["LONGITUDE"], df["LATITUDE"], c=df[parameter], cmap="jet", s=20, transform=ccrs.PlateCarree())

ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.RIVERS)     
ax.add_feature(cfeature.BORDERS)   
ax.add_feature(cfeature.LAKES, alpha=0.1) 

cbar = plt.colorbar(sc, ax=ax, orientation="vertical", shrink=0.6)
cbar.set_label(f"{parameter}")

plt.title(f"{regionname} {BDI} {parameter}  {mindate}-{maxdate}  {mindepth}-{maxdepth}m")

plt.show()
