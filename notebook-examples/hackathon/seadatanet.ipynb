# %% [markdown]
# ### Install the beacon_api package to interact with the Beacon Data Lake API
#
# You can find the package on PyPI: https://pypi.org/project/beacon-api/
#
# If you run into any issues, please refer to the GitHub repository: https://github.com/maris-development/beacon
#
# Documentation for the beacon_api package can be found here: https://maris-development.github.io/beacon/docs/1.2.0/query-docs/getting-started.html#python
#
# Documentation for the Beacon Data Lake technology can be found here: https://maris-development.github.io/beacon/

# %%
# %pip install beacon_api --upgrade
from beacon_api import * # Import the Beacon API client
import os
# Out:
# WARNING: Ignoring invalid distribution ~yproj (c:\Users\tjerk\anaconda3\envs\Blue-Cloud\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yproj (c:\Users\tjerk\anaconda3\envs\Blue-Cloud\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yproj (c:\Users\tjerk\anaconda3\envs\Blue-Cloud\Lib\site-packages)
# Requirement already satisfied: beacon_api in c:\users\tjerk\anaconda3\envs\blue-cloud\lib\site-packages (1.0.7)
# Requirement already satisfied: requests>=2.0.0 in c:\users\tjerk\anaconda3\envs\blue-cloud\lib\site-packages (from beacon_api) (2.32.3)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\tjerk\anaconda3\envs\blue-cloud\lib\site-packages (from beacon_api) (2.2.3)
# Requirement already satisfied: pyarrow>=17.0.0 in c:\users\tjerk\anaconda3\envs\blue-cloud\lib\site-packages (from beacon_api) (21.0.0)
# Requirement already satisfied: xarray>=2023.1.0 in c:\users\tjerk\anaconda3\envs\blue-cloud\lib\site-packages (from beacon_api) (2025.9.0)
# Requirement already satisfied: netCDF4>=1.5.0 in c:\users\tjerk\anaconda3\envs\blue-cloud\lib\site-packages (from beacon_api) (1.7.1.post2)
# Requirement already satisfied: typing_extensions>=4.10.0 in c:\users\tjerk\anaconda3\envs\blue-cloud\lib\site-packages (from beacon_api) (4.12.2)
# Requirement already satisfied: cftime in c:\users\tjerk\anaconda3\envs\blue-cloud\lib\site-packages (from netCDF4>=1.5.0->beacon_api) (1.6.4)
# Requirement already satisfied: certifi in c:\users\tjerk\anaconda3\envs\blue-cloud\lib\site-packages (from netCDF4>=1.5.0->beacon_api) (2024.8.30)
# Requirement already satisfied: numpy in c:\users\tjerk\anaconda3\envs\blue-cloud\lib\site-packages (from netCDF4>=1.5.0->beacon_api) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tjerk\anaconda3\envs\blue-cloud\lib\site-packages (from pandas>=2.0.0->beacon_api) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tjerk\anaconda3\envs\blue-cloud\lib\site-packages (from pandas>=2.0.0->beacon_api) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tjerk\anaconda3\envs\blue-cloud\lib\site-packages (from pandas>=2.0.0->beacon_api) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tjerk\anaconda3\envs\blue-cloud\lib\site-packages (from requests>=2.0.0->beacon_api) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tjerk\anaconda3\envs\blue-cloud\lib\site-packages (from requests>=2.0.0->beacon_api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tjerk\anaconda3\envs\blue-cloud\lib\site-packages (from requests>=2.0.0->beacon_api) (2.2.3)
# Requirement already satisfied: packaging>=24.1 in c:\users\tjerk\anaconda3\envs\blue-cloud\lib\site-packages (from xarray>=2023.1.0->beacon_api) (24.1)
# Requirement already satisfied: six>=1.5 in c:\users\tjerk\anaconda3\envs\blue-cloud\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->beacon_api) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### In order to get access to the Beacon endpoint, you will need a token.
#
# The notebook will fetch the Token for you when running in the D4science VRE.
# If you are running the notebook outside the D4Science VRE you will need to get the token from the D4science VRE and fill it in manually.

# %%
TOKEN = os.getenv('D4SCIENCE_TOKEN') # This will fetch the token from the VRE environment.
# If you want to run this notebook locally, you can set the TOKEN variable directly here:
#TOKEN = " " # Get your token from https://blue-cloud.d4science.org/group/blue-cloudlab/authorization. Simply press "Get Token" and copy the token here.
BEACON_INSTANCE_URL = "https://beacon-cdi.maris.nl" # Can optionally be replaced with the Beacon running on D4Science: https://beacon-argo.d4science.org

# %% [markdown]
# #### Connect to the Beacon Data Lake

# %%
if TOKEN is None:
    raise ValueError("TOKEN is not set. Please set the TOKEN variable with your actual token.")
client = Client(BEACON_INSTANCE_URL, jwt_token=TOKEN)
# Out:
# Connected to: https://beacon-cdi.maris.nl/ server successfully

# %% [markdown]
# #### List the available columns and their data types (e.g., string, integer) that can be queried.

# %%
available_columns = client.available_columns_with_data_type()
# Search for all available columns where the column name contains a specific keyword or part of it
search_keyword = "TEMP"
matching_columns = [col.name for col in available_columns if search_keyword.lower() in col.name.lower()]
matching_columns
# Out:
# ['TEMPPR01',
#  'TEMPPR01.long_name',
#  'TEMPPR01.sdn_parameter_urn',
#  'TEMPPR01.sdn_parameter_name',
#  'TEMPPR01.sdn_uom_urn',
#  'TEMPPR01.sdn_uom_name',
#  'TEMPPR01.units',
#  'TEMPPR01.coordinates',
#  'TEMPPR01.ancillary_variables',
#  'TEMPPR01._FillValue',
#  'TEMPPR01_SEADATANET_QC',
#  'TEMPPR01_SEADATANET_QC.long_name',
#  'TEMPPR01_SEADATANET_QC.Conventions',
#  'TEMPPR01_SEADATANET_QC._FillValue',
#  'TEMPPR01_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPPR01_SEADATANET_QC.flag_meanings',
#  'TEMPPR01_SEADATANET_QC.coordinates',
#  'TEMP',
#  'TEMP.long_name',
#  'TEMP.sdn_parameter_urn',
#  'TEMP.sdn_parameter_name',
#  'TEMP.sdn_uom_urn',
#  'TEMP.sdn_uom_name',
#  'TEMP.units',
#  'TEMP.coordinates',
#  'TEMP.ancillary_variables',
#  'TEMP._FillValue',
#  'TEMP_SEADATANET_QC',
#  'TEMP_SEADATANET_QC.long_name',
#  'TEMP_SEADATANET_QC.Conventions',
#  'TEMP_SEADATANET_QC._FillValue',
#  'TEMP_SEADATANET_QC.sdn_conventions_urn',
#  'TEMP_SEADATANET_QC.flag_meanings',
#  'TEMP_SEADATANET_QC.coordinates',
#  'TEMPST01',
#  'TEMPST01.long_name',
#  'TEMPST01.sdn_parameter_urn',
#  'TEMPST01.sdn_parameter_name',
#  'TEMPST01.sdn_uom_urn',
#  'TEMPST01.sdn_uom_name',
#  'TEMPST01.units',
#  'TEMPST01.sdn_instrument_urn',
#  'TEMPST01.sdn_instrument_name',
#  'TEMPST01.coordinates',
#  'TEMPST01.ancillary_variables',
#  'TEMPST01._FillValue',
#  'TEMPST01_SEADATANET_QC',
#  'TEMPST01_SEADATANET_QC.long_name',
#  'TEMPST01_SEADATANET_QC.Conventions',
#  'TEMPST01_SEADATANET_QC._FillValue',
#  'TEMPST01_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPST01_SEADATANET_QC.flag_meanings',
#  'TEMPST01_SEADATANET_QC.coordinates',
#  'TEMPST02',
#  'TEMPST02.long_name',
#  'TEMPST02.sdn_parameter_urn',
#  'TEMPST02.sdn_parameter_name',
#  'TEMPST02.sdn_uom_urn',
#  'TEMPST02.sdn_uom_name',
#  'TEMPST02.units',
#  'TEMPST02.sdn_instrument_urn',
#  'TEMPST02.sdn_instrument_name',
#  'TEMPST02.coordinates',
#  'TEMPST02.ancillary_variables',
#  'TEMPST02._FillValue',
#  'TEMPST02_SEADATANET_QC',
#  'TEMPST02_SEADATANET_QC.long_name',
#  'TEMPST02_SEADATANET_QC.Conventions',
#  'TEMPST02_SEADATANET_QC._FillValue',
#  'TEMPST02_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPST02_SEADATANET_QC.flag_meanings',
#  'TEMPST02_SEADATANET_QC.coordinates',
#  'TEMPRTNX',
#  'TEMPRTNX.long_name',
#  'TEMPRTNX.sdn_parameter_urn',
#  'TEMPRTNX.sdn_parameter_name',
#  'TEMPRTNX.sdn_uom_urn',
#  'TEMPRTNX.sdn_uom_name',
#  'TEMPRTNX.units',
#  'TEMPRTNX.coordinates',
#  'TEMPRTNX.ancillary_variables',
#  'TEMPRTNX._FillValue',
#  'TEMPRTNX_SEADATANET_QC',
#  'TEMPRTNX_SEADATANET_QC.long_name',
#  'TEMPRTNX_SEADATANET_QC.Conventions',
#  'TEMPRTNX_SEADATANET_QC._FillValue',
#  'TEMPRTNX_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPRTNX_SEADATANET_QC.flag_meanings',
#  'TEMPRTNX_SEADATANET_QC.coordinates',
#  'TEMPRTNX_2',
#  'TEMPRTNX_2.long_name',
#  'TEMPRTNX_2.sdn_parameter_urn',
#  'TEMPRTNX_2.sdn_parameter_name',
#  'TEMPRTNX_2.sdn_uom_urn',
#  'TEMPRTNX_2.sdn_uom_name',
#  'TEMPRTNX_2.units',
#  'TEMPRTNX_2.coordinates',
#  'TEMPRTNX_2.ancillary_variables',
#  'TEMPRTNX_2._FillValue',
#  'TEMPRTNX_2_SEADATANET_QC',
#  'TEMPRTNX_2_SEADATANET_QC.long_name',
#  'TEMPRTNX_2_SEADATANET_QC.Conventions',
#  'TEMPRTNX_2_SEADATANET_QC._FillValue',
#  'TEMPRTNX_2_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPRTNX_2_SEADATANET_QC.flag_meanings',
#  'TEMPRTNX_2_SEADATANET_QC.coordinates',
#  'TEMPS901',
#  'TEMPS901.long_name',
#  'TEMPS901.sdn_parameter_urn',
#  'TEMPS901.sdn_parameter_name',
#  'TEMPS901.sdn_uom_urn',
#  'TEMPS901.sdn_uom_name',
#  'TEMPS901.units',
#  'TEMPS901.coordinates',
#  'TEMPS901.ancillary_variables',
#  'TEMPS901._FillValue',
#  'TEMPS901_SEADATANET_QC',
#  'TEMPS901_SEADATANET_QC.long_name',
#  'TEMPS901_SEADATANET_QC.Conventions',
#  'TEMPS901_SEADATANET_QC._FillValue',
#  'TEMPS901_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPS901_SEADATANET_QC.flag_meanings',
#  'TEMPS901_SEADATANET_QC.coordinates',
#  'TEMPP901',
#  'TEMPP901.long_name',
#  'TEMPP901.sdn_parameter_urn',
#  'TEMPP901.sdn_parameter_name',
#  'TEMPP901.sdn_uom_urn',
#  'TEMPP901.sdn_uom_name',
#  'TEMPP901.units',
#  'TEMPP901.coordinates',
#  'TEMPP901.ancillary_variables',
#  'TEMPP901._FillValue',
#  'TEMPP901_SEADATANET_QC',
#  'TEMPP901_SEADATANET_QC.long_name',
#  'TEMPP901_SEADATANET_QC.Conventions',
#  'TEMPP901_SEADATANET_QC._FillValue',
#  'TEMPP901_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPP901_SEADATANET_QC.flag_meanings',
#  'TEMPP901_SEADATANET_QC.coordinates',
#  'TEMPTC01',
#  'TEMPTC01.long_name',
#  'TEMPTC01.sdn_parameter_urn',
#  'TEMPTC01.sdn_parameter_name',
#  'TEMPTC01.sdn_uom_urn',
#  'TEMPTC01.sdn_uom_name',
#  'TEMPTC01.units',
#  'TEMPTC01.coordinates',
#  'TEMPTC01.ancillary_variables',
#  'TEMPTC01._FillValue',
#  'TEMPTC01_SEADATANET_QC',
#  'TEMPTC01_SEADATANET_QC.long_name',
#  'TEMPTC01_SEADATANET_QC.Conventions',
#  'TEMPTC01_SEADATANET_QC._FillValue',
#  'TEMPTC01_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPTC01_SEADATANET_QC.flag_meanings',
#  'TEMPDTNX',
#  'TEMPDTNX.long_name',
#  'TEMPDTNX.sdn_parameter_urn',
#  'TEMPDTNX.sdn_parameter_name',
#  'TEMPDTNX.sdn_uom_urn',
#  'TEMPDTNX.sdn_uom_name',
#  'TEMPDTNX.units',
#  'TEMPDTNX.coordinates',
#  'TEMPDTNX.ancillary_variables',
#  'TEMPDTNX._FillValue',
#  'TEMPDTNX_SEADATANET_QC',
#  'TEMPDTNX_SEADATANET_QC.long_name',
#  'TEMPDTNX_SEADATANET_QC.Conventions',
#  'TEMPDTNX_SEADATANET_QC._FillValue',
#  'TEMPDTNX_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPDTNX_SEADATANET_QC.flag_meanings',
#  'TEMPDTNX_SEADATANET_QC.coordinates',
#  'TEMPCU01',
#  'TEMPCU01.long_name',
#  'TEMPCU01.sdn_parameter_urn',
#  'TEMPCU01.sdn_parameter_name',
#  'TEMPCU01.sdn_uom_urn',
#  'TEMPCU01.sdn_uom_name',
#  'TEMPCU01.units',
#  'TEMPCU01.coordinates',
#  'TEMPCU01.ancillary_variables',
#  'TEMPCU01._FillValue',
#  'TEMPCU01_SEADATANET_QC',
#  'TEMPCU01_SEADATANET_QC.long_name',
#  'TEMPCU01_SEADATANET_QC.Conventions',
#  'TEMPCU01_SEADATANET_QC._FillValue',
#  'TEMPCU01_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPCU01_SEADATANET_QC.flag_meanings',
#  'TEMPCU01_SEADATANET_QC.coordinates',
#  'TEMPMT01',
#  'TEMPMT01.long_name',
#  'TEMPMT01.sdn_parameter_urn',
#  'TEMPMT01.sdn_parameter_name',
#  'TEMPMT01.sdn_uom_urn',
#  'TEMPMT01.sdn_uom_name',
#  'TEMPMT01.units',
#  'TEMPMT01.sdn_instrument_urn',
#  'TEMPMT01.sdn_instrument_name',
#  'TEMPMT01.coordinates',
#  'TEMPMT01.ancillary_variables',
#  'TEMPMT01._FillValue',
#  'TEMPMT01_SEADATANET_QC',
#  'TEMPMT01_SEADATANET_QC.long_name',
#  'TEMPMT01_SEADATANET_QC.Conventions',
#  'TEMPMT01_SEADATANET_QC._FillValue',
#  'TEMPMT01_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPMT01_SEADATANET_QC.flag_meanings',
#  'TEMPMT01_SEADATANET_QC.coordinates',
#  'TEMPET01',
#  'TEMPET01.long_name',
#  'TEMPET01.sdn_parameter_urn',
#  'TEMPET01.sdn_parameter_name',
#  'TEMPET01.sdn_uom_urn',
#  'TEMPET01.sdn_uom_name',
#  'TEMPET01.units',
#  'TEMPET01.sdn_instrument_urn',
#  'TEMPET01.sdn_instrument_name',
#  'TEMPET01.coordinates',
#  'TEMPET01.ancillary_variables',
#  'TEMPET01._FillValue',
#  'TEMPET01_SEADATANET_QC',
#  'TEMPET01_SEADATANET_QC.long_name',
#  'TEMPET01_SEADATANET_QC.Conventions',
#  'TEMPET01_SEADATANET_QC._FillValue',
#  'TEMPET01_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPET01_SEADATANET_QC.flag_meanings',
#  'TEMPET01_SEADATANET_QC.coordinates',
#  'TEMPS601',
#  'TEMPS601.long_name',
#  'TEMPS601.sdn_parameter_urn',
#  'TEMPS601.sdn_parameter_name',
#  'TEMPS601.sdn_uom_urn',
#  'TEMPS601.sdn_uom_name',
#  'TEMPS601.units',
#  'TEMPS601.coordinates',
#  'TEMPS601.ancillary_variables',
#  'TEMPS601._FillValue',
#  'TEMPS601_SEADATANET_QC',
#  'TEMPS601_SEADATANET_QC.long_name',
#  'TEMPS601_SEADATANET_QC.Conventions',
#  'TEMPS601_SEADATANET_QC._FillValue',
#  'TEMPS601_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPS601_SEADATANET_QC.flag_meanings',
#  'TEMPS601_SEADATANET_QC.coordinates',
#  'TEMPPR01.sdn_instrument_urn',
#  'TEMPPR01.sdn_instrument_name',
#  'TEMPHG01',
#  'TEMPHG01.long_name',
#  'TEMPHG01.sdn_parameter_urn',
#  'TEMPHG01.sdn_parameter_name',
#  'TEMPHG01.sdn_uom_urn',
#  'TEMPHG01.sdn_uom_name',
#  'TEMPHG01.units',
#  'TEMPHG01.sdn_instrument_urn',
#  'TEMPHG01.sdn_instrument_name',
#  'TEMPHG01.coordinates',
#  'TEMPHG01.ancillary_variables',
#  'TEMPHG01._FillValue',
#  'TEMPHG01_SEADATANET_QC',
#  'TEMPHG01_SEADATANET_QC.long_name',
#  'TEMPHG01_SEADATANET_QC.Conventions',
#  'TEMPHG01_SEADATANET_QC._FillValue',
#  'TEMPHG01_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPHG01_SEADATANET_QC.flag_meanings',
#  'TEMPHG01_SEADATANET_QC.coordinates',
#  'TEMPHG02',
#  'TEMPHG02.long_name',
#  'TEMPHG02.sdn_parameter_urn',
#  'TEMPHG02.sdn_parameter_name',
#  'TEMPHG02.sdn_uom_urn',
#  'TEMPHG02.sdn_uom_name',
#  'TEMPHG02.units',
#  'TEMPHG02.coordinates',
#  'TEMPHG02.ancillary_variables',
#  'TEMPHG02._FillValue',
#  'TEMPHG02_SEADATANET_QC',
#  'TEMPHG02_SEADATANET_QC.long_name',
#  'TEMPHG02_SEADATANET_QC.Conventions',
#  'TEMPHG02_SEADATANET_QC._FillValue',
#  'TEMPHG02_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPHG02_SEADATANET_QC.flag_meanings',
#  'TEMPHG02_SEADATANET_QC.coordinates',
#  'TEMPHU01',
#  'TEMPHU01.long_name',
#  'TEMPHU01.sdn_parameter_urn',
#  'TEMPHU01.sdn_parameter_name',
#  'TEMPHU01.sdn_uom_urn',
#  'TEMPHU01.sdn_uom_name',
#  'TEMPHU01.units',
#  'TEMPHU01.sdn_instrument_urn',
#  'TEMPHU01.sdn_instrument_name',
#  'TEMPHU01.coordinates',
#  'TEMPHU01.ancillary_variables',
#  'TEMPHU01._FillValue',
#  'TEMPHU01_SEADATANET_QC',
#  'TEMPHU01_SEADATANET_QC.long_name',
#  'TEMPHU01_SEADATANET_QC.Conventions',
#  'TEMPHU01_SEADATANET_QC._FillValue',
#  'TEMPHU01_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPHU01_SEADATANET_QC.flag_meanings',
#  'TEMPHU01_SEADATANET_QC.coordinates',
#  'TEMPHU02',
#  'TEMPHU02.long_name',
#  'TEMPHU02.sdn_parameter_urn',
#  'TEMPHU02.sdn_parameter_name',
#  'TEMPHU02.sdn_uom_urn',
#  'TEMPHU02.sdn_uom_name',
#  'TEMPHU02.units',
#  'TEMPHU02.sdn_instrument_urn',
#  'TEMPHU02.sdn_instrument_name',
#  'TEMPHU02.coordinates',
#  'TEMPHU02.ancillary_variables',
#  'TEMPHU02._FillValue',
#  'TEMPHU02_SEADATANET_QC',
#  'TEMPHU02_SEADATANET_QC.long_name',
#  'TEMPHU02_SEADATANET_QC.Conventions',
#  'TEMPHU02_SEADATANET_QC._FillValue',
#  'TEMPHU02_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPHU02_SEADATANET_QC.flag_meanings',
#  'TEMPHU02_SEADATANET_QC.coordinates',
#  'TEMPS901.sdn_instrument_urn',
#  'TEMPS901.sdn_instrument_name',
#  'TEMPTC01.sdn_instrument_urn',
#  'TEMPTC01.sdn_instrument_name',
#  'TEMPTC01_SEADATANET_QC.coordinates',
#  'TEMPSZ01',
#  'TEMPSZ01.long_name',
#  'TEMPSZ01.sdn_parameter_urn',
#  'TEMPSZ01.sdn_parameter_name',
#  'TEMPSZ01.sdn_uom_urn',
#  'TEMPSZ01.sdn_uom_name',
#  'TEMPSZ01.units',
#  'TEMPSZ01.sdn_instrument_urn',
#  'TEMPSZ01.sdn_instrument_name',
#  'TEMPSZ01.coordinates',
#  'TEMPSZ01.ancillary_variables',
#  'TEMPSZ01._FillValue',
#  'TEMPSZ01_SEADATANET_QC',
#  'TEMPSZ01_SEADATANET_QC.long_name',
#  'TEMPSZ01_SEADATANET_QC.Conventions',
#  'TEMPSZ01_SEADATANET_QC._FillValue',
#  'TEMPSZ01_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPSZ01_SEADATANET_QC.flag_meanings',
#  'TEMPSZ01_SEADATANET_QC.coordinates',
#  'TEMPSZ01_2',
#  'TEMPSZ01_2.long_name',
#  'TEMPSZ01_2.sdn_parameter_urn',
#  'TEMPSZ01_2.sdn_parameter_name',
#  'TEMPSZ01_2.sdn_uom_urn',
#  'TEMPSZ01_2.sdn_uom_name',
#  'TEMPSZ01_2.units',
#  'TEMPSZ01_2.sdn_instrument_urn',
#  'TEMPSZ01_2.sdn_instrument_name',
#  'TEMPSZ01_2.coordinates',
#  'TEMPSZ01_2.ancillary_variables',
#  'TEMPSZ01_2._FillValue',
#  'TEMPSZ01_2_SEADATANET_QC',
#  'TEMPSZ01_2_SEADATANET_QC.long_name',
#  'TEMPSZ01_2_SEADATANET_QC.Conventions',
#  'TEMPSZ01_2_SEADATANET_QC._FillValue',
#  'TEMPSZ01_2_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPSZ01_2_SEADATANET_QC.flag_meanings',
#  'TEMPSZ01_2_SEADATANET_QC.coordinates',
#  'TEMPTC02',
#  'TEMPTC02.long_name',
#  'TEMPTC02.sdn_parameter_urn',
#  'TEMPTC02.sdn_parameter_name',
#  'TEMPTC02.sdn_uom_urn',
#  'TEMPTC02.sdn_uom_name',
#  'TEMPTC02.units',
#  'TEMPTC02.sdn_instrument_urn',
#  'TEMPTC02.sdn_instrument_name',
#  'TEMPTC02.coordinates',
#  'TEMPTC02.ancillary_variables',
#  'TEMPTC02._FillValue',
#  'TEMPTC02_SEADATANET_QC',
#  'TEMPTC02_SEADATANET_QC.long_name',
#  'TEMPTC02_SEADATANET_QC.Conventions',
#  'TEMPTC02_SEADATANET_QC._FillValue',
#  'TEMPTC02_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPTC02_SEADATANET_QC.flag_meanings',
#  'TEMPTC02_SEADATANET_QC.coordinates',
#  'TEMPCC01',
#  'TEMPCC01.long_name',
#  'TEMPCC01.sdn_parameter_urn',
#  'TEMPCC01.sdn_parameter_name',
#  'TEMPCC01.sdn_uom_urn',
#  'TEMPCC01.sdn_uom_name',
#  'TEMPCC01.units',
#  'TEMPCC01.coordinates',
#  'TEMPCC01.ancillary_variables',
#  'TEMPCC01._FillValue',
#  'TEMPCC01_SEADATANET_QC',
#  'TEMPCC01_SEADATANET_QC.long_name',
#  'TEMPCC01_SEADATANET_QC.Conventions',
#  'TEMPCC01_SEADATANET_QC._FillValue',
#  'TEMPCC01_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPCC01_SEADATANET_QC.flag_meanings',
#  'TEMPCC01_SEADATANET_QC.coordinates',
#  'TEMPBT01',
#  'TEMPBT01.long_name',
#  'TEMPBT01.sdn_parameter_urn',
#  'TEMPBT01.sdn_parameter_name',
#  'TEMPBT01.sdn_uom_urn',
#  'TEMPBT01.sdn_uom_name',
#  'TEMPBT01.units',
#  'TEMPBT01.coordinates',
#  'TEMPBT01.ancillary_variables',
#  'TEMPBT01._FillValue',
#  'TEMPBT01_SEADATANET_QC',
#  'TEMPBT01_SEADATANET_QC.long_name',
#  'TEMPBT01_SEADATANET_QC.Conventions',
#  'TEMPBT01_SEADATANET_QC._FillValue',
#  'TEMPBT01_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPBT01_SEADATANET_QC.flag_meanings',
#  'TEMPBT01_SEADATANET_QC.coordinates',
#  'TEMPPR01_2',
#  'TEMPPR01_2.long_name',
#  'TEMPPR01_2.sdn_parameter_urn',
#  'TEMPPR01_2.sdn_parameter_name',
#  'TEMPPR01_2.sdn_uom_urn',
#  'TEMPPR01_2.sdn_uom_name',
#  'TEMPPR01_2.units',
#  'TEMPPR01_2.coordinates',
#  'TEMPPR01_2.ancillary_variables',
#  'TEMPPR01_2._FillValue',
#  'TEMPPR01_2_SEADATANET_QC',
#  'TEMPPR01_2_SEADATANET_QC.long_name',
#  'TEMPPR01_2_SEADATANET_QC.Conventions',
#  'TEMPPR01_2_SEADATANET_QC._FillValue',
#  'TEMPPR01_2_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPPR01_2_SEADATANET_QC.flag_meanings',
#  'TEMPPR01_2_SEADATANET_QC.coordinates',
#  'TEMPCC02',
#  'TEMPCC02.long_name',
#  'TEMPCC02.sdn_parameter_urn',
#  'TEMPCC02.sdn_parameter_name',
#  'TEMPCC02.sdn_uom_urn',
#  'TEMPCC02.sdn_uom_name',
#  'TEMPCC02.units',
#  'TEMPCC02.coordinates',
#  'TEMPCC02.ancillary_variables',
#  'TEMPCC02._FillValue',
#  'TEMPCC02_SEADATANET_QC',
#  'TEMPCC02_SEADATANET_QC.long_name',
#  'TEMPCC02_SEADATANET_QC.Conventions',
#  'TEMPCC02_SEADATANET_QC._FillValue',
#  'TEMPCC02_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPCC02_SEADATANET_QC.flag_meanings',
#  'TEMPCC02_SEADATANET_QC.coordinates',
#  'TEMPHGNX',
#  'TEMPHGNX.long_name',
#  'TEMPHGNX.sdn_parameter_urn',
#  'TEMPHGNX.sdn_parameter_name',
#  'TEMPHGNX.sdn_uom_urn',
#  'TEMPHGNX.sdn_uom_name',
#  'TEMPHGNX.units',
#  'TEMPHGNX.coordinates',
#  'TEMPHGNX.ancillary_variables',
#  'TEMPHGNX._FillValue',
#  'TEMPHGNX_SEADATANET_QC',
#  'TEMPHGNX_SEADATANET_QC.long_name',
#  'TEMPHGNX_SEADATANET_QC.Conventions',
#  'TEMPHGNX_SEADATANET_QC._FillValue',
#  'TEMPHGNX_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPHGNX_SEADATANET_QC.flag_meanings',
#  'TEMPHGNX_SEADATANET_QC.coordinates',
#  'TEMPPR01.sdn_fall_rate_urn',
#  'TEMPPR01.sdn_fall_rate_name',
#  'TEMPS902',
#  'TEMPS902.long_name',
#  'TEMPS902.sdn_parameter_urn',
#  'TEMPS902.sdn_parameter_name',
#  'TEMPS902.sdn_uom_urn',
#  'TEMPS902.sdn_uom_name',
#  'TEMPS902.units',
#  'TEMPS902.coordinates',
#  'TEMPS902.ancillary_variables',
#  'TEMPS902._FillValue',
#  'TEMPS902_SEADATANET_QC',
#  'TEMPS902_SEADATANET_QC.long_name',
#  'TEMPS902_SEADATANET_QC.Conventions',
#  'TEMPS902_SEADATANET_QC._FillValue',
#  'TEMPS902_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPS902_SEADATANET_QC.flag_meanings',
#  'TEMPS902_SEADATANET_QC.coordinates',
#  'TEMPP901.sdn_instrument_urn',
#  'TEMPP901.sdn_instrument_name',
#  'TEMPSU01',
#  'TEMPSU01.long_name',
#  'TEMPSU01.sdn_parameter_urn',
#  'TEMPSU01.sdn_parameter_name',
#  'TEMPSU01.sdn_uom_urn',
#  'TEMPSU01.sdn_uom_name',
#  'TEMPSU01.units',
#  'TEMPSU01.coordinates',
#  'TEMPSU01.ancillary_variables',
#  'TEMPSU01._FillValue',
#  'TEMPSU01_SEADATANET_QC',
#  'TEMPSU01_SEADATANET_QC.long_name',
#  'TEMPSU01_SEADATANET_QC.Conventions',
#  'TEMPSU01_SEADATANET_QC._FillValue',
#  'TEMPSU01_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPSU01_SEADATANET_QC.flag_meanings',
#  'TEMPSU01_SEADATANET_QC.coordinates',
#  'BEDXTEMP',
#  'BEDXTEMP.long_name',
#  'BEDXTEMP.sdn_parameter_urn',
#  'BEDXTEMP.sdn_parameter_name',
#  'BEDXTEMP.sdn_uom_urn',
#  'BEDXTEMP.sdn_uom_name',
#  'BEDXTEMP.units',
#  'BEDXTEMP.coordinates',
#  'BEDXTEMP.ancillary_variables',
#  'BEDXTEMP._FillValue',
#  'BEDXTEMP_SEADATANET_QC',
#  'BEDXTEMP_SEADATANET_QC.long_name',
#  'BEDXTEMP_SEADATANET_QC.Conventions',
#  'BEDXTEMP_SEADATANET_QC._FillValue',
#  'BEDXTEMP_SEADATANET_QC.sdn_conventions_urn',
#  'BEDXTEMP_SEADATANET_QC.flag_meanings',
#  'BEDXTEMP_SEADATANET_QC.coordinates',
#  'TEMP.sdn_instrument_urn',
#  'TEMP.sdn_instrument_name',
#  'TEMP.standard_name',
#  'TEMP_DOXY',
#  'TEMP_DOXY.long_name',
#  'TEMP_DOXY.sdn_parameter_urn',
#  'TEMP_DOXY.sdn_parameter_name',
#  'TEMP_DOXY.sdn_uom_urn',
#  'TEMP_DOXY.sdn_uom_name',
#  'TEMP_DOXY.units',
#  'TEMP_DOXY.standard_name',
#  'TEMP_DOXY.ancillary_variables',
#  'TEMP_DOXY.coordinates',
#  'TEMP_DOXY._FillValue',
#  'TEMP_DOXY_SEADATANET_QC',
#  'TEMP_DOXY_SEADATANET_QC.long_name',
#  'TEMP_DOXY_SEADATANET_QC.Conventions',
#  'TEMP_DOXY_SEADATANET_QC._FillValue',
#  'TEMP_DOXY_SEADATANET_QC.sdn_conventions_urn',
#  'TEMP_DOXY_SEADATANET_QC.flag_meanings',
#  'TEMP_DOXY_SEADATANET_QC.coordinates',
#  'TEMP_CPU_CHLA',
#  'TEMP_CPU_CHLA.long_name',
#  'TEMP_CPU_CHLA.sdn_parameter_urn',
#  'TEMP_CPU_CHLA.sdn_parameter_name',
#  'TEMP_CPU_CHLA.sdn_uom_urn',
#  'TEMP_CPU_CHLA.sdn_uom_name',
#  'TEMP_CPU_CHLA.units',
#  'TEMP_CPU_CHLA.standard_name',
#  'TEMP_CPU_CHLA.ancillary_variables',
#  'TEMP_CPU_CHLA.coordinates',
#  'TEMP_CPU_CHLA._FillValue',
#  'TEMP_CPU_CHLA_SEADATANET_QC',
#  'TEMP_CPU_CHLA_SEADATANET_QC.long_name',
#  'TEMP_CPU_CHLA_SEADATANET_QC.Conventions',
#  'TEMP_CPU_CHLA_SEADATANET_QC._FillValue',
#  'TEMP_CPU_CHLA_SEADATANET_QC.sdn_conventions_urn',
#  'TEMP_CPU_CHLA_SEADATANET_QC.flag_meanings',
#  'TEMP_CPU_CHLA_SEADATANET_QC.coordinates',
#  'TEMP_CNDC',
#  'TEMP_CNDC.long_name',
#  'TEMP_CNDC.sdn_parameter_urn',
#  'TEMP_CNDC.sdn_parameter_name',
#  'TEMP_CNDC.sdn_uom_urn',
#  'TEMP_CNDC.sdn_uom_name',
#  'TEMP_CNDC.units',
#  'TEMP_CNDC.standard_name',
#  'TEMP_CNDC.ancillary_variables',
#  'TEMP_CNDC.coordinates',
#  'TEMP_CNDC._FillValue',
#  'TEMP_CNDC_SEADATANET_QC',
#  'TEMP_CNDC_SEADATANET_QC.long_name',
#  'TEMP_CNDC_SEADATANET_QC.Conventions',
#  'TEMP_CNDC_SEADATANET_QC._FillValue',
#  'TEMP_CNDC_SEADATANET_QC.sdn_conventions_urn',
#  'TEMP_CNDC_SEADATANET_QC.flag_meanings',
#  'TEMP_CNDC_SEADATANET_QC.coordinates',
#  'TR_TEMP',
#  'TR_TEMP.long_name',
#  'TR_TEMP.sdn_parameter_urn',
#  'TR_TEMP.sdn_parameter_name',
#  'TR_TEMP.sdn_uom_urn',
#  'TR_TEMP.sdn_uom_name',
#  'TR_TEMP.units',
#  'TR_TEMP.standard_name',
#  'TR_TEMP.coordinates',
#  'TR_TEMP.ancillary_variables',
#  'TR_TEMP._FillValue',
#  'TR_TEMP_SEADATANET_QC',
#  'TR_TEMP_SEADATANET_QC.long_name',
#  'TR_TEMP_SEADATANET_QC.Conventions',
#  'TR_TEMP_SEADATANET_QC._FillValue',
#  'TR_TEMP_SEADATANET_QC.sdn_conventions_urn',
#  'TR_TEMP_SEADATANET_QC.flag_meanings',
#  'TEMPCU01.sdn_instrument_urn',
#  'TEMPCU01.sdn_instrument_name',
#  'TEMPCU01.standard_name',
#  'TEMPCU02',
#  'TEMPCU02.long_name',
#  'TEMPCU02.sdn_parameter_urn',
#  'TEMPCU02.sdn_parameter_name',
#  'TEMPCU02.sdn_uom_urn',
#  'TEMPCU02.sdn_uom_name',
#  'TEMPCU02.units',
#  'TEMPCU02.coordinates',
#  'TEMPCU02.ancillary_variables',
#  'TEMPCU02._FillValue',
#  'TEMPCU02_SEADATANET_QC',
#  'TEMPCU02_SEADATANET_QC.long_name',
#  'TEMPCU02_SEADATANET_QC.Conventions',
#  'TEMPCU02_SEADATANET_QC._FillValue',
#  'TEMPCU02_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPCU02_SEADATANET_QC.flag_meanings',
#  'TEMPCU02_SEADATANET_QC.coordinates',
#  'TEMPPR02',
#  'TEMPPR02.long_name',
#  'TEMPPR02.sdn_parameter_urn',
#  'TEMPPR02.sdn_parameter_name',
#  'TEMPPR02.sdn_uom_urn',
#  'TEMPPR02.sdn_uom_name',
#  'TEMPPR02.units',
#  'TEMPPR02.coordinates',
#  'TEMPPR02.ancillary_variables',
#  'TEMPPR02._FillValue',
#  'TEMPPR02_SEADATANET_QC',
#  'TEMPPR02_SEADATANET_QC.long_name',
#  'TEMPPR02_SEADATANET_QC.Conventions',
#  'TEMPPR02_SEADATANET_QC._FillValue',
#  'TEMPPR02_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPPR02_SEADATANET_QC.flag_meanings',
#  'TEMPPR02_SEADATANET_QC.coordinates',
#  'TEMPSG01',
#  'TEMPSG01.long_name',
#  'TEMPSG01.sdn_parameter_urn',
#  'TEMPSG01.sdn_parameter_name',
#  'TEMPSG01.sdn_uom_urn',
#  'TEMPSG01.sdn_uom_name',
#  'TEMPSG01.units',
#  'TEMPSG01.coordinates',
#  'TEMPSG01.ancillary_variables',
#  'TEMPSG01._FillValue',
#  'TEMPSG01_SEADATANET_QC',
#  'TEMPSG01_SEADATANET_QC.long_name',
#  'TEMPSG01_SEADATANET_QC.Conventions',
#  'TEMPSG01_SEADATANET_QC._FillValue',
#  'TEMPSG01_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPSG01_SEADATANET_QC.flag_meanings',
#  'TEMPSG01_SEADATANET_QC.coordinates',
#  'TEMPPR03',
#  'TEMPPR03.long_name',
#  'TEMPPR03.sdn_parameter_urn',
#  'TEMPPR03.sdn_parameter_name',
#  'TEMPPR03.sdn_uom_urn',
#  'TEMPPR03.sdn_uom_name',
#  'TEMPPR03.units',
#  'TEMPPR03.coordinates',
#  'TEMPPR03.ancillary_variables',
#  'TEMPPR03._FillValue',
#  'TEMPPR03_SEADATANET_QC',
#  'TEMPPR03_SEADATANET_QC.long_name',
#  'TEMPPR03_SEADATANET_QC.Conventions',
#  'TEMPPR03_SEADATANET_QC._FillValue',
#  'TEMPPR03_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPPR03_SEADATANET_QC.flag_meanings',
#  'TEMPPR03_SEADATANET_QC.coordinates',
#  'TEMPSTEK',
#  'TEMPSTEK.long_name',
#  'TEMPSTEK.sdn_parameter_urn',
#  'TEMPSTEK.sdn_parameter_name',
#  'TEMPSTEK.sdn_uom_urn',
#  'TEMPSTEK.sdn_uom_name',
#  'TEMPSTEK.units',
#  'TEMPSTEK.coordinates',
#  'TEMPSTEK.ancillary_variables',
#  'TEMPSTEK._FillValue',
#  'TEMPSTEK_SEADATANET_QC',
#  'TEMPSTEK_SEADATANET_QC.long_name',
#  'TEMPSTEK_SEADATANET_QC.Conventions',
#  'TEMPSTEK_SEADATANET_QC._FillValue',
#  'TEMPSTEK_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPSTEK_SEADATANET_QC.flag_meanings',
#  'TEMPSTEK_SEADATANET_QC.coordinates',
#  'TEMPSDEK',
#  'TEMPSDEK.long_name',
#  'TEMPSDEK.sdn_parameter_urn',
#  'TEMPSDEK.sdn_parameter_name',
#  'TEMPSDEK.sdn_uom_urn',
#  'TEMPSDEK.sdn_uom_name',
#  'TEMPSDEK.units',
#  'TEMPSDEK.coordinates',
#  'TEMPSDEK.ancillary_variables',
#  'TEMPSDEK._FillValue',
#  'TEMPSDEK_SEADATANET_QC',
#  'TEMPSDEK_SEADATANET_QC.long_name',
#  'TEMPSDEK_SEADATANET_QC.Conventions',
#  'TEMPSDEK_SEADATANET_QC._FillValue',
#  'TEMPSDEK_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPSDEK_SEADATANET_QC.flag_meanings',
#  'TEMPSDEK_SEADATANET_QC.coordinates',
#  'TEMPMC01',
#  'TEMPMC01.long_name',
#  'TEMPMC01.sdn_parameter_urn',
#  'TEMPMC01.sdn_parameter_name',
#  'TEMPMC01.sdn_uom_urn',
#  'TEMPMC01.sdn_uom_name',
#  'TEMPMC01.units',
#  'TEMPMC01.coordinates',
#  'TEMPMC01.ancillary_variables',
#  'TEMPMC01._FillValue',
#  'TEMPMC01_SEADATANET_QC',
#  'TEMPMC01_SEADATANET_QC.long_name',
#  'TEMPMC01_SEADATANET_QC.Conventions',
#  'TEMPMC01_SEADATANET_QC._FillValue',
#  'TEMPMC01_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPMC01_SEADATANET_QC.flag_meanings',
#  'TEMPMC01_SEADATANET_QC.coordinates',
#  'TEMPMV01',
#  'TEMPMV01.long_name',
#  'TEMPMV01.sdn_parameter_urn',
#  'TEMPMV01.sdn_parameter_name',
#  'TEMPMV01.sdn_uom_urn',
#  'TEMPMV01.sdn_uom_name',
#  'TEMPMV01.units',
#  'TEMPMV01.coordinates',
#  'TEMPMV01.ancillary_variables',
#  'TEMPMV01._FillValue',
#  'TEMPMV01_SEADATANET_QC',
#  'TEMPMV01_SEADATANET_QC.long_name',
#  'TEMPMV01_SEADATANET_QC.Conventions',
#  'TEMPMV01_SEADATANET_QC._FillValue',
#  'TEMPMV01_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPMV01_SEADATANET_QC.flag_meanings',
#  'TEMPMV01_SEADATANET_QC.coordinates',
#  'TEMPEQMN',
#  'TEMPEQMN.long_name',
#  'TEMPEQMN.sdn_parameter_urn',
#  'TEMPEQMN.sdn_parameter_name',
#  'TEMPEQMN.sdn_uom_urn',
#  'TEMPEQMN.sdn_uom_name',
#  'TEMPEQMN.units',
#  'TEMPEQMN.coordinates',
#  'TEMPEQMN.ancillary_variables',
#  'TEMPEQMN._FillValue',
#  'TEMPEQMN_SEADATANET_QC',
#  'TEMPEQMN_SEADATANET_QC.long_name',
#  'TEMPEQMN_SEADATANET_QC.Conventions',
#  'TEMPEQMN_SEADATANET_QC._FillValue',
#  'TEMPEQMN_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPEQMN_SEADATANET_QC.flag_meanings',
#  'TEMPEQMN_SEADATANET_QC.coordinates',
#  'TEMPMEAS',
#  'TEMPMEAS.long_name',
#  'TEMPMEAS.sdn_parameter_urn',
#  'TEMPMEAS.sdn_parameter_name',
#  'TEMPMEAS.sdn_uom_urn',
#  'TEMPMEAS.sdn_uom_name',
#  'TEMPMEAS.units',
#  'TEMPMEAS.coordinates',
#  'TEMPMEAS.ancillary_variables',
#  'TEMPMEAS._FillValue',
#  'TEMPMEAS_SEADATANET_QC',
#  'TEMPMEAS_SEADATANET_QC.long_name',
#  'TEMPMEAS_SEADATANET_QC.Conventions',
#  'TEMPMEAS_SEADATANET_QC._FillValue',
#  'TEMPMEAS_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPMEAS_SEADATANET_QC.flag_meanings',
#  'TEMPPRES',
#  'TEMPPRES.long_name',
#  'TEMPPRES.sdn_parameter_urn',
#  'TEMPPRES.sdn_parameter_name',
#  'TEMPPRES.sdn_uom_urn',
#  'TEMPPRES.sdn_uom_name',
#  'TEMPPRES.units',
#  'TEMPPRES.coordinates',
#  'TEMPPRES.ancillary_variables',
#  'TEMPPRES._FillValue',
#  'TEMPPRES_SEADATANET_QC',
#  'TEMPPRES_SEADATANET_QC.long_name',
#  'TEMPPRES_SEADATANET_QC.Conventions',
#  'TEMPPRES_SEADATANET_QC._FillValue',
#  'TEMPPRES_SEADATANET_QC.sdn_conventions_urn',
#  'TEMPPRES_SEADATANET_QC.flag_meanings',
#  'TEMPPRES_SEADATANET_QC.coordinates']

# %% [markdown]
# #### Build a query

# %%
# Input parameters
regionname = f"Med"
BDI = "SEADATANET"
mindate = "2000-01-01T00:00:00"
maxdate = "2015-01-01T00:00:00"
minlon = -8
maxlon = 36.5
minlat = 30
maxlat = 46
AOI_POLY = [
    (-9.50, 30.00),
    (-9.50, 39.00),
    (-0.80, 43.20),
    (16.00, 46.50),
    (36.50, 38.00),
    (36.50, 30.00),
    (-9.50, 30.00)
]
mindepth = 0
maxdepth = 500
format = "pandas" # Options are: pandas, geopandas, netcdf, zarr, parquet, geoparquet, odv, arrow, csv
output_file_name = f"{BDI}_{regionname}"
df = None
gdf = None

#bigram="PF"

# Here we build the query step by step. First we select the columns we want to retrieve, then we add the filters and finally we specify the output format.
query_builder = client.query()

query_builder.add_select_column("TIME")  # Select the columns you want to retrieve
query_builder.add_select_column("TIME.units")
query_builder.add_select_column("TIME_SEADATANET_QC", alias="TIME_QC") 
query_builder.add_select_column("POSITION_SEADATANET_QC", alias="POSITION_QC") 
query_builder.add_select_column("SDN_LOCAL_CDI_ID", alias="LOCAL_CDI_ID")
query_builder.add_select_column("SDN_EDMO_CODE", alias="EDMO_CODE") 
query_builder.add_select_column("LONGITUDE") 
query_builder.add_select_column("LATITUDE") 

query_builder.add_select_coalesced([
                #"PSSTBK01",
                "PSSTTS01",
                #"PSSTZZ01",
                #"PTMATS01",
                #"PTMATS02",
                #"PTMATS03",
                #"PTMATS04",
                #"PTMATS05",
                #"PTMATS06",
                #"PTMATS07",
                #"PTMATS08",
                #"PTMATS09",
                #"PTMATS10",
                #"PTMATS11",
                #"PTMATS12",
                #"PTMATS13",
                #"PTMATS14",
                #"PTMATS15",
                #"PTMAZZ01",
                #"TEMPAPRT",
                "TEMPBT01",
                "TEMPCC01",
                "TEMPCC02",
                "TEMPCU01",
                "TEMPCU02",
                "TEMPDTNX",
                "TEMPET01",
                "TEMPHG01",
                "TEMPHG02",
                "TEMPHGNX",
                "TEMPHU01",
                #"TEMPMC01",
                "TEMPMT01",
                #"TEMPMV01",
                "TEMPP901",
                #"TEMPPH01",
                #"TEMPPP01",
                #"TEMPPP02",
                "TEMPPR01",
                #"TEMPPR02",
                #"TEMPPR03",
                #"TEMPR901",
                "TEMPRTNX",
                "TEMPS601",
                "TEMPS901",
                #"TEMPS902",
                #"TEMPSB35",
                #"TEMPSG01",
                "TEMPST01",
                "TEMPST02",
                "TEMPSU01",
                "TEMPSZ01",
                #"TEMPTB01",
                "TEMPTC01",
                "TEMPTC02",
                #"TEMPTC03",
                #"TEMPTC04",
                #"TEMPTC05",
                #"TEMPTC06",
                #"TEMPTC07",
                #"TEMPTC08",
                #"TEMPTC09",
                #"TEMPTC10",
                #"TEMPTC11",
                #"TEMPTC12",
                #"TEMPZZXX",
                "TMCLCCI1",
                "TMCLCCL1"], 
                alias="TEMPERATURE")

query_builder.add_select_coalesced(["PSSTTS01_SEADATANET_QC",
                "TEMPCC01_SEADATANET_QC",
                "TEMPCC02_SEADATANET_QC",
                "TEMPCU01_SEADATANET_QC",
                "TEMPCU02_SEADATANET_QC",
                "TEMPDTNX_SEADATANET_QC",
                "TEMPET01_SEADATANET_QC",
                "TEMPHG01_SEADATANET_QC",
                "TEMPHG02_SEADATANET_QC",
                "TEMPHGNX_SEADATANET_QC",
                "TEMPHU01_SEADATANET_QC",
                "TEMPMT01_SEADATANET_QC",
                "TEMPP901_SEADATANET_QC",
                "TEMPPR01_SEADATANET_QC",
                "TEMPRTNX_SEADATANET_QC",
                "TEMPS601_SEADATANET_QC",
                "TEMPS901_SEADATANET_QC",
                "TEMPST01_SEADATANET_QC",
                "TEMPST02_SEADATANET_QC",
                "TEMPSU01_SEADATANET_QC",
                "TEMPSZ01_SEADATANET_QC",
                "TEMPTC01_SEADATANET_QC",
                "TEMPTC02_SEADATANET_QC",
                "TMCLCCI1_SEADATANET_QC",
                "TMCLCCL1_SEADATANET_QC",],
                alias="TEMPERATURE_QC")
  
query_builder.add_select_coalesced([
                "ASLTZZ01",
                "ODSDM021",
                #"PSALBRBR",
                "PSALBSTX",
                "PSALCC01",
                "PSALCC02",
                "PSALCU01",
                "PSALCU02",
                #"PSALMC01",
                #"PSALMV01",
                "PSALPR01",
                "PSALPR02",
                #"PSALSG01",
                #"PSALSG02",
                "PSALST01",
                #"PSALST02",
                "PSALSU01",
                "PSALSZ01",
                "PSALTC01",
                "PSALTC02",
                #"PSALTC03",
                #"PSALTC04",
                #"PSALTC05",
                #"PSALTC06",
                "PSALZZXX",
                "PSCLCCI1",
                "PSCLCCL1",
                "PSLTZZ01",
                "SSALAGT1",
                "SSALBSTX",
                "SSALPR01",
                "SSALSG01",
                #"SSALSL01",
                "SSALST01",], 
                alias="SALINITY")
 
query_builder.add_select_coalesced(["ASLTZZ01_SEADATANET_QC",
                "ODSDM021_SEADATANET_QC",
                "PSALBSTX_SEADATANET_QC",
                "PSALCC01_SEADATANET_QC",
                "PSALCC02_SEADATANET_QC",
                "PSALCU01_SEADATANET_QC",
                "PSALCU02_SEADATANET_QC",
                "PSALPR01_SEADATANET_QC",
                "PSALPR02_SEADATANET_QC",
                "PSALST01_SEADATANET_QC",
                "PSALSU01_SEADATANET_QC",
                "PSALSZ01_SEADATANET_QC",
                "PSALTC01_SEADATANET_QC",
                "PSALTC02_SEADATANET_QC",
                "PSALZZXX_SEADATANET_QC",
                "PSCLCCI1_SEADATANET_QC",
                "PSCLCCL1_SEADATANET_QC",
                "PSLTZZ01_SEADATANET_QC",
                "SSALAGT1_SEADATANET_QC",
                "SSALBSTX_SEADATANET_QC",
                "SSALPR01_SEADATANET_QC",
                "SSALSG01_SEADATANET_QC",
                "SSALST01_SEADATANET_QC",], 
                alias="SALINITY_QC") 

query_builder.add_select(
    Functions.coalesce(
        [
            Functions.map_pressure_to_depth(
                Functions.coalesce(["PRES",
                                    "PRESPR01",
                                    "PRESPS02"], alias = 'PRESSURE'),
                "LATITUDE",
                alias="depth_from_pres",
            ),  "DEPTH",
                "ADEPZZ01",
                "DEPH",
                "DEPHPR01"
        ],
        alias="DEPTH",
    )
)

query_builder.add_select_coalesced(["PRES_SEADATANET_QC", 
                                    "PRESPR01_SEADATANET_QC", 
                                    "PRESPS02_SEADATANET_QC", 
                                    "DEPTH_SEADATANET_QC", 
                                    "ADEPZZ01_SEADATANET_QC", 
                                    "DEPH_SEADATANET_QC", 
                                    "DEPHPR01_SEADATANET_QC"], 
                                    alias="DEPTH_QC") 

## Add the filters
query_builder.add_range_filter("TIME", mindate, maxdate)  # You can adjust the date range as needed. The format is ISO 8601.
query_builder.add_range_filter("LONGITUDE", minlon, maxlon)  # Longitude range
query_builder.add_range_filter("LATITUDE", minlat, maxlat)  # Latitude range from -90 to 90 (you can adjust as needed)
query_builder.add_polygon_filter("LONGITUDE","LATITUDE", AOI_POLY)  # Define a polygon area (you can adjust the coordinates as needed)
query_builder.add_is_not_null_filter("TEMPERATURE")  # Ensure Temperature is not null
query_builder.add_equals_filter("TEMPERATURE_QC", 49)  # Only good quality temperature
query_builder.add_is_not_null_filter("SALINITY")  # Ensure Salinity is not
query_builder.add_equals_filter("SALINITY_QC", 49)  # Only good quality salinity
query_builder.add_is_not_null_filter("DEPTH")  # Ensure Depth is not null
query_builder.add_equals_filter("DEPTH_QC", 49)  # Only good quality
query_builder.add_range_filter("DEPTH", mindepth, maxdepth)  # Depth range from 0 to 500 meters (you can adjust as needed)

# Add the output format
if format == "pandas":
    df = query_builder.to_pandas_dataframe()
elif format == "geopandas":
    gdf = query_builder.to_geo_pandas_dataframe(longitude_column="LONGITUDE", latitude_column="LATITUDE")
elif format == "netcdf":
    query_builder.to_netcdf(output_file_name + ".nc")
elif format == "zarr":
    query_builder.to_zarr(output_file_name + ".zarr")
elif format == "parquet":
    query_builder.to_parquet(output_file_name + ".parquet")
elif format == "geoparquet":
    query_builder.to_geoparquet(output_file_name + ".parquet", longitude_column="LONGITUDE", latitude_column="LATITUDE")
elif format == "odv":
    odv_output = Odv(
        longitude_column=OdvDataColumn("LONGITUDE"),
        latitude_column=OdvDataColumn("LATITUDE"),
        time_column=OdvDataColumn("TIME"),
        depth_column=OdvDataColumn("DEPTH", qf_column="DEPTH_QC"),
        data_columns=[
            OdvDataColumn("TEMPERATURE", qf_column="TEMPERATURE_QC"),
            OdvDataColumn("SALINITY", qf_column="SALINITY_QC"),
        ],
        metadata_columns=[
            OdvDataColumn("LOCAL_CDI_ID"),
            OdvDataColumn("EDMO_CODE")
        ],
        qf_schema="SEADATANET",
        key_column="__entry_key"
    )
    query_builder.to_odv(odv_output, output_file_name + ".zip")
elif format == "arrow":
    query_builder.to_arrow(output_file_name + ".arrow")
elif format == "csv":
    query_builder.to_csv(output_file_name + ".csv")
# Out:
# Running query: {"from": "default", "select": [{"column": "TIME", "alias": null}, {"column": "TIME.units", "alias": null}, {"column": "TIME_SEADATANET_QC", "alias": "TIME_QC"}, {"column": "POSITION_SEADATANET_QC", "alias": "POSITION_QC"}, {"column": "SDN_LOCAL_CDI_ID", "alias": "LOCAL_CDI_ID"}, {"column": "SDN_EDMO_CODE", "alias": "EDMO_CODE"}, {"column": "LONGITUDE", "alias": null}, {"column": "LATITUDE", "alias": null}, {"function": "coalesce", "args": [{"column": "PSSTTS01", "alias": null}, {"column": "TEMPBT01", "alias": null}, {"column": "TEMPCC01", "alias": null}, {"column": "TEMPCC02", "alias": null}, {"column": "TEMPCU01", "alias": null}, {"column": "TEMPCU02", "alias": null}, {"column": "TEMPDTNX", "alias": null}, {"column": "TEMPET01", "alias": null}, {"column": "TEMPHG01", "alias": null}, {"column": "TEMPHG02", "alias": null}, {"column": "TEMPHGNX", "alias": null}, {"column": "TEMPHU01", "alias": null}, {"column": "TEMPMT01", "alias": null}, {"column": "TEMPP901", "alias": null}, {"column": "TEMPPR01", "alias": null}, {"column": "TEMPRTNX", "alias": null}, {"column": "TEMPS601", "alias": null}, {"column": "TEMPS901", "alias": null}, {"column": "TEMPST01", "alias": null}, {"column": "TEMPST02", "alias": null}, {"column": "TEMPSU01", "alias": null}, {"column": "TEMPSZ01", "alias": null}, {"column": "TEMPTC01", "alias": null}, {"column": "TEMPTC02", "alias": null}, {"column": "TMCLCCI1", "alias": null}, {"column": "TMCLCCL1", "alias": null}], "alias": "TEMPERATURE"}, {"function": "coalesce", "args": [{"column": "PSSTTS01_SEADATANET_QC", "alias": null}, {"column": "TEMPCC01_SEADATANET_QC", "alias": null}, {"column": "TEMPCC02_SEADATANET_QC", "alias": null}, {"column": "TEMPCU01_SEADATANET_QC", "alias": null}, {"column": "TEMPCU02_SEADATANET_QC", "alias": null}, {"column": "TEMPDTNX_SEADATANET_QC", "alias": null}, {"column": "TEMPET01_SEADATANET_QC", "alias": null}, {"column": "TEMPHG01_SEADATANET_QC", "alias": null}, {"column": "TEMPHG02_SEADATANET_QC", "alias": null}, {"column": "TEMPHGNX_SEADATANET_QC", "alias": null}, {"column": "TEMPHU01_SEADATANET_QC", "alias": null}, {"column": "TEMPMT01_SEADATANET_QC", "alias": null}, {"column": "TEMPP901_SEADATANET_QC", "alias": null}, {"column": "TEMPPR01_SEADATANET_QC", "alias": null}, {"column": "TEMPRTNX_SEADATANET_QC", "alias": null}, {"column": "TEMPS601_SEADATANET_QC", "alias": null}, {"column": "TEMPS901_SEADATANET_QC", "alias": null}, {"column": "TEMPST01_SEADATANET_QC", "alias": null}, {"column": "TEMPST02_SEADATANET_QC", "alias": null}, {"column": "TEMPSU01_SEADATANET_QC", "alias": null}, {"column": "TEMPSZ01_SEADATANET_QC", "alias": null}, {"column": "TEMPTC01_SEADATANET_QC", "alias": null}, {"column": "TEMPTC02_SEADATANET_QC", "alias": null}, {"column": "TMCLCCI1_SEADATANET_QC", "alias": null}, {"column": "TMCLCCL1_SEADATANET_QC", "alias": null}], "alias": "TEMPERATURE_QC"}, {"function": "coalesce", "args": [{"column": "ASLTZZ01", "alias": null}, {"column": "ODSDM021", "alias": null}, {"column": "PSALBSTX", "alias": null}, {"column": "PSALCC01", "alias": null}, {"column": "PSALCC02", "alias": null}, {"column": "PSALCU01", "alias": null}, {"column": "PSALCU02", "alias": null}, {"column": "PSALPR01", "alias": null}, {"column": "PSALPR02", "alias": null}, {"column": "PSALST01", "alias": null}, {"column": "PSALSU01", "alias": null}, {"column": "PSALSZ01", "alias": null}, {"column": "PSALTC01", "alias": null}, {"column": "PSALTC02", "alias": null}, {"column": "PSALZZXX", "alias": null}, {"column": "PSCLCCI1", "alias": null}, {"column": "PSCLCCL1", "alias": null}, {"column": "PSLTZZ01", "alias": null}, {"column": "SSALAGT1", "alias": null}, {"column": "SSALBSTX", "alias": null}, {"column": "SSALPR01", "alias": null}, {"column": "SSALSG01", "alias": null}, {"column": "SSALST01", "alias": null}], "alias": "SALINITY"}, {"function": "coalesce", "args": [{"column": "ASLTZZ01_SEADATANET_QC", "alias": null}, {"column": "ODSDM021_SEADATANET_QC", "alias": null}, {"column": "PSALBST ...

# %% [markdown]
# #### If `geopandas` or `pandas` is selected as output format, the data will be loaded into a dataframe for further analysis.

# %%
if df is not None:
    display(df)
# Out:
#                            TIME                        TIME.units  TIME_QC  \
# 0       2008-11-23 00:00:08.999  days since -4713-01-01T00:00:00Z       48
# 1       2008-11-23 00:01:14.999  days since -4713-01-01T00:00:00Z       48
# 2       2008-11-23 00:02:14.999  days since -4713-01-01T00:00:00Z       48
# 3       2008-11-23 00:03:20.999  days since -4713-01-01T00:00:00Z       48
# 4       2008-11-23 00:04:26.999  days since -4713-01-01T00:00:00Z       48
# ...                         ...                               ...      ...
# 6220161 2006-05-27 02:00:00.000  days since -4713-01-01T00:00:00Z       48
# 6220162 2006-05-27 02:00:00.000  days since -4713-01-01T00:00:00Z       48
# 6220163 2006-05-27 02:00:00.000  days since -4713-01-01T00:00:00Z       48
# 6220164 2006-05-27 02:00:00.000  days since -4713-01-01T00:00:00Z       48
# 6220165 2006-05-27 02:00:00.000  days since -4713-01-01T00:00:00Z       48
#
#          POSITION_QC              LOCAL_CDI_ID  EDMO_CODE  LONGITUDE  \
# 0                 48  29HE20081122_tsg_353_H71        353  -5.317380
# 1                 48  29HE20081122_tsg_353_H71        353  -5.314430
# 2                 48  29HE20081122_tsg_353_H71        353  -5.311620
# 3                 48  29HE20081122_tsg_353_H71        353  -5.308870
# 4                 48  29HE20081122_tsg_353_H71        353  -5.303480
# ...              ...                       ...        ...        ...
# 6220161           48                   ISKI_90        802  28.943333
# 6220162           48                   ISKI_90        802  28.943333
# 6220163           48                   ISKI_90        802  28.943333
# 6220164           48                   ISKI_90        802  28.943333
# 6220165           48                   ISKI_90        802  28.943333
#
#          LATITUDE  TEMPERATURE  TEMPERATURE_QC  SALINITY  SALINITY_QC  DEPTH  \
# 0          36.077      18.1021              49   36.5682           49    3.0
# 1          36.079      17.9278              49   36.6283           49    3.0
# 2          36.081      17.6594              49   36.6576           49    3.0
# 3          36.082      17.4275              49   36.6803           49    3.0
# 4          36.086      17.2447              49   36.6584           49    3.0
# ...           ...          ...             ...       ...          ...    ...
# 6220161    40.940      17.0981              49   21.6429           49   10.0
# 6220162    40.940      11.6155              49   24.9164           49   20.0
# 6220163    40.940      10.3660              49   29.7932           49   25.0
# 6220164    40.940      15.0987              49   38.5323           49   40.0
# 6220165    40.940      14.8976              49   38.6182           49   62.0
#
#          DEPTH_QC
# 0              49
# 1              49
# 2              49
# 3              49
# 4              49
# ...           ...
# 6220161        49
# 6220162        49
# 6220163        49
# 6220164        49
# 6220165        49
#
# [6220166 rows x 14 columns]

# %%
if gdf is not None:
    display(gdf)

# %% [markdown]
# #### Plotting can be done using the pandas dataframe in combination with matplotlib or other plotting libraries.
#
# You can also just use the pandas dataframe if you do not need the geometry column.

# %%
df['TEMPERATURE_QC'].unique()
# Out:
# array([49], dtype=int8)

# %%
df['SALINITY_QC'].unique()
# Out:
# array([49], dtype=int8)

# %%
df['DEPTH_QC'].unique()
# Out:
# array([49], dtype=int8)

# %%
df['TIME_QC'].unique()
# Out:
# array([48, 49], dtype=int8)

# %%
df['POSITION_QC'].unique()
# Out:
# array([48], dtype=int8)

# %%
from datetime import datetime
par = "TIME"
data=df['TIME']
m=min(data)
M=max(data)
print(m,M)
# Out:
# 2000-01-01 15:12:00 2014-12-31 23:44:00

# %%
from datetime import datetime
par = "TIME"
data=df['TIME']
m=min(data)
M=max(data)
print(m,M)
# Out:
# 2000-01-01 15:12:00 2014-12-31 23:44:00

# %%
import matplotlib.pyplot as plt
#par = "TIME"
data=df['TIME'].unique()
plt.hist(data, bins=70, color='skyblue', edgecolor='black')
#plt.ylim((0,310))
#plt.xlim(mm,MM)
plt.grid()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title(f"{BDI} {regionname} {mindate}-{maxdate} {mindepth}-{maxdepth}m")
plt.show()

# %%
parameter = "TEMPERATURE"
tdata=df[parameter]
plt.hist(tdata, bins=30, color='skyblue', edgecolor='black')
#plt.xlim((9,13))
plt.grid()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title(f"{BDI} {regionname} {parameter} {mindate}-{maxdate} {mindepth}-{maxdepth}m")
plt.show()
print(min(tdata),max(tdata))
# Out:
# -1.1 31.7509

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
fig = plt.figure(figsize=(15, 10))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent([minlon, maxlon, minlat, maxlat], crs=ccrs.PlateCarree())  # (west, east, south, north)

ax.coastlines(resolution="10m")
ax.gridlines(draw_labels=True)

sc = ax.scatter(df["LONGITUDE"], df["LATITUDE"], c=df[parameter], cmap="jet", s=15, transform=ccrs.PlateCarree())

ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.RIVERS)     
ax.add_feature(cfeature.BORDERS)   
ax.add_feature(cfeature.LAKES, alpha=0.1) 

cbar = plt.colorbar(sc, ax=ax, orientation="vertical", shrink=0.6, label=parameter)
cbar.set_label(f"{parameter} [C]")

plt.title(f"{regionname} {BDI} {parameter} {mindate}-{maxdate} {mindepth}-{maxdepth}m")

plt.show()

# %%
parameter = "SALINITY"
tdata=df[parameter]
plt.hist(tdata, bins=30, color='skyblue', edgecolor='black')
#plt.xlim((9,13))
plt.grid()
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title(f"{BDI} {regionname} {parameter} {mindate}-{maxdate} {mindepth}-{maxdepth}m")
plt.show()
print(min(tdata),max(tdata))
# Out:
# 0.11 47.4

# %%
fig = plt.figure(figsize=(15, 10))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent([minlon, maxlon, minlat, maxlat], crs=ccrs.PlateCarree())  # (west, east, south, north)

ax.coastlines(resolution="10m")
ax.gridlines(draw_labels=True)

sc = ax.scatter(df["LONGITUDE"], df["LATITUDE"], c=df[parameter], cmap="jet", s=15, transform=ccrs.PlateCarree())

ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.RIVERS)     
ax.add_feature(cfeature.BORDERS)   
ax.add_feature(cfeature.LAKES, alpha=0.1) 

cbar = plt.colorbar(sc, ax=ax, orientation="vertical", shrink=0.6, label=parameter)
cbar.set_label(f"{parameter}")

plt.title(f"{regionname} {BDI} {parameter}  {mindate}-{maxdate} {mindepth}-{maxdepth}m")

plt.show()
